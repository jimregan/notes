# %%
# !pip install ffmpeg-python

# %%
_BASE = "/Users/joregan/asr/slt/audio"

# %%
import json
from pathlib import Path

# %%
slt = {}
with open("/Users/joregan/asr/slt.json") as slt_file:
    for line in slt_file.readlines():
        linedata = json.loads(line)
        slt_id = Path(linedata["path"]).stem
        slt[slt_id] = linedata

# %%
from pathlib import Path
base = Path(_BASE)
for shn in base.glob("**/*.shn"):
    meta = {}
    meta["id"] = shn.stem
    probe = ffmpeg.probe(shn)
    if not "format" in probe and not "tags" in probe["format"]:
        continue
    tags = probe["format"]["tags"]
    if "Gender" in tags:
        meta["gender"] = tags["Gender"]
    if "UserID" in tags:
        meta["user_id"] = tags["UserID"]
    if "Dialect" in tags:
        meta["dialect"] = tags["Dialect"]
    if "recording_date" in tags:
        meta["recording_date"] = tags["recording_date"]
    if "recording_time" in tags:
        meta["recording_time"] = tags["recording_time"]
    if meta["id"] in slt:
        slt[meta["id"]].update(meta)
    else:
        slt[meta["id"]] = meta

# %%
slt
# Out:
# {'s01x0000.wv1': {'client_id': 's01-sess00',
#   'path': '/data/asr/asr/slt/wav/s01x0000.wv1.wav',
#   'sentence': 'De nybevattnade fälten lyste gröna i solskenet.'},
#  's01x0001.wv1': {'client_id': 's01-sess00',
#   'path': '/data/asr/asr/slt/wav/s01x0001.wv1.wav',
#   'sentence': 'Hela gruppen gav upp ett beundrande tjut inför den enastående prestationen.'},
#  's01x0002.wv1': {'client_id': 's01-sess00',
#   'path': '/data/asr/asr/slt/wav/s01x0002.wv1.wav',
#   'sentence': 'Kaffe- och tedrickandet var mycket utbrett i landet, särskilt under den regniga och kalla tiden på året.'},
#  's01x0003.wv1': {'client_id': 's01-sess00',
#   'path': '/data/asr/asr/slt/wav/s01x0003.wv1.wav',
#   'sentence': 'Vad är det på TV ikväll?'},
#  's01x0004.wv1': {'client_id': 's01-sess00',
#   'path': '/data/asr/asr/slt/wav/s01x0004.wv1.wav',
#   'sentence': 'Jag skulle helst vilja se något garanterat lättsamt.'},
#  's01x0005.wv1': {'client_id': 's01-sess00',
#   'path': '/data/asr/asr/slt/wav/s01x0005.wv1.wav',
#   'sentence': 'En rolig film eller ett underhållningsprogram med musik eller dans.'},
#  's01x0006.wv1': {'client_id': 's01-sess00',
#   'path': '/data/asr/asr/slt/wav/s01x0006.wv1.wav',
#   'sentence': 'Ibland känner man verkligen lust för något riktigt onyttigt.'},
#  's01x0007.wv1': {'client_id': 's01-sess00',
#   'path': '/data/asr/asr/slt/wav/s01x0007.wv1.wav',
#   'sentence': 'Det bästa han visste var en stor saftig stek med svampsås och stekt potatis.'},
#  's01x0008.wv1': {'client_id': 's01-sess00',
#   'path': '/data/asr/asr/slt/wav/s01x0008.wv1.wav',
#   'sentence': 'Till detta ett gott rött vin.'},
#  's01x0009.wv1': {'client_id': 's01-sess00',
#   'path': '/data/asr/asr/slt/wav/s01x0009.wv1.wav',
#   'sentence': 'Inte så exklusivt kanske eller speciellt märkvärdigt, men gott, mycket gott.'},
#  's01x000a.wv1': {'client_id': 's01-sess00',
#   'path': '/data/asr/asr/slt/wav/s01x000a.wv1.wav',
#   'sentence': 'Och så vill alla hans vänner helst äta havregrynsgröt och dricka örtextrakt.'},
#  's01x000b.wv1': {'client_id': 's01-sess00',
#   'path': '/data/asr/asr/slt/wav/s01x000b.wv1.wav',
#   'sentence': 'Då kan det bli svårt med middagskonversationen.'},
#  's01c1000.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1000.wv1.wav',
#   'sentence': 'De svenska bryggerierna är medvetna om att de kommer att få konkurrens.'},
#  's01c1001.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1001.wv1.wav',
#   'sentence': 'Striden har nu resulterat i att en omfattande utredning igångsatts.'},
#  's01c1002.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1002.wv1.wav',
#   'sentence': 'Han tillägnar sig med lätthet de olika ämnena med undantag av historia.'},
#  's01c1003.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1003.wv1.wav',
#   'sentence': 'Vad som automatiskt följer en tredjeklasskrog är faktiskt garanterad trivsel.'},
#  's01c1004.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1004.wv1.wav',
#   'sentence': 'Den gamle professorn lät sina känsliga fingertoppar glida över blindskriften.'},
#  's01c1005.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1005.wv1.wav',
#   'sentence': 'Äldre europeisk arkitektur uppvisar vid fingranskning vissa moderna drag.'},
#  's01c1006.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1006.wv1.wav',
#   'sentence': 'Efter nederlaget i spansk-amerikanska kriget avträdde Spanien Kuba till USA.'},
#  's01c1007.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1007.wv1.wav',
#   'sentence': 'Man kan spekulera över vilken emotionell motivering vissa konstverk har.'},
#  's01c1008.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1008.wv1.wav',
#   'sentence': 'Våra upplevelser av gammal musik är säkert bemängd med missuppfattningar.'},
#  's01c1009.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1009.wv1.wav',
#   'sentence': 'Tolv av de tjugo närvarande delegaterna var medlemmar i samma exklusiva klubb.'},
#  's01c100a.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100a.wv1.wav',
#   'sentence': 'De bar var sin fackla i handen och ledsagade honom uppför marmortrapporna.'},
#  's01c100b.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100b.wv1.wav',
#   'sentence': 'Därför hamnar dessa konstnärer så lätt i en absurdism utan djupare mening.'},
#  's01c100c.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100c.wv1.wav',
#   'sentence': 'Det dröjer ytterligare tre dygn innan forskarna får veta om försöket lyckats.'},
#  's01c100d.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100d.wv1.wav',
#   'sentence': 'Det är oftast mycket svårt att jämföra olycksstatistik mellan olika länder.'},
#  's01c100e.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100e.wv1.wav',
#   'sentence': 'Den viggstjärtade örnen lever huvudsakligen av kaniner, ekorrar och kadaver.'},
#  's01c100f.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100f.wv1.wav',
#   'sentence': 'Stilistiskt sett har paviljongens pelare inte något sammanhang med platsen.'},
#  's01c100g.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100g.wv1.wav',
#   'sentence': 'Scenen ger associationer till de teatrar där mirakelspel en gång uppfördes.'},
#  's01c100h.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100h.wv1.wav',
#   'sentence': 'Docenten var lärd på ett närmast orientaliskt sätt och förstod allt i grunden.'},
#  's01c100i.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100i.wv1.wav',
#   'sentence': 'Vissa av lagunerna är så stora att ordet sjö egentligen passar bättre.'},
#  's01c100j.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100j.wv1.wav',
#   'sentence': 'De närvarande forskarna hade ingen aning om vad resultatet kunde ha berott på.'},
#  's01c100k.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100k.wv1.wav',
#   'sentence': 'I fyra år åt den raggiga och förslagna vovven alltid upp de nybakta kakorna.'},
#  's01c100l.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100l.wv1.wav',
#   'sentence': 'Muminmamman tvivlade på den traditionella skildringen av världsalltet.'},
#  's01c100m.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100m.wv1.wav',
#   'sentence': 'Det kostade en överdriven summa att rusta upp gårdarna till beboeligt skick.'},
#  's01c100n.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100n.wv1.wav',
#   'sentence': 'Den ryske schackspelaren var självfallet favoriten när mästerskapet inleddes.'},
#  's01c100o.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100o.wv1.wav',
#   'sentence': 'Enligt den juridiska modell som tillämpas i väst skall ingen dömas ohörd.'},
#  's01c100p.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100p.wv1.wav',
#   'sentence': 'De slavar som arbetade på plantagerna och bomullsfälten var inte sysslolösa.'},
#  's01c100q.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100q.wv1.wav',
#   'sentence': 'Åhörarna sprang fram till scenen för att försöka få en bit av idolens skjorta.'},
#  's01c100r.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100r.wv1.wav',
#   'sentence': 'I den lilla stugan skulle man inte kunnat bo ens om den varit ny och billig.'},
#  's01c100s.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100s.wv1.wav',
#   'sentence': 'Samtliga kritiker uppskattade den lysande symboliska skildringen av anfallet.'},
#  's01c100t.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100t.wv1.wav',
#   'sentence': 'En kortfattad biografi över Bergman inleder den sjunde volymen i bokverket.'},
#  's01c100u.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100u.wv1.wav',
#   'sentence': 'Efter borgarna tillkom kyrkorna och först därefter utvecklades städerna.'},
#  's01c100v.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100v.wv1.wav',
#   'sentence': 'Firman letade efter en begåvad modist för vinterkollektionens skjortor.'},
#  's01c100w.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100w.wv1.wav',
#   'sentence': 'Korparna kretsade ovanför det mänskliga följet tills man gjorde stopp.'},
#  's01c100x.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100x.wv1.wav',
#   'sentence': 'Man borde ange hur många minuter potatisen kan kokas utan att bli torr.'},
#  's01c100y.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100y.wv1.wav',
#   'sentence': 'Musikanterna spelade säckpipa, flöjt, harpa eller olika stränginstrument.'},
#  's01c100z.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c100z.wv1.wav',
#   'sentence': 'Tårna blänker av jolmigt rosa nagellack genom de spindelvävstunna strumporna.'},
#  's01c1010.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1010.wv1.wav',
#   'sentence': 'En senmedeltida krönika innehåller allehanda uppgifter om slottets tillkomst.'},
#  's01c1011.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1011.wv1.wav',
#   'sentence': 'Josef gav i torsdags sin synpunkt på förslagets anpassning till framtida behov.'},
#  's01c1012.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1012.wv1.wav',
#   'sentence': 'Anteckningarna i hans katalog blev kortare, torftigare och mer skissartade.'},
#  's01c1013.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1013.wv1.wav',
#   'sentence': 'Den avhoppade spionen angav under förhören sina forna vänner och kontakter.'},
#  's01c1014.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1014.wv1.wav',
#   'sentence': 'Kungens ekipage övertogs av en stiftelse vars plikttrohet saknade motstycke.'},
#  's01c1015.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1015.wv1.wav',
#   'sentence': 'Trots att han var ohyggligt ohyfsad och sjaskig ägde chauffören en viss charm.'},
#  's01c1016.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1016.wv1.wav',
#   'sentence': 'De historier Sheherazade berättade har samlats i sagoboken Tusen och en natt.'},
#  's01c1017.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1017.wv1.wav',
#   'sentence': 'Som bofast på Bahamas var han van vid att se havet och avskydde Kalahariöknen.'},
#  's01c1018.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1018.wv1.wav',
#   'sentence': 'Som en bohemisk hippie stirrade han upp i himlen medan han fimpade cigaretten.'},
#  's01c1019.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c1019.wv1.wav',
#   'sentence': 'Byfogdens höga krav innebar att vartenda paket och gåvobrev skulle redovisas.'},
#  's01c101a.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c101a.wv1.wav',
#   'sentence': 'Byns enda bevarade vapensmedja hade brukats utan uppehåll i elvahundra år.'},
#  's01c101b.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c101b.wv1.wav',
#   'sentence': 'Partipolitiken har kommit att överskuggas av sakfrågor som narkotikahantering.'},
#  's01c101c.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c101c.wv1.wav',
#   'sentence': 'Artikelns fokus låg på exploderande stjärnor, de så kallade supernovorna.'},
#  's01c101d.wv1': {'client_id': 's01-sess01',
#   'path': '/data/asr/asr/slt/wav/s01c101d.wv1.wav',
#   'sentence': 'Kyrkoherden hade studerat filosofihistoria under sin tid på vilohemmet.'},
#  's01a2000.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a2000.wv1.wav',
#   'sentence': 'Tur på måndag från philadelphia till oakland kalifornien tidigt på morgonen.'},
#  's01a2001.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a2001.wv1.wav',
#   'sentence': 'Turer från atlanta till washington d c på torsdagmorgonen.'},
#  's01a2003.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a2003.wv1.wav',
#   'sentence': 'Ge mig en lista på turer mellan pittsburgh och baltimore.'},
#  's01a2004.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a2004.wv1.wav',
#   'sentence': 'Ge mig en lista på turer mellan pittsburgh och baltimore.'},
#  's01a2005.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a2005.wv1.wav',
#   'sentence': 'Ge mig informationen om d l ett femtiosex.'},
#  's01a2006.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a2006.wv1.wav',
#   'sentence': 'Ge mig enkelresorna från pittsburgh till boston.'},
#  's01a2007.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a2007.wv1.wav',
#   'sentence': 'Ge mer information om flight u a två noll ett.'},
#  's01a2008.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a2008.wv1.wav',
#   'sentence': 'Hej jag skulle vilja få en deltatur från atlanta till boston.'},
#  's01a2009.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a2009.wv1.wav',
#   'sentence': 'Går det att anlända till baltimore före tio före nio och trettio.'},
#  's01a200a.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a200a.wv1.wav',
#   'sentence': 'Hur kan jag ta mig från denver flygplats till centrum.'},
#  's01a200b.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a200b.wv1.wav',
#   'sentence': 'Hur kommer jag från pittsburgh flygplats till pittsburgh city.'},
#  's01a200c.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a200c.wv1.wav',
#   'sentence': 'Hur kommer jag till philadelphia centrum från flygplatsen.'},
#  's01a200d.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a200d.wv1.wav',
#   'sentence': 'Hur lång är turen mellan dallas och san francisco.'},
#  's01a200e.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a200e.wv1.wav',
#   'sentence': 'Hur långt är uppehållet på delta flight ett åttio.'},
#  's01a200f.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a200f.wv1.wav',
#   'sentence': 'Hur många flygbolag har turer med service klass y n.'},
#  's01a200g.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a200g.wv1.wav',
#   'sentence': 'Hur många business class-turer står varje flygbolag för.'},
#  's01a200h.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a200h.wv1.wav',
#   'sentence': 'Hur många continentalturer finns det från denver under samma dag.'},
#  's01a200i.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a200i.wv1.wav',
#   'sentence': 'Hur många delta avgångar finns det från denver på samma dag.'},
#  's01a200j.wv1': {'client_id': 's01-sess02',
#   'path': '/data/asr/asr/slt/wav/s01a200j.wv1.wav',
#   'sentence': 'Hur många förstaklassturer står american airlines för.'},
#  's01n3000.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n3000.wv1.wav',
#   'sentence': 'Så atmosfären i klostret blev en annan då, sa jag.'},
#  's01n3001.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n3001.wv1.wav',
#   'sentence': 'Vi vitkalkade alla väggarna, som varit grå.'},
#  's01n3002.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n3002.wv1.wav',
#   'sentence': 'Det var kulingstyrka och byig vind.'},
#  's01n3003.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n3003.wv1.wav',
#   'sentence': 'Och dagen därpå blåste det ännu mer.'},
#  's01n3004.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n3004.wv1.wav',
#   'sentence': 'Brukar det blåsa så här mycket, frågade jag.'},
#  's01n3005.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n3005.wv1.wav',
#   'sentence': 'Islänningen tog fram det bästa inom oss, sa han.'},
#  's01n3006.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n3006.wv1.wav',
#   'sentence': 'Islänningen var inte mycket för öl, avbröt munken.'},
#  's01n3007.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n3007.wv1.wav',
#   'sentence': 'På Island fick man inte dricka öl, det var förbjudet.'},
#  's01n3008.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n3008.wv1.wav',
#   'sentence': 'Aj, aj, aj, förmanade han skämtsamt.'},
#  's01n3009.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n3009.wv1.wav',
#   'sentence': 'Syntetiskt material påverkar auran på ett ofördelaktigt sätt.'},
#  's01n300a.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n300a.wv1.wav',
#   'sentence': 'Och han fortsatte sin väg med ett inåtvänt leende.'},
#  's01n300b.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n300b.wv1.wav',
#   'sentence': 'Det är uppkallat efter Aura ån som flyter genom Öbo.'},
#  's01n300c.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n300c.wv1.wav',
#   'sentence': 'Här finns ju bara danskt öl.'},
#  's01n300d.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n300d.wv1.wav',
#   'sentence': 'Ja, på tal om det följer du med i morgon.'},
#  's01n300e.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n300e.wv1.wav',
#   'sentence': 'Vi stämde möte vid stranden kvart i elva.'},
#  's01n300f.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n300f.wv1.wav',
#   'sentence': 'Sedan berättade artikeln om hur denne sjöman förvandlades till guru.'},
#  's01n300g.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n300g.wv1.wav',
#   'sentence': 'Var vänlig acceptera denna sedel som en första gåva.'},
#  's01n300h.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n300h.wv1.wav',
#   'sentence': 'Och det var gott med en pilsner.'},
#  's01n300j.wv1': {'client_id': 's01-sess03',
#   'path': '/data/asr/asr/slt/wav/s01n300j.wv1.wav',
#   'sentence': 'Jo, Svendsen lärde sig snabbt hur en guru skall uppträda.'},
#  's02x0000.wv1': {'client_id': 's02-sess00',
#   'path': '/data/asr/asr/slt/wav/s02x0000.wv1.wav',
#   'sentence': 'De nybevattnade fälten lyste gröna i solskenet.'},
#  's02x0001.wv1': {'client_id': 's02-sess00',
#   'path': '/data/asr/asr/slt/wav/s02x0001.wv1.wav',
#   'sentence': 'Hela gruppen gav upp ett beundrande tjut inför den enastående prestationen.'},
#  's02x0002.wv1': {'client_id': 's02-sess00',
#   'path': '/data/asr/asr/slt/wav/s02x0002.wv1.wav',
#   'sentence': 'Kaffe- och tedrickandet var mycket utbrett i landet, särskilt under den regniga och kalla tiden på året.'},
#  's02x0003.wv1': {'client_id': 's02-sess00',
#   'path': '/data/asr/asr/slt/wav/s02x0003.wv1.wav',
#   'sentence': 'Vad är det på TV ikväll?'},
#  's02x0004.wv1': {'client_id': 's02-sess00',
#   'path': '/data/asr/asr/slt/wav/s02x0004.wv1.wav',
#   'sentence': 'Jag skulle helst vilja se något garanterat lättsamt.'},
#  's02x0005.wv1': {'client_id': 's02-sess00',
#   'path': '/data/asr/asr/slt/wav/s02x0005.wv1.wav',
#   'sentence': 'En rolig film eller ett underhållningsprogram med musik eller dans.'},
#  's02x0006.wv1': {'client_id': 's02-sess00',
#   'path': '/data/asr/asr/slt/wav/s02x0006.wv1.wav',
#   'sentence': 'Ibland känner man verkligen lust för något riktigt onyttigt.'},
#  's02x0007.wv1': {'client_id': 's02-sess00',
#   'path': '/data/asr/asr/slt/wav/s02x0007.wv1.wav',
#   'sentence': 'Det bästa han visste var en stor saftig stek med svampsås och stekt potatis.'},
#  's02x0008.wv1': {'client_id': 's02-sess00',
#   'path': '/data/asr/asr/slt/wav/s02x0008.wv1.wav',
#   'sentence': 'Till detta ett gott rött vin.'},
#  's02x0009.wv1': {'client_id': 's02-sess00',
#   'path': '/data/asr/asr/slt/wav/s02x0009.wv1.wav',
#   'sentence': 'Inte så exklusivt kanske eller speciellt märkvärdigt, men gott, mycket gott.'},
#  's02x000a.wv1': {'client_id': 's02-sess00',
#   'path': '/data/asr/asr/slt/wav/s02x000a.wv1.wav',
#   'sentence': 'Och så vill alla hans vänner helst äta havregrynsgröt och dricka örtextrakt.'},
#  's02x000b.wv1': {'client_id': 's02-sess00',
#   'path': '/data/asr/asr/slt/wav/s02x000b.wv1.wav',
#   'sentence': 'Då kan det bli svårt med middagskonversationen.'},
#  's02c1000.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1000.wv1.wav',
#   'sentence': 'De svenska bryggerierna är medvetna om att de kommer att få konkurrens.'},
#  's02c1001.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1001.wv1.wav',
#   'sentence': 'Striden har nu resulterat i att en omfattande utredning igångsatts.'},
#  's02c1002.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1002.wv1.wav',
#   'sentence': 'Han tillägnar sig med lätthet de olika ämnena med undantag av historia.'},
#  's02c1003.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1003.wv1.wav',
#   'sentence': 'Vad som automatiskt följer en tredjeklasskrog är faktiskt garanterad trivsel.'},
#  's02c1004.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1004.wv1.wav',
#   'sentence': 'Den gamle professorn lät sina känsliga fingertoppar glida över blindskriften.'},
#  's02c1005.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1005.wv1.wav',
#   'sentence': 'Äldre europeisk arkitektur uppvisar vid fingranskning vissa moderna drag.'},
#  's02c1006.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1006.wv1.wav',
#   'sentence': 'Efter nederlaget i spansk-amerikanska kriget avträdde Spanien Kuba till USA.'},
#  's02c1007.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1007.wv1.wav',
#   'sentence': 'Man kan spekulera över vilken emotionell motivering vissa konstverk har.'},
#  's02c1008.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1008.wv1.wav',
#   'sentence': 'Våra upplevelser av gammal musik är säkert bemängda med missuppfattningar.'},
#  's02c1009.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1009.wv1.wav',
#   'sentence': 'Tolv av de tjugo närvarande delegaterna var medlemmar i samma exklusiva klubb.'},
#  's02c100a.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100a.wv1.wav',
#   'sentence': 'De bar var sin fackla i handen och ledsagade honom uppför marmortrapporna.'},
#  's02c100b.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100b.wv1.wav',
#   'sentence': 'Därför hamnar dessa konstnärer så lätt i en absurdism utan djupare mening.'},
#  's02c100c.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100c.wv1.wav',
#   'sentence': 'Det dröjer ytterligare tre dygn innan forskarna får veta om försöket lyckats.'},
#  's02c100d.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100d.wv1.wav',
#   'sentence': 'Det är oftast mycket svårt att jämföra olycksstatistik mellan olika länder.'},
#  's02c100e.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100e.wv1.wav',
#   'sentence': 'Den viggstjärtade örnen lever huvudsakligen av kaniner, ekorrar och kadaver.'},
#  's02c100f.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100f.wv1.wav',
#   'sentence': 'Stilistiskt sett har paviljongens pelare inte något sammanhang med platsen.'},
#  's02c100g.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100g.wv1.wav',
#   'sentence': 'Scenen ger associationer till de teatrar där mirakelspel en gång uppfördes.'},
#  's02c100h.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100h.wv1.wav',
#   'sentence': 'Docenten var lärd på ett närmast orientaliskt sätt och förstod allt i grunden.'},
#  's02c100i.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100i.wv1.wav',
#   'sentence': 'Vissa av lagunerna är så stora att ordet sjö egentligen passar bättre.'},
#  's02c100j.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100j.wv1.wav',
#   'sentence': 'De närvarande forskarna hade ingen aning om vad resultatet kunde ha berott på.'},
#  's02c100k.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100k.wv1.wav',
#   'sentence': 'I fyra år åt den raggiga och förslagna vovven alltid upp de nybakta kakorna.'},
#  's02c100l.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100l.wv1.wav',
#   'sentence': 'Muminmamman tvivlade på den traditionella skildringen av världsalltet.'},
#  's02c100m.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100m.wv1.wav',
#   'sentence': 'Det kostade en överdriven summa att rusta upp gårdarna till beboeligt skick.'},
#  's02c100n.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100n.wv1.wav',
#   'sentence': 'Den ryske schackspelaren var självfallet favoriten när mästerskapet inleddes.'},
#  's02c100o.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100o.wv1.wav',
#   'sentence': 'Enligt den juridiska modell som tillämpas i väst skall ingen dömas ohörd.'},
#  's02c100p.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100p.wv1.wav',
#   'sentence': 'De slavar som arbetade på plantagerna och bomullsfälten var inte sysslolösa.'},
#  's02c100q.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100q.wv1.wav',
#   'sentence': 'Åhörarna sprang fram till scenen för att försöka få en bit av idolens skjorta.'},
#  's02c100r.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100r.wv1.wav',
#   'sentence': 'I den lilla stugan skulle man inte kunnat bo ens om den varit ny och billig.'},
#  's02c100s.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100s.wv1.wav',
#   'sentence': 'Samtliga kritiker uppskattade den lysande symboliska skildringen av anfallet.'},
#  's02c100t.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100t.wv1.wav',
#   'sentence': 'En kortfattad biografi över Bergman inleder den sjunde volymen i bokverket.'},
#  's02c100u.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100u.wv1.wav',
#   'sentence': 'Efter borgarna tillkom kyrkorna och först därefter utvecklades städerna.'},
#  's02c100v.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100v.wv1.wav',
#   'sentence': 'Firman letade efter en begåvad modist för vinterkollektionens skjortor.'},
#  's02c100w.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100w.wv1.wav',
#   'sentence': 'Korparna kretsade ovanför det mänskliga följet tills man gjorde stopp.'},
#  's02c100x.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100x.wv1.wav',
#   'sentence': 'Man borde ange hur många minuter potatisen kan kokas utan att bli torr.'},
#  's02c100y.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100y.wv1.wav',
#   'sentence': 'Musikanterna spelade säckpipa, flöjt, harpa eller olika stränginstrument.'},
#  's02c100z.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c100z.wv1.wav',
#   'sentence': 'Tårna blänker av jolmigt rosa nagellack genom de spindelvävstunna strumporna.'},
#  's02c1010.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1010.wv1.wav',
#   'sentence': 'En senmedeltida krönika innehåller allehanda uppgifter om slottets tillkomst.'},
#  's02c1011.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1011.wv1.wav',
#   'sentence': 'Josef gav i torsdags sin synpunkt på förslagets anpassning till framtida behov.'},
#  's02c1012.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1012.wv1.wav',
#   'sentence': 'Anteckningarna i hans katalog blev kortare, torftigare och mer skissartade.'},
#  's02c1013.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1013.wv1.wav',
#   'sentence': 'Den avhoppade spionen angav under förhören sina forna vänner och kontakter.'},
#  's02c1014.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1014.wv1.wav',
#   'sentence': 'Kungens ekipage övertogs av en stiftelse vars plikttrohet saknade motstycke.'},
#  's02c1015.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1015.wv1.wav',
#   'sentence': 'Trots att han var ohyggligt ohyfsad och sjaskig ägde chauffören en viss charm.'},
#  's02c1016.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1016.wv1.wav',
#   'sentence': 'De *historier* Sheherazade berättade har samlats i sagoboken Tusen och en natt.'},
#  's02c1017.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1017.wv1.wav',
#   'sentence': 'Som bofast på Bahamas var han van vid att se havet och avskydde Kalahariöknen.'},
#  's02c1018.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1018.wv1.wav',
#   'sentence': 'Som en bohemisk hippie stirrade han upp i himlen medan han fimpade cigaretten.'},
#  's02c1019.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c1019.wv1.wav',
#   'sentence': 'Byfogdens höga krav innebar att vartenda paket och gåvobrev skulle redovisas.'},
#  's02c101a.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c101a.wv1.wav',
#   'sentence': 'Byns enda bevarade vapensmedja hade brukats utan uppehåll i elvahundra år.'},
#  's02c101b.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c101b.wv1.wav',
#   'sentence': 'Partipolitiken har kommit att överskuggas av sakfrågor som narkotikahantering.'},
#  's02c101c.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c101c.wv1.wav',
#   'sentence': 'Artikelns fokus låg på exploderande stjärnor, de så kallade supernovorna.'},
#  's02c101d.wv1': {'client_id': 's02-sess01',
#   'path': '/data/asr/asr/slt/wav/s02c101d.wv1.wav',
#   'sentence': 'Kyrkoherden hade studerat filosofihistoria under sin tid på vilohemmet.'},
#  's02a2000.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a2000.wv1.wav',
#   'sentence': 'Hur många turer har continental in till och ut från atlanta.'},
#  's02a2001.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a2001.wv1.wav',
#   'sentence': 'Hur många människor får plats på ett sju två s flygplan.'},
#  's02a2002.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a2002.wv1.wav',
#   'sentence': 'Hur många billiga ekonomiklassturer har delta airlines.'},
#  's02a2003.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a2003.wv1.wav',
#   'sentence': 'Hur många unitedavgångar finns det från san francisco tack.'},
#  's02a2004.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a2004.wv1.wav',
#   'sentence': 'Vad kostar sju-turen med eastern airlines.'},
#  's02a2005.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a2005.wv1.wav',
#   'sentence': 'Hur mycket kostar en biljett på u s trettiotre.'},
#  's02a2006.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a2006.wv1.wav',
#   'sentence': 'Vad kostar den billigaste turen från denver till pittsburgh.'},
#  's02a2007.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a2007.wv1.wav',
#   'sentence': 'Hur mycket kostar marktransport mellan atlanta och centrum.'},
#  's02a2008.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a2008.wv1.wav',
#   'sentence': 'Hur mycket skulle det kosta på flight u s trettio.'},
#  's02a2009.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a2009.wv1.wav',
#   'sentence': 'Jag tycker inte om att flyga med delta vilka andra flygbolag finns .'},
#  's02a200a.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a200a.wv1.wav',
#   'sentence': 'Jag behöver en tur från baltimore till dallas i morgon bitti.'},
#  's02a200b.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a200b.wv1.wav',
#   'sentence': 'Jag behöver en tur från denver till philadelphia på lördag.'},
#  's02a200c.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a200c.wv1.wav',
#   'sentence': 'Jag behöver en tur från logan till atlanta i eftermiddag.'},
#  's02a200d.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a200d.wv1.wav',
#   'sentence': 'Jag behöver en tur från philadelphia till denver på söndag.'},
#  's02a200e.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a200e.wv1.wav',
#   'sentence': 'Jag behöver information om en tur från denver till atlanta.'},
#  's02a200f.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a200f.wv1.wav',
#   'sentence': 'Jag behöver information om en tur från boston till denver.'},
#  's02a200g.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a200g.wv1.wav',
#   'sentence': 'Jag behöver en lista över turer från atlanta.'},
#  's02a200h.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a200h.wv1.wav',
#   'sentence': 'Jag behöver återlämna en tur från denver till atlanta.'},
#  's02a200i.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a200i.wv1.wav',
#   'sentence': 'Jag vill ha en enkelbiljett från dallas till baltimore.'},
#  's02a200j.wv1': {'client_id': 's02-sess02',
#   'path': '/data/asr/asr/slt/wav/s02a200j.wv1.wav',
#   'sentence': 'Jag vill ha en tidig morgontur från boston till philadelphia.'},
#  's02n3000.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n3000.wv1.wav',
#   'sentence': 'Irriterade gester och vassa repliker hade ersatt bugningar och leenden.'},
#  's02n3001.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n3001.wv1.wav',
#   'sentence': 'Det är som hemma i Bretagne.'},
#  's02n3002.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n3002.wv1.wav',
#   'sentence': 'Under en sten i gräset bodde en padda.'},
#  's02n3003.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n3003.wv1.wav',
#   'sentence': 'Den tjocka halsen rörde sig pumpande ut och in.'},
#  's02n3004.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n3004.wv1.wav',
#   'sentence': 'Vi var något av enstöringar både han och jag.'},
#  's02n3005.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n3005.wv1.wav',
#   'sentence': 'En fiskekutter som red elegant på vågorna.'},
#  's02n3006.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n3006.wv1.wav',
#   'sentence': 'Och se på sälarna, så roligt de har.'},
#  's02n3007.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n3007.wv1.wav',
#   'sentence': 'Äntligen litet liv här, sa han förtroligt.'},
#  's02n3008.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n3008.wv1.wav',
#   'sentence': 'Vi gjorde sällskap tillbaka till klostret.'},
#  's02n3009.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n3009.wv1.wav',
#   'sentence': 'Ja, jag tycker om att ta en öl, sa jag.'},
#  's02n300a.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n300a.wv1.wav',
#   'sentence': 'Jag brukar passa på då, på Carlsens Krog.'},
#  's02n300b.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n300b.wv1.wav',
#   'sentence': 'Det danska ölet är ju så gott.'},
#  's02n300c.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n300c.wv1.wav',
#   'sentence': 'Då jag kom upp i klitterna stod Kvist där.'},
#  's02n300d.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n300d.wv1.wav',
#   'sentence': 'Det syntes på honom att han var missmodig.'},
#  's02n300e.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n300e.wv1.wav',
#   'sentence': 'Vad var detta, ville han provocera mig.'},
#  's02n300f.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n300f.wv1.wav',
#   'sentence': 'Man behöver i alla fall ingen regnrock, sa jag.'},
#  's02n300g.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n300g.wv1.wav',
#   'sentence': 'Denne man var ingen medlem av det hemliga sällskapet.'},
#  's02n300h.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n300h.wv1.wav',
#   'sentence': 'Min egen brist på omdöme hade avslöjats.'},
#  's02n300i.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n300i.wv1.wav',
#   'sentence': 'Att få vara i föräldrahemmet, att få klippa gräsmattan.'},
#  's02n300j.wv1': {'client_id': 's02-sess03',
#   'path': '/data/asr/asr/slt/wav/s02n300j.wv1.wav',
#   'sentence': 'Några aktiviteter tänkte jag inte ta del i.'},
#  's03x0000.wv1': {'client_id': 's03-sess00',
#   'path': '/data/asr/asr/slt/wav/s03x0000.wv1.wav',
#   'sentence': 'De nybevattnade fälten lyste gröna i solskenet.'},
#  's03x0001.wv1': {'client_id': 's03-sess00',
#   'path': '/data/asr/asr/slt/wav/s03x0001.wv1.wav',
#   'sentence': 'Hela gruppen gav upp ett beundrande tjut inför den enastående prestationen.'},
#  's03x0003.wv1': {'client_id': 's03-sess00',
#   'path': '/data/asr/asr/slt/wav/s03x0003.wv1.wav',
#   'sentence': 'Vad är det på TV ikväll?'},
#  's03x0004.wv1': {'client_id': 's03-sess00',
#   'path': '/data/asr/asr/slt/wav/s03x0004.wv1.wav',
#   'sentence': 'Jag skulle helst vilja se något garanterat lättsamt.'},
#  's03x0005.wv1': {'client_id': 's03-sess00',
#   'path': '/data/asr/asr/slt/wav/s03x0005.wv1.wav',
#   'sentence': 'En rolig film eller ett underhållningsprogram med musik eller dans.'},
#  's03x0006.wv1': {'client_id': 's03-sess00',
#   'path': '/data/asr/asr/slt/wav/s03x0006.wv1.wav',
#   'sentence': 'Ibland känner man verkligen lust för något riktigt onyttigt.'},
#  's03x0007.wv1': {'client_id': 's03-sess00',
#   'path': '/data/asr/asr/slt/wav/s03x0007.wv1.wav',
#   'sentence': 'Det bästa han visste var en stor saftig stek med svampsås och stekt potatis.'},
#  's03x0008.wv1': {'client_id': 's03-sess00',
#   'path': '/data/asr/asr/slt/wav/s03x0008.wv1.wav',
#   'sentence': 'Till detta ett gott rött vin.'},
#  's03x0009.wv1': {'client_id': 's03-sess00',
#   'path': '/data/asr/asr/slt/wav/s03x0009.wv1.wav',
#   'sentence': 'Inte så exklusivt kanske eller speciellt märkvärdigt, men gott, mycket gott.'},
#  's03x000b.wv1': {'client_id': 's03-sess00',
#   'path': '/data/asr/asr/slt/wav/s03x000b.wv1.wav',
#   'sentence': 'Då kan det bli svårt med *middagskonversationen*.'},
#  's03c1000.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c1000.wv1.wav',
#   'sentence': 'De svenska bryggerierna är medvetna om att de kommer att få konkurrens.'},
#  's03c1001.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c1001.wv1.wav',
#   'sentence': 'Striden har nu resulterat i att en omfattande utredning igångsatts.'},
#  's03c1002.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c1002.wv1.wav',
#   'sentence': 'Han tillägnar sig med lätthet de olika ämnena med undantag av historia.'},
#  's03c1005.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c1005.wv1.wav',
#   'sentence': 'Äldre europeisk arkitektur uppvisar vid fingranskning vissa moderna drag.'},
#  's03c1006.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c1006.wv1.wav',
#   'sentence': 'Efter nederlaget i spansk-amerikanska kriget avträdde Spanien Kuba till USA.'},
#  's03c1007.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c1007.wv1.wav',
#   'sentence': 'Man kan spekulera över vilken emotionell motivering vissa konstverk har.'},
#  's03c1008.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c1008.wv1.wav',
#   'sentence': 'Våra upplevelser av gammal musik är säkert bemängda med missuppfattningar.'},
#  's03c1009.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c1009.wv1.wav',
#   'sentence': 'Tolv av de tjugo närvarande delegaterna var medlemmar i samma exklusiva klubb.'},
#  's03c100a.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100a.wv1.wav',
#   'sentence': 'De bar var sin fackla i handen och ledsagade honom uppför marmortrapporna.'},
#  's03c100b.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100b.wv1.wav',
#   'sentence': 'Därför hamnar dessa konstnärer så lätt i en absurdism utan djupare mening.'},
#  's03c100c.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100c.wv1.wav',
#   'sentence': 'Det dröjer ytterligare tre dygn innan forskarna får veta om försöket lyckats.'},
#  's03c100e.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100e.wv1.wav',
#   'sentence': 'Den viggstjärtade örnen lever huvudsakligen av kaniner, ekorrar och kadaver.'},
#  's03c100g.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100g.wv1.wav',
#   'sentence': 'Scenen ger associationer till de teatrar där mirakelspel en gång uppfördes.'},
#  's03c100h.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100h.wv1.wav',
#   'sentence': 'Docenten var lärd på ett närmast orientaliskt sätt och förstod allt i grunden.'},
#  's03c100i.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100i.wv1.wav',
#   'sentence': 'Vissa av lagunerna är så stora att ordet sjö egentligen passar bättre.'},
#  's03c100j.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100j.wv1.wav',
#   'sentence': 'De närvarande forskarna hade ingen aning om vad resultatet kunde ha berott på.'},
#  's03c100m.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100m.wv1.wav',
#   'sentence': 'Det kostade en överdriven summa att rusta upp gårdarna till beboeligt skick.'},
#  's03c100n.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100n.wv1.wav',
#   'sentence': 'Den ryske schackspelaren var självfallet favoriten när mästerskapet inleddes.'},
#  's03c100o.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100o.wv1.wav',
#   'sentence': 'Enligt den juridiska modell som tillämpas i väst skall ingen dömas ohörd.'},
#  's03c100p.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100p.wv1.wav',
#   'sentence': 'De slavar som arbetade på plantagerna och bomullsfälten var inte sysslolösa.'},
#  's03c100q.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100q.wv1.wav',
#   'sentence': 'Åhörarna sprang fram till scenen för att försöka få en bit av idolens skjorta.'},
#  's03c100r.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100r.wv1.wav',
#   'sentence': 'I den lilla stugan skulle man inte kunnat bo ens om den varit ny och billig.'},
#  's03c100s.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100s.wv1.wav',
#   'sentence': 'Samtliga kritiker uppskattade den lysande symboliska skildringen av anfallet.'},
#  's03c100t.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100t.wv1.wav',
#   'sentence': 'En kortfattad biografi över Bergman inleder den sjunde volymen i bokverket.'},
#  's03c100u.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100u.wv1.wav',
#   'sentence': 'Efter borgarna tillkom kyrkorna och först därefter utvecklades städerna.'},
#  's03c100v.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100v.wv1.wav',
#   'sentence': 'Firman letade efter en begåvad modist för vinterkollektionens skjortor.'},
#  's03c100w.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100w.wv1.wav',
#   'sentence': 'Korparna kretsade ovanför det mänskliga följet tills man gjorde stopp.'},
#  's03c100x.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100x.wv1.wav',
#   'sentence': 'Man borde ange hur många minuter potatisen kan kokas utan att bli torr.'},
#  's03c100y.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100y.wv1.wav',
#   'sentence': 'Musikanterna spelade säckpipa, flöjt, harpa eller olika stränginstrument.'},
#  's03c100z.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c100z.wv1.wav',
#   'sentence': 'Tårna blänker av jolmigt rosa nagellack genom de spindelvävstunna strumporna.'},
#  's03c1010.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c1010.wv1.wav',
#   'sentence': 'En senmedeltida krönika innehåller allehanda uppgifter om slottets tillkomst.'},
#  's03c1011.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c1011.wv1.wav',
#   'sentence': 'Josef gav i torsdags sin synpunkt på förlagets anpassning till framtida behov.'},
#  's03c1012.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c1012.wv1.wav',
#   'sentence': 'Anteckningarna i hans katalog blev kortare, torftigare och mer skissartade.'},
#  's03c1013.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c1013.wv1.wav',
#   'sentence': 'Den avhoppade spionen angav under förhören sina forna kontakter.'},
#  's03c1014.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c1014.wv1.wav',
#   'sentence': 'Kungens ekipage övertogs av en stiftelse vars plikttrohet saknade motstycke.'},
#  's03c1016.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c1016.wv1.wav',
#   'sentence': 'De historier Sheherazade berättade har samlats i sagoboken Tusen och en natt.'},
#  's03c1017.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c1017.wv1.wav',
#   'sentence': 'Som bofast på Bahamas var han van vid att se havet och avskydde Kalahariöknen.'},
#  's03c1018.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c1018.wv1.wav',
#   'sentence': 'Som en bohemisk hippie stirrade han upp i himlen medan han fimpade cigaretten.'},
#  's03c1019.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c1019.wv1.wav',
#   'sentence': 'Byfogdens höga krav innebar att vartenda paket och gåvobrev skulle redovisas.'},
#  's03c101a.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c101a.wv1.wav',
#   'sentence': 'Byns enda bevarade vapensmedja har brukats utan uppehåll i elvahundra år.'},
#  's03c101b.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c101b.wv1.wav',
#   'sentence': 'Partipolitiken har kommit att överskuggas av sakfrågor som narkotikahantering.'},
#  's03c101c.wv1': {'client_id': 's03-sess01',
#   'path': '/data/asr/asr/slt/wav/s03c101c.wv1.wav',
#   'sentence': 'Artikelns fokus låg på exploderande stjärnor, de så kallade supernovorna.'},
#  's03a2000.wv1': {'client_id': 's03-sess02',
#   'path': '/data/asr/asr/slt/wav/s03a2000.wv1.wav',
#   'sentence': 'Jag vill ha priserna på u a ett nio fyra.'},
#  's03a2001.wv1': {'client_id': 's03-sess02',
#   'path': '/data/asr/asr/slt/wav/s03a2001.wv1.wav',
#   'sentence': 'Jag vill hitta en tur från boston till atlanta.'},
#  's03a2002.wv1': {'client_id': 's03-sess02',
#   'path': '/data/asr/asr/slt/wav/s03a2002.wv1.wav',
#   'sentence': 'Jag vill flyga från baltimore till dallas tur-och-retur.'},
#  's03a2003.wv1': {'client_id': 's03-sess02',
#   'path': '/data/asr/asr/slt/wav/s03a2003.wv1.wav',
#   'sentence': 'Jag vill resa från boston till atlanta på måndag.'},
#  's03a2004.wv1': {'client_id': 's03-sess02',
#   'path': '/data/asr/asr/slt/wav/s03a2004.wv1.wav',
#   'sentence': 'Jag vill ha onsdagsturer från atlanta till washington d c.'},
#  's03a2005.wv1': {'client_id': 's03-sess02',
#   'path': '/data/asr/asr/slt/wav/s03a2005.wv1.wav',
#   'sentence': 'Jag skulle vilja ha direkttur turistklass från pittsburgh till atlanta.'},
#  's03a2006.wv1': {'client_id': 's03-sess02',
#   'path': '/data/asr/asr/slt/wav/s03a2006.wv1.wav',
#   'sentence': 'Jag vill flyga delta från pittsburgh till atlanta.'},
#  's03a2007.wv1': {'client_id': 's03-sess02',
#   'path': '/data/asr/asr/slt/wav/s03a2007.wv1.wav',
#   'sentence': 'Jag skulle vilja åka nio noll noll runt nio noll noll.'},
#  's03a2008.wv1': {'client_id': 's03-sess02',
#   'path': '/data/asr/asr/slt/wav/s03a2008.wv1.wav',
#   'sentence': 'Jag skulle vilja åka klockan sjutton och femton.'},
#  's03a2009.wv1': {'client_id': 's03-sess02',
#   'path': '/data/asr/asr/slt/wav/s03a2009.wv1.wav',
#   'sentence': 'Jag skulle vilja åka från atlanta efter arton.'},
#  's03a200a.wv1': {'client_id': 's03-sess02',
#   'path': '/data/asr/asr/slt/wav/s03a200a.wv1.wav',
#   'sentence': 'Jag skulle vilja planera en tur med american airlines.'},
#  's03a200b.wv1': {'client_id': 's03-sess02',
#   'path': '/data/asr/asr/slt/wav/s03a200b.wv1.wav',
# ...
#   'sentence': 'Som en bohemisk hippie stirrade han upp i himlen medan han fimpade cigaretten.'},
#  's0ac1019.wv1': {'client_id': 's0a-sess01',
#   'path': '/data/asr/asr/slt/wav/s0ac1019.wv1.wav',
#   'sentence': 'Byfogdens höga krav innebar att vartenda paket och gåvobrev skulle redovisas.'},
#  's0ac101a.wv1': {'client_id': 's0a-sess01',
#   'path': '/data/asr/asr/slt/wav/s0ac101a.wv1.wav',
#   'sentence': 'Byns enda bevarade vapensmedja hade brukats utan uppehåll i elvahundra år.'},
#  's0ac101b.wv1': {'client_id': 's0a-sess01',
#   'path': '/data/asr/asr/slt/wav/s0ac101b.wv1.wav',
#   'sentence': 'Partipolitiken har kommit att överskuggas av sakfrågor som narkotikahantering.'},
#  's0ac101c.wv1': {'client_id': 's0a-sess01',
#   'path': '/data/asr/asr/slt/wav/s0ac101c.wv1.wav',
#   'sentence': 'Artikelns fokus låg på exploderande *stjärnor*, de så kallade supernovorna.'},
#  's0ac101d.wv1': {'client_id': 's0a-sess01',
#   'path': '/data/asr/asr/slt/wav/s0ac101d.wv1.wav',
#   'sentence': 'Kyrkoherden hade studerat filosofihistoria under sin tid på vilohemmet.'},
#  's0aa2000.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa2000.wv1.wav',
#   'sentence': 'Visa mig de billigaste turerna från San Francisco till Philadelphia.'},
#  's0aa2001.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa2001.wv1.wav',
#   'sentence': 'Visa mig den dagliga flygtidtabellen mellan Boston och Pittsburgh.'},
#  's0aa2002.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa2002.wv1.wav',
#   'sentence': 'Visa mig Deltaturerna från San Francisco till Boston.'},
#  's0aa2003.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa2003.wv1.wav',
#   'sentence': 'Visa mig priset på Delta flight två nio sex.'},
#  's0aa2004.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa2004.wv1.wav',
#   'sentence': 'Visa mig priset på eastern flight fem tre fyra.'},
#  's0aa2005.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa2005.wv1.wav',
#   'sentence': 'Visa mig priset på United flight ett nio fyra.'},
#  's0aa2006.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa2006.wv1.wav',
#   'sentence': 'Visa mig biljettpriser för Eastern flight tre noll sju.'},
#  's0aa2007.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa2007.wv1.wav',
#   'sentence': 'Visa mig priserna för turerna före klockan tio noll noll.'},
#  's0aa2008.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa2008.wv1.wav',
#   'sentence': 'Visa mig förstaklasspriser från Baltimore till Dallas.'},
#  's0aa2009.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa2009.wv1.wav',
#   'sentence': 'Visa mig förstaklasspriserna från Boston till Denver.'},
#  's0aa200a.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa200a.wv1.wav',
#   'sentence': 'Visa mig förstaklassavgångarna från Denver till Baltimore.'},
#  's0aa200b.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa200b.wv1.wav',
#   'sentence': 'Visa mig turen för Eastern flight fem trettiofyra.'},
#  's0aa200c.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa200c.wv1.wav',
#   'sentence': 'Visa mig turerna från Atlanta till B W I.'},
#  's0aa200d.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa200d.wv1.wav',
#   'sentence': 'Visa mig avgångar från Atlanta till Denver på fredag.'},
#  's0aa200e.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa200e.wv1.wav',
#   'sentence': 'Visa mig turerna från Atlanta till Denver på måndag.'},
#  's0aa200f.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa200f.wv1.wav',
#   'sentence': 'Visa mig turerna från Boston till Pittsburgh på torsdag.'},
#  's0aa200g.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa200g.wv1.wav',
#   'sentence': 'Visa mig avgångarna från Pittsburgh till Boston på onsdag.'},
#  's0aa200h.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa200h.wv1.wav',
#   'sentence': 'Visa mig turerna från Denver till Atlanta på fredag.'},
#  's0aa200i.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa200i.wv1.wav',
#   'sentence': 'Visa mig turerna från Denver till Pittsburgh och *Atlanta*.'},
#  's0aa200j.wv1': {'client_id': 's0a-sess02',
#   'path': '/data/asr/asr/slt/wav/s0aa200j.wv1.wav',
#   'sentence': 'Visa mig det lägsta priset på biljett från Boston till San Francisco.'},
#  's0an3000.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an3000.wv1.wav',
#   'sentence': 'De jävlarna sket ner mig, grät han.'},
#  's0an3001.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an3001.wv1.wav',
#   'sentence': 'Människorna, filosoferade han, de vill så mycket, de önskar så mycket.'},
#  's0an3002.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an3002.wv1.wav',
#   'sentence': 'En förstämning lade sig över klosterträdgården.'},
#  's0an3003.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an3003.wv1.wav',
#   'sentence': 'Jag längtar ut till civilisationen och kulturen igen.'},
#  's0an3004.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an3004.wv1.wav',
#   'sentence': 'Han reste sig ur fåtöljen, bugade sig omärkligt och försvann ut.'},
#  's0an3005.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an3005.wv1.wav',
#   'sentence': 'Han hade fått syn på en högvuxen vresros och höjde rösten.'},
#  's0an3006.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an3006.wv1.wav',
#   'sentence': 'Se på denna rosbuske, predikade han.'},
#  's0an3007.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an3007.wv1.wav',
#   'sentence': 'Han mönstrade oss med högtidlig min.'},
#  's0an3008.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an3008.wv1.wav',
#   'sentence': 'Vi svarade ingenting, vi hoppades att han skulle gå.'},
#  's0an3009.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an3009.wv1.wav',
#   'sentence': 'Medan munken mumlande gick sin väg, tittade doktorn närmare på rosenbusken.'},
#  's0an300a.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an300a.wv1.wav',
#   'sentence': 'En rugosahybrid, konstaterade han och rörde försiktigt vid de röda blommorna.'},
#  's0an300b.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an300b.wv1.wav',
#   'sentence': 'Det är ett underbart ställe, sa han och luktade på rosen.'},
#  's0an300c.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an300c.wv1.wav',
#   'sentence': 'Det var för varmt också i skuggan.'},
#  's0an300d.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an300d.wv1.wav',
#   'sentence': 'Elof, tänkte jag, det var längesedan jag såg honom.'},
#  's0an300e.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an300e.wv1.wav',
#   'sentence': 'Pernilla låg framstupa och solade i sin vita bikini.'},
#  's0an300f.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an300f.wv1.wav',
#   'sentence': 'Han ryste och slöt ögonen, vit i ansiktet.'},
#  's0an300g.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an300g.wv1.wav',
#   'sentence': 'Detta är våran Algot, sa hon.'},
#  's0an300h.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an300h.wv1.wav',
#   'sentence': 'Munken slog matt upp ögonen och såg en padda.'},
#  's0an300i.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an300i.wv1.wav',
#   'sentence': 'Jag kommer att dö av blodförgiftning.'},
#  's0an300j.wv1': {'client_id': 's0a-sess03',
#   'path': '/data/asr/asr/slt/wav/s0an300j.wv1.wav',
#   'sentence': 'Bed för mig broder, grät han.'},
#  's0bx0001.wv1': {'client_id': 's0b-sess00',
#   'path': '/data/asr/asr/slt/wav/s0bx0001.wv1.wav',
#   'sentence': 'Hela gruppen gav upp ett beundrande tjut inför den enastående prestationen.'},
#  's0bx0002.wv1': {'client_id': 's0b-sess00',
#   'path': '/data/asr/asr/slt/wav/s0bx0002.wv1.wav',
#   'sentence': 'Kaffe- och tedrickandet var mycket utbrett i landet, särskilt under den regniga och kalla tiden på året.'},
#  's0bx0007.wv1': {'client_id': 's0b-sess00',
#   'path': '/data/asr/asr/slt/wav/s0bx0007.wv1.wav',
#   'sentence': 'Det bästa han visste var en stor saftig stek med svampsås och stekt potatis.'},
#  's0bx0008.wv1': {'client_id': 's0b-sess00',
#   'path': '/data/asr/asr/slt/wav/s0bx0008.wv1.wav',
#   'sentence': 'Till detta ett gott rött vin.'},
#  's0bx0009.wv1': {'client_id': 's0b-sess00',
#   'path': '/data/asr/asr/slt/wav/s0bx0009.wv1.wav',
#   'sentence': 'Inte så exklusivt kanske eller speciellt märkvärdigt, men gott, mycket gott.'},
#  's0bc1000.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc1000.wv1.wav',
#   'sentence': 'De svenska bryggerierna är medvetna om att de kommer att få konkurrens.'},
#  's0bc1002.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc1002.wv1.wav',
#   'sentence': 'Han tillägnar sig med lätthet de olika ämnena med undantag av historia.'},
#  's0bc1003.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc1003.wv1.wav',
#   'sentence': 'Vad som automatiskt följer en tredjeklasskrog är faktiskt garanterad trivsel.'},
#  's0bc1004.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc1004.wv1.wav',
#   'sentence': 'Den gamle professorn lät sina känsliga fingertoppar glida över blindskriften.'},
#  's0bc1005.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc1005.wv1.wav',
#   'sentence': 'Äldre europeisk arkitektur uppvisar vid fingranskning vissa moderna drag.'},
#  's0bc1006.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc1006.wv1.wav',
#   'sentence': 'Efter nederlaget i spansk-amerikanska kriget avträdde Spanien Kuba till USA.'},
#  's0bc1007.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc1007.wv1.wav',
#   'sentence': 'Man kan spekulera över vilken emotionell motivering vissa konstverk har.'},
#  's0bc1008.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc1008.wv1.wav',
#   'sentence': 'Våra upplevelser av gammal musik är säkert bemängda med missuppfattningar.'},
#  's0bc1009.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc1009.wv1.wav',
#   'sentence': 'Tolv av de tjugo närvarande delegaterna var medlemmar i samma exklusiva klubb.'},
#  's0bc100a.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100a.wv1.wav',
#   'sentence': 'De bar var sin fackla i handen och ledsagade honom uppför marmortrapporna.'},
#  's0bc100b.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100b.wv1.wav',
#   'sentence': 'Därför hamnar dessa konstnärer så lätt i en absurdism utan djupare mening.'},
#  's0bc100c.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100c.wv1.wav',
#   'sentence': 'Det dröjer ytterligare tre dygn innan forskarna får veta om försöket lyckats.'},
#  's0bc100d.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100d.wv1.wav',
#   'sentence': 'Det är oftast mycket svårt att jämföra olycksstatistik mellan olika länder.'},
#  's0bc100e.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100e.wv1.wav',
#   'sentence': 'Den viggstjärtade örnen lever huvudsakligen av kaniner, ekorrar och kadaver.'},
#  's0bc100f.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100f.wv1.wav',
#   'sentence': 'Stilistiskt sett har paviljongens pelare inte något sammanhang med platsen.'},
#  's0bc100g.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100g.wv1.wav',
#   'sentence': 'Scenen ger associationer till de teatrar där mirakelspel en gång uppfördes.'},
#  's0bc100h.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100h.wv1.wav',
#   'sentence': 'Docenten var lärd på ett närmast orientaliskt sätt och förstod allt i grunden.'},
#  's0bc100i.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100i.wv1.wav',
#   'sentence': 'Vissa av lagunerna är så stora att ordet sjö egentligen passar bättre.'},
#  's0bc100j.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100j.wv1.wav',
#   'sentence': 'De närvarande forskarna hade ingen aning om vad resultatet kunde ha berott på.'},
#  's0bc100k.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100k.wv1.wav',
#   'sentence': 'I fyra år åt den raggiga och förslagna vovven alltid upp de nybakta kakorna.'},
#  's0bc100l.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100l.wv1.wav',
#   'sentence': 'Muminmamman tvivlade på den traditionella skildringen av världsalltet.'},
#  's0bc100n.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100n.wv1.wav',
#   'sentence': 'Den ryske schackspelaren var självfallet favoriten när mästerskapet inleddes.'},
#  's0bc100o.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100o.wv1.wav',
#   'sentence': 'Enligt den juridiska modell som tillämpas i väst skall ingen dömas ohörd.'},
#  's0bc100p.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100p.wv1.wav',
#   'sentence': 'De slavar som arbetade på plantagerna och bomullsfälten var inte sysslolösa.'},
#  's0bc100q.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100q.wv1.wav',
#   'sentence': 'Åhörarna sprang fram till scenen för att försöka få en bit av idolens skjorta.'},
#  's0bc100r.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100r.wv1.wav',
#   'sentence': 'I den lilla stugan skulle man inte kunnat bo ens om den varit ny och billig.'},
#  's0bc100s.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100s.wv1.wav',
#   'sentence': 'Samtliga kritiker uppskattade den lysande symboliska skildringen av anfallet.'},
#  's0bc100t.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100t.wv1.wav',
#   'sentence': 'En kortfattad biografi över Bergman inleder den sjunde volymen i bokverket.'},
#  's0bc100u.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100u.wv1.wav',
#   'sentence': 'Efter borgarna tillkom kyrkorna och först därefter utvecklades städerna.'},
#  's0bc100v.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100v.wv1.wav',
#   'sentence': 'Firman letade efter en begåvad modist för vinterkollektionens skjortor.'},
#  's0bc100w.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100w.wv1.wav',
#   'sentence': 'Korparna kretsade ovanför det mänskliga följet tills man gjorde stopp.'},
#  's0bc100x.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100x.wv1.wav',
#   'sentence': 'Man borde ange hur många minuter potatisen kan kokas utan att bli torr.'},
#  's0bc100y.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100y.wv1.wav',
#   'sentence': 'Musikanterna spelade säckpipa, flöjt, harpa eller olika stränginstrument.'},
#  's0bc100z.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc100z.wv1.wav',
#   'sentence': 'Tårna blänker av jolmigt rosa nagellack genom de spindelvävstunna strumporna.'},
#  's0bc1011.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc1011.wv1.wav',
#   'sentence': 'Josef gav i torsdags sin synpunkt på förlagets anpassning till framtida behov.'},
#  's0bc1012.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc1012.wv1.wav',
#   'sentence': 'Anteckningarna i hans katalog blev kortare, torftigare och mer skissartade.'},
#  's0bc1013.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc1013.wv1.wav',
#   'sentence': 'Den avhoppade spionen angav under förhören sina forna vänner och kontakter.'},
#  's0bc1014.wv1': {'client_id': 's0b-sess01',
#   'path': '/data/asr/asr/slt/wav/s0bc1014.wv1.wav',
#   'sentence': 'Kungens ekipage övertogs av en stiftelse vars plikttrohet saknade motstycke.'},
#  ...}

# %%
input
# Out:
# {'streams': [{'index': 0,
#    'codec_name': 'shorten',
#    'codec_long_name': 'Shorten',
#    'codec_type': 'audio',
#    'codec_tag_string': '[0][0][0][0]',
#    'codec_tag': '0x0000',
#    'sample_fmt': 's16p',
#    'sample_rate': '16000',
#    'channels': 1,
#    'bits_per_sample': 0,
#    'r_frame_rate': '0/0',
#    'avg_frame_rate': '0/0',
#    'time_base': '1/16000',
#    'duration_ts': 61350,
#    'duration': '3.834375',
#    'disposition': {'default': 0,
#     'dub': 0,
#     'original': 0,
#     'comment': 0,
#     'lyrics': 0,
#     'karaoke': 0,
#     'forced': 0,
#     'hearing_impaired': 0,
#     'visual_impaired': 0,
#     'clean_effects': 0,
#     'attached_pic': 0,
#     'timed_thumbnails': 0}}],
#  'format': {'filename': '/Users/joregan/asr/slt/audio/stockholm_test/s05/sess02/s05a2006.wv2.shn',
#   'nb_streams': 1,
#   'nb_programs': 0,
#   'format_name': 'nistsphere',
#   'format_long_name': 'NIST SPeech HEader REsources',
#   'duration': '3.834375',
#   'size': '57581',
#   'bit_rate': '120136',
#   'probe_score': 100,
#   'tags': {'recording_date': '26-Jul-1995',
#    'recording_time': '01:20:05',
#    'sample_min': '-3396',
#    'sample_max': '3087',
#    'UserID': 's05',
#    'Gender': 'Female',
#    'BirthDate': '590510',
#    'Dialect': 'Stockholm',
#    'Data_collection_type': 'SLT',
#    'Location': 'Sweden',
#    'Recording_Person': 'Anita',
#    'Program': 'GRT-1.0',
#    'sample_checksum': '13727'}}}
