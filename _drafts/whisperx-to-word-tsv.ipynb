# %%
from pathlib import Path

BASE = Path("/Users/joregan/Playing/hsi/audio/whisperx-json/")
TSVBASE = Path("/Users/joregan/Playing/hsi/audio/whisperx-tsv/")

# %%
import json

# %%
if not TSVBASE.is_dir():
    TSVBASE.mkdir()

# %%
# %pip install num2words
# Out:
# Collecting num2words
#   Using cached num2words-0.5.13-py3-none-any.whl (143 kB)
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=f2c212274d0fde8ae733a9c0919ea7f6c056035f7e7985a6e15a5e05321094f2
#   Stored in directory: /Users/joregan/Library/Caches/pip/wheels/70/4a/46/1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
# Successfully built docopt
# Installing collected packages: docopt, num2words
# Successfully installed docopt-0.6.2 num2words-0.5.13
# Note: you may need to restart the kernel to use updated packages.

# %%
from num2words import num2words

# %%
import re

def get_words(word):
    if re.match("^[2-9]0s$", word):
        oword = num2words(int(word[0:-1]), lang="en")
        return oword[:-1] + "ies"
    if re.match("^[0-9]+(?:th|st|nd|rd)$", word):
        return num2words(int(word[0:-2]), lang="en", to="ordinal")
    if re.match("^[0-9]+(?:,[0-9][0-9][0-9])+$", word):
        return num2words(int(word.replace(",", "")), lang="en")
    if re.match("^\$[0-9]+(?:,[0-9][0-9][0-9])*$", word):
        return num2words(int(word[1:].replace(",", "")), lang="en") + " dollars"
    if re.match("^20[1-9][0-9]$", word):
        return "twenty " + num2words(int(word[2:]), lang="en")
    if re.match("^[0-9]+$", word):
        return num2words(int(word), lang="en")
    return word

# %%
for jsonfile in BASE.glob("*.json"):
    last_end = 0.0
    outtsv = TSVBASE / f"{jsonfile.stem}.tsv"
    with open(str(jsonfile)) as inf, open(str(outtsv), "w") as outf:
        data = json.load(inf)
        for segment in data['segments']:
            for word in segment['words']:
                if not "start" in word:
                    start = last_end
                    end = last_end + 0.05
                    text = get_words(word['word'])
                else:
                    start = word['start']
                    end = word['end']
                    text = word['word']
                outf.write(str(start) + "\t" + str(end) + "\t" + text + "\n")
                last_end = end

# %%
for segment in data['segments']:
    for word in segment['words']:
        print(str(word['start']) + "\t" + str(word['end']) + "\t" + word['word'])
# Out:
# 1.895	2.075	Okay,
# 2.095	2.216	so
# 2.256	2.436	can
# 2.476	2.576	you
# 2.596	2.776	look
# 2.836	2.936	at
# 2.976	3.136	this
# 3.176	3.416	green
# 3.456	3.776	ball?
# 4.036	4.456	This
# 4.937	11.259	is
# 11.319	11.339	a
# 11.379	11.559	green
# 11.579	11.76	ball
# 11.8	12.0	now?
# 12.2	12.52	Okay,
# 12.92	13.14	thanks.
# 29.042	29.242	Uh-huh.
# 29.902	30.122	Well,
# 30.142	30.323	that
# 30.503	30.763	sounds
# 30.843	31.243	interesting.
# 31.263	31.343	What
# 31.403	31.503	is
# 31.523	31.683	the
# 31.703	32.764	title?
# 32.784	33.064	Brains.
# 33.164	33.324	Brains.
# 33.384	33.524	OK,
# 33.584	33.664	I
# 33.764	34.024	will
# 34.104	34.344	check
# 34.384	34.524	for
# 34.544	34.704	that.
# 35.045	35.165	Now
# 35.365	35.425	we
# 35.445	35.545	have
# 35.565	35.625	it
# 35.665	35.745	on
# 35.765	35.965	tape.
# 36.565	36.625	I
# 36.645	36.745	can
# 36.765	36.905	look
# 36.925	37.085	back.
# 37.606	37.706	Now
# 37.746	37.806	I'm
# 37.826	38.226	recording
# 38.266	38.366	it.
# 39.126	39.266	Yeah,
# 39.286	39.386	so
# 39.406	39.527	this
# 39.627	39.727	is
# 39.787	39.987	your
# 40.087	40.287	maybe
# 40.447	40.807	bragging
# 40.867	41.107	stuff
# 41.167	41.327	now.
# 41.447	41.567	This
# 41.607	41.667	is
# 41.687	41.807	your
# 41.828	42.608	apartment.
# 42.968	43.048	Is
# 43.068	43.248	that
# 43.268	43.288	a
# 43.308	45.129	window?
# 45.269	45.409	Yeah,
# 45.429	45.449	I
# 45.489	45.669	think
# 45.689	45.889	so.
# 45.929	45.969	I
# 46.009	46.129	don't
# 46.149	46.249	know.
# 46.449	46.51	I
# 46.53	46.65	think
# 46.67	46.85	that's
# 46.89	46.91	a
# 46.97	47.21	ridge.
# 47.27	47.43	That's
# 47.47	47.57	the
# 47.61	47.87	most
# 48.15	48.79	interesting
# 48.851	49.151	thing.
# 49.271	49.511	What
# 49.571	49.631	do
# 49.671	49.791	you
# 51.011	51.252	think?
# 52.612	52.832	Yeah,
# 52.912	52.992	it
# 53.052	53.232	seems
# 53.272	53.392	like
# 53.432	53.452	a
# 53.513	54.113	fireplace,
# 54.193	54.353	no?
# 54.393	54.573	Yes,
# 54.633	54.733	it
# 54.773	54.953	looks
# 54.973	55.253	like
# 55.273	55.293	a
# 55.313	55.934	fireplace,
# 56.014	56.174	but
# 56.194	56.274	what?
# 59.212	59.352	Yeah,
# 59.392	59.492	it's
# 59.532	59.653	like
# 59.693	59.713	a
# 59.733	60.053	window.
# 69.923	70.044	But
# 70.084	70.144	do
# 70.184	70.344	you
# 70.784	70.924	really
# 70.945	71.085	need
# 71.105	71.245	that
# 71.265	71.385	with
# 71.425	71.485	the
# 71.545	71.725	other
# 71.765	72.106	window?
# 75.149	75.349	Because
# 75.409	75.529	it's
# 75.549	75.71	kind
# 75.75	75.79	of...
# 89.284	89.484	Mm-hmm.
# 89.504	89.564	Yes.
# 89.584	89.784	Mm-hmm.
# 122.882	124.803	It's
# 124.823	124.963	very
# 124.983	125.464	interesting,
# 125.504	125.644	this
# 125.684	126.084	contrast,
# 126.104	126.344	because
# 126.384	126.504	this
# 126.584	126.824	rug
# 126.904	127.165	seems
# 127.245	127.285	a
# 127.345	127.505	bit
# 127.625	127.805	more
# 127.925	128.325	archaic.
# 128.445	128.585	It's
# 128.725	128.985	older,
# 129.025	129.166	no?
# 129.206	129.266	And
# 129.286	129.406	then
# 129.446	129.506	it
# 129.526	129.646	was
# 129.686	129.846	very
# 129.866	130.186	modern
# 130.226	130.706	technology.
# 131.727	132.047	Yes,
# 132.347	132.807	and
# 132.827	133.127	you
# 133.227	133.448	also
# 133.488	133.628	see
# 133.648	136.869	that.
# 142.252	142.332	You
# 142.352	142.452	mean
# 142.472	142.552	the
# 142.572	142.912	sofa?
# 143.352	143.512	Yeah.
# 153.976	154.456	Mm-hm.
# 154.476	154.797	Mm-hm.
# 154.957	155.117	Mm-hm.
# 185.322	185.482	This
# 185.502	185.562	is
# 185.682	185.843	an
# 185.963	186.103	art
# 186.163	186.403	piece.
# 187.224	187.344	Ah,
# 187.424	187.504	I
# 187.524	187.685	see.
# 188.926	189.587	It
# 189.607	189.807	looks
# 189.847	190.007	very
# 190.047	190.267	nice.
# 190.367	190.447	It
# 190.688	190.928	almost
# 190.948	191.128	looks
# 191.188	191.348	like
# 191.388	191.429	an
# 191.509	191.649	art
# 191.689	191.889	piece.
# 194.452	194.592	No.
# 195.513	195.613	Ah.
# 197.255	197.435	Yes.
# 203.742	204.022	Yeah,
# 204.062	204.302	that's
# 205.684	205.884	nice.
# 221.035	221.375	Mm-hm.
# 221.595	224.117	Mm-hm.
# 224.477	225.277	Mm-hm.
# 229.039	229.96	Mm-hm.
# 234.502	234.582	Oh?
# 250.115	250.335	That's
# 250.375	250.535	very
# 250.575	250.756	nice.
# 251.316	251.436	But
# 251.496	251.556	I
# 251.596	251.736	see
# 251.776	252.056	you're
# 252.196	252.396	really
# 252.416	252.617	into
# 252.717	252.917	art,
# 253.037	253.177	like
# 253.197	253.257	you
# 253.297	253.377	have
# 253.417	253.737	also
# 253.757	253.817	a
# 253.877	253.997	lot
# 254.017	254.097	of
# 254.137	254.538	paintings
# 254.618	254.778	here.
# 259.34	259.46	Mm?
# 261.641	261.781	Oh?
# 268.125	268.345	Mm?
# 277.43	277.55	Mm?
# 288.722	288.942	Yes,
# 289.542	289.642	but
# 289.702	289.762	it
# 289.802	290.002	seems
# 290.042	290.242	very
# 290.262	290.663	contrasted
# 290.683	290.783	with
# 290.803	290.863	the
# 290.903	291.063	other
# 291.123	291.443	painting
# 291.483	291.603	you
# 291.623	291.783	have.
# 312.933	315.454	No?
# 317.355	317.515	No.
# 317.735	317.815	You
# 317.855	318.055	haven't
# 318.075	318.236	seen
# 318.256	318.336	the
# 318.356	318.556	film,
# 318.576	318.736	have
# 318.796	318.876	you?
# 320.137	320.257	Oh,
# 320.917	321.157	yeah,
# 321.197	321.377	maybe
# 321.417	321.477	I
# 321.497	321.638	have,
# 321.658	321.838	yeah.
# 322.218	322.358	Yeah,
# 322.378	322.638	you
# 322.658	322.838	will.
# 323.379	323.579	Yeah.
# 323.739	324.079	Yeah,
# 324.199	324.459	really?
# 326.34	326.4	I
# 326.42	326.64	think.
# 327.401	327.501	You
# 327.521	327.701	don't
# 327.741	327.961	remember
# 327.981	328.041	if
# 328.061	328.221	you've
# 328.241	328.381	seen
# 328.401	328.542	the
# 328.562	331.243	film?
# 331.283	331.583	But
# 331.623	331.783	do
# 331.803	331.964	you
# 331.984	332.284	remember
# 332.304	332.424	the
# 332.464	332.664	scene?
# 332.684	332.784	Yeah.
# 335.726	336.206	She,
# 336.226	336.366	yeah.
# 349.093	349.193	Ah.
# 355.617	355.737	Ah,
# 356.118	356.198	so
# 356.238	356.338	it's
# 356.358	356.478	not
# 356.518	356.538	a
# 356.578	356.778	happy
# 356.858	357.178	ending?
# 358.559	359.6	Okay.
# 360.1	360.34	Yeah,
# 360.521	360.841	okay,
# 361.181	361.561	drama,
# 361.661	361.861	yeah.
# 362.182	362.802	Yes.
# 367.705	367.945	Mm-hmm.
# 389.909	390.089	That's
# 390.109	390.449	something.
# 393.83	393.89	It
# 393.91	394.09	looks
# 394.13	394.15	a
# 394.19	394.59	bit
# 395.63	395.79	out
# 395.85	395.99	of
# 396.11	396.53	style.
# 396.61	396.95	It's
# 396.97	397.17	very
# 397.21	397.51	stern
# 397.53	397.81	looking,
# 398.091	398.251	that
# 398.371	398.711	couple.
# 399.351	399.431	Do
# 399.451	399.531	you
# 399.571	399.711	like
# 400.911	401.051	that
# 401.091	401.371	painting
# 401.391	401.531	that
# 401.591	401.811	much?
# 403.011	404.672	Yes,
# 412.253	412.373	I
# 412.953	413.253	do.
# 414.454	414.534	It
# 414.554	414.714	makes
# 414.734	415.034	sense,
# 415.054	415.074	a
# 415.094	415.214	lot
# 415.254	415.314	of
# 415.354	415.814	contrasts,
# 416.114	416.174	it
# 416.254	416.474	seems
# 416.534	416.674	like.
# 442.436	442.516	Is
# 442.556	442.616	it
# 442.656	442.776	the
# 443.377	443.577	same
# 443.617	443.857	place
# 443.917	443.997	as
# 444.017	444.097	the
# 444.137	444.318	other
# 444.398	444.778	statue
# 444.798	444.938	that
# 444.958	445.058	you
# 445.098	445.258	have?
# 445.278	445.559	That
# 445.639	446.9	one?
# 447.1	447.26	No,
# 447.5	447.74	that's
# 447.981	448.181	actually...
# 452.759	453.699	Mm-hmm.
# 455.4	455.9	Mm-hmm.
# 455.94	456.28	Mm-hmm.
# 456.3	460.882	Oh.
# 499.651	499.751	Oh,
# 500.032	500.252	yeah,
# 500.292	500.433	that
# 500.453	500.593	would
# 500.613	500.753	make
# 500.773	501.034	sense.
# 501.434	501.494	I
# 501.534	501.715	also
# 501.995	502.095	see
# 502.115	502.236	that
# 502.256	502.376	you
# 502.416	502.576	like
# 502.616	502.957	reading,
# 503.017	503.117	you
# 503.157	503.277	have
# 503.798	504.019	books
# 504.159	504.379	lying
# 504.399	504.74	around.
# 504.84	504.96	Yes,
# 504.98	505.621	yeah,
# 505.642	505.742	and
# 505.762	505.902	as
# 505.922	505.982	you
# 506.002	506.102	can
# 506.223	506.363	see,
# 506.423	506.583	it's
# 507.024	507.284	also
# 513.675	513.816	iPad.
# 531.175	531.415	Mm-hmm.
# 532.876	533.036	Oh.
# 538.618	538.838	Oh.
# 538.858	538.918	Oh.
# 565.675	565.795	OK.
# 579.208	579.348	Oh,
# 579.469	579.969	that's.
# 583.833	583.953	Oh.
# 586.776	586.916	OK.
# 591.505	591.885	Shouldn't
# 591.905	591.945	it
# 592.045	592.325	be
# 592.365	592.766	somewhere
# 592.806	592.986	like
# 593.146	593.206	an
# 593.486	594.146	installation
# 594.186	594.266	on
# 594.286	594.366	the
# 594.386	594.666	wall?
# 595.007	595.087	Or
# 595.147	595.207	is
# 595.287	595.367	it
# 595.407	595.567	good
# 595.627	595.747	in
# 595.847	596.407	legislating?
# 596.447	596.507	It
# 596.527	596.687	seems
# 596.727	596.847	like
# 596.887	596.907	a
# 596.947	597.308	simple
# 597.488	597.828	racket,
# 598.168	598.268	but
# 598.308	598.628	if
# 598.648	598.708	you
# 598.728	598.848	put
# 598.868	598.908	it
# 598.948	599.008	on
# 599.028	599.108	the
# 599.128	613.234	wall...
# 615.375	615.455	You
# 615.475	615.555	can
# 615.575	615.655	do
# 615.675	615.735	the
# 615.775	615.916	same
# 615.956	616.056	thing
# 616.076	616.116	in
# 616.156	616.236	the
# 616.256	616.516	wall,
# 616.536	616.656	you
# 616.676	616.856	put
# 616.936	617.056	it
# 617.096	617.136	on
# 617.156	617.216	the
# 617.236	617.416	wall
# 617.456	617.536	and
# 617.576	617.736	just
# 617.756	617.896	pick
# 617.936	618.016	it
# 618.036	618.156	from
# 618.196	618.257	the
# 618.277	618.457	wall,
# 618.517	618.597	no?
# 624.602	624.742	By
# 624.762	624.862	the
# 624.882	625.322	statue,
# 625.382	625.422	no?
# 625.442	625.703	It's
# 625.803	626.143	actually
# 626.183	626.343	not
# 630.926	631.046	a
# 631.066	632.666	bomb.
# 634.708	634.828	It's
# 638.17	638.25	a
# 638.27	638.49	lamp.
# 640.711	640.771	Is
# 640.791	640.851	it
# 640.871	640.991	like
# 641.031	641.151	this
# 641.211	641.611	natural
# 641.651	641.972	light
# 642.072	642.332	lamp
# 642.452	642.572	for
# 642.592	642.672	the
# 642.692	644.073	dark
# 644.113	644.373	times
# 644.413	644.473	in
# 644.493	644.833	winter?
# 644.853	645.554	Yes,
# 645.894	645.954	it
# 646.054	646.194	is.
# 647.155	647.335	That's
# 647.355	647.515	very
# 647.555	647.795	smart.
# 655.234	655.334	Oh,
# 655.474	655.574	you
# 655.594	655.714	mean
# 655.734	655.855	the
# 655.935	656.035	one,
# 656.055	656.435	the
# 656.475	656.835	standing
# 656.935	657.015	one?
# 657.536	657.796	Okay.
# 686.465	686.605	And
# 686.645	686.945	who
# 687.566	687.906	had
# 687.946	688.206	to
# 693.248	693.949	give
# 694.949	695.029	the
# 695.049	695.249	medicine,
# 695.269	695.429	as
# 695.449	695.589	it
# 695.609	695.869	was
# 695.889	696.09	there,
# 696.11	696.15	to
# 696.19	696.29	be
# 696.33	696.47	the
# 696.51	696.63	third.
# 696.65	696.85	That's
# 697.55	697.81	sad.
# 697.83	697.89	Yes,
# 700.412	705.574	it's
# 705.614	705.834	really
# 705.854	706.114	sad.
# 706.174	706.334	But
# 706.354	706.474	she
# 706.494	706.635	had
# 706.655	706.755	to
# 706.795	707.015	wait
# 707.035	707.175	for
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [10], line 3
#       1 for segment in data['segments']:
#       2     for word in segment['words']:
# ----> 3         print(str(word['start']) + "\t" + str(word['end']) + "\t" + word['word'])
#
# KeyError: 'start'
