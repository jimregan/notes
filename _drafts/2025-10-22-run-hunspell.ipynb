# %% [markdown]
# [Repo](https://github.com/wooorm/dictionaries)

# %%
from pathlib import Path

DICT_DIR = Path("/Users/joregan/Playing/dictionaries")
# Out:
# Running cells with 'hunspell (Python 3.11.14)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n hunspell ipykernel --update-deps --force-reinstall'

# %%
# !conda install -n hunspell ipykernel --update-deps --force-reinstall
# Out:
# Running cells with 'hunspell (Python 3.11.14)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n hunspell ipykernel --update-deps --force-reinstall'

# %%
import hunspell
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import hunspell
#
# ModuleNotFoundError: No module named 'hunspell'
