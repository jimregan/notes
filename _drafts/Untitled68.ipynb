# %%
REEL = "https://www.instagram.com/p/DX4GoITNq7b/"

# %%
# %pip install openai-whisper instaloader
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 12.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 6.2 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=122c74ed63a6c4e64d02839985e6ea234feadab7aaaea9fffc32fe5cde7cd227
#   Stored in directory: /root/.cache/pip/wheels/61/d2/20/09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# Successfully built openai-whisper
# ...

# %%
parts = [x for x in REEL.split("/") if x != ""]
id = parts[-1]
# !instaloader -- -{id}
# Out:
# JSON Query to graphql/query: Expecting value: line 1 column 1 (char 0) [retrying; skip with ^C]
# -DX4GoITNq7b/2026-05-03_12-34-48_UTC.jpg [What are you going to learn i…] -DX4GoITNq7b/2026-05-03_12-34-48_UTC.mp4 json

# %%
# !apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.

# %%
# !for file in ./-*/*.mp4;do whisper $file;done
