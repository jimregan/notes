# %%
# !find ../input/run-kaldi-on-librispeech-test -name best_wer|while read i;do echo $i; cat $i;done
# Out:
# ../input/run-kaldi-on-librispeech-test/exp/tdnn_1d_sp/decode_test-other_tgsmall/scoring_kaldi/best_wer
# %WER 17.92 [ 9378 / 52343, 1384 ins, 723 del, 7271 sub ] exp/tdnn_1d_sp/decode_test-other_tgsmall/wer_17_1.0
# ../input/run-kaldi-on-librispeech-test/exp/tdnn_1d_sp/decode_test-clean_tgsmall/scoring_kaldi/best_wer
# %WER 7.13 [ 3747 / 52576, 648 ins, 242 del, 2857 sub ] exp/tdnn_1d_sp/decode_test-clean_tgsmall/wer_17_0.5

# %%
#!steps/score_kaldi.sh --cmd "run.pl" data/test-clean_hires $graph_dir $tdnndir/decode_test-clean_rescore
#!steps/score_kaldi.sh --cmd "run.pl" data/test-other_hires $graph_dir $tdnndir/decode_test-other_rescore
# %env tdnndir=../input/run-kaldi-on-librispeech-test/exp/tdnn_1d_sp
# %env graph_dir=../input/run-kaldi-on-librispeech-test/exp/chain_cleaned_out/graph_tgsmall
# !steps/score_kaldi.sh --cmd "run.pl" data/test-clean_hires $graph_dir $tdnndir/decode_test-clean_rescore
# !steps/score_kaldi.sh --cmd "run.pl" data/test-other_hires $graph_dir $tdnndir/decode_test-other_rescore
