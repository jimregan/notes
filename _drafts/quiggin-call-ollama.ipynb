# %%
import requests
import json
from pathlib import Path

OLLAMA_HOST = "http://130.237.3.106:11434"  # or the IP of your Ollama machine
MODEL = "phi3"

def extract_sections(text: str) -> list[dict]:
    """
    Send one text chunk (sections) to Ollama, return parsed JSON.
    """
    prompt = f"""
You are a careful extractor. Convert Irish phonetic dictionary snippets into JSON.

Rules:
- Output ONLY JSON (UTF-8), an array of entry objects. No prose.
- Preserve phonetic strings exactly. Strip soft hyphens and HTML entities (&shy;, &nbsp;).
- Fields (include only when present): section, phonetic, gloss, transcription, etymology,
  source_refs, related, also, examples, derived_from, relations, components, see_section,
  notes, sic, warning, literature_refs.
- Etymology = historical language stage, not a bibliography.
- Dictionary citations go in source_refs (not etymology).
- Relations: use explicit *_of when dependent is stated (e.g. "genitive_singular_of").
- Variants/emphatic forms → "also":[...]
- Compounds → "components":[ {...}, {...} ]
- Quotes/proverbs → "examples":[{"quote":"…","gloss":"…","type":"proverb","source":"…"}]
- Don’t invent spellings. If an Irish spelling is given, put it in "transcription".

Now extract the following snippet to JSON:

<<<
{text}
>>>
    """

    r = requests.post(
        f"{OLLAMA_HOST}/api/generate",
        headers={"Content-Type": "application/json"},
        json={
            "model": MODEL,
            "prompt": prompt,
            "options": {"temperature": 0.1},
            "stream": False,
        },
        timeout=600,
    )
    r.raise_for_status()
    data = r.json()

    # Ollama wraps the text inside `response` as a string
    try:
        return json.loads(data["response"])
    except json.JSONDecodeError:
        print("⚠️ Could not parse response:")
        print(data["response"])
        return []

# %%
from pathlib import Path

json_path = Path("/tmp/pron2/quiggin/raw")
wiki_path = Path("/tmp/pron2/quiggin/wiki")

for file in wiki_path.glob("*.wiki"):
    stem = file.stem
    if (json_path / f"{stem}.json").exists():
        print(f"Skipping {stem}, already done")
        continue
    with open(file, "r") as f:
        text = f.read()
    text = text.strip()
    output = extract_sections(text)
    with open(json_path / f"{stem}.json", "w", encoding="utf-8") as f:
        json.dump(output, f, ensure_ascii=False, indent=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 14
#      12     text = f.read()
#      13 text = text.strip()
# ---> 14 output = extract_sections(text)
#      15 with open(json_path / f"{stem}.json", "w", encoding="utf-8") as f:
#      16     json.dump(output, f, ensure_ascii=False, indent=2)
#
# Cell In[2], line 12, in extract_sections(text)
#       8 def extract_sections(text: str) -> list[dict]:
#       9     """
#      10     Send one text chunk (sections) to Ollama, return parsed JSON.
#      11     """
# ---> 12     prompt = f"""
#      13 You are a careful extractor. Convert Irish phonetic dictionary snippets into JSON.
#      14
#      15 Rules:
#      16 - Output ONLY JSON (UTF-8), an array of entry objects. No prose.
#      17 - Preserve phonetic strings exactly. Strip soft hyphens and HTML entities (&shy;, &nbsp;).
#      18 - Fields (include only when present): section, phonetic, gloss, transcription, etymology,
#      19   source_refs, related, also, examples, derived_from, relations, components, see_section,
#      20   notes, sic, warning, literature_refs.
#      21 - Etymology = historical language stage, not a bibliography.
#      22 - Dictionary citations go in source_refs (not etymology).
#      23 - Relations: use explicit *_of when dependent is stated (e.g. "genitive_singular_of").
#      24 - Variants/emphatic forms → "also":[...]
#      25 - Compounds → "components":[ {...}, {...} ]
#      26 - Quotes/proverbs → "examples":[{"quote":"…","gloss":"…","type":"proverb","source":"…"}]
#      27 - Don’t invent spellings. If an Irish spelling is given, put it in "transcription".
#      28
#      29 Now extract the following snippet to JSON:
#      30
#      31 <<<
#      32 {text}
#      33 >>>
#      34     """
#      36     r = requests.post(
#      37         f"{OLLAMA_HOST}/api/generate",
#      38         headers={"Content-Type": "application/json"},
#    (...)
#      45         timeout=600,
#      46     )
#      47     r.raise_for_status()
#
# ValueError: Invalid format specifier
