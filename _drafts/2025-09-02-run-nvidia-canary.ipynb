# %%
from nemo.collections.asr.models import ASRModel
import torch

file = "/NeMo/362.wav"
MODEL_NAME="nvidia/canary-1b-v2"
device = "cuda" if torch.cuda.is_available() else "cpu"

model = ASRModel.from_pretrained(model_name=MODEL_NAME)
model.eval()
model.to(device)
output = model.transcribe([file], timestamps=True, source_lang="sv", target_lang="sv")

# %% [markdown]
# ```python
#
# [Hypothesis(score=0.0, y_sequence=tensor([ 5858,  3124,  1648,  5175,  1185,  2241,  1579,  6085,  5061,  3744,
#          1176,  2824,  6510,  3305,  4296, 13340,  2535,  1310,  1180,  1202,
#          3050,  4543, 16066,  1928,  1163, 16067,  6694,  1563, 10524,  2149,
#          4004,  1338,  1580,  2773,  2241, 16073,  1333,  1928,  1579,  2036,
#          2789,  1657,  5749,  1881,  1220, 16061,  1814,  1713,  3124,  1648,
#          5175,  2031,  1646, 10972,  1478,  5100,  1636,  7656,  2653,  3512,
#         14137,  3411, 16067,  1724,  1430,  1749,  1258,  3318,  6032,  1724,
#          1260,  1601,  1657,  2920, 15588, 16060,  1209,  4524, 16073,  1305,
#          1703, 10602,  1601, 10001,  2974,  3641,  1163,  3287,  1579,  3053,
#          1258,  9022,  1203,  1928, 16060,  1728, 16056,  1267,  2773, 15950,
#          4613,  1580,  2274, 16060,  2113,  2092,  1826,  1239, 16072,  2361,
#          1539, 16067,  1590,  1430,  3287,  2146]), text='Om ett kommunalval nu helt ändrar majoritetsförhållandet i väljarkåren, bör man då inte ordna med nyval. Vår nuvarande författning inrymmer ett kommunalt samband som också påpekats tidigare här, men det är enligt vår mening av för begränsad natur. Hälften av första kammaren ska nu under en fyraårsperiod nyväljas med hänsyn till valutgången, och det ska ju', dec_out=None, dec_state=None, timestamp={'word': [{'word': 'Om', 'start_offset': 12, 'end_offset': 13, 'start': 0.96, 'end': 1.04}, {'word': 'ett', 'start_offset': 14, 'end_offset': 15, 'start': 1.12, 'end': 1.2}, {'word': 'kommunalval', 'start_offset': 16, 'end_offset': 22, 'start': 1.28, 'end': 1.76}, {'word': 'nu', 'start_offset': 25, 'end_offset': 26, 'start': 2.0, 'end': 2.08}, {'word': 'helt', 'start_offset': 27, 'end_offset': 28, 'start': 2.16, 'end': 2.24}, {'word': 'ändrar', 'start_offset': 33, 'end_offset': 37, 'start': 2.64, 'end': 2.96}, {'word': 'majoritetsförhållandet', 'start_offset': 42, 'end_offset': 57, 'start': 3.36, 'end': 4.56}, {'word': 'i', 'start_offset': 57, 'end_offset': 58, 'start': 4.64, 'end': 4.72}, {'word': 'väljarkåren,', 'start_offset': 60, 'end_offset': 69, 'start': 4.8, 'end': 5.52}, {'word': 'bör',
76, 'end': 18.24}, {'word': 'natur.', 'start_offset': 231, 'end_offset': 233, 'start': 18.56, 'end': 18.64}, {'word': 'Hälften', 'start_offset': 256, 'end_offset': 261, 'start': 20.48, 'end': 20.88}, {'word': 'av', 'start_offset': 265, 'end_offset': 266, 'start': 21.2, 'end': 21.28}, {'word': 'första', 'start_offset': 268, 'end_offset': 269, 'start': 21.44, 'end': 21.52}, {'word': 'kammaren', 'start_offset': 275, 'end_offset': 280, 'start': 22.0, 'end': 22.4}, {'word': 'ska', 'start_offset': 291, 'end_offset': 292, 'start': 23.28, 'end': 23.36}, {'word': 'nu', 'start_offset': 294, 'end_offset': 295, 'start': 23.52, 'end': 23.6}, {'word': 'under', 'start_offset': 297, 'end_offset': 298, 'start': 23.76, 'end': 23.84}, {'word': 'en', 'start_offset': 299, 'end_offset': 300, 'start': 23.92, 'end': 24.0}, {'word': 'fyraårsperiod', 'start_offset': 301, 'end_offset': 312, 'start': 24.08, 'end': 24.96}, {'word': 'nyväljas', 'start_offset': 314, 'end_offset': 322, 'start': 25.12, 'end': 25.76}, {'word': 'med', 'start_offset': 332, 'end_offset': 333, 'start': 26.56, 'end': 26.64}, {'word': 'hänsyn', 'start_offset': 335, 'end_offset': 339, 'start': 26.8, 'end': 27.12}, {'word': 'till', 'start_offset': 342, 'end_offset': 343, 'start': 27.36, 'end': 27.44}, {'word': 'valutgången,', 'start_offset': 348, 'end_offset': 357, 'start': 27.84, 'end': 28.56}, {'word': 'och', 'start_offset': 358, 'end_offset': 359, 'start': 28.64, 'end': 28.72}, {'word': 'det', 'start_offset': 359, 'end_offset': 360, 'start': 28.72, 'end': 28.8}, {'word': 'ska', 'start_offset': 361, 'end_offset': 362, 'start': 28.88, 'end': 28.96}, {'word': 'ju', 'start_offset': 362, 'end_offset': 363, 'start': 28.96, 'end': 29.04}], 'segment': [{'segment': 'Om ett kommunalval nu helt ändrar majoritetsförhållandet i väljarkåren, bör man då inte ordna med nyval.', 'start_offset': 12, 'end_offset': 96, 'start': 0.96, 'end': 7.68}, {'segment': 'Vår nuvarande författning inrymmer ett kommunalt samband som också påpekats tidigare här, men det är enligt vår mening av för begränsad natur.', 'start_offset': 120, 'end_offset': 233, 'start': 9.6, 'end': 18.64}, {'segment': 'Hälften av första kammaren ska nu under en fyraårsperiod nyväljas med hänsyn till valutgången, och det ska ju', 'start_offset': 256, 'end_offset': 363, 'start': 20.48, 'end': 29.04}]}, alignments=None, frame_confidence=None, token_confidence=None, word_confidence=None, length=0, y=None, lm_state=None, lm_scores=None, ngram_lm_state=None, tokens=None, last_token=None, token_duration=None, last_frame=None)]
# ```
