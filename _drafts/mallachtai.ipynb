# %%
MALLACHTAI = {
    "https://www.leighleat.com/pages/1": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.right > h1",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.right > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.right > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.right > p:nth-child(5)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.right > p:nth-child(6)"
    ],
    "https://www.leighleat.com/pages/2": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > h1",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/4": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(5)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(6)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(7)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(8)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(9)"
    ],
    "https://www.leighleat.com/pages/5": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(5)"
    ],
    "https://www.leighleat.com/pages/6": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.top > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.top > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/7": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(5)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(6)"
    ],
    "https://www.leighleat.com/pages/8": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.right > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.right > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.right > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.right > p:nth-child(5)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.right > p:nth-child(6)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.right > p:nth-child(7)"
    ],
    "https://www.leighleat.com/pages/9": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > h1",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(5)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(6)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(7)"
    ],
    "https://www.leighleat.com/pages/10": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(5)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(6)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(7)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(8)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(9)"
    ],
    "https://www.leighleat.com/pages/11": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.bottom > p"
    ],
    "https://www.leighleat.com/pages/13": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.bottom > p:nth-child(3)"
    ],
    "https://www.leighleat.com/pages/14": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(5)"
    ],
    "https://www.leighleat.com/pages/16": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(5)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(6)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(7)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(8)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(9)"
    ],
    "https://www.leighleat.com/pages/18": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(5)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(6)"
    ],
    "https://www.leighleat.com/pages/19": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(5)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(6)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(7)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(8)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(9)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(10)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(11)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(12)"
    ],
    "https://www.leighleat.com/pages/20": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(5)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(6)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(7)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(8)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(9)"
    ],
    "https://www.leighleat.com/pages/21": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(5)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(6)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(7)"
    ],
    "https://www.leighleat.com/pages/23": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(5)"
    ],
    "https://www.leighleat.com/pages/24": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > h1",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(5)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(6)"
    ],
    "https://www.leighleat.com/pages/25": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(5)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(6)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(7)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(8)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(9)"
    ],
    "https://www.leighleat.com/pages/26": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(5)"
    ],
    "https://www.leighleat.com/pages/27": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(5)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(6)"
    ],
    "https://www.leighleat.com/pages/28": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p"
    ],
    "https://www.leighleat.com/pages/29": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(4)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(5)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(6)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(7)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(8)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(9)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p:nth-child(10)"
    ],
    "https://www.leighleat.com/pages/30": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p"
    ],
    "https://www.leighleat.com/pages/31": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p"
    ],
    "https://www.leighleat.com/pages/32": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)"
    ],
    "https://www.leighleat.com/pages/33": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(10)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(11)"
    ],
    "https://www.leighleat.com/pages/34": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(10)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(11)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(12)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(13)"
    ],
    "https://www.leighleat.com/pages/36": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(10)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(11)"
    ],
    "https://www.leighleat.com/pages/37": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)"
    ],
    "https://www.leighleat.com/pages/38": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(10)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(11)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(12)"
    ],
    "https://www.leighleat.com/pages/39": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(10)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(11)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(12)"
    ],
    "https://www.leighleat.com/pages/40": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(10)"
    ],
    "https://www.leighleat.com/pages/41": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(10)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(11)"
    ],
    "https://www.leighleat.com/pages/42": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(10)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(11)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(12)"
    ],
    "https://www.leighleat.com/pages/43": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(10)"
    ],
    "https://www.leighleat.com/pages/44": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(10)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(11)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(12)"
    ],
    "https://www.leighleat.com/pages/45": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)"
    ],
    "https://www.leighleat.com/pages/46": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(10)"
    ],
    "https://www.leighleat.com/pages/47": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)"
    ],
    "https://www.leighleat.com/pages/48": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)"
    ],
    "https://www.leighleat.com/pages/49": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)"
    ],
    "https://www.leighleat.com/pages/50": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)"
    ],
    "https://www.leighleat.com/pages/51": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(10)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(11)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(12)"
    ],
    "https://www.leighleat.com/pages/52": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(10)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(11)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(12)"
    ],
    "https://www.leighleat.com/pages/53": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(10)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(11)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(12)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(13)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(14)"
    ],
    "https://www.leighleat.com/pages/54": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(10)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(11)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(12)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(13)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(14)"
    ],
    "https://www.leighleat.com/pages/55": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(8)",
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(9)"
    ],
    "https://www.leighleat.com/pages/488": [
        "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
    ]
}

# %%
AN_BHEAN_CHAOINTE = {
    "https://www.leighleat.com/pages/15": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > h1",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p:nth-child(2)"
    ],
    "https://www.leighleat.com/pages/175": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/177": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/178": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/188": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/217": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/222": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/257": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/261": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/272": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/274": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/277": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/283": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/285": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/291": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/293": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/299": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/307": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/315": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/318": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/320": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/323": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/324": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/325": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/326": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/518": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ]
}

# %%
CLIONA = {
    "https://www.leighleat.com/pages/2177": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > h1",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2178": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > h1",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p:nth-child(1)",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p:nth-child(2)",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p:nth-child(3)",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/2179": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2181": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2180": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2182": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2183": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > h1",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2184": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2185": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2187": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2188": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > h1",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2189": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2190": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2191": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2192": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2193": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2194": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > h1",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2195": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2196": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2197": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2198": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > h1",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2199": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2200": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2201": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2202": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2203": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2204": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2205": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > h1",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2206": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2207": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2208": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2209": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2210": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2211": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > h1",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2212": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2213": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2214": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2215": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2216": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/2217": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ]
}

# %%
JIMIN = {
    "https://www.leighleat.com/pages/181": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > h1",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/182": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p:nth-child(3)"
    ],
    "https://www.leighleat.com/pages/183": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p:nth-child(3)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/189": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p:nth-child(3)"
    ],
    "https://www.leighleat.com/pages/190": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p"
    ],
    "https://www.leighleat.com/pages/191": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > h1",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p"
    ],
    "https://www.leighleat.com/pages/192": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p"
    ],
    "https://www.leighleat.com/pages/193": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p"
    ],
    "https://www.leighleat.com/pages/194": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p"
    ],
    "https://www.leighleat.com/pages/195": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p"
    ],
    "https://www.leighleat.com/pages/197": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p:nth-child(2)",
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p:nth-child(3)"
    ],
    "https://www.leighleat.com/pages/198": [
        "#ajax-page-container > div.g-hidden-lg-down > div.page-text.fill-page > div > p"
    ],
    "https://www.leighleat.com/pages/199": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > h2",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/200": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/201": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(5)"
    ],
    "https://www.leighleat.com/pages/203": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)",
    ],
    "https://www.leighleat.com/pages/204": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/205": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/206": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/207": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > h2",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(5)"
    ],
    "https://www.leighleat.com/pages/208": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(5)"
    ],
    "https://www.leighleat.com/pages/209": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/210": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(5)"
    ],
    "https://www.leighleat.com/pages/211": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/212": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/213": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/215": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/216": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/218": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > h2",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/219": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/220": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/221": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(5)"
    ],
    "https://www.leighleat.com/pages/223": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/224": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/225": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(5)"
    ],
    "https://www.leighleat.com/pages/227": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/228": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/229": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/230": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > h2",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/231": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/232": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/233": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/234": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/235": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/236": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/238": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/239": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/240": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/241": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/243": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/244": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/245": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/246": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/247": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/248": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/249": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > h2",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/250": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/251": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/252": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/253": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/254": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/256": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/258": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/259": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/260": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/262": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > h2",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/263": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/264": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/265": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/266": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/269": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/270": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/271": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/273": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > h2",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/275": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/276": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/278": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/280": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/281": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/282": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/284": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/286": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > h2",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/287": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/289": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/292": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/294": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/295": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/296": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > h2",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/297": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/298": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/300": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/301": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/303": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/304": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/305": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/306": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/308": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/309": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/310": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/311": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > h2",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)"
    ],
    "https://www.leighleat.com/pages/312": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/313": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/316": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/317": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/319": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ],
    "https://www.leighleat.com/pages/321": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(3)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(4)",
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p:nth-child(5)"
    ],
    "https://www.leighleat.com/pages/516": [
        "#ajax-page-container > div.small-screen > div > div.row.mobile-page-text > p"
    ]
}

# %%
FABHALSCEALTA = {
    "LEON_BAINEANN": {
        "https://www.leighleat.com/pages/87": [
            "#ajax-page-container > div.g-hidden-lg-down > div.page-text.top > h1",
            "#ajax-page-container > div.g-hidden-lg-down > div.page-text.top > p"
        ],
        "https://www.leighleat.com/pages/88": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ]
    },
    "GAOTH_AGUS_GRIAN": {
        "https://www.leighleat.com/pages/75": [
            "#ajax-page-container > div.g-hidden-lg-down > div.page-text.right > h1",
            "#ajax-page-container > div.g-hidden-lg-down > div.page-text.right > p"
        ],
        "https://www.leighleat.com/pages/78": [
            "#ajax-page-container > div.g-hidden-lg-down > div.page-text.left > p"
        ]
    },
    "COILEACH": {
        "https://www.leighleat.com/pages/64": [
            "#ajax-page-container > div.g-hidden-lg-down > div.page-text.right > h1",
            "#ajax-page-container > div.g-hidden-lg-down > div.page-text.right > p"
        ],
        "https://www.leighleat.com/pages/65": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ]
    },
    "FIA_FIREANN": {
        "https://www.leighleat.com/pages/56": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)"
        ],
        "https://www.leighleat.com/pages/57": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ]
    },
    "CAILIN_BLEANAI": {
        "https://www.leighleat.com/pages/58": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)"
        ],
        "https://www.leighleat.com/pages/59": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)"
        ]
    },
    "CAT_AGUS_LUCHA": {
        "https://www.leighleat.com/pages/60": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ],
        "https://www.leighleat.com/pages/61": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ]
    },
    "FEAR_AGUS_INIONACHA": {
        "https://www.leighleat.com/pages/62": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ],
        "https://www.leighleat.com/pages/63": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ]
    },
    "AN_GHE": {
        "https://www.leighleat.com/pages/80": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ],
        "https://www.leighleat.com/pages/82": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ]
    },
    "GIORRIA_AGUS_CAIRDE": {
        "https://www.leighleat.com/pages/84": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ],
        "https://www.leighleat.com/pages/86": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ]
    },
    "LUCH_TUAITHE": {
        "https://www.leighleat.com/pages/89": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ],
        "https://www.leighleat.com/pages/90": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ]
    },
    "MACTIRE_MATHAIR_AGUS_LEANBH": {
        "https://www.leighleat.com/pages/103": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ],
        "https://www.leighleat.com/pages/105": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ]
    },
    "MACTIRE_GLEASTA_MAR_CHAORA": {
        "https://www.leighleat.com/pages/106": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ],
        "https://www.leighleat.com/pages/107": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ]
    },
    "MADRA_AGUS_A_SCATH": {
        "https://www.leighleat.com/pages/108": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ],
        "https://www.leighleat.com/pages/109": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)"
        ]
    },
    "MADRA_SA_MHAINSEAR": {
        "https://www.leighleat.com/pages/111": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)"
        ],
        "https://www.leighleat.com/pages/185": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ]
    },
    "MEANNAN_AGUS_MACTIRE": {
        "https://www.leighleat.com/pages/113": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ],
        "https://www.leighleat.com/pages/114": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)"
        ]
    },
    "SIONNACH_AGUS_PREACHAN": {
        "https://www.leighleat.com/pages/115": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ],
        "https://www.leighleat.com/pages/116": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ]
    },
    "SPRIONLOIR": {
        "https://www.leighleat.com/pages/117": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ],
        "https://www.leighleat.com/pages/118": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)"
        ]
    },
    "IOLAR_AGUS_COILIGH": {
        "https://www.leighleat.com/pages/119": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)"
        ],
        "https://www.leighleat.com/pages/120": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(3)",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p:nth-child(4)"
        ]
    },
    "CAT_AGUS_SIONNACH": {
        "https://www.leighleat.com/pages/186": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > h2",
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ],
        "https://www.leighleat.com/pages/187": [
            "#ajax-page-container > div.small-screen > div.row.mobile-page-text.white-bg > p"
        ]
    }
}

# %%
DANTA = {
    "https://www.leighleat.com/poems/55": [
        "#full-screen-container > div > div.g-hidden-lg-down.poem-container.left.non-overlapping > div > h1",
        "#full-screen-container > div > div.g-hidden-lg-down.poem-container.left.non-overlapping > div > span > p:nth-child(1)"
    ],
    "https://www.leighleat.com/poems/80": [
        "#full-screen-container > div > div.g-hidden-lg-down.poem-container.left.non-overlapping > div > h1",
        "#full-screen-container > div > div.small-screen.text-center > div.row.mobile-page-text.white-bg > p:nth-child(3)",
        "#full-screen-container > div > div.small-screen.text-center > div.row.mobile-page-text.white-bg > p:nth-child(4)",
        "#full-screen-container > div > div.small-screen.text-center > div.row.mobile-page-text.white-bg > p:nth-child(5)",
        "#full-screen-container > div > div.small-screen.text-center > div.row.mobile-page-text.white-bg > p:nth-child(6)",
        "#full-screen-container > div > div.small-screen.text-center > div.row.mobile-page-text.white-bg > p:nth-child(7)",
        "#full-screen-container > div > div.small-screen.text-center > div.row.mobile-page-text.white-bg > p:nth-child(8)"
    ],
    "https://www.leighleat.com/poems/79": [
        "#full-screen-container > div > div.g-hidden-lg-down.poem-container.left.non-overlapping > div > h1",
        "#full-screen-container > div > div.g-hidden-lg-down.poem-container.left.non-overlapping > div > span > p:nth-child(1)"
    ]
}

# %%
import requests
from bs4 import BeautifulSoup

def get_selector_from_url(url, selector):
    req = requests.get(url)
    assert req.status_code == 200, f"Failed to fetch {url}"
    soup = BeautifulSoup(req.text, 'html.parser')
    element = soup.select(selector)
    assert len(element) == 1, f"Selector {selector} did not match exactly one element in {url}"
    return element[0].get_text()

# %%
import hashlib

def get_hash_from_url(text):
    return hashlib.md5(text.encode()).hexdigest()

def get_selectors_from_dict(url_dict, url):
    if not url in url_dict:
        raise ValueError(f"URL {url} not found in the provided dictionary.")
    item = url_dict[url]

    req = requests.get(url)
    assert req.status_code == 200, f"Failed to fetch {url}"
    soup = BeautifulSoup(req.text, 'html.parser')

    result = {
        "url": url,
        "paragraphs": []
    }

    for aud in soup.find_all("audio"):
        for source in aud.find_all("source"):
            if source.has_attr("src"):
                result["audio"] = "https://www.leighleat.com" + source["src"]

    for selector in item:
        element = soup.select(selector)
        assert len(element) == 1, f"Selector {selector} did not match exactly one element in {url}"
        hash = get_hash_from_url(element[0].get_text())
        result["paragraphs"].append({
            "text": element[0].get_text(),
            "selector": selector,
            "hash": hash
        })
    return result

# %%
import json

pages = []
for page in MALLACHTAI:
    pages.append(get_selectors_from_dict(MALLACHTAI, page))
with open("mallachtaí.json", "w") as f:
    f.write(json.dumps(pages, indent=4))

# %%
pages = []
for page in AN_BHEAN_CHAOINTE:
    pages.append(get_selectors_from_dict(AN_BHEAN_CHAOINTE, page))
with open("an_bhean_chaointe.json", "w") as f:
    f.write(json.dumps(pages, indent=4))

# %%
pages = []
for page in CLIONA:
    pages.append(get_selectors_from_dict(CLIONA, page))
with open("cliona.json", "w") as f:
    f.write(json.dumps(pages, indent=4))

# %%
pages = []
for page in JIMIN:
    pages.append(get_selectors_from_dict(JIMIN, page))
with open("jimin.json", "w") as f:
    f.write(json.dumps(pages, indent=4))

# %%
pages = {}
for item in FABHALSCEALTA:
    pages[item] = []
    for page in FABHALSCEALTA[item]:
        pages[item].append(get_selectors_from_dict(FABHALSCEALTA[item], page))
    with open("fabhalscealta.json", "w") as f:
        f.write(json.dumps(pages, indent=4))

# %%
def mkbbox(x, y, width, height):
    return f"{x} {y} {width+x} {height+y}"

# %%
mkbbox(x= 244, y= 641, width= 662, height= 141)
# Out:
# '244 641 906 782'
