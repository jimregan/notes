# %% [markdown]
# playlist is [here](https://ljud1-cdn.sr.se/lc/p4dala/p4dala_32.pls)

# %% [markdown]
# ```javascript
# fetch("https://ljud1-cdn.sr.se/lc/p4dala/p4dala_192.pls", {
#   "headers": {
#     "accept": "*/*",
#     "accept-language": "en-IE,en-GB;q=0.9,en-US;q=0.8,en;q=0.7,sv;q=0.6",
#     "if-modified-since": "Thu, 20 Nov 2025 14:45:04 GMT",
#     "priority": "u=1, i",
#     "sec-ch-ua": "\"Chromium\";v=\"142\", \"Google Chrome\";v=\"142\", \"Not_A Brand\";v=\"99\"",
#     "sec-ch-ua-mobile": "?0",
#     "sec-ch-ua-platform": "\"macOS\"",
#     "sec-fetch-dest": "empty",
#     "sec-fetch-mode": "cors",
#     "sec-fetch-site": "cross-site"
#   },
#   "referrer": "https://www.sverigesradio.se/",
#   "body": null,
#   "method": "GET",
#   "mode": "cors",
#   "credentials": "omit"
# });
# ```
#
# Next:
# ```
# "if-modified-since": "Thu, 20 Nov 2025 14:45:10 GMT",
# ```
#
# Next:
# ```
# "if-modified-since": "Thu, 20 Nov 2025 14:45:17 GMT",
# ```
#
# Next:
# ```
# "if-modified-since": "Thu, 20 Nov 2025 14:45:23 GMT",
# ```

# %% [markdown]
# ```
# fetch("https://www.sverigesradio.se/api/trpc/player.stream?batch=1&input=%7B%220%22%3A%7B%22json%22%3A%7B%22id%22%3A%22223%22%7D%7D%7D", {
#   "headers": {
#     "accept": "*/*",
#     "accept-language": "en-IE,en-GB;q=0.9,en-US;q=0.8,en;q=0.7,sv;q=0.6",
#     "baggage": "sentry-environment=production,sentry-release=1.281.0,sentry-public_key=beb140bb5e79c127c513c807e6945a17,sentry-trace_id=8fd1f3f07db242f9b5cdde304132702e,sentry-org_id=4509044191854592,sentry-sampled=false,sentry-sample_rand=0.9736451760228032,sentry-sample_rate=0.01",
#     "priority": "u=1, i",
#     "sec-ch-ua": "\"Chromium\";v=\"142\", \"Google Chrome\";v=\"142\", \"Not_A Brand\";v=\"99\"",
#     "sec-ch-ua-mobile": "?0",
#     "sec-ch-ua-platform": "\"macOS\"",
#     "sec-fetch-dest": "empty",
#     "sec-fetch-mode": "cors",
#     "sec-fetch-site": "same-origin",
#     "sentry-trace": "8fd1f3f07db242f9b5cdde304132702e-89d1840c54410c5a-0"
#   },
#   "referrer": "https://www.sverigesradio.se/kanaler/hitta-lokal-kanal",
#   "body": null,
#   "method": "GET",
#   "mode": "cors",
#   "credentials": "include"
# });
# ```

# %%
PLAYING_NOW = "https://api.sr.se/api/v2/playlists/rightnow?channelid=213"

# %% [markdown]
# ```xml
# <sr>
#     <playlist>
#         <previoussong>
#             <title>Moviestar (Engelsk version)</title>
#             <description>Harpo - Moviestar (Engelsk version)</description>
#             <artist>Harpo</artist>
#             <composer/>
#             <conductor/>
#             <albumname>Moviestar</albumname>
#             <recordlabel>EMI</recordlabel>
#             <producer/>
#             <starttimeutc>2025-11-20T15:14:45Z</starttimeutc>
#             <stoptimeutc>2025-11-20T15:17:56Z</stoptimeutc>
#         </previoussong>
#         <song>
#             <title>The One</title>
#             <description>Mathias Melo - The One</description>
#             <artist>Mathias Melo</artist>
#             <composer>Emil Sällström</composer>
#             <conductor/>
#             <albumname/>
#             <recordlabel>Amuse</recordlabel>
#             <producer/>
#             <starttimeutc>2025-11-20T15:21:47Z</starttimeutc>
#             <stoptimeutc>2025-11-20T15:25:10Z</stoptimeutc>
#         </song>
#         <channel id="213" name="P4 Blekinge"/>
#     </playlist>
# </sr>
# ```
