# %% [markdown]
# [Saldo's morphology](https://spraakbanken.gu.se/en/resources/saldom)
#
# ```bibtex
# @misc{https://doi.org/10.23695/agcm-ny22,
#   doi = {10.23695/AGCM-NY22},
#   url = {https://spraakbanken.gu.se/resurser/saldom},
#   author = {{Språkbanken Text}},
#   keywords = {Language Technology (Computational Linguistics)},
#   language = {sv},
#   title = {SALDOs morfologi},
#   publisher = {Språkbanken Text},
#   year = {2024},
#   copyright = {Creative Commons Attribution 4.0 International}
# }
# ```

# %%
# !wget https://svn.spraakbanken.gu.se/sb-arkiv/pub/lmf/saldom/saldom.xml
# Out:
# --2026-01-08 13:01:52--  https://svn.spraakbanken.gu.se/sb-arkiv/pub/lmf/saldom/saldom.xml
# Resolving svn.spraakbanken.gu.se (svn.spraakbanken.gu.se)... 130.241.170.166
# Connecting to svn.spraakbanken.gu.se (svn.spraakbanken.gu.se)|130.241.170.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 254107385 (242M) [text/xml]
# Saving to: ‘saldom.xml’
#
# saldom.xml          100%[===================>] 242.33M  27.6MB/s    in 9.8s
#
# 2026-01-08 13:02:03 (24.8 MB/s) - ‘saldom.xml’ saved [254107385/254107385]
