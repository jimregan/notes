# %% [markdown]
# The input is the output from MFA, so tiers have specific names.

# %%
from praatio import textgrid

def get_phone_sequences(tgfile):
    tg = textgrid.openTextgrid(tgfile, False)

    def get_tier_list(tiername):
        utterances = []
        tier = tg.getTier(tiername)
        for entry in tier.entries:
            text = entry.label.strip()
            if text == "":
                continue
            utterance = {}
            utterance["start"] = entry.start
            utterance["end"] = entry.end
            utterance["text"] = text
            utterances.append(utterance)
        return utterances
    
    utterances = get_tier_list("utterances")
    words = get_tier_list("words")
    phones = get_tier_list("phones")

    i = j = k = 0
    while i < len(utterances):
        utterance = utterances[i]
        utterance["words"] = []

        while j < len(words) and words[j]["end"] <= utterance["end"]:
            word = words[j]
            if word["end"] <= utterance["end"]:
                word["phones"] = []

                while k < len(phones) and phones[k]["end"] <= word["end"]:
                    phone = phones[k]
                    if phone["end"] <= word["end"]:
                        word["phones"].append(phone)
                    k += 1

                utterance["words"].append(word)
            j += 1
        i += 1

    return utterances

# %%
ps = get_phone_sequences("/Users/joregan/Desktop/hsi_5_0718_209_001_main.TextGrid")

# %%
def get_dictionary(phone_sequence):
    lines = set()
    for utterance in phone_sequence:
        for word in utterance["words"]:
            phone_seq = [p["text"] for p in word["phones"]]
            lines.add(f"{word['text']}\t{' '.join(phone_seq)}")
    return list(lines)

# %%
MAPPING = """
AA0 ɑː
AA1 ˈɑː
AA2 ˌɑː
AE0 æ
AE1 ˈæ
AE2 ˌæ
AH0 ə
AH0 ɐ
AH1 ˈʌ
AH2 ˌʌ
AO0 ɔː
AO1 ˈɔː
AO2 ˌɔː
AW0 aʊ
AW1 ˈaʊ
AW2 ˌaʊ
AY0 aɪ
AY1 ˈaɪ
AY2 ˌaɪ
B b
CH tʃ
D d
DH ð
EH0 ɛ
EH1 ˈɛ
EH2 ˌɛ
ER0 ɚ
ER1 ˈɜː
ER2 ˌɜː
EY0 eɪ
EY1 ˈeɪ
EY2 ˌeɪ
F f
G ɡ
HH h
IH0 ɪ
IH1 ˈɪ
IH2 ˌɪ
IY0 i
IY1 ˈiː
IY2 ˌiː
JH dʒ
K k
L l
M m
N n
NG ŋ
OW0 oʊ
OW1 ˈoʊ
OW2 ˌoʊ
OY0 ɔɪ
OY1 ˈɔɪ
OY2 ˌɔɪ
P p
R ɹ
S s
SH ʃ
T t
TH θ
UH0 ʊ
UH1 ˈʊ
UH2 ˌʊ
UW0 uː
UW1 ˈuː
UW2 ˌuː
V v
W w
Y j
Z z
ZH ʒ
"""

# %%
cmudict_to_espeak = {}
for line in MAPPING.split("\n"):
    if line == "":
        continue
    line = line.strip()
    parts = line.split(" ")

    if len(parts) != 2:
        print(line)
        continue
    k, v = line.split(" ")
    if not k in cmudict_to_espeak:
        cmudict_to_espeak[k] = v

# %%
def espeakify(phlist, sep=""):
    output = []
    if phlist == ["spn"] or phlist == ["sil"]:
        return ""
    for phone in phlist:
        if phone == "":
            continue
        if " " in phone:
            output += [cmudict_to_espeak[x] for x in phone.split(" ")]
        else:
            output.append(cmudict_to_espeak[phone])
    return sep.join(output)

# %%
import re

def get_utterances_like_espeak(phone_sequence):
    pairs = {}
    for utterance in phone_sequence:
        words = []
        text = utterance["text"]
        if text.startswith("[") and text.endswith("]"):
            continue
        for word in utterance["words"]:
            phones = [x["text"] for x in word["phones"]]
            phword = espeakify(phones)
            words.append(phword)
        joined = " ".join(words)
        joined = re.sub("  +", " ", joined)
        pairs[text] = joined
    return pairs

# %%
get_utterances_like_espeak(ps)
# Out:
# {"Yeah, but we we can't walk around in the entire room.": 'jˈæ bˈʌt wˈiː wˈiː kˈɑːnt wˈɔːk əɹˈaʊnd ɪn ɪntˈaɪɚ ɹˈuːm',
#  'Yeah.': 'jˈæ',
#  'Ah, there you are. And you...': 'ˈɑː ðˈɛɹ jˈuː ˈɑːɹ ən jˈuː',
#  'Yes.': 'jˈɛs',
#  'So it is so nice that you came here and I just want to... I just have to brag of it. Ah, you see this couch and and the...': 'sˈoʊ ˈɪt ˈɪ sˈoʊ nˈaɪs ðˈæt jˈuː kˈeɪm hˈiːɹ ˈænd ˈaɪ dʒˈʌst wˈɑːn tˈuː ˈaɪ dʒˈʌst hˈæv tə bɹˈæɡ əv ˈɪt ˈæ jˈuː sˈiː ðˈɪs kˈaʊtʃ ˈɑːn ˈɑːnd ə',
#  'What do you call this one in Swedish eh or in English, fåtölj?': 'wˈʌt jˈuː kˈɔːl ðˈɪs wˈʌn ɪn swˈiːdɪʃ ˈɛ ˈɔːɹ ɪn ˈɪŋlɪʃ fˈoʊtˈʌlj',
#  "Chair yes this- armchair, yes, this armchair eh is really really amazing because it's a Danish designer who's uh really famous. He's called... his name is eh Jensen.": 'tʃˈɛɹ jˈɛs ðɪs ˈɑːɹmtʃˌɛɹ jˈɛs ðˈɪs ˈɑːɹmtʃˌɛɹ ˈɛ ˈɪs ɹˈiːli ɹˈiːli əmˈeɪsɪŋ bɪkˈɑːz ɪts ə dˈeɪnɪʃ dɪsˈaɪnɚ hˈuːs ˈɛ ɹˈiːli fˈeɪməs hˈiːs kˈɔːld hɪz nˈeɪm ˈɪz ˈɛ jˈɛnsən',
#  "And he's also doing uh like... other stuff, like like the vases there. He designed those.": 'ˈæn hˈiːz ˈɔːlsoʊ dˈuːɪŋ ə lˈaɪk ˈʌðə stˈʌf lˈaɪ lˈaɪk ðə vˈɑːsɪs ðˈɛɹ hˈiː dɪsˈaɪnd ðˈoʊs',
#  'Eh... the... Those three.': 'ˈɛ ði ðˈoʊz θɹˈiː',
#  'Eh, so he designed them and... just various colors, but he designed them.': 'ˈɛ sˈoʊ ˈiː dɪsˈaɪnd ˈɛm ˈænd dʒˈʌst vˈɛɹiəs kˈʌlɚs bˈʌt hˈiː dɪsˈaɪnd əm',
#  "And I really like the Danish em designers because they're doing so simple things and and yet so beautiful.": 'ˈænd ˈaɪ ɹˈiːli lˈaɪk ðə dˈeɪnɪʃ ˈɛm dɪzˈaɪnɚz bəkˈɑːs ðˈɛɹ dˈuːɪŋ sˈoʊ sˈɪmpəl θˈɪŋs ən ənd jˈɛt sˈoʊ bjˈuːtəfəl',
#  "Ah, and that's Danish as well, the table.": 'hˈæ hˈænd ðˈæts dˈeɪnɪʃ ˈæz wˈɛl ðə tˈeɪbəl',
#  'Ah, of course... [sniff] really expensive, but what do you do when you love something?': 'ˈæ ˈʌv kˈɔːɹs ɹˈiːli hɪkspˈɛnsɪv bˈʌt hwˈʌt dˈuː jˈuː dˈuː wˈɛn jˈuː lˈʌv sˈʌmθɪŋ',
#  'Ah and that table there is actually from the fifties.': 'hˈæ ˈænd ðˈæt tˈeɪbəl ðˈɛɹ ˈɪz ˈækʃəli fɹˈʌm ðə fˈɪftiz',
#  "Ah and his name, the designer's name, was Kristiansen.": 'hˈæ hˈænd hˈɪz nˈeɪm ðə dɪzˈaɪnɚz nˈeɪm wˈɑːz kɹˈɪstʃɛnsɛn',
#  "And unfortunately, actually, there are not... a lot of female designers that... that are famous. But if you look at the armchair over there by the desk, that's actually a female designer.": 'hˈænd hənfˈɔːɹtʃnətli hˈæktʃli ðˈɛ ˈæɹ nˈɑːt hə lˈɑːt ˈʌv fˈiːmˌeɪl dɪzˈaɪnɚz ðˈæt ðˈæt ˈɑːɹ fˈeɪməs bˈʌt ˈɪf jˈuː lˈʊk ˈæt ðə ˈɑːɹmtʃˌɛɹ ˈoʊvɚ ðˈɛɹ bˈaɪ ðə dˈɛsk ðˈæts ˈækʃəli ə fˈiːmˌeɪl dɪzˈaɪnɚ',
#  "Yes, of course. [laughter] I'm all into Danish stuff when it comes to furnitures, but eh [breath] I'm I'm also into like the little statue...": 'jˈɛs əv kˈɔːɹs hˈaɪm hˈɔːl ɪntə dˈeɪnɪʃ stˈʌf hwˈɛn ˈɪt kˈʌmz tə fˈʌnɪtʃɚz bˈʌt hˈɛ ˈaɪm hˈaɪm ˈɔːlsoʊ hˈɪntuː lˈaɪk ðə lˈɪtəl stˈætʃˌuː',
#  "Eh that one, the female, ah the curvy female, [sniff] that's actually a symbol of em...": 'hˈɛ ðˈæt wˈʌn ðə fˈiːmˌeɪl ˈæ ðə kˈɜːbi fˈiːmˌeɪl ðˈæts ˈækʃəli hə sˈɪmbəl ˈʌv ˈɛm',
#  'Oh, I lost the words.': 'ˈoʊ ˈaɪ lˈɑːst ðə wˈɜːdz',
#  'Uh.': 'hˈɑː',
#  'A symbol of fertility.': 'hə sˈɪmbəl ˈʌv fɚtˈɪləti',
#  'Is a woman fertile?': 'ˈɪz ə wˈʊmən fɚtˈaɪl',
#  'Yes, yes, she is.': 'jˈɛs jˈɛs ʃˈiː hˈɪz',
#  "Of of fertility, so that's supposed to be a Peruvian ah fertility symbol.": 'hˈʌv ˈʌv fətˈɪləti sˈoʊ ðˈæts səpˈoʊzd tə bi hə pɚˈuːən ˈæ fətˈɪləti sˈɪmbəl',
#  'Eh.': 'ˈɛ',
#  "Unfortunately, the copy because you you can't bring the real stuff out.": 'ənfˈɔːɹtʃənətli ðə kˈɑːpi bɪkˈɔːz jˈuː jˈuː kˈɑːnt bɹˈɪŋ ðə ɹˈiːl stˈʌf hˈaʊ',
#  'Y- yes, I went to Picamacho ahm... and eh then I went the eh Inca Trail, ah which was [labial_trill] so exciting.': 'j jˈɛs ˈaɪ wˈɛnt tˈuː pˈiːkəmˌætʃuː ˈɑːm hˈæn hˈɛ ðə hˈaɪ wˈɛn ðə ˈɛ ˈɪŋkə tɹˈeɪl ə vˈɪtʃ vˈɔːz sˈoʊ ɪksˈaɪtɪŋ',
#  'Ah, sorry, I just had a text message.': 'ˈɑː sˈɑːɹi hˈaɪ dʒˈʌst hˈæd ə tˈɛkst mˈɛsɪdʒ',
#  "And em no, that was really interesting. And, and then, then, of course, I'm also into more modern stuff like the hand there, ah which I really enjoy because it's": 'ˈænd ˈɛm nˈoʊ ðˈæt wəz ɹˈiːli ˈɪntɹɪstɪŋ hˈænd hˈænd ðˈɛd ðˈɛn ˈʌv kˈɔːɹs ˈaɪ ˈɑːlsoʊ hɪntˈuː mˈɔːɹ mˈɑːdən stˈʌf lˈaɪ ðə hˈænd ðˈɛɹ ˈæ hwˈɪtʃ hˈaɪ ɹˈiːli ɪndʒˈɔɪ vɪkˈɔːz hɪts',
#  "at the same time eh demanding and asking you could you give me or you have to give me so I think it's a lot of stuff in it and of course I can also put some bananas in it if I want to.": 'ˈæt ðə sˈeɪm tˈaɪm ˈɛ dɪmˈɑːndɪŋ ˈænd ˈɑːskɪŋ jˈuː kˈʊd jˈuː ɡˈɪv mˈiː ˈɔːɹ jˈuː hˈæv tə ɡˈɪv mˈiː sˈoʊ ˈaɪ θˈɪŋk hɪts ə lˈɑːt ˈʌv stˈʌf ˈɪn ˈɪt hˈænd ˈʌv kˈɔːɹs ˈaɪ kən ˈɔːlsoʊ pˈʊt sˈʌm bənˈɑːnəz hɪn hɪt hɪf ˈaɪ wˈɑːnt tə',
#  'Yes. So ah...': 'jˈɛs sˈoʊ ˈæ',
#  "Yes, of course, because I'm also into art and eh [exhale] of course you know you you can't buy the actual yeah the the ones you want like a Matisse or something but that one is really really interesting and that's one of my most valuable paintings": 'jˈɛs əv kˈɔːɹs bɪkˈʌz ˈaɪm ˈɔːlsoʊ hɪntˈuː ˈɑːɹt hˈænd ˈɛ ˈʌv kˈɔːɹs ˈuː nˈoʊ jˈuː jˈuː kˈɑːnt bˈaɪ ði hˈæktʃəwəl jˈɪ ðə ðə vˈʌnz jˈuː wˈɑːnt lˈaɪk ə mˈætis hɚ sˈʌmθɪŋ bˈʌt ðˈæt wˈʌn ˈɪz ɹˈiːli ɹˈiːli ˈɪntɹɪstɪŋ ˈæn ðˈæts wˈʌn ˈʌv mˈaɪ mˈoʊst bˈæljuːvəl pˈeɪntɪŋz',
#  "eh because it's eh made by an American eh artist who lived in the nineteenth century and he described a lot of eh the movement towards the west of the country.": 'hˈɛ bɪkəz hɪts ˈɛ mˈeɪd bˈaɪ ən əmˈɛɹɪkən hˈɛ ˈɑːɹtɪst hˈuː lˈɪvd ˈɪn ðə nˈaɪntˈiːnθ sˈɛntʃɚi hˈænd hˈiː dɪskɹˈaɪbd ə lˈɑːt ˈʌv ˈɛ ðə mˈuːvmənt təwˈɔːɹdz ðə wˈɛst ˈʌv ðə kˈʌntɹi',
#  "So that one, eh I haven't bought it myself because [laughter] I could never afford to buy it, but I I inherited it.": 'sˈoʊ ðˈæt wˈʌn ˈɛ ˈaɪ hˈævənt bˈɔːt hɪt mˌaɪsˈɛlf bɪkˈɑːz hˈaɪ kˈʊd nˈɛvɚ əfˈɔːɹd tə bˈaɪ ɪt bˈʌt hˈaɪ hˈaɪ hɪnhˈɛɹətɪd ˈɪt',
#  "So it's eh really eh raising my insurance fees because uh it's really valuable.": 'sˈoʊ ɪts ˈɛ ɹˈiːli hˈɛ ɹˈeɪzɪŋ mˈaɪ ɪnʃˈʊɹəns fˈiːz bɪkˈʌz hˈɛ hɪts ɹˈiːli bˈæljəbəl',
#  "And em so that's the only painting I have that includes human beings because I'm more into landscapes and and I I'm very much into em darker stuff like that one.": 'hˈænd ˈɛm sˈoʊ ðˈæts ði ˈoʊnli pˈeɪntɪŋ ˈaɪ hˈæv ðˈæt ɪnklˈuːdz hjˈuːmən bˈiːɪŋz bɪkˈʌz ˈaɪm mˈɔːɹ ɪntˈuː lˈændskˌeɪps ˈæn hˈæn hˈaɪ hˈaɪm vˈɛɹi mˈʌtʃ hɪntˈuː hˈɛm dˈɑːɹkə stˈʌf lˈaɪk ðˈæt wˈʌn',
#  'Ah.': 'ˈæ',
#  "uh it's... it's a ship.": 'hˈʌ hˈɪts ɪts ˈeɪ ʃˈɪp',
#  'It could be a ship or it could be a ghost ship or something.': 'ˈɪt kˈʊd bi ə ʃˈɪp ˈɔːɹ ˈɪt kˈʊd bi ə ɡˈoʊst ʃˈɪp ɚ sˈʌmθɪŋ',
#  'Ahm.': 'ˈɑːm',
#  "And if you look to the left, you see th- there's a we- could be rocks or or like the Flying Dutchman, ah or the Pirates of Caribbean, of course, too.": 'ˈæn ˈɪf jˈuː lˈʊk tə ði lˈɛft jˈuː sˈiː ð ðˈɛɹz hˈæ wˈiː kˈʊd bi ɹˈɑːks ˈɔːɹ ˈɔːɹ lˈaɪk ðə flˈaɪɪŋ dˈʌtʃmən ˈæ hə ðə pˈaɪɹəts əv kˌɛɹɪvˈiːən əv kˈɔːɹs tˈuː',
#  'And... and you see this darkness coming and...': 'hˈænd ˈænd jˈuː sˈiː ðˈɪs dˈɑːɹknəs kˈʌmɪŋ hˈænd',
#  'killing the light.': 'kˈɪlɪŋ ðə lˈaɪt',
#  "And I ta- three- th- really think it's interesting because it's ah": 'ə hˈaɪ tˈæ θɹˈiː θ ɹˈiːli θˈɪŋk ɪts ˈɪntɹɪstɪŋ bɪkəz ɪts ə',
#  'it uh grabs you.': 'hɪ ˈɛ ɡɹˈæbz jˈuː',
#  "Yes, and and I I don't care that much about eh styles. I I I I want things that I like and enjoy to see, like for instance this lamp.": 'jˈɛs ˈæn hˈænd ˈaɪ hˈaɪ dˈoʊnt kˈɛ ðˈæt mˈʌtʃ əbˈaʊt hˈɛ ɛstˈaɪlz ˈaɪ hˈaɪ ˈaɪ hˈaɪ wˈɑːnt θˈɪŋz ðˈæt ˈaɪ lˈaɪ ˈænd ɪndʒˈɔɪ tɪ sˈiː lˈaɪk fɹɚ ˈɪnsəns ðˈɪs lˈæmp',
#  "It's totally out of, uh doesn't look like anything in this room.": 'ˈɪts tˈoʊtəli ˈaʊt ˈʌv ˈʌ dˈʌzənt lˈʊk lˈaɪk ˈɛniθˌɪŋ ɪn ðˈɪs ɹˈuːm',
#  "Ah but eh that's... so that's actually two things. The... the lower part, the lamp, it's eh ah that's quite modern. It's from the sixties, from a Swedish designer actually.": 'hˈæ bˈʌt hˈɛ ðˈæts sˈoʊ ðˈæts ˈækʃəli tˈuː θˈɪŋz ðə ðə lˈoʊə pˈɑːɹt ðə lˈæmp ˈɪts ˈɛ ə ðˈæts kwˈaɪt mˈɑːdən hɪts fɹˈʌm ðə sˈɪkstiz fɹˈʌm ə swˈiːdɪʃ dɪzˈaɪnɚ hˈæktʃli',
#  'And the... [noise] what do you call that?': 'hˈænd ðə vˈʌ d hˈuː kˈɔːl ðˈæt',
#  "The [spn] cover or wh- wh- whatever you call it, that's actually [laugh] from my grandparents' house. So I I mixed those.": 'ðə kˈʌvɚ ˈɔːɹ hw w wˌʌtˈɛvɚ jˈuː kˈɔːl ɪt ðˈæts ˈækʃəli fɹˈʌm mˈaɪ ɡɹˈændpˌɛɹəntshˈaʊs sˈoʊ ˈaɪ hˈaɪ mˈɪks ðˈoʊz',
#  "Yes. Yes, I I think it's nice to have v- various things.": 'jˈɛs jˈɛs ˈaɪ ˈaɪ θˈɪŋk ɪts nˈaɪs tə hˈæb v bˈɛɹiəs θˈɪŋz',
#  'And then of course, uh [exhale] I... I... I always wonder why w- why I turned the sofa this way when I have this wonderful view.': 'hˈænd ðˈɛn ˈʌv kˈɔːɹs hˈɛ ˈaɪ ˈaɪ ˈaɪ ˈɔːlwiz wˈʌndə wˈaɪ w hwˈaɪ ˈaɪ tˈɜːnd ðə sˈoʊfə ðˈɪs wˈeɪ hwˈɛn ˈaɪ hˈæv ðˈɪs wˈʌndəfəl vjˈuː',
#  "Uh... Actually, I... I'm starting to think about refurnishing now that you... you came... because I should have it there.": 'hˈɛ ˈæktʃli ˈaɪ hˈaɪm stˈɑːtɪŋ tə θˈɪŋk əbˈaʊt ɹifˈʌnɪʃɪŋ nˈaʊ ðˈæt jˈuː jˈuː kˈeɪm bɪkəz hˈaɪ ʃˈʊd hˈæv ɪt ðˈɛɹ',
#  'What do you think?': 'vˈʌ dˈuː jˈuː θˈɪŋk',
#  "And then I could have, but I... I don't know where I should have the the TV then.": 'ən ðˈɛn ˈaɪ kˈʊd hˈæv bˈʌt ˈaɪ hˈaɪ dˈoʊn nˈoʊ wˈɛɹ ˈaɪ ʃˈʊd hˈæb ðə ðə tˈiːvˈiː ðˈɛn',
#  "But on the other hand, I I don't look much at TV and... the window could be my TV because there are a lot of eh deers outside and the um it's...": 'vˈʌt ˈɑːn ði ˈʌðɚ hˈænd ˈaɪ hˈaɪ dˈoʊnt lˈʊk mˈʌtʃ ˈæt tˈiːvˈiː hˈænd ðə wˈɪndoʊ kˈʊd bi mˈaɪ tˈiːbˈiː bɪkˈɔːz ðˈɛɹ ˈɑːɹ hə lˈɑːt ˈʌv ˈɛ dˈɪɹz hˈaʊtsˈaɪd ənd ðə ˈæm ɪts',
#  'Uh... s- sorry?': 'ˈɛ s sˈɑːɹi',
#  'Plants?': 'plˈæns',
#  "No, I just have that one because it's ehm... that one doesn't eh care eh need much care eh because I forget to water... I I don't know why I have the water eh w- water there, eh but you know, it's... it should be on the table, but eh maybe it's because...": 'nˈoʊ ˈaɪ dʒˈʌst hˈæv ðˈæt vˈʌn bɪkˈɑːz hˈɪts ˈɛm ðˈæt hwˈʌn dˈʌzənt ˈɛ kˈɛɹ ˈɛ nˈiːd mˈʌtʃ kˈɛɹ hˈɛ vɪkˈɑːz ˈaɪ fɚɡˈɛt tə wˈɔːtə hˈaɪ hˈaɪ dˈoʊn nˈoʊ wˈaɪ ˈaɪ hˈæv ðə wˈɔːtɛ ˈɛ w wˈɔːtɚ ðˈɛɹ ˈɛ bˈʌt jˈuː nˈoʊ ɪts ɪt ʃˈʊd bi ˈɑːn ðə tˈeɪbəl bˈʌt hˈɛ mˈeɪbi ˈɪts bɪkˈɔːz',
#  'because I read somewhere that you should have the water in the the water... watering thing eh to to get the...': 'bɪkəz ˈaɪ ɹˈɛd sˈʌmwˌɛɹ ðˈæt jˈuː ʃˈʊd hˈæv ðə wˈɔːtɚ ˈɪn ðə ðə wˈɔːtɚ wˈɔːtɚɪŋ θˈɪŋ ˈɛ tˈuː tˈuː ɡˈɪt ðə',
#  'what you call it?': 'vˈʌt hˈuː kˈɔːl ɪt',
#  'Chalk?': 'tʃˈɔːk',
#  'Calc?': 'kˌælk',
#  'Calcium!': 'kˈælsiəm',
#  "eh going down so you don't get too much on the plants.": 'hˈɛ ɡˈoʊɪŋ dˈaʊn sˈoʊ jˈuː dˈoʊnt ɡˈɪt tˈuː mˈʌtʃ ˈɑːn ðə plˈænts',
#  'But on the other hand, that that one can take anything.': 'bˈʌt ˈɑːn ði ˈʌðɚ hˈɑːnd ðˈæt ðˈæt vˈʌn kən tˈeɪk ˈɛniθˌɪŋ',
#  'Yeah, r- really nice that you came and...': 'jˈæ ɹ ɹˈɪli nˈaɪs ðˈæt ˈuː kˈeɪm ˈɑːnd',
#  'Yes, I hope so.': 'jˈɛs ˈaɪ hˈoʊp sˈoʊ',
#  'Oh my god, you can walk through walls.': 'ˈoʊ mˈaɪ ɡˈɑːd jˈuː kən wˈɔːk θɹˈuː wˈɔːlz',
#  'Was it a ghost?': 'vˈɔːz hɪt ə ɡˈoʊst'}
