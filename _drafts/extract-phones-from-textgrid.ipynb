# %% [markdown]
# The input is the output from MFA, so tiers have specific names.

# %%
from praatio import textgrid

def get_phone_sequences(tgfile):
    tg = textgrid.openTextgrid(tgfile, False)

    def get_tier_list(tiername):
        utterances = []
        tier = tg.getTier(tiername)
        for entry in tier.entries:
            text = entry.label.strip()
            if text == "":
                continue
            utterance = {}
            utterance["start"] = entry.start
            utterance["end"] = entry.end
            utterance["text"] = text
            utterances.append(utterance)
        return utterances
    
    utterances = get_tier_list("utterances")
    words = get_tier_list("words")
    phones = get_tier_list("phones")

    i = j = k = 0
    while i < len(utterances):
        utterance = utterances[i]
        utterance["words"] = []

        while j < len(words) and words[j]["end"] <= utterance["end"]:
            word = words[j]
            if word["end"] <= utterance["end"]:
                word["phones"] = []

                while k < len(phones) and phones[k]["end"] <= word["end"]:
                    phone = phones[k]
                    if phone["end"] <= word["end"]:
                        word["phones"].append(phone)
                    k += 1

                utterance["words"].append(word)
            j += 1
        i += 1

    return utterances

# %%
def get_dictionary(phone_sequence):
    lines = set()
    for utterance in phone_sequence:
        for word in utterance["words"]:
            phone_seq = [p["text"] for p in word["phones"]]
            lines.add(f"{word['text']}\t{' '.join(phone_seq)}")
    return list(lines)

# %%
MAPPING = """
AA0 ɑː
AA1 ˈɑː
AA2 ˌɑː
AE0 æ
AE1 ˈæ
AE2 ˌæ
AH0 ə
AH0 ɐ
AH1 ˈʌ
AH2 ˌʌ
AO0 ɔː
AO1 ˈɔː
AO2 ˌɔː
AW0 aʊ
AW1 ˈaʊ
AW2 ˌaʊ
AY0 aɪ
AY1 ˈaɪ
AY2 ˌaɪ
B b
CH tʃ
D d
DH ð
EH0 ɛ
EH1 ˈɛ
EH2 ˌɛ
ER0 ɚ
ER1 ˈɜː
ER2 ˌɜː
EY0 eɪ
EY1 ˈeɪ
EY2 ˌeɪ
F f
G ɡ
HH h
IH0 ɪ
IH1 ˈɪ
IH2 ˌɪ
IY0 i
IY1 ˈiː
IY2 ˌiː
JH dʒ
K k
L l
M m
N n
NG ŋ
OW0 oʊ
OW1 ˈoʊ
OW2 ˌoʊ
OY0 ɔɪ
OY1 ˈɔɪ
OY2 ˌɔɪ
P p
R ɹ
S s
SH ʃ
T t
TH θ
UH0 ʊ
UH1 ˈʊ
UH2 ˌʊ
UW0 uː
UW1 ˈuː
UW2 ˌuː
V v
W w
Y j
Z z
ZH ʒ
"""

# %%
extended = True
if extended:
    MAPPING += """
DX ɾ
"""

# %%
cmudict_to_espeak = {}
for line in MAPPING.split("\n"):
    if line == "":
        continue
    line = line.strip()
    parts = line.split(" ")

    if len(parts) != 2:
        print(line)
        continue
    k, v = line.split(" ")
    if not k in cmudict_to_espeak:
        cmudict_to_espeak[k] = v

# %%
def espeakify(phlist, sep=""):
    output = []
    if phlist == ["spn"] or phlist == ["sil"]:
        return ""
    for phone in phlist:
        if phone == "":
            continue
        if " " in phone:
            output += [cmudict_to_espeak[x] for x in phone.split(" ")]
        else:
            output.append(cmudict_to_espeak[phone])
    return sep.join(output)

# %%
import re

def get_utterances_like_espeak(phone_sequence):
    pairs = {}
    for utterance in phone_sequence:
        words = []
        text = utterance["text"]
        if text.startswith("[") and text.endswith("]"):
            continue
        for word in utterance["words"]:
            phones = [x["text"] for x in word["phones"]]
            phword = espeakify(phones)
            words.append(phword)
        joined = " ".join(words)
        joined = re.sub("  +", " ", joined)
        pairs[text] = joined
    return pairs

# %%
ps = get_phone_sequences("/Users/joregan/Playing/textgrids_shared/hsi_7_0719_209_003_main.TextGrid")
# ps = get_phone_sequences("/Users/joregan/Desktop/hsi_7_0719_227_003_inter.TextGrid")
utts = get_utterances_like_espeak(ps)

# %%
def run_espeak(text):
    phon = !echo "{text}"| espeak -v en-us --ipa -q
    return (" ".join(phon)).strip()

# %%
FIXES = {
    "kˈɑːlɚ": "kˈʌlɚ",
    "dʒɪs": "dʒˈʌs",
    "fɹɚ": "fɚ",
    "fɹə": "fɚ",
}

# %%
def cmudict_fixes(text):
    words = text.split(" ")
    out = []
    for word in words:
        if word in FIXES:
            out.append(FIXES[word])
        else:
            out.append(word)
    return " ".join(out)

# %%
def assimilations(text):
    text = text.replace("ð ð", " ð")
    text = text.replace("d ð", " ð")
    text = text.replace("d d", " d")
    return text

# %%
for utt in utts:
    print(utt)
    print(assimilations(cmudict_fixes(utts[utt])))
    print(run_espeak(utt))
    print()
# Out:
# Yeah, you look normal.
# jˈɛ jˈuː lˈʊk nˈɔːɹməl
# jˈɛh  juː lˈʊk nˈoːɹməl
#
# Kay.
# kˈeɪ
# kˈeɪ
#
# So hi, how are you? I think uh you made a good choice purchasing this one no?
# sˈoʊ hˈaɪ hˈaʊ ˈɑːɹ jˈuː ˈaɪ θˈɪŋk ˈɛ jˈuː mˈeɪd ə ɡˈʊd tʃˈɔɪs pˈɜːtʃəsɪŋ ðˈɪs wˈʌn nˈoʊ
# sˌoʊ hˈaɪ  hˈaʊ ɑːɹ juː  aɪ θˈɪŋk ˈʌ juː mˌeɪd ɐ ɡˈʊd tʃˈɔɪs pˈɜːtʃɪsɪŋ ðˈɪswˌʌn nˈoʊ
#
# It has a lot of potential.
# ˈɪt hˈæz ˈæ lˈɑːt ˈʌb pətˈɛntʃəl
# ɪt hɐz ɐ lˈɑːt ʌv pətˈɛnʃəl
#
# Yeah.
# jˈæ
# jˈɛh
#
# Yeah, yeah, of course. I mean um, first of all, I think the color, it's not the most favorable one.
# jˈæ jˈæ ˈʌv kˈɔːɹs hˈaɪ mˈiːn ˈæm fˈɜːst əv hˈɔːl ˈaɪ θˈɪŋk ðə kˈʌlɚ ˈɪts nˈɑːt ðə mˈoʊs fˈeɪvɚəbəl wˈʌn
# jˈɛh  jˈɛh  ʌv kˈoːɹs  aɪ mˈiːn ˈʌm  fˈɜːst ʌv ˈɔːl  aɪ θˈɪŋk ðə kˈʌlɚ  ɪts nˌɑːt ðə mˈoʊst fˈeɪvɚɹəbəl wˌʌn
#
# I would I would go for something more uh neutral, like white or a l- really light gray.
# ˈaɪ vˈʊd ˈaɪ wˈʊd ɡˈoʊ fɚ sˈʌmθɪŋ mˈɔːɹ hˈʌ nˈuːtɹəl lˈaɪk hwˈaɪt ˈɔːɹ ə l ɹˈiːli lˈaɪt ɡɹˈeɪ
# aɪ wʊd aɪ wʊd ɡˌoʊ fɔːɹ sˈʌmθɪŋ mˈoːɹ ˈʌ nˈuːtɹəl  lˈaɪk wˈaɪt ɔːɹ ɐ ˈɛl ɹˈiəli lˈaɪt ɡɹˈeɪ
#
# Yeah, the walls.
# jˈæ ðə wˈɔːlz
# jˈɛh  ðə wˈɔːlz
#
# Because uh because really, I I don't think this color really matches.
# vɪkəz ˈɛ vɪkəz ɹˈiːli ˈaɪ ˈaɪ dˈoʊn θˈɪŋk ðˈɪs kˈʌlɚ ɹˈiːli mˈætʃɪz
# bɪkˈʌz ˈʌ bɪkˈʌz ɹˈiəli  aɪ aɪ dˈoʊnt θˈɪŋk ðɪs kˈʌlɚ ɹˈiəli mˈætʃᵻz
#
# Eh...
# hˈɛ
# ˈeɪ
#
# I mean...  it matches but the the problem is that eh it might be too much if you want something more like a a place where you can take some rest and stay in the night like watch some TV.
# ˈaɪ mən ˈɪt mˈætʃɪz bˈʌt ðə ðə pɹˈɑːbləm ˈɪz ðˈæt ˈɛ ˈɪt mˈaɪt bi tˈuː mˈʌtʃ ˈɪf jˈuː wˈɑːn sˈʌmθɪŋ mˈɔːɹ lˈaɪk hə ə plˈeɪs hwˈɛɹ jˈuː kˈæn tˈeɪk sˈʌm ɹˈɛst ənd stˈeɪ hˈɪn ðə nˈaɪt lˈaɪk wˈɑːtʃ sˈʌm tˈiːvˈiː
# aɪ mˈiːn  ɪt mˈætʃᵻz bˌʌt ðə ðə pɹˈɑːbləm ɪz ðæt ˈeɪ ɪt mˌaɪt biː tˈuː mʌtʃ ɪf juː wˈɑːnt sˈʌmθɪŋ mˈoːɹ lˈaɪk ɐ ɐ plˈeɪs wˌɛɹ juː kæn tˈeɪk sˌʌm ɹˈɛst ænd stˈeɪ ɪnðə nˈaɪt lˈaɪk wˈɑːtʃ sˌʌm tˌiːvˈiː
#
# Maybe you don't want so much information incoming. Same with the with the mm pictures.
# mˈeɪbi jˈuː dˈoʊn wˈɑːnt sˈoʊ mˈʌtʃ ˌɪnfɚmˈeɪʃən ˈɪnkˌʌmɪŋ sˈeɪm wɪ ðə wˈɪ ðə m pˈɪktʃɚz
# mˈeɪbiː juː dˈoʊnt wˈɑːnt sˈoʊ mˌʌtʃ ˌɪnfɚmˈeɪʃən ˈɪnkʌmˌɪŋ  sˈeɪm wɪððə wɪððɪ ˌɛmˈɛm pˈɪktʃɚz
#
# Maybe you just should keep one or two because more than that is ah...
# mˈeɪbi jˈuː dʒˈʌs ʃˈʊd kˈiːp hwˈʌn ˈɔːɹ tˈuː bɪkəz mˈɔːɹ ðən ðˈæt ˈɪz hə
# mˈeɪbiː juː dʒˈʌst ʃˌʊd kˈiːp wˈʌn ɔːɹ tˈuː bɪkˈʌz mˈoːɹ ðɐn ðæt ɪz ˈɑː
#
# Yeah, of course.
# jˈæ ˈʌv kˈɔːɹs
# jˈɛh  ʌv kˈoːɹs
#
# Ah... I mean, I think in this case, you should decide because ah so the flooring is gray.
# ˈɑː ˈaɪ mˈiːn ˈaɪ θˈɪŋk ɪn ðˈɪs kˈeɪs jˈuː ʃˈʊ dˌɪsˈaɪd vɪkəz ˈɑː sˈoʊ ðˈʌ flˈɔːɹɪŋ ˈɪz ɡɹˈeɪ
# ˈɑː  aɪ mˈiːn  aɪ θˈɪŋk ɪn ðɪs kˈeɪs  juː ʃˌʊd dᵻsˈaɪd bɪkˈʌz ˈɑː sˌoʊ ðə flˈoːɹɪŋ ɪz ɡɹˈeɪ
#
# So uh I don't know if the furniture should be gray, same as the floor, or you want to keep this um [smack] this color because.
# sˈoʊ ˈɑː ˈaɪ dˈoʊn nˈoʊ hˈɪf ðə fˈɜːnɪtʃɚ ʃˈʊd bˈiː ɡɹˈeɪ sˈeɪm ˈɑːz ðə flˈɔːɹ ˈɔːɹ jˈuː wˈɑːn tə kˈiːp ðˈɪs hˈæm ðˈɪs kˈʌlɚ vɪkəz
# sˌoʊ ˈʌ aɪ dˈoʊnt nˈoʊ ɪf ðə fˈɜːnɪtʃɚ ʃˌʊd biː ɡɹˈeɪ  sˈeɪm æz ðə flˈoːɹ  ɔːɹ juː wˈɑːnt tə kˈiːp ðɪs ˈʌm smˈæk ðɪs kˈʌlɚ bɪkˈʌz
#
# Mm.
# m
# ˌɛmˈɛm
#
# Eh no, the tables, the table and the and the furniture there.
# ˈɛ nˈoʊ ðə tˈeɪbəlz ðə tˈeɪbəl ən ðə ˈɑːn ðə fˈɜːnɪtʃɚ ðˈɛɹ
# ˈeɪ nˈoʊ  ðə tˈeɪbəlz  ðə tˈeɪbəl ænd ðɪ ænd ðə fˈɜːnɪtʃɚ ðˈɛɹ
#
# Yeah, because uh I can see that they are from the same, same color, little bit brown, eh but like really saturated brown.
# jˈæ vɪkəz ˈɛ hˈaɪ kən sˈiː ðˈæt ðˈeɪ hˈɑːɹ fɚm ðə sˈeɪm sˈeɪm kˈʌlɚ lˈɪ bˈɪt bɹˈaʊn ˈɛ bˈʌt lˈaɪk ɹˈiːli sˈætʃɚˌeɪtɪd bɹˈaʊn
# jˈɛh  bɪkˈʌz ˈʌ aɪ kæn sˈiː ðæt ðeɪ ɑːɹ fɹʌmðə sˈeɪm  sˈeɪm kˈʌlɚ  lˈɪɾəl bˈɪt bɹˈaʊn  ˈeɪ bˌʌt lˈaɪk ɹˈiəli sˈætʃɚɹˌeɪɾᵻd bɹˈaʊn
#
# So in that case, maybe I would go for something lighter
# sˈoʊ ɪn ðˈæt kˈeɪs mˈeɪbi ˈaɪ wˈʊd ɡˈoʊ fɚ sˈʌmθɪŋ lˈaɪtɚ
# sˌoʊ ɪn ðæt kˈeɪs  mˈeɪbiː aɪ wʊd ɡˌoʊ fɔːɹ sˈʌmθɪŋ lˈaɪɾɚ
#
# if you want like uh more uh es- ah space to take some rest.
# ˈɪf jˈuː wˈɑːnt lˈaɪk hˈʌ mˈɔːɹ ˈʌ ˈɛs ə spˈeɪs tˈuː tˈeɪk sˈʌm ɹˈɛst
# ɪf juː wˈɑːnt lˈaɪk ˈʌ mˈoːɹ ˈʌ ˈiːz ˈɑː spˈeɪs tə tˈeɪk sˌʌm ɹˈɛst
#
# With um with the sofas ah I would just put them in a different eh direction so I would put... keep the big one in the center and then the small one on the side and then maybe you can get another to put on the other side or maybe you can actually purchase one new one in L shape and then it would be nice because you can see more people and then you can also lay on on the sofa that would be nice
# wɪð hˈæm wɪ ðə sˈoʊfəz ˈɑː ˈaɪ wˈʊ dʒˈʌs pˈʊt ðˈɛm ɪn ə dˈɪfɹənt ˈɛ dɚˈɛkʃən sˈoʊ ˈaɪ wˈʊd pˈʊt kˈiːp ðə bˈɪɡ wˈʌn ˈɪn ðə sˈɛntɚ ˈæn ðˈɛn ðə ɛsmˈɔːl wˈʌn ˈɑːn ðə sˈaɪd ˈæn ðˈɛn mˈeɪvi jˈuː kən ɡˈɛt ənˈʌðɚ tə pˈʊt ˈɑːn ði ˈʌðə sˈaɪd ˈɔːɹ mˈeɪvi jˈuː kən ˈækʃəli pɚtʃˈeɪs wˈʌn njˈuː wˈʌn ˈɪn ˈɛl ʃˈeɪp ˈæn ðˈɛn ˈiː vˈʊd bi nˈaɪs vɪkəz jˈuː kən sˈiː mˈɔːɹ pˈiːpəl ən ðˈɛn jˈuː kən ˈɑːlsoʊ lˈeɪ ˈɑːn ˈɑːn ðˈʌ sˈoʊfə ðˈæt wˈʊd bi nˈaɪs
# wɪð ˈʌm wɪððə sˈoʊfəz ˈɑː aɪ wʊd dʒˈʌst pˌʊt ðˌɛm ɪn ɐ dˈɪfɹənt ˈeɪ dɚɹˈɛkʃən sˌoʊ aɪ wʊd pˈʊt  kˈiːp ðə bˈɪɡ wˈʌn ɪnðə sˈɛntɚ ænd ðˈɛn ðə smˈɔːl wˈʌn ɑːnðə sˈaɪd ænd ðˈɛn mˈeɪbiː juː kæn ɡɛt ɐnˈʌðɚ tə pˌʊt ɑːnðɪ ˈʌðɚ sˈaɪd ɔːɹ mˈeɪbiː juː kæn ˈæktʃuːəli pˈɜːtʃɪs wˈʌn nˈuː wˈʌn ɪn ˈɛl ʃˈeɪp ænd ðˈɛn ɪt wʊd biː nˈaɪs bɪkˈʌz juː kæn sˈiː mˈoːɹ pˈiːpəl ænd ðˈɛn juː kæn ˈɑːlsoʊ lˈeɪ ˌɑːn ɑːnðə sˈoʊfə ðæt wʊd biː nˈaɪs
#
# And towards the color I would go for something lighter and then I would just put a little bit of a pop of color with some pillows or some other um you know decorations that you can put on like a little blanket or something like this.
# ˈænd tˈɔːɹdz ðə kˈʌlɚ ˈaɪ wˈʊd ɡˈoʊ fɚ sˈʌmθɪŋ lˈaɪtɚ ˈæn ðˈɛn ˈaɪ wˈʊ dʒˈʌs pˈʊt ə lˈɪtə bˈɪt ˈʌv ə pˈɑːp ˈʌv kˈʌlɚ wɪθ sˈʌm pˈɪloʊz hˈɔːɹ sˈʌm ˈʌðɚ ˈɑːm jˈuː nˈoʊ dˌɛkɚˈeɪʃənz ðə jˈuː kən pˈʊt ˈɑːn lˈaɪk ə lˈɪtə blˈæŋkɪt hɚ sˈʌmθɪŋ ˈaɪk ðɪs
# ænd tʊwˈɔːɹdz ðə kˈʌlɚɹ aɪ wʊd ɡˌoʊ fɔːɹ sˈʌmθɪŋ lˈaɪɾɚ ænd ðˈɛn aɪ wʊd dʒˈʌst pˌʊt ɐ lˈɪɾəl bˈɪt əvə pˈɑːp ʌv kˈʌlɚ wɪð sˌʌm pˈɪloʊz ɔːɹ sˌʌm ˈʌðɚɹ ˈʌm juː nˈoʊ dˌɛkɚɹˈeɪʃənz ðæt juː kæn pˌʊt ˌɑːn lˈaɪk ɐ lˈɪɾəl blˈæŋkɪt ɔːɹ sˈʌmθɪŋ lˈaɪk ðˈɪs
#
# Uh I think that table is, uh, I mean, for that placement, it's really big.
# ˈɑː ˈaɪ θˈɪŋk ðˈæt tˈeɪvəl hɪz ˈɑː ˈaɪ mˈiːn fɚ ðˈæt plˈeɪsmənt hˈɪs ɹˈɪli bˈɪɡ
# ˈʌ aɪ θˈɪŋk ðæt tˈeɪbəl ɪz  ˈʌ  aɪ mˈiːn  fɔːɹ ðæt plˈeɪsmənt  ɪts ɹˈiəli bˈɪɡ
#
# So you need to go for something ah more minimalist in terms of maybe two small ones, like a little bit short in eh in height.
# sˈoʊ jˈuː nˈiːd tɪ ɡˈoʊ fɚ sˈʌmθɪŋ hˈæ mˈɔːɹ mˈɪnəmələst hɪn tˈɜːmz ˈʌv mˈeɪbi tˈuː smˈɔːl wˈʌnz lˈaɪk ə lˈɪtə bˈɪt ʃˈɔːɹt ɪn ˈɛ ˈɪn hˈaɪt
# sˌoʊ juː nˈiːd tə ɡˌoʊ fɔːɹ sˈʌmθɪŋ ˈɑː mˈoːɹ mˈɪnɪməlˌɪst ɪn tˈɜːmz ʌv mˈeɪbiː tˈuː smˈɔːl wˌʌnz  lˈaɪk ɐ lˈɪɾəl bˈɪt ʃˈɔːɹt ɪn ˈeɪ ɪn hˈaɪt
#
# Ah, y- eh you mean the desk for the mm, yeah.
# ˈæ j ˈɛ jˈuː mˈiːn ðə dˈɛsk fɚ ðə m jˈæ
# ˈɑː  wˈaɪ ˈeɪ juː mˈiːn ðə dˈɛsk fɚðɪ ˌɛmˈɛm  jˈɛh
#
# I mean, that desk is a little bit confusing in position, because because you have the fireplace here, and maybe you want to make that your focal point.
# ˈaɪ mˈiːn ðˈæt dˈɛsk ˈɪz hˈæ lˈɪtə bˈɪt kənfjˈuːzɪŋ ɪn pəzˈɪʃən vɪkəz bɪkəz jˈuː hˈæv ðə fˈaɪɚplˌeɪs hˈiːɹ ən mˈeɪbi jˈuː wˈɑːn tˈuː mˈeɪk ðˈæt jˈʊɹ fˈoʊkəl pˈɔɪnt
# aɪ mˈiːn  ðæt dˈɛsk ɪz ɐ lˈɪɾəl bˈɪt kənfjˈuːzɪŋ ɪn pəzˈɪʃən  bɪkˈʌz bɪkˈʌz juː hæv ðə fˈaɪɚpleɪs hˈɪɹ  ænd mˈeɪbiː juː wˈɑːnt tə mˌeɪk ðæt jʊɹ fˈoʊkəl pˈɔɪnt
#
# Because uh maybe the TV will look really nice on top of the of the fireplace, and then you can move the desk toward this area here, maybe next to the window, which would be nice if you work here to have some natural light while you're working. I think that would be nice.
# vɪkəz ˈɛ mˈeɪbi ðə tˈiːvˈiː wˈɪl lˈʊk ɹˈiːli nˈaɪs ˈɑːn tˈɑːp ˈʌv ðə ˈʌv ðˈʌ fˈaɪɚplˌeɪs ˈæn ðˈɛn jˈuː kˈæn mˈuːv ðə dˈɛsk təwˈɔːɹ ðˈɪs hˈɛɹiə hˈiːɹ mˈeɪbi nˈɛks tə ðə wˈɪndoʊ wˈɪtʃ wˈʊd bi nˈaɪs hɪf jˈuː wˈɜːk hˈiːɹ tɪ hˈæv sˈʌm nˈætʃɹəl lˈaɪt hwˈaɪl jˈʊɹ wˈɜːkɪŋ ˈaɪ θˈɪŋk ðˈæt vˈʊd bi nˈaɪs
# bɪkˈʌz ˈʌ mˈeɪbiː ðə tˌiːvˈiː wɪl lˈʊk ɹˈiəli nˈaɪs ˌɑːn tˈɑːp ʌvðɪ ʌvðə fˈaɪɚpleɪs  ænd ðˈɛn juː kæn mˈuːv ðə dˈɛsk tʊwˈɔːɹd ðɪs ˈɛɹiə hˈɪɹ  mˈeɪbiː nˈɛkst tə ðə wˈɪndoʊ  wˌɪtʃ wʊd biː nˈaɪs ɪf juː wˈɜːk hˈɪɹ tə hæv sˌʌm nˈætʃɚɹəl lˈaɪt wˌaɪl jʊɹ wˈɜːkɪŋ  aɪ θˈɪŋk ðæt wʊd biː nˈaɪs
#
# That might work.
# ðˈæt mˈaɪt wˈɜːk
# ðæt mˌaɪt wˈɜːk
#
# Your laptop, I mean, if you're if you're actually working ah in the couch, then maybe you can ah get one of those tables that you can flip and and take back.
# jˈʊɹ lˈæptˌɑːp ˈaɪ mˈiːn hɪf jˈʊɹ ˈɪf jˈʊɹ ˈækʃəli wˈɜːkɪŋ hˈæ ˈɪn ðə kˈaʊtʃ ðˈɛn mˈeɪbi jˈuː kən ə ɡˈɪt wˈʌn əv ðˈoʊz tˈeɪbəlz ðˈæt jˈuː kən flˈɪp ˈænd ˈænd tˈeɪk bˈæk
# jʊɹ lˈæptɑːp  aɪ mˈiːn  ɪf jʊɹ ɪf jʊɹ ˈæktʃuːəli wˈɜːkɪŋ ˈɑː ɪnðə kˈaʊtʃ  ðˈɛn mˈeɪbiː juː kæn ˈɑː ɡɛt wˈʌn ʌv ðoʊz tˈeɪbəlz ðæt juː kæn flˈɪp ænd ænd tˈeɪk bˈæk
#
# Like ah, y- y- you lift them, and then you put... put them closer to to the couch, and then you can work there.
# lˈaɪk ˈæ j j jˈuː lˈɪft ðˈɛm ˈæn ðˈɛn jˈuː pˈʊt pˈʊt ðəm klˈoʊsɚ tˈuː tˈuː ðə kˈaʊtʃ ˈæn ðˈɛn jˈuː kən wˈɜːk ðˈɛɹ
# lˈaɪk ˈɑː  wˈaɪ wˈaɪ juː lˈɪft ðˌɛm  ænd ðˈɛn juː pˈʊt  pˌʊt ðˌɛm klˈoʊsɚ tʊtə ðə kˈaʊtʃ  ænd ðˈɛn juː kæn wˈɜːk ðˈɛɹ
#
# But definitely, I would go for a lower height one.
# bˈʌt dˈɛfənətli ˈaɪ wˈʊd ɡˈoʊ fɚ ˈæ lˈoʊɚ hˈaɪt wˈʌn
# bˌʌt dˈɛfɪnətli  aɪ wʊd ɡˌoʊ fɚɹə lˈoʊɚ hˈaɪt wˌʌn
#
# Yeah, I I wouldn't I wouldn't put like the laptop close by to the s- to the statues because, in that case you would be uh moving the laptop or just working there and then... I mean you're really close to the statues and then maybe some ah accident happens and then you break some of uh the statues. So I I wouldn't do that.
# jˈæ ˈaɪ ˈaɪ wˈʊdən ˈaɪ wˈʊdənt pˈʊt lˈaɪk ðə lˈæptˌɑːp klˈoʊs bˈaɪ tə ðə s tə ðə stˈætʃˌuːz bɪkəz ɪn ðˈæt kˈeɪs jˈuː wˈʊd bˈiː hˈʌ mˈuːvɪŋ ðə lˈæptˌɑːp ˈɔːɹ dʒɪst wˈɜːkɪŋ ðˈɛɹ ən ðˈɛn ˈaɪ mˈiːn jˈʊɹ ɹˈiːli klˈoʊs tə ðə stˈætʃˌuːz ən ðˈɛn mˈeɪbi sˈʌm ə ˈæksədənt hˈæpənz ən ðˈɛn jˈuː bɹˈeɪk sˈʌm ˈʌv ˈʌ ðə stˈætʃˌuːz sˈoʊ ˈaɪ ˈaɪ wˈʊdən dˈuː ðˈæt
# jˈɛh  aɪ aɪ wˈʊdənt aɪ wˈʊdənt pˌʊt lˈaɪk ðə lˈæptɑːp klˈoʊs baɪ tə ðɪ ˈɛs tə ðə stˈætʃuːz bɪkˈʌz  ɪn ðæt kˈeɪs juː wʊd biː ˈʌ mˈuːvɪŋ ðə lˈæptɑːp ɔːɹ dʒˈʌst wˈɜːkɪŋ ðɛɹ ænd ðˈɛn  aɪ mˈiːn jʊɹ ɹˈiəli klˈoʊz tə ðə stˈætʃuːz ænd ðˈɛn mˈeɪbiː sˌʌm ˈɑː ˈæksɪdənt hˈæpənz ænd ðˈɛn juː bɹˈeɪk sˌʌm ʌv ˈʌ ðə stˈætʃuːz  sˌoʊ aɪ aɪ wˈʊdənt dˈuː ðˈæt
#
# I I I think this is more of a static area in which, you don't want, nothing much to happen because it's more of a a place to actually eh l- take a look.
# ˈaɪ ˈaɪ hˈaɪ θˈɪŋk ɪs hɪz mˈɔːɹ əv ə stˈætɪk ˈɛɹiə ɪn wˈɪtʃ jˈuː dˈoʊn wˈɑːnt nˈʌθɪŋ mˈʌtʃ tˈuː hˈæpən bɪkəz ɪts mˈɔːɹ əv ə ə plˈeɪs tˈuː ˈækʃəli ˈɛ l tˈeɪk hə lˈʊk
# aɪ aɪ aɪ θˈɪŋk ðɪs ɪz mˈoːɹ əvə stˈæɾɪk ˈɛɹiə ɪn wˌɪtʃ  juː dˈoʊnt wˈɑːnt  nˈʌθɪŋ mˈʌtʃ tə hˈæpən bɪkˈʌz ɪts mˈoːɹ əvə ɐ plˈeɪs tʊ ˈæktʃuːəli ˈeɪ ˈɛl tˈeɪk ɐ lˈʊk
#
# But uh but yeah, I don't I don't know.
# bˈʌt ˈɑː bˈʌt jˈæ ˈaɪ dˈoʊnt ˈaɪ dˈoʊn nˈoʊ
# bˌʌt ˈʌ bˌʌt jˈɛh  aɪ dˈoʊnt aɪ dˈoʊnt nˈoʊ
#
# I don't think uh I would put the laptop there.
# ˈaɪ dˈoʊn θˈɪŋk ˈɑː ˈaɪ wˈʊd pˈʊt ðə lˈæptˌɑːp ðˈɛɹ
# aɪ dˈoʊnt θˈɪŋk ˈʌ aɪ wʊd pˌʊt ðə lˈæptɑːp ðˈɛɹ
#
# Maybe you can put it on the desk as well.
# mˈeɪbi jˈuː kən pˈʊt ˈɪt ˈɑːn ðə dˈɛsk ˈæz wˈɛl
# mˈeɪbiː juː kæn pˌʊt ɪt ɑːnðə dˈɛsk æz wˈɛl
#
# I think uh the black one would be the best uh choice.
# ˈaɪ θˈɪŋk ˈɑː ðə blˈæk wˈʌn wˈʊd bi ðə bˈɛst ˈɛ tʃˈɔɪs
# aɪ θˈɪŋk ˈʌ ðə blˈæk wˈʌn wʊd biː ðə bˈɛst ˈʌ tʃˈɔɪs
#
# Uh yeah, the brown one, it's i- l- it's looks a little bit flat in this furniture, because uh it's the same color of the furniture.
# ˈɑː jˈæ ðə bɹˈaʊn wˈʌn ˈɪts ˈɪ l ˈɪts lˈʊks ə lˈɪ bˈɪt flˈæt ɪn ðˈɪs fˈɜːnɪtʃɚ bɪkəz ˈɛ ˈɪts ðə sˈeɪm kˈʌlɚ ˈʌv ðə fˈɜːnɪtʃɚ
# ˈʌ jˈɛh  ðə bɹˈaʊn wˌʌn  ɪts ˈaɪ ˈɛl ɪts lˈʊks ɐ lˈɪɾəl bˈɪt flˈæt ɪn ðɪs fˈɜːnɪtʃɚ  bɪkˈʌz ˈʌ ɪts ðə sˈeɪm kˈʌlɚɹ ʌvðə fˈɜːnɪtʃɚ
#
# But eve- but if you wish to actually change the color of the furniture, maybe the brown one, it would be a better choice.
# bˈʌt ˈiːvɪ bˈʌt ˈɪf jˈuː wˈɪʃ tˈuː ˈækʃəli tʃˈeɪndʒ ðə kˈʌlɚ əv ðə fˈɜːnɪtʃɚ mˈeɪbi ðə bɹˈaʊn wˈʌn ˈɪt wˈʊd bˈiː ə bˈɛtɚ tʃˈɔɪs
# bˌʌt ˈiːv bˌʌt ɪf juː wˈɪʃ tʊ ˈæktʃuːəli tʃˈeɪndʒ ðə kˈʌlɚɹ ʌvðə fˈɜːnɪtʃɚ  mˈeɪbiː ðə bɹˈaʊn wˌʌn  ɪt wʊd biː ɐ bˈɛɾɚ tʃˈɔɪs
#
# Yeah, I think ah maybe you should just keep one.
# jˈæ hˈaɪ θˈɪŋk ə mˈeɪvi jˈuː ʃˈʊ dʒˈʌs kˈiːp wˈʌn
# jˈɛh  aɪ θˈɪŋk ˈɑː mˈeɪbiː juː ʃˌʊd dʒˈʌst kˈiːp wˌʌn
#
# Because now with the two of them, it's a little bit too much.
# vɪkəz nˈaʊ wɪ ðə tˈuː əv ðˈɛm ˈɪts ə lˈɪ bˈɪt tˈuː mˈʌtʃ
# bɪkˈʌz nˈaʊ wɪððə tˈuː ʌv ðˌɛm  ɪts ɐ lˈɪɾəl bˈɪt tˈuː mʌtʃ
#
# So maybe if you just keep one of them, eh I would go definitely for that one.
# sˈoʊ mˈeɪbi ˈɪf jˈuː dʒˈʌs kˈiːp wˈʌn ˈʌv ðˈɛm ˈɛ ˈaɪ wˈʊd ɡˈoʊ dˈɛfənətli fɚ ðˈæt wˈʌn
# sˌoʊ mˈeɪbiː ɪf juː dʒˈʌst kˈiːp wˈʌn ʌv ðˌɛm  ˈeɪ aɪ wʊd ɡˌoʊ dˈɛfɪnətli fɔːɹ ðˈætwˌʌn
#
# Eh.
# hˈɛ
# ˈeɪ
#
# The gray one.
# ðə ɡɹˈeɪ wˈʌn
# ðə ɡɹˈeɪ wˌʌn
#
# Because really, it's not uh... [I_mean], it it matches better with the whole uh room.
# bɪkˈʌz ɹˈɪli ɪts nˈɑːt hˈʌ hˈiː ˈɪt mˈætʃɪz bˈɛtɚ wɪ ðə hˈoʊl ˈɑː ɹˈuːm
# bɪkˈʌz ɹˈiəli  ɪts nˌɑːt ˈʌ  aɪ mˈiːn  ɪt ɪt mˈætʃᵻz bˈɛɾɚ wɪððə hˈoʊl ˈʌ ɹˈuːm
#
# This one, it looks like trash can from the street.
# ðˈɪs wˈʌn hɪ lˈʊks lˈaɪk tɹˈæʃ kˈæn fɚm ðə stɹˈiːt
# ðˈɪswˌʌn  ɪt lˈʊks lˈaɪk tɹˈæʃ kæn fɹʌmðə stɹˈiːt
#
# The blue one looks like the trash can from the street.
# ðə blˈuː wˈʌn lˈʊks lˈaɪk ðə tɹˈæʃ kən fɚm ðə stɹˈiːt
# ðə blˈuː wˈʌn lˈʊks lˈaɪk ðə tɹˈæʃ kæn fɹʌmðə stɹˈiːt
#
# So, it it I mean, I would keep that inside a a a drawer or inside a cupboard, something like that, hidden, like not to be visible for the people.
# sˈoʊ ɪt ˈɪt ˈaɪ mˈiːn ˈaɪ wˈʊd kˈiːp ðˈæt ɪnsˈaɪd ə hə ə dɹˈɔːɹ ˈɔːɹ ɪnsˈaɪd ə kˈʌbɚd sˈʌmθɪŋ ˈaɪk ðˈæt hˈɪdən ˈaɪk nˈɑːt tə bi bˈɪzəbəl fˈɔːɹ ðə pˈiːpəl
# sˈoʊ  ɪt ɪt aɪ mˈiːn  aɪ wʊd kˈiːp ðæt ɪnsˈaɪd ɐ ɐ ɐ dɹˈɔːɹ ɔːɹ ɪnsˈaɪd ɐ kˈʌbəd  sˈʌmθɪŋ lˈaɪk ðˈæt  hˈɪdən  lˈaɪk nˌɑːt təbi vˈɪzəbəl fɚðə pˈiːpəl
#
# Yes.
# jˈɛs
# jˈɛs
#
# Yeah, yeah.
# jˈæ jˈæ
# jˈɛh  jˈɛh
#
# I think, yeah, you should keep a maximum of two.
# ˈaɪ θˈɪŋk jˈæ jˈuː ʃˈʊd kˈiːp ə mˈæksəməm ˈʌv tˈuː
# aɪ θˈɪŋk  jˈɛh  juː ʃˌʊd kˈiːp ɐ mˈæksɪməm ʌv tˈuː
#
# But as I was saying, maybe if you move the TV on the upper part of the fireplace, then maybe you can put one, there, in in the place of the TV.
# vˈʌ ˈæz ˈaɪ wəz sˈeɪɪŋ mˈeɪbi ˈɪf jˈuː mˈuːv ðə tˈiːvˈiː ˈɑːn ðə ˈʌpɚ pˈɑːɹt əv ðə fˈaɪɚplˌeɪs ðˈɛn mˈeɪbi jˈuː kən pˈʊt wˈʌn ðˈɛɹ ɪn ˈɪn ðə plˈeɪs əv ðə tˈiːbˈiː
# bˌʌt æz aɪ wʌz sˈeɪɪŋ  mˈeɪbiː ɪf juː mˈuːv ðə tˌiːvˈiː ɑːnðɪ ˌʌpɚ pˈɑːɹt ʌvðə fˈaɪɚpleɪs  ðˈɛn mˈeɪbiː juː kæn pˈʊt wˌʌn  ðˈɛɹ  ɪn ɪnðə plˈeɪs ʌvðə tˌiːvˈiː
#
# And then this one, I think it's perfect.
# ˈæn ðˈɛn ðˈɪs wˈʌn ˈaɪ θˈɪŋk ˈɪts pˈɜːfˌɪkt
# ænd ðˈɛn ðˈɪswˌʌn  aɪ θˈɪŋk ɪts pˈɜːfɛkt
#
# Even the the color pick is really nice.
# ˈiːvɪn ðə ðə kˈʌlɚ pˈɪk ˈɪz ɹˈiː nˈaɪs
# ˈiːvən ðə ðə kˈʌlɚ pˈɪk ɪz ɹˈiəli nˈaɪs
#
# But from the rest, if you have to pick one and we would have like this grayish walls, I would go for this one, ah to keep and just put it there, even because it goes with the eh
# vˈʌt fɹˈʌm ðə ɹˈɛst ˈɪf jˈuː hˈæv tə pˈɪk wˈʌn ˈæn wˈiː wˈʊd hˈæv lˈaɪk ðˈɪs ɡɹˈeɪɪʃ wˈɔːlz ˈaɪ wˈʊd ɡˈoʊ fɚ ðˈɪs wˈʌn ˈæ tɪ kˈiːp ˈæn dʒˈʌs pˈʊt hˈiː ðˈɛɹ ˈiːvɪn bɪkəz ˈɪt ɡˈoʊz wˈɪ ðə ˈɛ
# bˌʌt fɹʌmðə ɹˈɛst  ɪf juː hæv tə pˈɪk wˈʌn ænd wiː wʊdhɐv lˈaɪk ðɪs ɡɹˈeɪɪʃ wˈɔːlz  aɪ wʊd ɡˌoʊ fɔːɹ ðˈɪswˌʌn  ˈɑː tə kˈiːp ænd dʒˈʌst pˌʊt ɪt ðˈɛɹ  ˈiːvən bɪkˈʌz ɪt ɡoʊz wɪððɪ ˈeɪ
#
# theme, so you would have landscape and landscape, because the other two I think they are a little bit different in in the theme
# θˈiːm sˈoʊ jˈuː wˈʊd hˈæv lˈændskˌeɪp ən lˈænskˌeɪp vɪkəz ði ˈʌðə tˈuː ˈaɪ θˈɪŋk ðˈeɪ ˈɑːɹ ə lˈɪtə vˈɪt dˈɪfɹənt ɪn ɪn ðə θˈiːm
# θˈiːm  sˌoʊ juː wʊdhɐv lˈændskeɪp ænd lˈændskeɪp  bɪkˈʌz ðɪ ˈʌðɚ tˈuː aɪ θˈɪŋk ðeɪ ɑːɹ ɐ lˈɪɾəl bˈɪt dˈɪfɹənt ɪn ɪnðə θˈiːm
#
# I think you should remove this one and that one, and this one move it there and the TV move it... on top of the mm fireplace.
# ˈaɪ θˈɪŋk jˈuː ʃˈʊd ɹimˈuːv ðˈɪs wˈʌn ən ðˈæt wˈʌn ˈænd ɪs wˈʌn mˈuːb ˈɪt ðˈɛɹ ˈæn ðə tˈiːvˈiː mˈuːv ˈɪt ˈɑːn tˈɑːp ˈʌv ðə m fˈaɪɚplˌeɪs
# aɪ θˈɪŋk juː ʃˌʊd ɹɪmˈuːv ðˈɪswˌʌn ænd ðˈætwˌʌn  ænd ðˈɪswˌʌn mˈuːv ɪt ðɛɹ ænd ðə tˌiːvˈiː mˈuːv ɪt  ˌɑːn tˈɑːp ʌvðɪ ˌɛmˈɛm fˈaɪɚpleɪs
#
# Yeh.
# jˈɛ
# jˈeɪ
#
# Ah yes, yes, you definitely eh purchase one of those... small um... arrangements for the the next of...  [spn] for the side of the... so [spn] where you put... place your arm, and then you can just put put it there even with the control uh the the the control of the TV... the remote control. So uh you can put everything there.
# ˈɑː jˈɛs jˈɛs jˈuː dˈɛfənətli ˈɛ pɚtʃˈeɪs wˈʌn əv ðˈoʊz smˈɑːl ˈæm ɚˈeɪndʒməns fˈɔːɹ ðə ðə nˈɛkst ˈʌv fɚ ðə sˈaɪd ˈʌv ðə sˈoʊ hwˈɛɹ jˈuː pˈʊt plˈeɪs jˈʊɹ ˈɑːɹm ˈæn ðˈɛn jˈuː kən dʒɪst pˈʊt pˈʊt hɪt ðˈɛɹ ˈiːvɪn wɪ ðə kəntɹˈoʊl ˈʌ ðə ðə ðə kəntɹˈoʊl əv ðə tˈiːbˈiː ðə ɹɪmˈoʊt kəntɹˈoʊl sˈoʊ ˈɑː jˈuː kən pˈʊt ˈɛvɹiθˌɪŋ ðˈɛɹ
# ˈɑː jˈɛs  jˈɛs  juː dˈɛfɪnətli ˈeɪ pˈɜːtʃɪs wˈʌn ʌv ðˈoʊz  smˈɔːl ˈʌm  ɐɹˈeɪndʒmənts fɚðə ðə nˈɛkst ʌv  ˌɛspˌiːˈɛn fɚðə sˈaɪd ʌvðə  sˌoʊ ˌɛspˌiːˈɛn wˌɛɹ juː pˈʊt  plˈeɪs jʊɹ ˈɑːɹm  ænd ðˈɛn juː kæn dʒˈʌst pˌʊt pˌʊt ɪt ðɛɹ ˈiːvən wɪððə kəntɹˈoʊl ˈʌ ðə ðə ðə kəntɹˈoʊl ʌvðə tˌiːvˈiː  ðə ɹɪmˈoʊt kəntɹˈoʊl  sˌoʊ ˈʌ juː kæn pˌʊt ˈɛvɹɪθˌɪŋ ðˈɛɹ
#
# I think that would...
# ˈaɪ θˈɪŋk ðˈæt wˈʊd
# aɪ θˈɪŋk ðæt wˈʊd
#
# Yeah, I think uh you can buy one of those um... places where you can keep it.
# jˈæ ˈaɪ θˈɪŋk ˈɛ jˈuː kən bˈaɪ wˈʌn əv ðˈoʊz hˈæm plˈeɪsɪz wˈɛɹ jˈuː kən kˈiːp ɪt
# jˈɛh  aɪ θˈɪŋk ˈʌ juː kæn bˈaɪ wˈʌn ʌv ðoʊz ˈʌm  plˈeɪsᵻz wˌɛɹ juː kæn kˈiːp ɪt
#
# Like uh they're... nn they come in different uh... colors and yeah, it's like a little bit more organized in that sense.
# lˈaɪk hˈɛ ðˈɛɹ n ðˈeɪ kˈʌm ɪn dˈɪfɛən ˈɛ kˈoʊlɛz hə jˈɔː ɪts ˈaɪ hə lˈɪl vˈɪt mˈɔː ˈɔːɡənˌaɪzd ɪn ðə sˈɛns
# lˈaɪk ˈʌ ðeɪɚ  ˌɛnˈɛn ðeɪ kˈʌm ɪn dˈɪfɹənt ˈʌ  kˈʌlɚz ænd jˈɛh  ɪts lˈaɪk ɐ lˈɪɾəl bˈɪt mˈoːɹ ˈɔːɹɡɐnˌaɪzd ɪn ðæt sˈɛns
#
# Okay. You're welcome.
# həkˈeɪ jˈʊɹ wˈɛlkəm
# oʊkˈeɪ  jʊɹ wˈɛlkʌm

# %%
filestem = "hsi_7_0719_209_003_main"
audio_dir = "/Users/joregan/Playing/hsi/audio/"

with open("/tmp/run_ffmpeg.sh", "w") as outf:
    for item in ps:
        start = item["start"]
        dur = item["end"] - item["start"]
        outf.write(f"ffmpeg -i {audio_dir}{filestem}.wav -acodec pcm_s16le -ac 1 -ar 16000 -ss {start} -t {dur} /tmp/phoninput/{filestem}_{start}_{item['end']}.wav\n")
