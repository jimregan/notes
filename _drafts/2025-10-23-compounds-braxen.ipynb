# %%
def clean_accent(phone):
    if phone.startswith("'") or phone.startswith(",") or phone.startswith('"'):
        return phone[1:]
    return phone

def clean_phone(phones):
    phones = phones.strip()
    each_phone = phones.split(" ")
    each_phone = [clean_accent(p) for p in each_phone]
    return " ".join(each_phone)

def clean_phones(pron_parts):
    return [clean_phone(p) for p in pron_parts]

def ends_with_list(word, endings):
    for ending in endings:
        if word.endswith(ending):
            return ending
    return ""

def split_acronym(word, pron):
    base_word = word
    endings = [":s"]
    ending = ends_with_list(word, endings)
    if ending:
        base_word = word[:-len(ending)]
    if not "|" in pron:
        pron_parts = pron.split("~")
        pron_parts = clean_phones(pron_parts)
        letters = list(base_word)
        if ending:
            letters[-1] = letters[-1] + ending
        if len(pron_parts) == len(letters):
            pieces = zip(letters, pron_parts)
            return [p for p in pieces]
            #if base_word != word:
            #    pass

# %%
split_acronym("sRPE:s", "e s ~ ae r ~ p e: ~ 'e s")
# Out:
# [('s', 'e s'), ('R', 'ae r'), ('P', 'p e:'), ('E:s', 'e s')]

# %%
parts = []
with open("/Users/joregan/Playing/braxen/dict/braxen-sv.tsv") as braxen:
    for line in braxen:
        if line.startswith("#"):
            continue
        pieces = line.strip().split("\t")

        parts.append(
            {
                "id": pieces[-1],
                "orth": pieces[0],
                "phones": pieces[1],
                "pos": pieces[2],
                "lang": pieces[3],
                "pos_tb": pieces[2].replace(" ", "|"),
            }
        )

# %% [markdown]
# ```bash
# cat ~/Playing/UD/UD_Swedish-Talbanken/sv_talbanken-ud-train.conllu |awk -F'\t' '{print $5 "\t" $4 "\t" $6}'|sort|uniq > /tmp/sv_talbanken-tags.txt
# ```

# %%
def read_talbanken_tags(file="/tmp/sv_talbanken-tags.txt"):
    tagset = {}
    with open(file) as tags_file:
        tags = {}
        for line in tags_file:
            line = line.strip()
            if line == "":
                continue
            parts = line.split("\t")
            tags = {
                "tag": parts[0],
                "pos": parts[1],
                "ud_tags": parts[2]
            }
            if not parts[0] in tagset:
                tagset[parts[0]] = []
            tagset[parts[0]].append(tags)
    return tagset

# %%
tagset = read_talbanken_tags()

# %%
for entry in parts:
    pos_tb = entry["pos_tb"]
    if pos_tb in tagset:
        if len(tagset[pos_tb]) == 1:
            entry["tags_ud"] = tagset[pos_tb][0]

# %%
import json

with open("/tmp/braxen-sv-with-ud.json", "w") as out_file:
    json.dump(parts, out_file, indent=2)

# %% [markdown]
# ```
# 5-vxl	f "e m - v ,ä k . s l a d	AB	swe	-	-	-	733024
# 5-växlad	f "e m - v ,ä k . s l a d	JJ POS UTR SIN IND NOM	swe	751234
# femväxlad	f "ä m - v ,ä k . s l a d	JJ POS UTR SIN IND NOM	swe	115986
# ```

# %%
braxen = {}
for part in parts:
    orth = part["orth"]
    if not orth in braxen:
        braxen[orth] = []
    braxen[orth].append(part)
with open("/tmp/braxen-sv-by-orth.json", "w") as out_file:
    json.dump(braxen, out_file, indent=2)

# %%
import json
with open("/tmp/braxen-sv-by-orth.json") as in_file:
    braxen = json.load(in_file)

# %%
ambiguous = {}
for orth in braxen:
    entries = braxen[orth]
    if len(entries) > 1:
        ambiguous[orth] = entries

# %%
with open("/tmp/braxen-sv-ambiguous.json", "w") as out_file:
    json.dump(ambiguous, out_file, indent=2)

# %%
for amb in ambiguous.keys():
    pronunciations = set()
    languages = set()
    for entry in ambiguous[amb]:
        pronunciations.add(entry["phones"])
    if len(pronunciations) > 1 and len(languages) != 1:
        for entry in ambiguous[amb]:
            print(amb, entry["phones"], entry["lang"])
# Out:
# Aaron 'a: . r o n swe
# Aaron 'ae . rh ex n eng
# Abagail 'ae . b ex . g e j l eng
# Abagail 'ae . b ex . g ei l eng
# Abaljarnasdottir 'a . b a l . j a r . n a s ~ d o . t i r ice
# Abaljarnasdottir a . b "a l . j a . rn a s - d ,o . t i r ice
# Abbi 'a . b i swe
# Abbi a . b 'i: unk
# Abel 'a: . b ex l swe
# Abel 'ei . b ex l eng
# Abramovitj a . b r 'a: . m u . v i tc sla
# Abramovitj a . b r a . m 'o: . v i tc rus
# Abul-Qasem a . b uu l ~ k 'a . s ex m per
# Abul-Qasem a: . b uu l ~ k 'a . s ex m swe
# Acheson 'a . tc i . s o n eng
# Acheson 'ae . tc i . s o n swe
# Achille a . k 'i . l ex swe
# Achille a . k 'i l swe
# Actionaid 'a k . rs ex n ~ e j d eng
# Actionaid 'ae k . rs ex n ~ ei d eng
# Adam "a: . d ,a m swe
# Adam 'ae . d ex m eng
# Adams "a: . d ,a m s swe
# Adams 'ae . d ex m s eng
# Adamson "a: . d a m . s ,o n swe
# Adamson 'ae . d ex m . s ex n eng
# Adewale a . d ex . w 'a . l ex afr
# Adewale ae . d i . v 'a: . l ei eng
# Adrians 'a: . d r ih . a n s swe
# Adrians 'e j . d r ih . a n s swe
# Adwords 'ae d ~ w oe: r0 d s eng
# Adwords 'ae d ~ w oe: rh d s eng
# Aebersold 'e j . b ex rh . s o l d eng
# Aebersold 'ei . b ex r0 . s o l d eng
# Afry 'e j . f rh i eng
# Afry 'ei . f rh i eng
# Aftersun 'a: f . t ex r0 ~ s a n eng
# Aftersun a: f . t ex r ~ s 'a n eng
# Agutter 'ae . g uu . t ex r eng
# Agutter 'ae . g uw . t ex r0 eng
# Ahmadinejad a x . m a . d 'i . n ex . j a d ara
# Ahmadinejad a xx . m a . d i . n eh . rs 'a d per
# Aidans 'e j . d ex n s eng
# Aidans 'ei . d ex n s eng
# Ainsworths 'e j n s ~ w oe: rh th s eng
# Ainsworths 'ei n s ~ w oe: r0 th s eng
# Ajagán 'a . j a . g a n swe
# Ajagán a . j a . g 'a n swe
# Ajdarevic a j . d 'a . r ex . v i tc sla
# Ajdarevic a j . d 'aa: . r ex . v i tc srp
# Akhtar 'a k . t a r swe
# Akhtar 'a x . t a r ara
# Akio 'a . k ih . u fin
# Akio a . k 'i: . o jpn
# Albert 'a l . b ex r t swe
# Albert 'ae l . b ex r0 t eng
# Albright 'o: l . b r a j t eng
# Albright 'o: l ~ b rh ai t eng
# Aldershot 'ae l . d ex r0 ~ rs o t eng
# Aldershot 'o: l . d ex rh ~ rs o t eng
# Aletheia a . l eh . t 'e . j a swe
# Aletheia a . l eh . th 'e . j a gre
# Allan 'a . l a n swe
# Allan 'ae . l ex n eng
# Allaway 'a . l ex . w e j eng
# Allaway 'ae . l ex . w ei eng
# Allspace 'o: l ~ s p e j s eng
# Allspace 'o: l ~ s p ei s eng
# Allwood 'o: l . w uu d eng
# Allwood 'o: l ~ w u d eng
# Almeria a l . m 'e: . r ih . a swe
# Almeria a l . m eh . r 'i: . a spa
# Alports 'ae l . p o: rt swe
# Alports 'ae l . p o: rt rs swe
# Alstom 'a l . s t o m swe
# Alstom a l . s t 'o m fre
# Altug 'a l . t u k ger
# Altug 'a l . t u: tur
# Alwin 'a l . v i n swe
# Alwin 'o: l ~ w i n eng
# Amar 'a: . m a r swe
# Amar a . m 'a r unk
# Amesbury 'e j m s ~ b e . rh i eng
# Amesbury 'ei m s ~ b ex . rh i eng
# Amirov a . m 'i: . r o f aze
# Amirov a . m 'i: . r o v rus
# Amman 'a . m a n s swe
# Amman a . m 'a n unk
# Analytica a . n a . l 'i . t i . k a eng
# Analytica ae . n ex . l 'i . t i . k a eng
# Analyticas a . n a . l 'i . t i . k a s eng
# Analyticas ae . n ex . l 'i . t i . k a s eng
# Anapen 'a . n a ~ p e n swe
# Anapen a n . a . p 'e: n swe
# Anddontsayitsover 'ae n d | d 'ou n t | s 'ei | 'i t s | 'ou . v ex r0 eng
# Anddontsayitsover ae n d ~ d ou n t ~ s 'e j | i t s ~ 'ou . v ex rh eng
# Anderlecht 'a n . d ex r . l e rs rt ger
# Anderlecht 'a n . d ex r . l e x t swe
# Anderson "a n . d ex . rs ,o n swe
# Anderson 'ae n . d ex r0 . s ex n eng
# Anes "a: . n ,ex s swe
# Anes 'a: . n ex s swe
# Angela 'a n . d j ex . l a swe
# Angela 'ae n . dj ex . l a eng
# Angelas 'a n . d j ex . l a s swe
# Angelas 'ae: n . dj ex . l a s eng
# Angelus 'a ng . g ex . l u s ger
# Angelus 'a ng . g ex . l uu s swe
# Angies 'e j n . dj i s eng
# Angies 'ei n . dj i s eng
# Anne "a . n ,ex swe
# Anne 'a n swe
# Anne 'ae n eng
# Annedal "a . n ex - d ,a: l swe
# Annedal a . n ex ~ d 'a: l swe
# Annie 'a . n i swe
# Annie 'ae . n i eng
# Anning "a . n ,i ng eng
# Anning 'ae . n i ng eng
# Anonymus a . n 'o . n i . m ex s swe
# Anonymus a . n oh . n 'y: . m uu s lat
# Ant-Man 'a n t ~ m a n eng
# Ant-Man 'ae n t ~ m ex n eng
# Antboy 'ae n t . b o j eng
# Antboy 'ae n t ~ b oi eng
# Anthony 'a n . t o . n i swe
# Anthony 'ae n . th ex . n i eng
# Anﬁeld 'ae n . f i: l d eng
# Anﬁeld 'ae n ~ f i: l d eng
# Aomame au . m 'a . m ex jpn
# Aomame au . m 'a: . m ex swe
# Aperfectdream 'ae | p 'oe: r0 . f e k t | d rh 'i: m eng
# Aperfectdream ae . p 'oe: rh . f ex k t | d rh 'i: m eng
# Aquaman "a . k v a - m ,a n eng
# Aquaman 'ae . k w ex ~ m ae n eng
# Archies 'a: r0 . tc i s eng
# Archies 'a: rh . tc i s eng
# Ardern 'a: . rd ex rn eng
# Ardern 'a: r0 . d ex r0 n eng
# Arial 'ae . r i . ex l swe
# Arial a . r ih . 'a: l swe
# Arkhangelsk a r . k 'a ng . ex l s swe
# Arkhangelsk a r . k 'a ng . g ex l s k swe
# Arlene a r . l 'e: n swe
# Arlene a: r0 . l 'i: n eng
# Armstrongs 'a: r m ~ s t r o ng s swe
# Armstrongs 'a: rh m ~ s t rh o ng s eng
# Arna "a: . r n ,a swe
# Arna "a: . rn ,a swe
# Arnie's 'a . rn i s swe
# Arnie's 'a: . rn i s swe
# Aronowitz a . r 'o: . n o . v i t s sla
# Aronowitz a . r 'o: . n u . v i t s sla
# Arsenal 'a: . rs ex . n ex l eng
# Arsenal 'a: r0 . s ex . n ex l eng
# Arthur 'a . rt uu r swe
# Arthur 'a: r0 . th ex r0 eng
# Artscape 'a: r0 t ~ s k ei p eng
# Artscape 'a: rt ~ s k e j p eng
# Arved "a r . v ,ex d swe
# Arved 'a r . v ex d swe
# Ascaride a . s k 'a . r i . d ex spa
# Ascaride a . s k a . r 'i . d ex fre
# Asda "a s . d ,a swe
# Asda 'a s . d a swe
# Ashforth 'ae rs ~ f o: r0 th eng
# Ashforth 'ae rs ~ f o: rh th eng
# Ashgate 'ae rs ~ g e j t eng
# Ashgate 'ae rs ~ g ei t eng
# Ashleigh 'ae . rs rl i swe
# Ashleigh 'ae c . l i eng
# AsianMidCap 'e j . rs ex n | m 'i d | k 'ae p eng
# AsianMidCap 'ei . rs ex n | m 'i d | k 'ae p eng
# Astrit 'a . s t r i t swe
# Astrit a . s t r 'i t sla
# Athens 'ae . th ex n s eng
# Athens a . t 'e: n s swe
# Atkinson 'a t . k i n . s o n swe
# Atkinson 'ae t . k i n . s ex n eng
# Atlanta a t . l 'a n . t a swe
# Atlanta ae t . l 'ae n . t a eng
# Attenius a . t 'e: . n i . uu s swe
# Attenius a . t 'e: . n ih . uu s swe
# Atwal 'a t . v a l eng
# Atwal 'ae t . w ex l eng
# Audra 'o: . d r a eng
# Audra 'o: . d rh ex eng
# August 'au . g uu s t swe
# August 'o: . g ex s t eng
# Augustine au . g uuh . s t 'i n swe
# Augustine o: . g ex . s t 'i: n eng
# Avebury 'e j v ~ b e . rh i eng
# Avebury 'ei v ~ b e . rh i eng
# Aventador a . v 'e n . t a . d o: r0 eng
# Aventador a . v 'e n . t a . d o: rh eng
# Aveyard 'e j . v j a: rd eng
# Aveyard 'ei v ~ j a: r0 d eng
# Awkwafina a: . k w a . f 'i: . n a eng
# Awkwafina o: . k w ex . f 'i: . n a eng
# Aylesbury 'e j l s ~ b uu . r i eng
# Aylesbury 'ei l s . b ex . rh i eng
# Aylott 'e j . l o t eng
# Aylott 'ei . l o t eng
# Ayoade a . j ou . 'a: . d i: eng
# Ayoade ai . ou . 'a: . d i: eng
# Azure 'ae . rs ex r0 eng
# Azure a . s 'u: . r ex unk
# BAU-enheten b "au - e: n - h ,e: . t ex n swe
# BAU-enheten b e: ~ a: ~ "uu: - e: n - h ,e: . t ex n swe
# BTJ b "e: ~ t e: ~ j ,i: swe
# BTJ b e: ~ t e: ~ j 'i: swe
# Bahta b 'a x . t a swe
# Bahta b 'aa: . t a unk
# Balanchine b 'a . l a n . tc i n unk
# Balanchine b 'ae . l ex n . tc i: n eng
# Baldock b 'a l . d o k eng
# Baldock b 'o: l . d o k eng
# Balke b "a l . k ,ex swe
# Balke b 'a l . k ex ger
# Ballin b 'a . l i n swe
# Ballin b 'o . l i n eng
# Banff b 'a n f eng
# Banff b 'ae n f eng
# Banner b 'a . n ex r swe
# Banner b 'ae . n ex r eng
# Banon b a . n 'o n spa
# Banon b a . n 'on fre
# Barak b 'a . r a k swe
# Barak b a . r 'a k swe
# Baran b 'a: . r a n ger
# Baran b 'ae . r a n eng
# Baran b a . r 'a n tur
# Barbara b 'a r . b a . r a swe
# Barbara b 'a: r . b a . r a eng
# Barbosa b a r . b 'o: . s a ita
# Barbosa b a: r . b 'ou . s a eng
# Barham b 'a: . rh ex m eng
# Barham b 'a: r . h a m eng
# Barin b 'a . r i n swe
# Barin b 'a: . r i n swe
# Barkel b 'a r . k ex l swe
# Barkel b 'a: r . k ex l swe
# Barkevious b a: r . k 'i: . v i . ex s unk
# Barkevious b a: r0 . k 'i: . v ih . ex s eng
# Barnes b 'a: r n s eng
# Barnes b 'a: rn rs swe
# Barnett b 'a: . rn e t eng
# Barnett b 'a: . rn ex t swe
# Barnwood b 'a: r0 n ~ w uw d eng
# Barnwood b 'a: rn ~ w uu d eng
# Baron-Cohen b ae . r ex n ~ k 'ou . ex n eng
# Baron-Cohen b ae . rh ex n ~ k 'ou . ex n eng
# Barrick b 'a . r i k eng
# Barrick b 'ae . rh i k eng
# Barrow b 'a . r o v eng
# Barrow b 'ae . rh ou eng
# Barry b 'a . r y swe
# Barry b 'ae . r i eng
# Barth b 'a: r0 th eng
# Barth b 'a: rt swe
# Barthes b 'a r . t ex s swe
# Barthes b 'a r t fre
# Bartkova b 'a r t . k o . v a sla
# Bartkova b 'a r t . k o: . v a swe
# Bartky b 'a rt . k y swe
# Bartky b 'a: rt . k y swe
# Basic b 'e j . s i k eng
# Basic b 'ä j . s i k eng
# Batchelor b 'a . tc ex . l o r eng
# Batchelor b 'ae . tc ex . l ex r0 eng
# Batherson b 'ae . dh ex rh . s ex n eng
# Batherson b 'ae . th ex r0 . s ex n eng
# Batmans b 'a t . m a n s swe
# Batmans b 'ae t ~ m ae n s eng
# Batterham b 'ae . t ex r ~ h ae m swe
# Batterham b 'ae . t ex r0 ~ h ae m eng
# Batuman b 'a . t uu . m a n unk
# Batuman b 'a . t uw . m a n eng
# Batwoman b 'ae t ~ w u . m ex n eng
# Batwoman b 'ae t ~ w uw . m ex n eng
# Bauckham b 'au k . h a m eng
# Bauckham b 'o: k . h ex m eng
# Baude b "au . d ,ex ger
# Baude b "o: . d ,ex swe
# Beardsworth b 'iex r0 d s ~ w oe: r0 th eng
# Beardsworth b 'iex rh d s ~ w oe: rh th eng
# Bearicecream b 'i: . ex . rh i s | k rh 'i: m eng
# Bearicecream b i: . ex . rh i s ~ k rh 'i: m eng
# Beatinathedevil b 'i: . t i . n a | dh 'e | d 'e . v i l eng
# Beatinathedevil b e . a . t i: . n a . dh ex . d 'e . v i l eng
# Beaumont b 'ou . m ex n t eng
# Beaumont b o . m 'o: ng fre
# Beckwith b 'e k ~ w i dh eng
# Beckwith b 'e k ~ w i th eng
# Bedfordshire b 'e d . f ex rh d ~ rs ex rh eng
# Bedfordshire b 'e d ~ f ex r0 d ~ rs iex r0 eng
# Beeput b 'i: . p a t eng
# Beeput b 'i: . p uu t unk
# Beevor b 'i: . v ex r eng
# Beevor b 'i: . v ex rh eng
# Beharrell b eh . h 'a . r ex l eng
# Beharrell b eh . h 'ae . rh ex l eng
# Beharrells b eh . h 'a . r ex l s eng
# Beharrells b eh . h 'ae . rh ex l s eng
# Behçets b 'e . tc ex t s tur
# Behçets b 'e x . tc ex t s unk
# Bekkengen b "e k - ,e ng . ex n nob
# Bekkengen b "ä k - ,ä ng . ex n nob
# Benjamin b "e: . n j a . m ,i n swe
# Benjamin b 'e n . dj a . m i n eng
# Benyu b 'e . n j u unk
# Benyu b 'e . n j uw eng
# Bercow b 'oe: r0 . k ou eng
# Bercow b 'oe: rh . k ou eng
# Bercows b 'oe: r0 . k ou s eng
# Bercows b 'oe: rh . k ou s eng
# Berg b 'ae r j swe
# Berg b 'oe: r g eng
# Berkeleys b 'oe: r0 . k l i s eng
# Berkeleys b 'oe: rh . k l i s eng
# Bermuda b ae r . m 'uu: . d a swe
# Bermuda b ae r . m j 'uu: . d a swe
# Bernard b 'ae: . rn a rd swe
# Bernard b ex r . n 'a: r d eng
# Bernies b 'oe: r0 . n i s eng
# Bernies b 'oe: rh . n i s eng
# Berri b 'ae . r i swe
# Berri b 'e . r i swe
# Berthoud b 'ae rt . h u d swe
# Berthoud b ae r . t 'o: fre
# Beshear b e . rs 'iex r0 eng
# Beshear b eh . rs 'e: rh eng
# Betfair b 'e t ~ f ae: rh eng
# Betfair b 'e t ~ f eex r0 eng
# Bettencourt b 'e . t ex n ~ k o: rt eng
# Bettencourt b e . t an ~ k 'u: r fre
# Betty b 'e . t i eng
# Betty b 'e . t y swe
# Betway b 'e . t w ei eng
# Betway b 'e t ~ w e j eng
# Beverlys b 'e . v ex r0 . l i s eng
# Beverlys b 'e . v ex rh . l i s eng
# Biden b 'a j . d ex n eng
# Biden b 'ai . d ex n eng
# Bidens b 'a j . d ex n s eng
# Bidens b 'ai . d ex n s eng
# Bigfoot b 'i g ~ f uu t swe
# Bigfoot b 'i g ~ f uw t eng
# Billings b "i . l ,i ng s swe
# Billings b 'i . l i ng s swe
# Billy b 'i . l i eng
# Billy b 'i . l y swe
# Binding b "i n . d ,i ng swe
# Binding b 'a j n . d i ng eng
# Binta b "i n . t ,a swe
# Binta b 'i n . t a swe
# BioArctic b 'a . j u | 'a: rh k . t i k eng
# BioArctic b ai . ou ~ 'a: r0 k . t i k eng
# Bionic b a . j 'o . n i k eng
# Bionic b ai . 'o . n i k eng
# Biontech b a . j 'o n ~ t e k eng
# Biontech b ai . 'o n ~ t e k eng
# Biontechs b a . j 'o n ~ t e k s eng
# Biontechs b ai . 'o n ~ t e k s eng
# Birch b 'i r c ger
# Birch b 'oe: r0 tc eng
# Birkdale b 'oe: r0 k ~ d ei l eng
# Birkdale b 'oe: rh k . d e j l eng
# Birrell b 'i . r ex l eng
# Birrell b 'i . rh ex l eng
# Bisnode b 'i . s n ou d eng
# Bisnode b 'i s ~ n ou d eng
# Bithell b 'i . th ex l eng
# Bithell b i . t 'e l swe
# Björnstjerne b j "oe: rn - s t j ,ae: . rn ex nob
# Björnstjerne b j "oe: rn - x ,ae: . rn ex swe
# Blackflash b l 'a k ~ f l ae rs eng
# Blackflash b l 'ae k ~ f l ae rs eng
# Blackmoore b l 'ae k ~ m o: r0 eng
# Blackmoore b l 'ae k ~ m o: rh eng
# Blackport b l 'ae k ~ p o: r0 t eng
# Blackport b l 'ae k ~ p o: rh t eng
# Blackthorne b l 'ae k - th o: rh n eng
# Blackthorne b l 'ae k ~ th o: r0 n eng
# Blackway b l 'ae k ~ w e j eng
# Blackway b l 'ae k ~ w ei eng
# Blanche b l 'a: n tc eng
# Blanche b l 'a: rn rs swe
# Blaney b l 'e j . n i eng
# Blaney b l 'ei . n i eng
# Blankenship b l 'a ng . k ex n ~ rs i p eng
# Blankenship b l 'ae ng . k ex n ~ rs i p eng
# Blanshard b l 'a rn . rs a: rd eng
# Blanshard b l 'ae n . rs a r d eng
# Blanshard b l a rn . rs 'a: rd swe
# Bloth b l 'o th eng
# Bloth b l 'o: t ger
# Blueridge b l 'uw: ~ r i dj eng
# Blueridge b l 'uw: ~ rh i dj eng
# Blythe b l 'a j dh eng
# Blythe b l 'ai dh eng
# Blyton b l 'a j . t o n eng
# Blyton b l 'a j . t o n swe
# Blyton b l 'ai . t ex n eng
# Bobby b 'o . b i eng
# Bobby b 'o . b y swe
# Bochum b "o . k ,uu m swe
# Bochum b 'o . rs u m swe
# Bodie b 'ou . d i eng
# Bodie b 'u: . d i eng
# Bogarde b 'u: . g a: rd eng
# Bogarde b ou . g 'a: r0 d eng
# Bohemia b o . h 'i: . m ih . a eng
# Bohemia b oh . h 'e: . m ih . a swe
# Boligjakt b "u: . l i - j ,a k t nob
# Boligjakt b 'u: . l i ~ j a k t dan
# Bonne b 'o . n ex swe
# Bonne b 'o n fre
# Booksmart b 'u k ~ s m a: rt eng
# Booksmart b 'uw k ~ s m a: r0 t eng
# Boonsboro b 'u: n s . b o . r u eng
# Boonsboro b 'uw: n s ~ b ex . rh ex eng
# Boozt b 'u: s t eng
# Boozt b 'uw: s t eng
# Borderforce b 'o: r0 . d ex r0 ~ f o: r0 s eng
# Borderforce b 'o: rh . d ex rh ~ f o: rh s eng
# Borderlands b 'o: r0 . d ex r0 ~ l ae n d s eng
# Borderlands b 'o: rh . d ex rh ~ l ae n d s eng
# Borkovec b 'o r . k o . v ex k sla
# Borkovec b 'o r . k u . v e k sla
# Botan b 'o: . t a n swe
# Botan b oh . t 'a: n swe
# Boxleitner b 'o k s ~ l a j t . n ex r ger
# Boxleitner b 'o k s ~ l ai t . n ex r0 eng
# Bragg b r 'a g swe
# Bragg b rh 'ae g eng
# Braine b r 'e n fre
# Braine b rh 'ei n eng
# Brainpool b rh 'e j n ~ p u: l eng
# Brainpool b rh 'ei n ~ p uw: l eng
# Brake b r "a: . k ,ex swe
# Brake b rh 'ei k eng
# Brantes b r "a n . t ,ex s swe
# Brantes b r 'a: n t fre
# Braverman b r 'a: . v ex r ~ m a n eng
# Braverman b rh 'ei . v ex r0 ~ m ex n eng
# Breakit b rh 'e j k ~ i t eng
# Breakit b rh 'ei k | 'i t eng
# Bree b r 'i: swe
# Bree b rh 'i: eng
# Bretton b r 'e . t o n eng
# Bretton b rh 'e . t ex n eng
# Brewsters b rh 'uw: . s t ex r0 s eng
# Brewsters b rh 'uw: . s t ex rh s eng
# Bridgerton b rh 'i . dj ex r0 . t ex n eng
# Bridgerton b rh 'i . dj ex rh - t o n eng
# Brighton b r 'a j . t ex n swe
# Brighton b rh 'ai . t ex n eng
# Brindley b r 'i n d . l i eng
# Brindley b rh 'i n d . l i eng
# Brion b r 'a . j o n eng
# Brion b r 'i: . o n swe
# Broadchurch b rh 'o: d ~ tc oe: r0 tc eng
# Broadchurch b rh 'o: d ~ tc oe: rh tc eng
# Broadfoot b rh 'o: d ~ f u t eng
# Broadfoot b rh 'o: d ~ f uw t eng
# Broander b r oh . 'a n . d ex r swe
# Broander b r u: . 'a n . d ex r swe
# Brodys b rh 'o: . d i s eng
# Brodys b rh 'ou . d i s eng
# Brokenwood b rh 'ou . k ex n ~ w u d eng
# Brokenwood b rh 'ou . k ex n ~ w uw d eng
# Broline b r 'u: . l a j n swe
# Broline b rh 'ou . l a j n eng
# Brooksby b rh 'uw k s . b i eng
# Brooksby b rh 'uw: k s . b i eng
# Brophy b r 'o . f i eng
# Brophy b rh 'ou . f i eng
# Brosnan b r 'o . s n a n swe
# Brosnan b rh 'o . s n ex n eng
# Brotherus b r oh . t 'e: . r uu s eng
# Brotherus b rh 'a . dh ex . rh ex s eng
# Browders b rh 'au . d ex r0 s eng
# Browders b rh 'au . d ex rs eng
# Browne b rh 'au . n ex eng
# Browne b rh 'au n eng
# Bruiser b rh 'uw: . s ex r0 eng
# Bruiser b rh 'uw: . s ex rh eng
# Bryants b rh 'a . j ex n t s eng
# Bryants b rh 'ai . ex n t s eng
# Bryony b rh 'a . j ex . n i eng
# Bryony b rh 'ai . ex . n i eng
# Buckeridge b 'a . k ex r0 ~ rh i dj eng
# Buckeridge b 'a . k ex rh ~ rh i dj eng
# Bullyoung b u l ~ j 'a ng eng
# Bullyoung b uw l ~ j 'a ng eng
# Bulow b 'uu: . l o v unk
# Bulow b j 'uw: . l ou eng
# Bunyan b 'a . n j ex n eng
# Bunyan b 'uu . n j a n eng
# Burbules b 'oe: r0 . b ex l s eng
# Burbules b oe rh . b j 'uw: . l ex s eng
# Burchnall b 'oe: r0 tc . n o: l eng
# Burchnall b 'oe: rh tc . n o: l eng
# Burford b 'oe: r0 ~ f ex r0 d eng
# Burford b 'uu: r ~ f o: rd eng
# Burger b 'oe: r0 . g ex r0 eng
# Burger b 'uu r . g ex r swe
# Burundi b uu . r 'uu n . d i swe
# Burundi b uuh . r 'uu n . d i swe
# Burwood b 'oe: r0 ~ w uw d eng
# Burwood b 'oe: rh ~ w u d eng
# Burås b "uu: . r ,o: s swe
# Burås b "uu: r - ,o: s swe
# Busby b 'uu: s ~ b y: swe
# Busby b 'uw s . b i eng
# Bushcraft b 'u rs . k r a: f t swe
# Bushcraft b 'uw rs ~ k rh a: f t eng
# Butker b 'a t . k ex r0 eng
# Butker b 'uu t . k ex r eng
# Buttigieg b 'uw . t i . dj ex dj eng
# Buttigieg b 'uw: . t i . dj i dj eng
# Byatt b 'a . j ex t eng
# Byatt b 'ai . ex t eng
# Byrock b "y: - r ,o k eng
# Byrock b 'ai . rh o k eng
# Bytedance b 'a j t . d ae n s eng
# Bytedance b 'ai t ~ d a: n s eng
# Bythebook b 'a j | dh ex ~ b 'uu k eng
# Bythebook b 'ai | dh 'e | b 'uw k eng
# Børresen b "oe . r ex . s ,e n nob
# Børresen b 'oe . r ex . s ex n dan
# C-Rad s 'i: ~ r a d eng
# C-Rad s 'i: ~ rh ae d eng
# COX-hämmare k "o k s - h ,ä m . a . r ex swe
# COX-hämmare k o k s ~ h 'ä m . a . r ex swe
# Cabret k a . b r 'e: fre
# Cabret k a b . r 'e: swe
# Caden k 'e j . d ex n eng
# Caden k 'ei . d ex n eng
# Caeleb k 'e j . l ex b eng
# Caeleb k 'ei . l ex b eng
# Cair k 'a j r unk
# Cair k 'eex r0 eng
# Caity k 'e j . t i eng
# Caity k 'ei . t i eng
# Californication k ae . l i . f o: r0 . n i . k 'ei . rs ex n eng
# Californication k ae . l i . f o: rh . n i . k 'e j . rs ex n swe
# Calkins k 'a l . k i n s eng
# Calkins k 'o: l . k i n s eng
# Callmeawinner k 'o: l | m 'i: | 'ae | w 'i . n ex r0 eng
# Callmeawinner k 'o: l | m i: ~ ex ~ w 'i . n ex rh eng
# Calvert k 'a l . v ex rt eng
# Calvert k 'ae l . v ex r0 t eng
# Calvin k 'ae l . v i n eng
# Calvin k a l . v 'i: n swe
# Campbell-Martin k 'ae m . b ex l | m 'a: r . t i n eng
# Campbell-Martin k 'ae m . b ex l | m 'a: r0 . t i n eng
# Canada k 'a . n a . d a swe
# Canada k 'ae . n ex . d a eng
# Canberra k 'ae n . b ex . rh ex eng
# Canberra k a n . b "ae . r ,a eng
# Candleford k 'ae n . d ex l ~ f ex r0 d eng
# Candleford k 'ae n . d ex l ~ f ex rh d eng
# Candyland k 'ae n . d i . l ae n d eng
# Candyland k 'ae n . d i ~ l ae n d eng
# Canmore k 'ae n ~ m o: r0 eng
# Canmore k 'ae n ~ m o: rh eng
# Canter k 'a n . t ex r eng
# Canter k 'ae n . t ex r0 eng
# Caporaso k a . oh . r 'a: . s u eng
# Caporaso k a . p oh . r 'a: . s u swe
# Capra k 'a . p r a swe
# Capra k 'a: . p r a swe
# Cardi k 'a r . d i unk
# Cardi k 'a: r0 . d i eng
# Cardiff k 'a: . rd i f swe
# Cardiff k 'a: r0 . d i f eng
# Carnap k 'a: r0 . n ex p eng
# Carnap k 'a: rh . n ex p eng
# Carnoustie k a: r0 . n 'uw: . s t i eng
# Carnoustie k a: rh . n 'uw: . s t i eng
# Carnoy k 'a: r0 . n oi eng
# Carnoy k 'a: rh . n o j eng
# Carolina k a . r o . l 'a j . n a eng
# Carolina k a . r oh . l "i: . n ,a swe
# Caroline k 'ae . rh ex . l ai n eng
# Caroline k a . r oh . l 'i: n swe
# Carsely k 'a: r0 . s l i eng
# Carsely k 'a: rh . s l i eng
# Carsons k 'a: r . s o n s swe
# Carsons k 'a: r0 . s ex n s eng
# Carter k 'a: . rt ex r eng
# Carter k 'a: r0 . t ex r0 eng
# Carthy k 'a: r0 . th i eng
# Carthy k 'a: rh . th i eng
# Catalonia k a . t a . l 'o . n ih . a spa
# Catalonia k ae . t a . l 'ou . n ih . ex eng
# Catherine k 'ae . th ex . rh i n eng
# Catherine k a . t r 'i: n swe
# Catlin k 'a t . l i n eng
# Catlin k 'ae t . l i n eng
# Caton k 'ae . t ex n eng
# Caton k 'ei . t ex n eng
# Cattrall k 'ae . t r ex l eng
# Cattrall k ae . t r 'e l swe
# Caty k 'ae . t i eng
# Caty k 'ei . t i eng
# Cavani k a . v 'a: . n i ita
# Cavani k a . v 'aa: . n i swe
# Ceci s 'e: . s i swe
# Ceci s eh . s 'i: swe
# Celibidache s e . l i . b i . d 'a . k ex swe
# Celibidache tc e . l i . b i . d 'a . k ex unk
# Chaouche k a . 'u rs fre
# Chaouche tc 'au . tc ex unk
# Chapelwaite tc 'ae . p ex l ~ w e j t eng
# Chapelwaite tc 'ae . p ex l ~ w ei t eng
# Chariandy tc ae . rh i . 'ae n . d i eng
# Chariandy tc ae: . rh i . 'ae: n . d i eng
# Charlie tc 'a: . rl i eng
# Charlie tc 'a: r0 . l i eng
# Charliebrown tc a: . rl i ~ b rh 'au n eng
# Charliebrown tc a: r0 . l i ~ b rh 'au n eng
# Charlock tc 'a: r0 . l o k eng
# Charlock tc 'a: rh . l o k eng
# Charlotte tc 'a: r . l ex t eng
# Charlotte x a . rl 'o t swe
# Charlton tc 'a: r0 . l t ex n eng
# Charlton tc 'a: rl . t ex n eng
# Charmy rs a r . m 'i: fre
# Charmy tc 'a: rh . m i eng
# Chatterjee tc 'a . t ex r0 ~ dj i: eng
# Chatterjee tc a . t ex r . dj 'i: ind
# Chatterley c 'ae . t ex r0 . l i eng
# Chatterley tc 'ae . t ex rh . l i eng
# Chaucer rs o . s 'e: swe
# Chaucer tc 'o: . s ex r0 eng
# Cheridene tc 'e . rh ex . d i: n eng
# Cheridene tc e . rh i . d 'i: n eng
# Cherub tc 'e . rh ex b eng
# Cherub tc eh . r 'uu: b swe
# Chesbrough tc 'e s . b rh ex eng
# Chesbrough tc 'e s ~ b rh ex eng
# Cheshires tc 'e . rs oe: r0 s eng
# Cheshires tc 'e . rs oe: rh s eng
# Chessington tc 'e . s i ng . t ex n eng
# Chessington tc 'e . s i ng . t o n eng
# Chet rs 'e t swe
# Chet tc 'e t eng
# Cheverton rs 'e . v ex r0 . t ex n eng
# Cheverton rs 'e . v ex rh . t o n eng
# Chewbacca tc uw: . b 'a . k a eng
# Chewbacca tc uw: . b 'ae . k a eng
# Chiara k i . 'aa: . r a ita
# Chiara tc i . 'a: . r a swe
# Chicago c i . k 'a: . g u eng
# Chicago tc i . k 'a: . g ou eng
# Chicky tc 'i . k i eng
# Chicky tc 'i . k y swe
# Chillmix c "i l - m ,i k s swe
# Chillmix tc 'i l ~ m i k s eng
# Chipperfield tc 'i . p ex r0 ~ f i: l d eng
# Chipperfield tc 'i . p ex rh ~ f i: l d swe
# Choi c 'o j swe
# Choi tc 'oi eng
# Chomsky c 'o m . s k i eng
# Chomsky tc 'o m . s k i eng
# Chopra tc 'o . p r a swe
# Chopra tc 'o: . p r a ind
# Christine k r i . s t 'i: n swe
# Christine k rh i . s t 'i: n eng
# Christopher k r i . s t 'o . f ex r swe
# Christopher k rh 'i . s t ex . f ex r0 eng
# Chromebooks k rh 'ou m ~ b u k s eng
# Chromebooks k rh 'ou m ~ b uw k s eng
# Chrusjtjev k r 'u s . tc e f sla
# Chrusjtjev k r 'uu s t . j ex v sla
# Chum c 'u m swe
# Chum tc 'a m eng
# Churchills tc 'oe: r0 . tc i l s eng
# Churchills tc 'oe: rh ~ tc i l s eng
# Cimberly k 'i m . b ex rh . l i eng
# Cimberly s 'i m . b ex r0 . l i eng
# Cina k "i: . n ,a swe
# Cina tc 'i: . n a ita
# Citizenfour s 'i . t i . s ex n | f 'o: r0 eng
# Citizenfour s 'i . t i . s ex n | f 'o: rh eng
# Claires k l 'ae: r s swe
# Claires k l 'eex r0 s eng
# Clanton k l 'a n . t o n eng
# Clanton k l 'ae n . t ex n eng
# Clarkes k l 'a: r k s swe
# Clarkes k l 'a: r0 k s eng
# Claudia k l 'au . d ih . a swe
# Claudia k l 'o: . d ih . a eng
# Clausen k l 'au . s e n swe
# Clausen k l 'au . s ex n swe
# Clausewitz k l "au . s ex - v ,i t s swe
# Clausewitz k l 'au . s ex . v i t s rus
# Clayne k l 'e j n eng
# Clayne k l 'ei n eng
# Clemenger k l 'e . m ex n . dj ex r0 eng
# Clemenger k l 'e . m ex n . dj ex rh eng
# Clement k l 'e . m ex n t eng
# Clement k l 'e: . m ex n t swe
# Clemente k l eh . m 'a: ng t fre
# Clemente k l eh . m 'e n . t ex ita
# Clementines k l e . m ex n . t 'a j n s eng
# Clementines k l e . m ex n . t 'ai n s eng
# Cliffords k l 'i . f ex r0 d s eng
# Cliffords k l 'i . f ex rh d s eng
# Clinton k l 'i n . t ex n eng
# Clinton k l 'i n . t o n swe
# Cloverfield k l 'a . v ex rh ~ f i: l d eng
# Cloverfield k l 'ou . ex r0 ~ f i: l d eng
# Clunes k l 'u: n s eng
# Clunes k l 'uw: n s eng
# Clutterbuck k l 'a . t ex r0 ~ b a k eng
# Clutterbuck k l 'a . t ex rh . b a k eng
# Clément k l 'e: . m ex n t swe
# Clément k l eh . m 'a: ng fre
# Coca k "u: . k ,a swe
# Coca k 'ou . k a eng
# Cochran k 'o . k r a n eng
# Cochran k 'o . k rh ex n eng
# Cochrane k 'o . k r a n swe
# Cochrane k 'o . k rh ei n eng
# Coger k 'u: . g ex r swe
# Coger k o . rs 'e: r fre
# Cogne k 'o . n j ex ita
# Cogne k 'o n j fre
# Cohu k 'ou . h j uw: eng
# Cohu k 'u: . h uu unk
# Coinshares k 'o j n ~ rs ae: rh s eng
# Coinshares k 'oi n ~ rs eex r0 s eng
# Colgate-Palmolive k 'o l . g ei t | p a: m ~ 'o . l i v eng
# Colgate-Palmolive k o l . g e j t ~ p "a l m - oh . l ,i: v eng
# Colombine k 'o . l o m . b a j n eng
# Colombine k 'o . l o m . b ai n eng
# Comery k 'o . m ex . r i swe
# Comery k 'o . m ex . rh i eng
# Comewithaflash k 'a m | w 'i dh | 'ae | f l 'ae rs eng
# Comewithaflash k 'a m | w i dh ~ ex ~ f l 'ae rs eng
# Commerzbank k o . m 'ae r t s ~ b a ng k ger
# Commerzbank k o . m 'e r t s ~ b a ng k swe
# Communicare k o . m j 'uw: . n i . k ae r eng
# Communicare k o . m j 'uw: . n i . k eex r0 eng
# Congo k 'o ng . g ou eng
# Congo k 'o ng . g u swe
# Connerton k 'o . n ex r0 . t ex n eng
# Connerton k 'o . n ex rh . t ex n eng
# Considine k 'au n . s i . d ai n eng
# Considine k 'o n . s i . d i n swe
# Constance k 'o n . s t a n s eng
# Constance k 'o n . s t ex n s eng
# Cooder k 'uw: . d ex r0 eng
# Cooder k 'uw: . d ex rh eng
# Cooper k 'u: . p ex r eng
# Cooper k 'uw: . p ex r0 eng
# Cooray k 'u: . r ex j eng
# Cooray k 'uw: . rh ei eng
# Copperhill k 'o . p ex r0 ~ h i l eng
# Copperhill k 'o . p ex rh ~ h i l eng
# Corbyns k 'o r . b i n s eng
# Corbyns k 'o: r0 . b i n s eng
# Corder k 'o r . d ex r eng
# Corder k 'o: r0 . d ex r0 eng
# Corlett k 'o r . l ex t eng
# Corlett k 'o r0 . l ex t eng
# Cornet k o r . n 'e t swe
# Cornet k o r . n 'e: fre
# Cornley k 'o: r0 n . l i eng
# Cornley k 'o: rh n . l i eng
# Cornwalls k 'o: r0 n ~ w o: l s eng
# Cornwalls k 'o: rh n ~ w o: l s eng
# Costco k 'o s t . k ou eng
# Costco k 'o s t . k u eng
# Countrygirl k 'a n . t rh i ~ g oe: r0 l eng
# Countrygirl k 'a n . t rh i ~ g oe: rl eng
# Courteney k 'o: r0 . t ex . n i eng
# Courteney k 'o: r0 t . n i eng
# Courteney k 'o: rh . t ex . n i eng
# Cragen k rh 'e j . g ex n eng
# Cragen k rh 'ei . g ex n eng
# Crandall k r 'a n . d a l eng
# Crandall k rh 'ae n . d ex l eng
# Creditsafe k rh 'e . d i t ~ s e j f eng
# Creditsafe k rh 'e . d i t ~ s ei f eng
# Cregård k r "e: - g ,o: rd swe
# Cregård k r 'e: ~ g o: rd swe
# Crocker k r 'o . k ex r eng
# Crocker k rh 'o . k ex r0 eng
# Crooks k r 'u: k s swe
# Crooks k rh 'uw k s eng
# Crowder k r 'au . d ex r eng
# Crowder k rh 'au . d ex r0 eng
# Croxford k rh 'o k s . f ex rh d eng
# Croxford k rh 'o k s ~ f ex r0 d eng
# Cruse k r "uu: . s ,ex eng
# Cruse k rh 'uw: s eng
# Cuba k "uu: . b ,a swe
# Cuba k j 'uw: . b a eng
# Cullinan k 'o . l i . n ex n eng
# Cullinan k 'uu . l i . n a n eng
# Cuoco k 'u . k u swe
# Cuoco k w 'o: . k u ita
# Curzan k 'oe: r0 . s a: n eng
# Curzan k 'oe: rh . s a: n eng
# Cushing k 'a . rs i ng eng
# Cushing k 'uw . rs i ng eng
# Cushings k 'a . rs i ng s eng
# Cushings k 'uw . rs i ng s eng
# Cyberphoto s 'a j . b ex r . f o . t u eng
# Cyberphoto s 'ai . b ex r0 ~ f ou . t ou eng
# Cyprus s 'a j . p rh ex s eng
# Cyprus s 'ai . p rh ex s eng
# Cyxone s 'i k . s ou n eng
# Cyxone s y k . s 'o: n eng
# Czarniawska rs 'a r . n i . a v . s k a swe
# Czarniawska tc 'a r . n i . a v . s k a swe
# Célestin s e . l e . s t 'i n fre
# Célestin s e . s l eh . s t 'i n fre
# DNA-bevis d e: . ä n . "a: - b eh . v ,i: s swe
# DNA-bevis d e: ~ ä n ~ "a: - b eh . v ,i: s swe
# Dacre d 'e j . k ex rh eng
# Dacre d 'ei . k ex r0 eng
# Dacres d 'e j . k rh ex s eng
# Dacres d 'ei . k rh ex s eng
# Dafo d 'a: . f u swe
# Dafo d a . f 'u: unk
# Dahlkemper d 'a: l ~ k e m . p ex r eng
# Dahlkemper d 'a: l ~ k e m . p ex r0 eng
# Dalkarlsbo d "a: l . k a: rs - b ,u: swe
# Dalkarlsbo d a: l ~ k a: rs ~ b 'u: swe
# Damergi d 'ae . m ex r0 . dj i eng
# Damergi d 'ae . m ex rh . dj i eng
# Damngoodlooking d 'ae m | g 'uw d | l 'uw . k i ng eng
# Damngoodlooking d 'ae m | g uu d ~ l 'uu . k i ng eng
# Dana d "a: . n ,a swe
# Dana d 'a: . n a swe
# Danceworks d 'a: n s ~ w oe: r0 k s eng
# Danceworks d 'a: n s ~ w oe: rh k s eng
# Dane d "a: . n ,ex swe
# Dane d 'e j n eng
# Dartaye d a: r0 . t 'e j eng
# Dartaye d a: rh . t 'e j eng
# Dartmouths d 'a: r0 t ~ m ex th s eng
# Dartmouths d 'a: rh t ~ m ex th s eng
# Darwin d 'a: r . w i n eng
# Darwin d 'a: r0 . w i n eng
# Darwish d 'a: r0 . w i rs eng
# Darwish d a r . v 'i rs per
# Dassault d a . s 'o: fre
# Dassault d a . s 'o: l t swe
# Davian d 'e j . v i . ex n eng
# Davian d 'ei . v ih . ex n eng
# DeGale d eh . g 'e j l eng
# DeGale d ex . g 'ei l eng
# DeGales d eh . g 'e j l s eng
# DeGales d ex . g 'ei l s eng
# DeGeneres d e ~ dj 'e . n ex . rh ex s eng
# DeGeneres d eh . dj 'e . n ex . r ex s swe
# Dealwithakiss d 'i: l | w 'i dh | ex . k 'i s eng
# Dealwithakiss d 'i: l | w 'i th | 'ae | k 'i s eng
# Debrincat d eh . b r 'i ng . k a t eng
# Debrincat d ex . b rh 'i ng . k ex t eng
# Deckard d 'e . k ex r0 d eng
# Deckard d 'e . k ex rh d eng
# Delamont d 'e . l a . m o n t eng
# Delamont d e . l a . m 'o: n t fre
# Deledda d eh . l 'e . d a ita
# Deledda d eh . l 'ä . d a spa
# Deloria d eh . l 'o: . r ih . a swe
# Deloria d eh . l 'u: . r ih . a swe
# Demir d 'e: . m i r swe
# Demir d eh . m 'i: r swe
# Denali d eh . n 'a: . l i eng
# Denali d i . n 'a: . l i eng
# Dermott d 'ae r . m o t swe
# Dermott d 'oe: r0 . m o t eng
# Descartes d eh . k 'a r t swe
# Descartes d eh . k 'a r t s swe
# Despres d e . s p r 'e s spa
# Despres d e s . p r 'e s swe
# Dexa d "e k . s ,a swe
# Dexa d "ä k . s ,a swe
# Dhavernas d ex . v 'oe: r0 . n ex eng
# Dhavernas d ex . v 'oe: rh . n ex eng
# DiZio d i . dj 'i: . u eng
# DiZio d i . dj 'i: . uw eng
# Diablo d i . 'aa: . b l o spa
# Diablo d i . 'aa: . b l u swe
# Diamondinthesky d 'a j . m ex n d | i n ~ dh ex ~ s k 'a j eng
# Diamondinthesky d 'ai . m ex n d | 'i n | dh 'e | s k 'ai eng
# Diana d ai . 'ae . n a eng
# Diana d i . "a: . n ,a swe
# Dianes d a . j 'ae n s eng
# Dianes d ai . 'ae n s eng
# Dibbas d "i . b ,a s swe
# Dibbas d 'i . b a s unk
# Dickerson d 'i . k ex r . s o n eng
# Dickerson d 'i . k ex r0 . s ex n eng
# Dillane d i . l 'e j n eng
# Dillane d i . l 'ei n eng
# Dimitar d 'i . m i . t a r swe
# Dimitar d i . m 'i: . t a r sla
# Dinamo d i . n 'a: . m u swe
# Dinamo d i . n 'aa: . m u sla
# Dix-Hallpikes d i k s ~ h 'a l . p a j k s swe
# Dix-Hallpikes d i k s ~ h 'o: l . p a j k s swe
# Djojj d j 'o j eng
# Djojj dj 'o j eng
# Dogborn d 'o g . b o: rn eng
# Dogborn d 'o g ~ b o: r0 n eng
# Dogboy d 'o g ~ b o j eng
# Dogboy d 'o g ~ b oi eng
# Doherty d 'o . h ex r0 . t i eng
# Doherty d 'o . h ex rh . t i eng
# Dohertys d 'o . h ex r0 . t i s eng
# Dohertys d 'o . h ex rh . t i s eng
# Dole d 'o: . l ex swe
# Dole d 'ou l eng
# Dolomite d 'o . l ex . m ai t eng
# Dolomite d o . l oh . m 'i: . t ex ita
# Dolores d oh . l 'o: . r ex s swe
# Dolores d oh . l 'o: . rh ex s eng
# Donald d 'o . n a l d swe
# Donald d 'o . n ex l d eng
# Doneisdone d 'a n | 'i s | d 'a n eng
# Doneisdone d a n ~ i s ~ d 'a n eng
# Donnellan d 'o . n ex . l a n eng
# Donnellan d 'o . n ex . l ex n eng
# Doyle d 'o j l eng
# Doyle d 'oi l eng
# Dplay d 'i: ~ p l e j eng
# Dplay d 'i: ~ p l ei eng
# Dreamboy d rh 'i: m ~ b o j eng
# Dreamboy d rh 'i: m ~ b oi eng
# Dreamlady d r 'i: m ~ l e j . d i eng
# Dreamlady d rh 'i: m ~ l ei . d i eng
# Dreammoko d rh 'i: m ~ m ou . k uw eng
# Dreammoko d rh 'i: m ~ m u: . k u eng
# Dumbledores d 'a m . b ex l . d o: r0 s eng
# Dumbledores d 'a m . b ex l . d o: rs swe
# Dunkerque d 'a n ~ k oe: r0 k eng
# Dunkerque d a ng . k 'e r k fre
# Dunston d 'a n . s t ex n eng
# Dunston d 'a n . s t o n eng
# Dupuytrens d y . p uu j . t r 'e n s swe
# Dupuytrens d y . p uu j . t r 'ä: n s fre
# During d 'uu: . r i ng swe
# During d j 'uw: . rh i ng eng
# Dursley d 'oe: r0 . s l i eng
# Dursley d 'oe: rh . s l i eng
# Dusktodawn d 'a s k | t 'uw | d 'o: n eng
# Dusktodawn d 'a s k | t uw: ~ d 'o: n eng
# Dustmann d "u s t - m ,a n ger
# Dustmann d 'u s t - m a n ger
# Dwyer-Owens d w 'a . j ex rh | 'ou . ex n s eng
# Dwyer-Owens d w 'ai . ex rh | 'ou . ex n s eng
# E4:an "e: - f ,y: . r a n swe
# E4:an "e: . f ,y: . r a n swe
# EFA "e: . f ,a swe
# EFA "e: ~ f ,a swe
# EU "e: . ,uu: swe
# EU "e: ~ ,uu: swe
# EU-toppmöte "e: ~ uu: - t o p - m ,ö: . t ex swe
# EU-toppmöte "e: ~ uu: - t o p . m ,ö: . t ex swe
# Eagleman 'i: . g ex l . m ae n eng
# Eagleman 'i: . g ex l ~ m ae n eng
# Eaglewood 'i: . g ex l ~ w u d eng
# Eaglewood 'i: . g ex l ~ w uw d eng
# Earnie 'oe: r0 . n i eng
# Earnie 'oe: rh . n i eng
# Earthscan 'oe: r0 th ~ s k ae n eng
# Earthscan 'oe: rh th ~ s k ae n eng
# Eastnine 'i: s t . n a j n eng
# Eastnine i: s t ~ n 'ai n eng
# Eastvale 'i: s t ~ v e j l eng
# Eastvale 'i: s t ~ v ei l eng
# Edinson 'e . d i n . s o n swe
# Edinson 'e d . i n . s o n swe
# Edmonds 'e d . m o n d s swe
# Edmonds 'e d . m o n d s eng
# Edmonds 'e: d . m o n d s swe
# Educare 'e . d j u . k eex rh eng
# Educare 'e . d j uw . k eex r0 eng
# Edward 'e d . w ex r0 d eng
# Edward 'e: d ~ v a rd swe
# Edwards 'e d . w ex r0 d s eng
# Edwards 'e d ~ v a rd rs swe
# Eggsy 'ae g . s i eng
# Eggsy 'e g . s i eng
# Egleton 'e . g ex l . t o n eng
# Egleton 'e . g l ex . t ex n eng
# Egmont 'e g . m ex n t eng
# Egmont 'e g . m o n t swe
# Eibhlín 'e v . l i: n gla
# Eibhlín ai . l 'i: n eng
# Eilish 'a j . l i rs eng
# Eilish 'ai . l i rs eng
# Ekwurtzel 'e: . k v uu rt . rs ex l eng
# Ekwurtzel e: . k v 'uu rt . rs ex l swe
# Elaines i . l 'e j n s eng
# Elaines i . l 'ei n s eng
# Eleanor 'e . l ex . n o: r0 eng
# Eleanor e . l eh . n 'o: r swe
# Elfström "e l f - s t r ,ö m swe
# Elfström "e l f s - s t r ,ö m swe
# Elgklou "e l j - k l ,u: swe
# Elgklou "ä l j - k l ,u: swe
# Elizabeth e . l 'i . s ex . b ex th eng
# Elizabeth eh . l "i: . s a . b ,e t swe
# Ellerton 'e . l ex . rt o n swe
# Ellerton 'e . l ex r ~ t o n eng
# Ellingham 'e . l i ng . ex m eng
# Ellingham 'e . l i ng . h a m eng
# Emmerdale 'e . m ex r0 ~ d ei l eng
# Emmerdale 'e . m ex rh . d e j l eng
# England 'e ng ~ l a n d swe
# England 'i ng g ~ l ex n d eng
# Enzensberger 'e n t . s ex n s ~ b ae r . g ex r swe
# Enzensberger 'e n t . s ex n ~ b ae r . g ex r swe
# Eragon 'e . rh ex . g o n eng
# Eragon 'e: . r a . g o n swe
# Erdin 'e r . d i n tur
# Erdin ae r . d 'i: n swe
# Eric "e: . r ,i k swe
# Eric 'e . rh i k eng
# Eritrea e . r i . t r "e: . ,a swe
# Eritrea eh . r i . t r "e: . ,a swe
# Ernest 'oe: . rn ex s t swe
# Ernest 'oe: r0 . n ex s t eng
# Eskisehirspor e . s k i . rs 'e: . h i r . s p o r swe
# Eskisehirspor e . s k i . s ex . h 'i r . s p o r tur
# Esposito e . s p o . s 'i: . t o spa
# Esposito e . s p oh . s 'i: . t u lat
# Estrada e . s t r 'a: . d a swe
# Estrada eh . s t r 'a: . d a swe
# Eugene eu . x 'e: n swe
# Eugene j uw . dj 'i: n eng
# Euroclear j 'uw: . rh ou . k l iex rh swe
# Euroclear j 'uw: . rh ou ~ k l iex r0 eng
# Eurocup j 'u . rh ou ~ k a p eng
# Eurocup j 'uw . rh ou ~ k a p eng
# Europ 'eu . r u: p eng
# Europ j 'uw: . rh ex p eng
# Europace j 'uw: . rh ou ~ p e j s eng
# Europace j 'uw: . rh ou ~ p ei s eng
# Eurosport j 'uu: . r u ~ s p o: rt eng
# Eurosport j 'uw: . rh ex . s p o: r0 t eng
# Eurythmic j ex . rh 'i t . m i k eng
# Eurythmic j uw: . rh 'i th . m i k eng
# Eustace e v . s t 'a: . s ex gre
# Eustace j 'uw: . s t ex s eng
# Eve "e: . v ,ex swe
# Eve 'i: v eng
# Everglo 'e . v ex r0 ~ g l ou eng
# Everglo 'e . v ex rh - g l ou eng
# Evermoor 'e . v ex r0 ~ m o: r0 eng
# Evermoor 'e . v ex rh . m o: rh eng
# Ewenfeldt "e: . v ex n - f ,e l t swe
# Ewenfeldt "e: . v ex n - f ,ä l t swe
# Exelon 'e k . s ex . l o n eng
# Exelon e k . s eh . l 'o: n eng
# Exmoor 'e k s . m o: r0 eng
# Exmoor 'e k s . m o: rh eng
# Fabergé f a . b ex r . rs 'e: fre
# Fabergé f a . b ex r . x 'e: swe
# Factortame f 'ae k . t ex r0 ~ t ei m eng
# Factortame f 'ae k . t ex rh . t e j m eng
# Fagin f 'ae . g i n eng
# Fagin f 'ei . g i n eng
# Faircloughs f 'eex r0 ~ k l a f s eng
# Faircloughs f 'eex rh ~ k l a f s eng
# Faithfull f 'e j th ~ f u l eng
# Faithfull f 'ei th ~ f uw l eng
# Faketruth f 'e j k ~ t r uw: th eng
# Faketruth f 'ei k ~ t rh uw: th eng
# Fallots f 'a . l o t s swe
# Fallots f a . l 'o: s fre
# Falmer f 'a: . m ex r0 eng
# Falmer f 'a: . m ex rh swe
# Falwell f 'ae l ~ w e l eng
# Falwell f 'o: l ~ w e l eng
# Fannie f 'a . n i swe
# Fannie f 'ae . n i eng
# Fanny f 'a . n y swe
# Fanny f 'ae . n i eng
# Fanuc f 'a: . n uu k eng
# Fanuc f 'ae: . n uw k eng
# Farhampton f 'a: r0 ~ h ae m . t ex n eng
# Farhampton f 'a: rh ~ h ae m . t ex n eng
# Faris f 'a: . r i s swe
# Faris f 'ae . rh i s eng
# Farlander f 'a: r0 ~ l ae n . d ex r0 eng
# Farlander f 'a: rh ~ l ae n . d ex rh eng
# Farmiga f 'a: r0 . m i . g ex eng
# Farmiga f a r . m 'i: . g a swe
# Farmville f 'a: r m ~ v i l eng
# Farmville f 'a: r0 m ~ v i l eng
# Fateh f 'aa: . t ex ara
# Fateh f a . t 'e: ind
# Fatou f 'a . t u ara
# Fatou f a . t 'u: fre
# Fayes f 'e j s eng
# Fayes f 'ei s eng
# Felicitys f e . l 'i . s i . t i s eng
# Felicitys f eh . l 'i . s i . t i s eng
# Felix f 'e: . l i k s swe
# Felix f 'i: . l i k s eng
# Ferb f 'ae r b swe
# Ferb f 'e j r b gle
# Fernand f 'ae: . rn a n d swe
# Fernand f ae . rn 'a n d swe
# Ferronordic f ae . rh ou ~ n 'o: r0 . d i k eng
# Ferronordic f ex . rh ou ~ n 'o: rh . d i k eng
# Feuchtwanger f 'o c t ~ v a ng . ex r ger
# Feuchtwanger f 'o j rs rt ~ v a ng . ex r swe
# Fidesz f 'i . d ex s swe
# Fidesz f i . d 'e s hun
# Fifi f 'i . f i swe
# Fifi f i . f 'i: swe
# Filles f "i . l ,ex s swe
# Filles f 'i . l ex s swe
# Firebuds f 'a . j ex rh ~ b a d s eng
# Firebuds f 'ai . ex r0 ~ b a d s eng
# Firefoot f 'a . j ex rh - f u t eng
# Firefoot f 'ai . ex r0 ~ f uw t eng
# Flapacha f l a . p 'a . tc a spa
# Flapacha f l a . p a . rs 'a: fre
# Flatliners f l 'ae t ~ l a j . n ex rh s eng
# Flatliners f l 'ae t ~ l ai . n ex r0 s eng
# Flaubert f l o . b 'ae: r fre
# Flaubert f l o . b 'ä: r fre
# Fleeton f l 'i: . t ex n eng
# Fleeton f l 'i: . t o n eng
# Flemmings f l "e . m ,i ng s swe
# Flemmings f l 'e . m i ng s swe
# Fligstein f l 'i g ~ rs rt a j n ger
# Fligstein f l 'i: g ~ rs rt a j n ger
# Floribama f l o . rh i . b 'a: . m a eng
# Floribama f l o: . r i . b 'a: . m a eng
# Flueger f l 'uu: . g ex r swe
# Flueger f l 'uw: . g ex rh eng
# Foer f 'o: r0 eng
# Foer f 'o: rh swe
# Foers f 'o: r0 s eng
# Foers f 'o: rh s eng
# Fogarty f 'o . g ex . rt i eng
# Fogarty f 'o . g ex r0 . t i eng
# Fogle f 'o: . g ex l eng
# Fogle f 'o: . g l ex eng
# Foles f "u: . l ,ex s swe
# Foles f 'ou l s eng
# Fortescue f 'o: r0 . t ex . s k j uw: eng
# Fortescue f 'o: rh . t ex . s k j uw: eng
# Fortnite f 'o: r0 t ~ n ai t eng
# Fortnite f 'o: rh t ~ n a j t eng
# Four-ties f 'o: r0 ~ t ai s eng
# Four-ties f 'o: rh ~ t a j s eng
# Foxcatcher f 'o k s ~ k ae . tc ex r0 eng
# Foxcatcher f 'o k s ~ k ae . tc ex rh eng
# Frage f r "a: . g ,ex swe
# Frage f r 'aa: . g ex ger
# Fragola f r 'a: . g o . l a lat
# Fragola f r a . g 'o: . l a swe
# Fran f r 'a n swe
# Fran f rh 'ae n eng
# Francisco f r a n . s 'i . s k u swe
# Francisco f rh ae n . s 'i . s k ou eng
# Frankenhaeuser f r 'a ng . k ex n ~ h au . s ex r swe
# Frankenhaeuser f r 'a ng . k ex n ~ h o j . s ex r swe
# Frasiers f rh 'e j . rs ex rh s swe
# Frasiers f rh 'ei . s ex r0 s eng
# Fred's f r 'e d s eng
# Fred's f rh 'e d s eng
# Frederick f r 'e: . d ex . r i k swe
# Frederick f rh 'e . d rh i k eng
# Freeride f rh 'i: ~ rh a j d eng
# Freeride f rh 'i: ~ rh ai d eng
# Freinet f r 'e j . n ex t swe
# Freinet f r eh . n 'e: fre
# Freinet f r eh . n 'e: swe
# Froggatt f r 'o . g a t eng
# Froggatt f rh 'o . g ex t eng
# Frontoffice f r 'o n t ~ o . f i s eng
# Frontoffice f rh 'o n t ~ o . f i s eng
# Frumerie f r "uu . m ex . r ,i: swe
# Frumerie f r y . m ex . r 'i: fre
# Frères f r 'ae: . r ex s swe
# Frères f r 'ae: r fre
# Frölander f r oe . l 'a n . d ex r swe
# Frölander f r ö . l 'a n . d ex r swe
# Fullan f 'u . l ex n eng
# Fullan f 'uw . l ex n eng
# Furch f 'oe: rh tc eng
# Furch f 'u r rs ger
# GLP-1-analoger g e: ~ e l ~ p e: ~ "e t - a n . a . l ,o: g . ex r swe
# GLP-1-analoger g e: ~ ä l ~ p e: ~ "e t - a n . a . l ,o: g . ex r swe
# GLP-1-receptorn g e: ~ e l ~ p e: ~ "e t - r e . s ,e p . t u rn swe
# GLP-1-receptorn g e: ~ ä l ~ p e: ~ "e t - r eh . s ,e p . t u rn swe
# GLP-2 g e: . e l . p e: ~ t v 'o: swe
# GLP-2 g e: ~ ä l ~ p e: ~ t v 'o: swe
# Gabriel g "a: . b r ,i . e l swe
# Gabriel g 'ei . b r ih . ex l eng
# Gainsbourg g 'e j n s ~ b oe: rh g eng
# Gainsbourg g 'ei n s ~ b oe: r0 g eng
# Galati g a . l 'a: . t i swe
# Galati g a . l 'aa: t s rum
# Gallaher g 'a . l a . h ex r swe
# Gallaher g 'ae . l ex . h ex r0 eng
# Gallwey g 'ae l . w e j eng
# Gallwey g 'ae l ~ w ei eng
# Gamby g 'a m . b y swe
# Gamby g 'a m ~ b y: swe
# Gapwaves g 'ae p ~ w e j v s eng
# Gapwaves g 'ae p ~ w ei v s eng
# Garfinkel g 'a: r . f i ng . k ex l swe
# Garfinkel g 'a: r0 ~ f i ng . k ex l eng
# Garton g 'a . rt o n eng
# Garton g 'a: r0 . t o n eng
# Gaskell g 'a . s k ex l swe
# Gaskell g a . s k 'e l swe
# Gasly g 'ae . s l i eng
# Gasly g a . s l 'i: fre
# Gauff g 'a: f eng
# Gauff g 'au f eng
# Gaylord g 'e j . l o: rd eng
# Gaylord g 'ei ~ l o: r0 d eng
# Gaynes g 'e j n s eng
# Gaynes g 'ei n s eng
# Genoway g 'e . n o . w ei eng
# Genoway g 'e . n u . w e j eng
# Gentletron dj 'ae n . t ex l ~ t rh o n eng
# Gentletron dj 'e n . t ex l . t rh o n eng
# George dj 'o: r0 dj eng
# George j 'e: . o r j swe
# Georges dj 'o: r0 . dj i s eng
# Georges dj 'o: rh . dj i s eng
# Georges j 'e: . o r j s eng
# Georgetowns dj 'o: r0 dj ~ t au n s eng
# Georgetowns dj 'o: rh dj ~ t au n s eng
# Georgias dj 'o: r0 . dj a s eng
# Georgias dj 'o: rh . dj a s eng
# Georgson dj 'o: r0 dj . s ex n eng
# Georgson j "e: . o r j . s ,o n eng
# Georgson j "e: . o r j . s ,o n swe
# Geostorm dj 'i: . ou ~ s t o: r0 m eng
# Geostorm dj 'i: . u ~ s t o: rh m eng
# Gerald dj 'ae . r a l d eng
# Gerald dj 'ae . rh ex l d eng
# Geriacare dj 'iex . rh iex ~ k eex r0 eng
# Geriacare g e: . r ih . a . k 'ae: r swe
# Gerrys dj 'e . rh i s eng
# Gerrys j 'ae . r y s swe
# Gershwins g 'oe: r0 rs . w i n s eng
# Gershwins g 'oe: rh rs . w i n s eng
# Ghostforce g 'ou s t ~ f o: r0 s eng
# Ghostforce g 'ou s t ~ f o: rh s eng
# Gijon g i . rs 'o n swe
# Gijon g i . xx 'o n spa
# Gilbert dj 'i l . b ex r0 t eng
# Gilbert j 'i l . b ex rt swe
# Gilbreth g 'i l . b r e t swe
# Gilbreth g 'i l . b rh e th eng
# Gileads g 'i . l e . a d s eng
# Gileads g 'i . l i . ae d s eng
# Gingrich g 'i ng . r i tc swe
# Gingrich g 'i ng . rh i tc sla
# Giolito dj oh . l 'i: . t u ita
# Giolito j i . oh . l 'i: . t u ita
# Giolitos dj 'o: . l i . t u s ita
# Giolitos dj i . oh . l 'i: . t u s ita
# Girmai g 'i r . m a j afr
# Girmai g i r . m 'a j unk
# Giveitgasandgo g 'i v | 'i t | g 'ae: s | 'ae n d | g 'ou eng
# Giveitgasandgo g 'i v ~ i t | g 'ae s | ae n d ~ g 'ou eng
# Glenister g l 'e . n i . s t ex r0 eng
# Glenister g l 'e . n i . s t ex rh eng
# Globalizer g l 'ou . b ex . l a j . s ex rh eng
# Globalizer g l 'ou . b ex . l ai . s ex r0 eng
# Go'kvälls g u . k v 'ä l s swe
# Go'kvälls g u ~ k v 'ä l s swe
# Godelier g o . d e l . j 'e: r swe
# Godelier g o . d ex l . j 'e: fre
# Goldberger g 'o l d ~ b ae r . g ex r swe
# Goldberger g 'u: l d ~ b ae r . j ex r swe
# Goldthorpe g 'ou l d ~ th o: r0 p eng
# Goldthorpe g 'ou l d ~ th o: rh p eng
# Goldwing g 'ou l d . w i ng eng
# Goldwing g 'ou l d ~ w i ng eng
# Goodlad g 'u d . l ae d eng
# Goodlad g 'uw d . l ae d eng
# Goodmans g 'u d . m ex n s eng
# Goodmans g 'uw d ~ m ex n s eng
# Goodweather g 'u d ~ w e . dh ex rh eng
# Goodweather g 'uw d ~ w e . dh ex r0 eng
# Goolagong g 'uw: . l ex . g o ng eng
# Goolagong g u . l a . g 'o ng eng
# Gooner g 'uw: . n ex r0 eng
# Gooner g 'uw: . n ex rh eng
# Gooseboy g 'uw: s . b oi eng
# Gooseboy g 'uw: s ~ b o j eng
# Goossens g 'uw: . s ex n s eng
# Goossens xx 'u: . s ex n s dut
# Gordon g 'o: . rd o n swe
# Gordon g 'o: r0 . d ex n eng
# Gorgo g 'o r . g u ita
# Gorgo g o r . g 'o: gre
# Gorlans g 'u: . rl a n swe
# Gorlans g 'u: . rl a n s swe
# Gorton g 'o: . rt o n swe
# Gorton g 'o: r0 . t ex n eng
# Gothus g 'o: . t uu s swe
# Gothus g 'u: . t uu s swe
# Gould g 'ou l d eng
# Gould g 'u: l d swe
# Grainfield g rh 'e j n ~ f i: l d eng
# Grainfield g rh 'ei n ~ f i: l d eng
# Gramma g r "a . m ,a swe
# Gramma g r 'a . m a swe
# Grantchester g rh 'a: n t ~ tc e . s t ex r0 eng
# Grantchester g rh 'ae n t ~ tc e . s t ex rh eng
# Granthams g rh 'ae n . t ex m s swe
# Granthams g rh 'ae n . th ex m s eng
# Grawe g r "a: . v ,ex swe
# Grawe g r 'a: . v ex ger
# Grayden g rh 'e j . d ex n eng
# Grayden g rh 'ei . d ex n eng
# Graydens g rh 'e j . d ex n s eng
# Graydens g rh 'ei . d ex n s eng
# Grayling g r 'e j . l i ng eng
# Grayling g rh 'ei . l i ng eng
# Graysons g rh 'e j . s ex n s eng
# Graysons g rh 'ei . s ex n s eng
# Greendale g rh 'i: n . d e j l eng
# Greendale g rh 'i: n ~ d ei l eng
# Greenson g rh 'e: n . s o n swe
# Greenson g rh 'i: n . s ex n eng
# Greentown g rh 'i: n - t au n eng
# Greentown g rh 'i: n ~ t au n eng
# Grenville g r 'e n . v i l swe
# Grenville g r 'i: n . v i l swe
# Greyjoy g rh 'e j ~ dj o j eng
# Greyjoy g rh 'ei ~ dj oi eng
# Grimwalker g rh 'i m ~ w o: . k ex r0 eng
# Grimwalker g rh 'i m ~ w o: . k ex rh eng
# Grobgeld g r 'o b ~ g e l d swe
# Grobgeld g r 'o: p ~ g e l t ger
# Grosseto g r o . s 'e: . t u ita
# Grosseto g r oh . s 'e: . t u swe
# Grune g r 'uu: . n ex swe
# Grune g rh 'uw: n eng
# Guadeloupe g oh . a . d eh . l 'u: p fre
# Guadeloupe g uuh . a . d eh . l 'u: p swe
# Guantanamo g uu: . a n . t 'a: . n a . m u swe
# Guantanamo g uuh . a n . t 'a: . n a . m u spa
# Guardiola g oh . a r . d i . 'o: . l a swe
# Guardiola g uuh . a r . d i . 'o: . l a spa
# Guernseys g 'oe: r0 n . s i s eng
# Guernseys g 'oe: rn . s i s eng
# Gumperz g 'u m . p ex r t s swe
# Gumperz g 'uu m . p ex r t s ger
# Gums g 'a m s eng
# Gums g 'uu m s swe
# Gunnerside g 'a . n ex r0 ~ s ai d eng
# Gunnerside g 'a . n ex rh ~ s a j d eng
# Gusfield g 'a s . f i: l d eng
# Gusfield g 'a s ~ f i: l d eng
# Guyatt g 'a . j ex t eng
# Guyatt g 'ai . ex t eng
# Görgl g 'oe r . g ex l ger
# Görgl j 'oe r g . ex l swe
# HBO e j dj ~ b i: ~ 'ou eng
# HBO h o: ~ b e: ~ 'u: swe
# HBO:s 'e dj | b 'i: | 'ou s eng
# HBO:s h o: ~ b e: ~ 'u: s swe
# Haapajärvi h 'aa: . p a . j ae r . v i swe
# Haapajärvi h 'aa: . p a ~ j ae r . v i fisa
# Haar h 'a: r swe
# Haar h 'aa: r swe
# Habor h 'a: . b o r swe
# Habor h 'a: . b u r swe
# Hackstable h 'a k . s t e j . b ex l swe
# Hackstable h 'ae k ~ s t ei . b ex l eng
# Hagia 'a . j a gre
# Hagia h 'a: . g ih . a swe
# Hailwood h 'e j l ~ w u d eng
# Hailwood h 'ei l ~ w uw d eng
# Hallidays h 'ae . l i . d e j s eng
# Hallidays h 'ae . l i ~ d ei s eng
# Hallmark h "a l - m ,a r k swe
# Hallmark h 'o: l ~ m a: r0 k eng
# Hallworth h 'o: l ~ w oe: r0 th eng
# Hallworth h 'o: l ~ w oe: rh th eng
# Hallyday h 'ae . l i . d e j eng
# Hallyday h 'ae . l i ~ d ei eng
# Hamilton h 'a . m i l . t o n swe
# Hamilton h 'ae . m i l . t ex n eng
# Hammerhead h 'ae . m ex r0 ~ h e d eng
# Hammerhead h 'ae . m ex rh ~ h e d eng
# Hammersleys h 'ae . m ex r0 . s l i s eng
# Hammersleys h 'ae . m ex rh . s l i s eng
# Hannele h "a . n ,ex . l ex swe
# Hannele h 'a . n ex . l ex swe
# Harari h 'a . r a . r i unk
# Harari h a . r 'a: . r i unk
# Hardenberg h "a: . rd ex n - b ,ae r j swe
# Hardenberg h 'a r . d ex n ~ b e r k ger
# Hardingham h 'a: . rd i ng . h a m eng
# Hardingham h 'a: r0 . d i ng . h ex m eng
# Hardtalk h 'a: r0 d ~ t o: k eng
# Hardtalk h 'a: rh d . t o: k eng
# Harel h 'a: . r ex l eng
# Harel h 'ae . rh ex l eng
# Haring h 'a: . r i ng eng
# Haring h 'ae . rh i ng eng
# Harmondsworth h 'a: r0 . m ex n d s ~ w oe: r0 th eng
# Harmondsworth h 'a: rh . m ex n d s ~ w oe: rh th eng
# Harolds h 'ae . r ex l d s eng
# Harolds h 'ae . rh ex l d s eng
# Harris h 'a . r i s swe
# Harris h 'ae . rh i s eng
# Harry h 'a . r y swe
# Harry h 'ae . rh i eng
# Harvick h "a: r . v ,i k eng
# Harvick h 'a: r0 . v i k eng
# Hasani h a . s 'a: . n i swe
# Hasani h a . s 'aa: . n i ara
# Haugh h 'au g eng
# Haugh h 'o: eng
# Hauke h "au . k ,ex nob
# Hauke h 'au . k ex ger
# Havnesköld h "a v . n ex - rs ,ö l d swe
# Havnesköld h "a v . n ex - x ,ö l d swe
# Hawryluk h 'a: . rh i . l u k eng
# Hawryluk h 'a: . rh i . l uw k eng
# Haylay h 'e j . l e j eng
# Haylay h 'ei . l ei eng
# Haysbert h 'e j s . b oe: rh t eng
# Haysbert h 'ei s . b oe: r0 t eng
# Haythrow h 'e j . th rh ou eng
# Haythrow h 'ei . th rh ou eng
# Hazell h 'ei . z ex l eng
# Hazell h a . s 'e l eng
# Hazlehurst h 'e j . z ex l ~ h oe: rh s t eng
# Hazlehurst h 'ei . z ex l ~ h oe: r0 s t eng
# HealthInvest h 'e l th | i n . v 'e s t eng
# HealthInvest h e l th ~ i n . v 'e s t eng
# Heartfield h 'a: r0 t ~ f i: l d eng
# Heartfield h 'a: rh t ~ f i: l d eng
# Heathcotes h 'i: th . k ou t s eng
# Heathcotes h 'i: th ~ k ou t s eng
# Heerenveen h 'e: . r ex n . v e: n swe
# Heerenveen h 'e: . r ex n ~ v e: n dut
# Heffermehl h 'e . f ex r ~ m e: l ger
# Heffermehl h 'ä . f ex r ~ m e: l swe
# Heigl h 'a j . g ex l ger
# Heigl h 'i: . g ex l swe
# Hellboy h 'e l ~ b o j eng
# Hellboy h 'e l ~ b oi eng
# Helmerson h "e l . m ex . rs ,o n swe
# Helmerson h "ä l . m ex . rs ,o n swe
# Hemsworth h "e m s - w ,oe: r0 th swe
# Hemsworth h 'e m s ~ w oe: rh th eng
# Henry h 'e n . r y swe
# Henry h 'e n . rh i eng
# Heracles h 'e . rh ex . k l i: s eng
# Heracles h 'e: . r a k . l ex s swe
# Herald h 'e . r a l d swe
# Herald h 'e . rh ex l d eng
# Herbert h 'ae r . b ex rt swe
# Herbert h 'oe: r0 . b ex r0 t eng
# Herc h 'oe: r0 k eng
# Herc h 'oe: rh k eng
# Hercegovina h ae r t . s e . g oh . v 'i: . n a swe
# Hercegovina h ae r t . s ex . g oh . v 'i: . n a sla
# Hercules e r . k 'y l s swe
# Hercules h 'ae r . k uu . l ex s swe
# Herculine e r . k y . l 'i n fre
# Herculine h 'oe: r0 k . j ex . l i n eng
# Hermiones h oe rh . m 'a j . n i s eng
# Hermiones h oe: r0 . m 'ai . ex . n i s eng
# Hersley h 'oe: r0 . s l i eng
# Hersley h 'oe: rh . s l i eng
# Hersleys h 'oe: r0 . s l i s eng
# Hersleys h 'oe: rh . s l i s eng
# Hiens h 'i: n s unk
# Hiens h i . 'e n s swe
# Highhouse h 'a j ~ h au s eng
# Highhouse h 'ai ~ h au s eng
# Highmore h 'a j ~ m o: rh eng
# Highmore h 'ai ~ m o: r0 eng
# Highsmiths h 'a j ~ s m i th s eng
# Highsmiths h 'ai ~ s m i th s eng
# Highspirit h 'a j ~ s p i . rh i t eng
# ...
# textilares t ä k . s t "i: . l ,a . r ex s swe
# textilares t ä k . s t 'i: . l a . r ex s swe
# thorakal t o: . r a . k 'a: l unk
# thorakal t oh . r a . k 'a: l swe
# tiaziddiuretika t i: . a . s "i: d - d i: . uu . r ,e: . t i . k a swe
# tiaziddiuretika t i: . a . s "i: d - d i: . uuh . r ,e: . t i . k a swe
# tid t 'i: nob
# tid t 'i: d swe
# tida t "i: . d ,a swe
# tida t "i: . d ,a swe
# tida t 'i: . a nob
# tidlig t "i: . l ,i nob
# tidlig t "i: d . l ,i g swe
# tidlige t "i . l ,i . ex nob
# tidlige t "i: d . l ,i . g ex swe
# tiggekors t "i . g ex - k ,o rs swe
# tiggekors t "i . g ex - k ,o rs swe
# tiggekors t "i . g ex - k ,o rs s swe
# tiggekors t "i . g ex - k ,o rs s swe
# titan t "i: . t ,a n swe
# titan t i . t 'a: n swe
# titan t i . t 'a: n swe
# titans t "i: . t ,a n s swe
# titans t i . t 'a: n s swe
# titans t i . t 'a: n s swe
# tjära c "ae: . r ,a swe
# tjära c "oe: . r ,a swe
# tjära c "oe: . r ,a swe
# tjäras c "ae: . r ,a s swe
# tjäras c "oe: . r ,a s swe
# tjäras c "oe: . r ,a s swe
# tjäras c "oe: . r ,a s swe
# tok t 'u k nob
# tok t 'u: k swe
# tok t 'u: k swe
# tok t 'u: k swe
# tom t 'o: m swe
# tom t 'u m swe
# toms t 'o: m s swe
# toms t 'u m s swe
# tomt t 'o m t swe
# tomt t 'u m t swe
# tomten t "o m . t ,ex n swe
# tomten t 'o m . t ex n swe
# tomtens t "o m . t ,ex n s swe
# tomtens t 'o m . t ex n s swe
# tomts t 'o m t s swe
# tomts t 'u m t s swe
# ton t 'o n swe
# ton t 'o n swe
# ton t 'o: n swe
# ton t 'u: n swe
# tonisk t 'o: . n i s k swe
# tonisk t 'u: . n i s k swe
# toniska t 'o: . n i . s k a swe
# toniska t 'o: . n i . s k a swe
# toniska t 'u: . n i . s k a swe
# toniska t 'u: . n i . s k a swe
# toniskare t 'o: . n i . s k a . r ex swe
# toniskare t 'u: . n i . s k a . r ex swe
# toniskares t 'o: . n i . s k a . r ex s swe
# toniskares t 'u: . n i . s k a . r ex s swe
# toniskas t 'o: . n i . s k a s swe
# toniskas t 'o: . n i . s k a s swe
# toniskas t 'u: . n i . s k a s swe
# toniskas t 'u: . n i . s k a s swe
# toniskast t 'o: . n i . s k a s t swe
# toniskast t 'u: . n i . s k a s t swe
# toniskaste t 'o: . n i . s k a . s t ex swe
# toniskaste t 'u: . n i . s k a . s t ex swe
# toniskastes t 'o: . n i . s k a . s t ex s swe
# toniskastes t 'u: . n i . s k a . s t ex s swe
# toniske t 'o: . n i . s k ex swe
# toniske t 'u: . n i . s k ex swe
# toniskes t 'o: . n i . s k ex s swe
# toniskes t 'u: . n i . s k ex s swe
# tonisks t 'o: . n i s k s swe
# tonisks t 'u: . n i s k s swe
# toniskt t 'o: . n i s t swe
# toniskt t 'u: . n i s t swe
# toniskts t 'o: . n i s k t s swe
# toniskts t 'u: . n i s k t s swe
# tons t 'o n s swe
# tons t 'o n s swe
# tons t 'u: n s swe
# topos t 'o . p o s swe
# topos t 'o: . p o s swe
# toskanska t o . s k 'a: n . s k a swe
# toskanska t oh . s k 'a: n . s k a swe
# touchen t 'a . tc ex n swe
# touchen t 'u . rs ex n swe
# toujours t u . rs 'u: r swe
# toujours t u . rs 'u: rs swe
# toxoplasmos t o k . s o . p l a . s m 'o: s swe
# toxoplasmos t o k . s o . p l a . s m 'o: s swe
# toxoplasmos t o k . s oh . p l 'a . s m o s lat
# trachomatis t r a . k oh . m "a: . t ,i s lat
# trachomatis t r a . k oh . m 'a: . t i s lat
# traktat t r "a k . t ,a t swe
# traktat t r a k . t 'a: t swe
# traktats t r "a k . t ,a t s swe
# traktats t r a k . t 'a: t s swe
# trans t r 'a n s swe
# trans t r 'a n s swe
# trans t r 'a n s swe
# trans t r 'a: n s swe
# transformellt t r a n s . f o r . m 'e l t swe
# transformellt t r a n s ~ f o r . m 'e l t swe
# traven t r "a: . v ,ex n swe
# traven t r 'a: . v ex n swe
# traven t r 'a: . v ex n swe
# travens t r "a: . v ,ex n s swe
# travens t r 'a: . v ex n s swe
# travens t r 'a: . v ex n s swe
# travers t r a . v 'ae rs swe
# travers t r a . v 'ae rs s swe
# tredska t r "e d . s k ,a swe
# tredska t r 'e d . s k a swe
# tredska t r 'e d . s k a swe
# tredskas t r "e d . s k ,a s swe
# tredskas t r "e d . s k ,a s swe
# tredskas t r "e d . s k ,a s swe
# tredskas t r 'e d . s k a s swe
# tredskas t r 'e d . s k a s swe
# tridentinska t r i . d 'ä n . t i . s k a swe
# tridentinska t r i . d 'ä n . t i . s k a swe
# tridentinska t r i . d e n . t 'i: n . s k a swe
# trigemino-autonoma t r i . g "e: . m i . n uu s - au . t oh . n ,o: . m a unk
# trigemino-autonoma t r i . g 'e: . m i . n uu s - au . t u . n o: . m a unk
# trijodtyronin t r i . j o d . t y . r o . n 'i: n unk
# trijodtyronin t r i: ~ j o d ~ t y . r oh . n 'i: n swe
# trikomoniasis t r i . k o . m oh . n 'i: . a . s i s swe
# trikomoniasis t r i . k o . m oh . n 'i: . a . s i s swe
# trikomoniasis t r i . k u . m o . n i . 'a: . s i s lat
# trilaterala t r i . l a . t eh . r 'a: . l a swe
# trilaterala t r i: . l a . t eh . r 'a: . l a swe
# trillekors t r "i . l ex - k ,o rs swe
# trillekors t r "i . l ex - k ,o rs swe
# trillekors t r "i . l ex - k ,o rs s swe
# trillekors t r "i . l ex - k ,o rs s swe
# trilska t r "i l . s k ,a swe
# trilska t r 'i l . s k a swe
# trilska t r 'i l . s k a swe
# trilskas t r "i l . s k ,a s swe
# trilskas t r "i l . s k ,a s swe
# trilskas t r "i l . s k ,a s swe
# trilskas t r "i l . s k ,a s swe
# trilskas t r 'i l . s k a s swe
# trilskas t r 'i l . s k a s swe
# trios t r 'i: . o s swe
# trios t r i . 'o: s swe
# trios t r i . 'o: s swe
# trodda t r "u . d ,a swe
# trodda t r 'u . d a swe
# troddas t r "u . d ,a s swe
# troddas t r 'u . d a s swe
# tromboembolism t r o m . b o . ä m . b oh . l 'i s m swe
# tromboembolism t r o m . b u . e m . b oh . l 'i s m swe
# tromboflebit t r o m . b o . f l eh . b 'i: t swe
# tromboflebit t r o m . b u . f l eh . b 'i: t swe
# troponin t r o . p oh . n 'i: n swe
# troponin t r o: . p oh . n 'i: n swe
# trubbnosiga t r "uu b - n ,u: . s i . g a swe
# trubbnosiga t r "uu b - n ,u: . s ih . g a swe
# trumpet t r "uu m . p ,ex t swe
# trumpet t r uu m . p 'e: t swe
# trumpets t r "uu m . p ,ex t s swe
# trumpets t r uu m . p 'e: t s swe
# trycken t r "y . k ,ex n swe
# trycken t r 'y . k ex n swe
# tryckens t r "y . k ,ex n s swe
# tryckens t r 'y . k ex n s swe
# tryckes t r "y . k ,ex s swe
# tryckes t r 'y . k ex s swe
# trycket t r "y . k ,ex t swe
# trycket t r 'y . k ex t swe
# tryckets t r "y . k ,ex t s swe
# tryckets t r 'y . k ex t s swe
# träden t r "ä: . d ,ex n swe
# träden t r 'ä: . d ex n swe
# trädens t r "ä: . d ,ex n s swe
# trädens t r 'ä: . d ex n s swe
# trädes t r "ä: . d ,ex s swe
# trädes t r 'ä: . d ex s swe
# trädet t r "ä: . d ,ex t swe
# trädet t r 'ä: . d ex t swe
# trädets t r "ä: . d ,ex t s swe
# trädets t r 'ä: . d ex t s swe
# träng t r 'e ng swe
# träng t r 'ä ng swe
# tuberkulin t uu . b ae r . k uuh . l 'i: n swe
# tuberkulin t uuh . b ae r . k uuh . l 'i: n swe
# tummen t "uu . m ,ex n swe
# tummen t 'uu . m ex n swe
# tummens t "uu . m ,ex n s swe
# tummens t 'uu . m ex n s swe
# turens t "uu: . r ,ex n s swe
# turens t 'uu: . r ex n s swe
# turs t 'uu rs swe
# turs t 'uu rs swe
# turs t 'uu: rs swe
# tvådda t v "o . d ,a swe
# tvådda t v 'o . d a swe
# tvåddas t v "o . d ,a s swe
# tvåddas t v 'o . d a s swe
# tyckes t "y . k ,ex s swe
# tyckes t 'y . k ex s swe
# tydda t "y . d ,a swe
# tydda t 'y . d a swe
# tyddas t "y . d ,a s swe
# tyddas t 'y . d a s swe
# tyreotoxikos t y . r eh . oh . t o k . s i . k 'o: s swe
# tyreotoxikos t y: . r eh . u . t o k . s i . k 'o: s swe
# tyreotoxikos t y: . r eh . u . t o k . s i . k 'o: s swe
# tyrosinas t y . r o . s i . n 'a: s swe
# tyrosinas t y . r o . s i . n 'a: s swe
# tyrosinas t y . r u . s i . n 'a: s swe
# tyrs t 'y rs swe
# tyrs t 'y rs s swe
# täckes t "ä . k ,ex s swe
# täckes t 'ä . k ex s swe
# tändes t "ä n . d ,ex s swe
# tändes t "ä n . d ,ex s swe
# tändes t 'ä n . d ex s swe
# tänkes t "ä ng . k ,ex s swe
# tänkes t 'ä ng . k ex s swe
# udden "uu . d ,ex n swe
# udden 'uu . d ex n swe
# uddens "uu . d ,ex n s swe
# uddens 'uu . d ex n s swe
# ulrikskors "uu l . r i k s - k ,o rs swe
# ulrikskors "uu l . r i k s - k ,o rs swe
# ulrikskors "uu l . r i k s - k ,o rs s swe
# ulrikskors "uu l . r i k s - k ,o rs s swe
# ultramarin "uu l . t r a - m a . r ,i: n swe
# ultramarin uu l . t r a . m a . r 'i: n swe
# ultrarapid "uu l . t r a . r a . p ,i: d swe
# ultrarapid "uu l . t r a . r a . p ,i: d swe
# ultrarapid uu l . t r a . r a . p 'i: d swe
# ultrarapids "uu l . t r a . r a . p ,i: d s swe
# ultrarapids uu l . t r a . r a . p 'i: d s swe
# underhavande "uu n . d ex r - h ,a: . v a n . d ex swe
# underhavande "uu n . d ex r . h ,a: . v a n . d ex swe
# unipolära uu: . n i ~ p oh . l 'ae: . r a swe
# unipolära uu: . n i ~ p oh . l 'ä: . r a swe
# unt.se "uu: . ä n . t ,e: | p 'uu ng t | "ä s . ,e: swe
# unt.se "uu: ~ ä n ~ t ,e: | p 'uu ng t | "ä s ~ ,e: swe
# uppifrån-och-ner "uu p - i . f r ,o: n | 'o: | n 'e: r swe
# uppifrån-och-ner uu p ~ i: ~ f r o: n ~ o k ~ n 'e: r swe
# urea uuh . r "e: . ,a swe
# urea uuh . r 'e: . a swe
# ureas uu: . r eh . 'a: s swe
# ureas uu: . r eh . 'a: s swe
# ureas uuh . r 'e: . a s swe
# uremi uu . r eh . m 'i: swe
# uremi uu: . r eh . m 'i: swe
# uretär uu: . r eh . t 'ae: r swe
# uretär uuh . r eh . t 'ae: r swe
# urtima "uu: . rt ,i: . m a swe
# urtima "uu: r - t ,i: . m a swe
# utför "uu: t - f ,oe: r swe
# utför 'uu: t ~ f oe: r swe
# vad v 'a: swe
# vad v 'a: swe
# vad v 'a: d swe
# vad v 'a: d swe
# vakans v "a: . k ,a n s swe
# vakans v a . k 'a n s swe
# vakans v a . k 'a n s swe
# vaken v "a: . k ,ex n swe
# vaken v 'a: . k ex n swe
# vakens v "a: . k ,ex n s swe
# vakens v 'a: . k ex n s swe
# vaket v "a: . k ,ex t swe
# vaket v 'a: . k ex t swe
# vakets v "a: . k ,ex t s swe
# vakets v 'a: . k ex t s swe
# valen v "a: . l ,ex n swe
# valen v 'a: . l ex n swe
# valen v 'a: . l ex n swe
# valens v "a: . l ,ex n s swe
# valens v 'a: . l ex n s swe
# valens v 'a: . l ex n s swe
# valens v a . l 'ä n s swe
# valens v a . l 'ä n s swe
# valet v "a: . l ,ex t swe
# valet v 'a: . l ex t swe
# valets v "a: . l ,ex t s swe
# valets v 'a: . l ex t s swe
# vals v 'a l s swe
# vals v 'a l s swe
# vals v 'a: l s swe
# vals v 'a: l s swe
# vals v 'a: l s swe
# vant v 'a n t swe
# vant v 'a: n t swe
# vant v 'a: n t swe
# var v 'a: swe
# var v 'a: nob
# var v 'a: swe
# var v 'a: r swe
# var v 'a: r swe
# var v 'a: r swe
# varan v "a: . r ,a n swe
# varan v a . r 'a: n swe
# varans v "a: . r ,a n s swe
# varans v a . r 'a: n s swe
# varhelst v a: r . h 'ä l s t swe
# varhelst v a: r ~ h 'e l s t swe
# vars v 'a rs swe
# vars v 'a: rs swe
# vars v 'a: rs swe
# vars v 'a: rs swe
# varse v "a . rs ,e swe
# varse v "a . rs ,ex swe
# vederbörande v "e: . d ex r - b ,oe: . r a n . d ex swe
# vederbörande v "e: . d ex r . b ,oe: . r a n . d ex swe
# vederbörande v "e: . d ex r . b ,oe: . r a n . d ex swe
# vederbörande v "e: . d ex r . b ,oe: . r a n . d ex swe
# vederbörandes v "e: . d ex r - b ,oe: . r a n . d ex s swe
# vederbörandes v "e: . d ex r . b ,oe: . r a n . d ex s swe
# vederbörandes v "e: . d ex r . b ,oe: . r a n . d ex s swe
# vederbörandes v "e: . d ex r . b ,oe: . r a n . d ex s swe
# velar v "e: . l ,a r swe
# velar v "e: . l ,a r swe
# velar v eh . l 'a: r swe
# velar v eh . l 'a: r swe
# velars v "e: . l ,a rs swe
# velars v eh . l 'a: rs swe
# velars v eh . l 'a: rs swe
# vers v 'ae rs swe
# vers v 'ae rs s swe
# vetes v "e: . t ,ex s swe
# vetes v 'e: . t ex s swe
# vette v "e . t ,ex swe
# vette v "ä . t ,ex swe
# vettes v "e . t ,ex s swe
# vettes v "ä . t ,ex s swe
# viges v "i: . g ,ex s swe
# viges v 'i: . g ex s swe
# viken v "i: . k ,ex n swe
# viken v 'i: . k ex n swe
# vikens v "i: . k ,ex n s swe
# vikens v 'i: . k ex n s swe
# viktorian v i k . t 'u: . r ih . a n swe
# viktorian v i k . t u . r i . 'a: n swe
# viktorians v i k . t 'u: . r ih . a n s swe
# viktorians v i k . t u . r i . 'a: n s swe
# vil v 'i l nob
# vil v 'i: l swe
# villa v "i . l ,a swe
# villa v "i . l ,a swe
# villa v "i . l ,a swe
# villa v 'i . l a swe
# villa v 'i . l a swe
# villas v "i . l ,a s swe
# villas v "i . l ,a s swe
# villas v "i . l ,a s swe
# villas v "i . l ,a s swe
# villas v 'i . l a s swe
# villas v 'i . l a s swe
# villes v "i . l ,ex s swe
# villes v 'i . l ex s swe
# viner v "i: . n ,ex r swe
# viner v 'i: . n ex r swe
# vingels v "i ng . ,ex l s swe
# vingels v 'i ng . ex l s swe
# vingen v "i ng . ,ex n swe
# vingen v 'i ng . ex n swe
# vingens v "i ng . ,ex n s swe
# vingens v 'i ng . ex n s swe
# vinter-OS v "i n . t ex r - ,u: . e s swe
# vinter-OS v "i n . t ex r - ,u: ~ e s swe
# visavis v "i: s - a . v ,i: swe
# visavis v i . s a . v 'i: s swe
# visen v "i: . s ,ex n swe
# visen v 'i: . s ex n swe
# visens v "i: . s ,ex n s swe
# visens v 'i: . s ex n s swe
# vits v 'i t s swe
# vits v 'i t s swe
# vits v 'i: t s swe
# voilà v u . a . l 'a fre
# voilà v u . a . l 'aa: fre
# voltakors v "o l . t a - k ,o rs swe
# voltakors v "o l . t a - k ,o rs swe
# voltakors v "o l . t a - k ,o rs s swe
# voltakors v "o l . t a - k ,o rs s swe
# vreden v r "e: . d ,ex n swe
# vreden v r 'e: . d ex n swe
# vredens v r "e: . d ,ex n s swe
# vredens v r 'e: . d ex n s swe
# väl v 'ä l swe
# väl v 'ä: l swe
# välden v "ä l . d ,ex n swe
# välden v 'ä l . d ex n swe
# väldens v "ä l . d ,ex n s swe
# väldens v 'ä l . d ex n s swe
# vältes v "ä l . t ,ex s swe
# vältes v "ä l . t ,ex s swe
# vältes v 'ä l . t ex s swe
# vän v 'ä n swe
# vän v 'ä: n swe
# väns v 'ä n s swe
# väns v 'ä: n s swe
# vänt v 'ä n t swe
# vänt v 'ä n t swe
# vänt v 'ä: n t swe
# vänts v 'ä n t s swe
# vänts v 'ä: n t s swe
# värda v "ae: . rd ,a swe
# värda v 'ae: . rd a swe
# värde v "ae: . rd ,ex swe
# värde v 'ae: . rd ex swe
# värden v "ae: . rd ,ex n swe
# värden v 'ae: . rd ex n swe
# värdens v "ae: . rd ,ex n s swe
# värdens v 'ae: . rd ex n s swe
# värdes v "ae: . rd ,ex s swe
# värdes v "ae: . rd ,ex s swe
# värdes v 'ae: . rd ex s swe
# värmes v "ae r . m ,ex s swe
# värmes v "ae r . m ,ex s swe
# värmes v 'ae r . m ex s swe
# värvade v "ae r . v ,a . d ex swe
# värvade v "ae: r . v ,a . d ex swe
# värvade v "ae: r . v ,a . d ex swe
# värvades v "ae r . v ,a . d ex s swe
# värvades v "ae: r . v ,a . d ex s swe
# värvades v "ae: r . v ,a . d ex s swe
# värvat v "ae r . v ,a t swe
# värvat v "ae: r . v ,a t swe
# väst v 'ä s t swe
# väst v 'ä s t swe
# väst v 'ä: s t swe
# västs v 'ä s t s swe
# västs v 'ä: s t s swe
# vätes v "ä: . t ,ex s swe
# vätes v 'ä: . t ex s swe
# vålen v "o: . l ,ex n swe
# vålen v 'o: . l ex n swe
# vålens v "o: . l ,ex n s swe
# vålens v 'o: . l ex n s swe
# werden v 'ae r . d ex n ger
# werden v 'e r . d ex n ger
# wienska v "i: n . s k ,a swe
# wienska v 'i: n . s k a swe
# wienska v 'i: n . s k a swe
# wienskas v "i: n . s k ,a s swe
# wienskas v 'i: n . s k a s swe
# wienskas v 'i: n . s k a s swe
# wind-up-fenomenet w "a j n d - a p - f e . n oh . m ,e: . n ex t swe
# wind-up-fenomenet w a j n d ~ "a p - f e . n oh . m ,e: . n ex t swe
# workout w 'oe: r k . au t swe
# workout w oe: r k . 'au t swe
# zu t s 'u ger
# zu t s 'u: ger
# zygoten s y . g 'o: . t ex n swe
# zygoten s y . g oh . t 'e: n swe
# zygotens s y . g 'o: . t ex n s swe
# zygotens s y . g oh . t 'e: n s swe
# Åkerfeldt "o: . k ex r - f ,e l t swe
# Åkerfeldt "o: . k ex r - f ,ä l t swe
# Åkerström "o: . k ex r - s t r ,ö m swe
# Åkerström o: . k ex r ~ s t r 'ö m swe
# Öffentlichkeit 'ö . f e n t . l i c ~ k a j t ger
# Öffentlichkeit 'ö . f ex n t . l i c ~ k a j t ger
# Ørsted "oe: - rs rt ,e: d nob
# Ørsted 'oe: r ~ s t e d dan
# ängen "ä ng . ,ex n swe
# ängen 'ä ng . ex n swe
# ängens "ä ng . ,ex n s swe
# ängens 'ä ng . ex n s swe
# åbäkas "o: - b ,ä: . k a s swe
# åbäkas "o: - b ,ä: . k a s swe
# åbäkas "o: . b ,ä: . k a s swe
# ådra "o: - d r ,a: swe
# ådra "o: . d r ,a swe
# ådra "o: . d r ,a swe
# ådra "o: . d r ,a swe
# ådras "o: . d r ,a s swe
# ådras "o: . d r ,a s swe
# ådras "o: . d r ,a s swe
# ådras "o: . d r ,a s swe
# ådras "o: . d r ,a: s swe
# ålade "o: - l ,a: . d ex swe
# ålade "o: . l ,a . d ex swe
# åra "o: . r ,a swe
# åra 'o: . r a nob
# året 'o: . r ex nob
# året 'o: . r ex t swe
# åsidosätts o . s "i: . d u - s ,ä t s swe
# åsidosätts o: ~ s "i: . d u - s ,ä t s swe
# åta "o: . t ,a swe
# åta "o: . t ,a: swe
# återblickar "o: . t ex r - b l ,i . k a r swe
# återblickar "o: . t ex r - b l i . k ,a r swe
# åtgångna "o: t - g ,o ng . n a swe
# åtgångna "o: t - g ,o ng . n a swe
# åtgångna "o: t . g ,o ng . n a swe
# åtrå "o: - t r ,o: swe
# åtrå "o: . t r ,o: swe
# écriture e . k r i . t 'y r fre
# écriture e . k r i . t 'y: fre
# ödes "ö: . d ,ex s swe
# ödes "ö: . d ,ex s swe
# ödes 'ö: . d ex s swe
# ören "oe: . r ,ex n swe
# ören 'oe: . r ex n swe
# ören 'oe: . r ex n swe
# örens "oe: . r ,ex n s swe
# örens 'oe: . r ex n s swe
# örens 'oe: . r ex n s swe
# öret "oe: . r ,ex t swe
# öret 'oe: . r ex t swe
# örets "oe: . r ,ex t s swe
# örets 'oe: . r ex t s swe
# öst 'ö s t swe
# öst 'ö s t swe
# öst 'ö: s t swe
# överhuvud "ö: . v ex r - h ,uu: . v uu d swe
# överhuvud ö: . v ex r . h "uu: . v ,uu d swe
# øjeblik "ö . j ex - b l ,i k nob
# øjeblik 'ö . j ex ~ b l i k dan

# %%
REPLACEMENTS = """
Hlavac;Hlaváč;cze
"""
