# %%
PAGE = "https://www.riksdagen.se/sv/webb-tv/video/beslut/teckensprakstolkat-beslut-ja-till-nya-mojligheter_hdc5uulkgixzejmvaqlott/"

# %%
import requests
from bs4 import BeautifulSoup
import json

def get_embedded_json(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    script_tag = soup.find('script', {"type": 'application/json', "id": "__NEXT_DATA__"})
    if script_tag:
        data = json.loads(script_tag.text)
        return data
    return None

# %%
data = get_embedded_json(PAGE)

# %%
data.keys()
# Out:
# dict_keys(['props', 'page', 'query', 'buildId', 'isFallback', 'isExperimentalCompile', 'gssp', 'scriptLoader'])

# %%
data["props"].keys()
# Out:
# dict_keys(['pageProps', '__N_SSP'])

# %%
data["props"]["pageProps"].keys()
# Out:
# dict_keys(['status', 'contentApiData', 'layoutData', 'isEditable', 'inEditMode', 'inPreviewMode', 'localeData', 'currentLocale', 'fallbackLocale', 'currentUrlString', 'theme', 'isCustomAppPage'])

# %%
data["props"]["pageProps"]["contentApiData"].keys()
# Out:
# dict_keys(['contentLink', 'name', 'language', 'contentType', 'url', 'metadata', 'readspeaker', 'body', 'contentArea', 'pageAnchorLinks', 'title', 'subTitle', 'date', 'documentId', 'documentType', 'content', 'speakers', 'video', 'broadcastInformation', 'links', 'summary', 'relatedVideos', 'jointlyAnsweredDocuments'])
