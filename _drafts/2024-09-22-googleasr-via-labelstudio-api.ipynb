# %% [markdown]
# # Adding Google ASR output via Label Studio API
#
# > "Because their import sucks"
#
# - hidden: true
# - branch: master
# - categories: [labelstudio, googleasr, hsi]

# %%
def slurpfile(filename) -> str:
    with open(filename) as inf:
        return inf.read().strip()

# %%
host = "http://130.237.3.107:8080/api/"
api_token = slurpfile("label_studio_google")
input_dir = "/Users/joregan/Playing/hsi_google/"

# %%
import requests
import json
from pathlib import Path

headers = {
    "Authorization": f"Token {api_token}"
}

# %%
def get_projects():
    req = requests.get(f"{host}projects", headers=headers)
    assert req.status_code == 200
    data = json.loads(req.text)
    return data

# %%
def get_project_id_from_name(name):
    projects = get_projects()
    for res in projects["results"]:
        if res["title"].strip() == name.strip():
            return res["id"]

# %%
get_project_id_from_name("Main 5")
# Out:
# 6

# %%
def get_tasks(projectid):
    req = requests.get(f"{host}tasks", headers=headers, params={"project": projectid})
    assert req.status_code == 200
    data = json.loads(req.text)
    return data

# %%
def index_task_filestem_to_id(tasks_data):
    tasks = tasks_data["tasks"]
    mapping = {}
    for task in tasks:
        task_id = task["id"]
        if "storage_filename" in task:
            task_raw_path = task["storage_filename"]
        else:
            task_raw_path = task["data"]["audio"]
        if not task_raw_path:
            continue
        task_stem = task_raw_path.split("/")[-1]
        mapping[task_stem] = task_id
    return mapping

# %%
get_project_id_from_name("Speaker 3")
# Out:
# 1

# %%
tasks = get_tasks(6)

# %%
mapping = index_task_filestem_to_id(tasks)

# %%
mapping
# Out:
# {'hsi_5_0718_209_001_main.wav': 84,
#  'hsi_5_0718_209_002_main.wav': 85,
#  'hsi_5_0718_209_003_main.wav': 86,
#  'hsi_5_0718_210_001_main.wav': 87,
#  'hsi_5_0718_210_002_main.wav': 88,
#  'hsi_5_0718_210_003_main.wav': 89,
#  'hsi_5_0718_211_002_main.wav': 90,
#  'hsi_5_0718_211_003_main.wav': 91,
#  'hsi_5_0718_222_002_main.wav': 92,
#  'hsi_5_0718_222_003_main.wav': 93,
#  'hsi_5_0718_227_001_main.wav': 94,
#  'hsi_5_0718_227_002_main.wav': 95}

# %%
import json

def convert_json(filename):
    segments = []
    last_end = 0.0

    with open(filename) as inf:
        data = json.load(inf)
    assert "results" in data, "no 'results' list, this is maybe not from Google ASR"
    for result in data["results"]:
        if len(result["alternatives"]) != 1:
            print("More than one alternative", result["alternatives"])
        item = result["alternatives"][0]
        if not "transcript" in item:
            continue
        text = item["transcript"]
        end_time = None
        start_time = last_end
        if "words" in item:
            if "startTime" in item["words"][0]:
                start_time = item["words"][0]["startTime"]
            if "words" in item:
                if "endTime" in item["words"][-1]:
                    end_time = item["words"][-1]["endTime"]
        else:
            if "resultEndTime" in item:
                end_time = item["resultEndTime"]
        if not end_time:
            print("Still no end time?", item)
            continue
        if start_time.endswith("s"):
            start_time = start_time[:-1]
        start_time = float(start_time)
        if end_time.endswith("s"):
            end_time = end_time[:-1]
        end_time = float(end_time)
        rec = {
            "value": {
                "start": start_time,
                "end": end_time,
                "channel": 0,
                "text": [text.strip()]
            },
            "from_name": "transcription",
            "to_name": "audio",
            "type": "textarea",
        }
        segments.append(rec)
        last_end = end_time

    return segments

# %%
def post_results(id, task, project, results):
    ep = f"{host}annotations/{id}/?taskID={task}&project={project}"

    cur_headers = {i: headers[i] for i in headers}
    cur_headers["Content-type"] = "application/json"

    content = {
        "was_cancelled": False,
        "ground_truth": False,
        "project": project,
        "draft_id": 0,
        "parent_prediction": None,
        "parent_annotation": None,
        "result": results
    }
    r = requests.patch(ep, data=json.dumps(content), headers=cur_headers)
    return r

# %%
file = f"{input_dir}hsi_3_0715_209_006_main.json"
data = convert_json(file)

# %%
r = post_results(98, 22, 1, data)
print(r.text)
# Out:
# {"id":98,"result":[{"value":{"start":9.994,"end":10.839,"channel":0,"labels":["Speech"]},"from_name":"labels","to_name":"audio","type":"labels"},{"value":{"start":9.994,"end":10.839,"channel":0,"text":["Comprehensible."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":57.443,"end":58.064,"channel":0,"labels":["Speech"]},"from_name":"labels","to_name":"audio","type":"labels"},{"value":{"start":57.443,"end":58.064,"channel":0,"text":["Yeah, further."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":58.264,"end":58.444,"channel":0,"labels":["Speech"]},"from_name":"labels","to_name":"audio","type":"labels"},{"value":{"start":58.264,"end":58.444,"channel":0,"text":["Yeah."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":73.675,"end":74.576,"channel":0,"labels":["Speech"]},"from_name":"labels","to_name":"audio","type":"labels"},{"value":{"start":73.675,"end":74.576,"channel":0,"text":["Oh, I'm good."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":74.636,"end":75.757,"channel":0,"labels":["Speech"]},"from_name":"labels","to_name":"audio","type":"labels"},{"value":{"start":74.636,"end":75.757,"channel":0,"text":["You're so welcome."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":78.359,"end":79.619,"channel":0,"labels":["Speech"]},"from_name":"labels","to_name":"audio","type":"labels"},{"value":{"start":78.359,"end":79.619,"channel":0,"text":["I'm so glad you're here."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":83.042,"end":84.403,"channel":0,"labels":["Speech"]},"from_name":"labels","to_name":"audio","type":"labels"},{"value":{"start":83.042,"end":84.403,"channel":0,"text":["Yeah, thank you."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":84.563,"end":85.224,"channel":0,"labels":["Speech"]},"from_name":"labels","to_name":"audio","type":"labels"},{"value":{"start":84.563,"end":85.224,"channel":0,"text":["Thank you."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":86.444,"end":86.945,"channel":0,"labels":["Speech"]},"from_name":"labels","to_name":"audio","type":"labels"},{"value":{"start":86.444,"end":86.945,"channel":0,"text":["Yeah."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":90.029,"end":97.773,"channel":0,"labels":["Speech"]},"from_name":"labels","to_name":"audio","type":"labels"},{"value":{"start":90.029,"end":97.773,"channel":0,"text":["Yeah, yeah, with the stove and... But I did... Yeah, yeah, yeah, yeah, yeah, yeah."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":98.234,"end":106.538,"channel":0,"labels":["Speech"]},"from_name":"labels","to_name":"audio","type":"labels"},{"value":{"start":98.234,"end":106.538,"channel":0,"text":["Now in the summer we don't need it, but in the winter it's... It changes everything, it does, it's really great."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":107.859,"end":118.365,"channel":0,"labels":["Speech"]},"from_name":"labels","to_name":"audio","type":"labels"},{"value":{"start":107.859,"end":118.365,"channel":0,"text":["Yeah, yeah, I'm really happy about... And also it's the view, it's so nice, and the sun comes in in the afternoon, and so..."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":120.16,"end":146.813,"channel":0,"labels":["Speech"]},"from_name":"labels","to_name":"audio","type":"labels"},{"value":{"start":120.16,"end":146.813,"channel":0,"text":["yeah yeah yeah it's nice but I also feel a little bit like prison feeling sometimes you know when it's dark and you have this I don't know but it's still it's beautiful yeah it is yeah and I do some yoga here in front of the window"]},"from_name":"transcription","to_name":"audio","type":"te ...

# %%
map2 = {
    "hsi_5_0718_210_002_main.wav": 243,
"hsi_5_0718_210_003_main.wav": 244,
"hsi_5_0718_211_003_main.wav": 246,
"hsi_5_0718_222_003_main.wav": 247,
"hsi_5_0718_210_001_main.wav": 248,
"hsi_5_0718_211_002_main.wav": 249
}

# %%
mapping
# Out:
# {'hsi_5_0718_209_001_main.wav': 84,
#  'hsi_5_0718_209_002_main.wav': 85,
#  'hsi_5_0718_209_003_main.wav': 86,
#  'hsi_5_0718_210_001_main.wav': 87,
#  'hsi_5_0718_210_002_main.wav': 88,
#  'hsi_5_0718_210_003_main.wav': 89,
#  'hsi_5_0718_211_002_main.wav': 90,
#  'hsi_5_0718_211_003_main.wav': 91,
#  'hsi_5_0718_222_002_main.wav': 92,
#  'hsi_5_0718_222_003_main.wav': 93,
#  'hsi_5_0718_227_001_main.wav': 94,
#  'hsi_5_0718_227_002_main.wav': 95}

# %%
for task in mapping:
    jsonfile = task.replace(".wav", ".json")
    file = Path(input_dir) / jsonfile
    print(file)
    if not file.exists():
        continue
    if not task in map2:
        continue
    data = convert_json(str(file))
    r = post_results(map2[task], mapping[task], 6, data)
    # count += 1
    print(r.text)
# Out:
# /Users/joregan/Playing/hsi_google/hsi_5_0718_209_001_main.json
# /Users/joregan/Playing/hsi_google/hsi_5_0718_209_002_main.json
# /Users/joregan/Playing/hsi_google/hsi_5_0718_209_003_main.json
# /Users/joregan/Playing/hsi_google/hsi_5_0718_210_001_main.json
# {"id":248,"result":[{"value":{"start":7.3,"end":7.6,"channel":0,"text":["Yeah."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":13.3,"end":13.6,"channel":0,"text":["Yeah."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":23.4,"end":23.7,"channel":0,"text":["Yes."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":40.0,"end":42.6,"channel":0,"text":["Oh, that was nice. Nice idea to have the"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":44.1,"end":44.9,"channel":0,"text":["Oh, I like this place."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":55.2,"end":61.5,"channel":0,"text":["Yeah, so what do you think? I, I really think I've made the best out of this place. Actually, uh,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":62.6,"end":62.9,"channel":0,"text":["Sorry."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":63.7,"end":96.7,"channel":0,"text":["Yeah, it does. And and I really like what I did with the flowers up there because it's like the Hanging Gardens of Babylon. Uh I would like to have more of course and and but I think in time uh they will hang down like a waterfall of green leaves. That's my intention anyway because I'm I'm really into uh plants and uh what? What's nice with these plants too, like the that's called the tongue of mother-in-law."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":97.2,"end":98.9,"channel":0,"text":["The 1 by the window in Swedish."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":100.4,"end":105.4,"channel":0,"text":["H, because it's called Dragon tongue and your mother-in-law."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":106.3,"end":110.6,"channel":0,"text":["In the old way, that everyone thought their mother-in-law was a dragon."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":112.0,"end":120.9,"channel":0,"text":["So it was called the mother-in-law tongue and uh, that of course, is monstera uh, a new 1. Uh, I actually bought it from uh,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":121.9,"end":126.6,"channel":0,"text":["Uh, the Amazon. Uh, so it's brought here by a friend."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":127.2,"end":141.0,"channel":0,"text":["As a just a little little coupling. And uh, now it's looks like that and and that's only in 3 months. So uh, I have to say I have green fingers and um,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":141.7,"end":142.5,"channel":0,"text":["Yes."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":143.1,"end":145.8,"channel":0,"text":["And do you wonder about the kettle? I have their"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":148.1,"end":179.4,"channel":0,"text":["Yes, but it's not actually uh, because when you boil water, you clean it. Uh and if you want the plants to grow properly, you, you want the water to be as clean as possible. But of course, you'll also take out the nourishment in the water. So you have to add nourishment uh fertilizers and so, uh, but it's really important to have clean water. And then I let it stand there for"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":180.5,"end":182.9,"channel":0,"text":["2 or 3 weeks. And then I put it in."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":183.8,"end":184.7,"channel":0,"text":["Regular water."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":185.7,"end":192.8,"channel": ...
# /Users/joregan/Playing/hsi_google/hsi_5_0718_210_002_main.json
# {"id":243,"result":[{"value":{"start":4.2,"end":4.8,"channel":0,"text":["Strange."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":17.5,"end":19.2,"channel":0,"text":["Oh sorry."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":22.9,"end":23.9,"channel":0,"text":["Yeah. Yeah yeah. Yeah."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":25.6,"end":27.2,"channel":0,"text":["Yeah. Yeah."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":49.0,"end":53.2,"channel":0,"text":["And you're going to rent it. Oh, could I have some water?"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":55.2,"end":55.5,"channel":0,"text":["Yeah."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":58.3,"end":58.5,"channel":0,"text":["oh,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":62.2,"end":63.2,"channel":0,"text":["God, it's strange too."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":70.2,"end":74.8,"channel":0,"text":["It's really strange because when when you can't see it you feel it but you can't see it."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":85.9,"end":86.3,"channel":0,"text":["Yeah."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":87.3,"end":89.1,"channel":0,"text":["Uh, but uh,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":89.8,"end":96.4,"channel":0,"text":["As you know, we we agreed on 6 months, so, so I wonder why you're leaving earlier."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":99.1,"end":100.1,"channel":0,"text":["Ah, okay."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":100.8,"end":105.7,"channel":0,"text":["And normally I would have to charge you for the whole time."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":106.5,"end":111.2,"channel":0,"text":["but I think I can make an exception because I really have"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":112.2,"end":114.5,"channel":0,"text":["some other persons who want it, but"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":116.2,"end":116.7,"channel":0,"text":["is it?"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":117.6,"end":125.1,"channel":0,"text":["Anything you think of that, that I could improve here for the next person or or did you think it worked fine?"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":129.1,"end":129.7,"channel":0,"text":["You think so?"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":131.4,"end":135.3,"channel":0,"text":["Oh so, so you think it was too much to take care of?"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":136.4,"end":136.7,"channel":0,"text":["Yeah."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":141.6,"end":156.8,"channel":0,"text":["Yeah. Yes because I I I had an idea that because 1 thing is that they're all uh, air cleaners, so they clean the air for you. But uh I understand that it could be some"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":158.4,"end":167.2,"channel":0,"text":["Difficulty is actually 2 to water those up there. So uh what do you think? Would it be all right if I put a ladder in or something."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":169.8,"end":170.4,"channel":0,"text":["That 1."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{ ...
# /Users/joregan/Playing/hsi_google/hsi_5_0718_210_003_main.json
# {"id":244,"result":[{"value":{"start":3.3,"end":8.0,"channel":0,"text":["Yeah."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":9.3,"end":14.8,"channel":0,"text":["I couldn't agree more. Uh what what what I suggest is uh what"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":16.2,"end":33.9,"channel":0,"text":["I think we should look at the room as a canvas. Uh so what I suggest that we do is to before we start thinking of what you want we have to take everything out uh everything actually even the sofa."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":34.8,"end":38.9,"channel":0,"text":["uh, it's big but uh, I think it would be good because"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":42.7,"end":45.9,"channel":0,"text":["I don't know what, what what's your budget is? But"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":47.4,"end":48.0,"channel":0,"text":["Could you?"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":49.7,"end":52.3,"channel":0,"text":["Uh, think of buying a new sofa."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":55.7,"end":60.8,"channel":0,"text":["yes it, uh, but but actually depends on what what what color scheme where because now it's just"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":61.9,"end":71.8,"channel":0,"text":["Uh, it's we we have this doesn't go with the Earth colors here and it doesn't go with. The the only thing it goes with is that blanket and the bin."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":77.4,"end":81.2,"channel":0,"text":["yeah, if you should replace 1 thing, it should be this 1, the armchair"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":82.2,"end":82.8,"channel":0,"text":["uh,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":83.4,"end":84.1,"channel":0,"text":["And maybe."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":85.2,"end":90.8,"channel":0,"text":["if but because what what what we can do, I don't mean that you just should, uh,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":91.5,"end":93.1,"channel":0,"text":["throw things out."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":95.7,"end":107.7,"channel":0,"text":["Uh, I I don't mean that you should throw things out. Uh, I mean that we sell it because I I can see that this is not an Ikea armchair. It's uh, was quite expensive."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":111.1,"end":117.2,"channel":0,"text":["Yes, you keep the the, the big sofa then. Yeah, because this 1, I think should go."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":120.5,"end":124.3,"channel":0,"text":["Oh, is this a memory? Okay. Oh, okay. But then"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":125.6,"end":130.2,"channel":0,"text":["Uh, you'll keep that 1. Is it something else in here? You really want to keep?"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":136.4,"end":143.3,"channel":0,"text":["Yeah, because what I think is that we could do because this is a bit modern."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":144.1,"end":145.7,"channel":0,"text":["and what we could do is,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":146.9,"end":149.5,"channel":0,"text":["Go with the more of a mixed."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":150.2,"end":150.8,"chan ...
# /Users/joregan/Playing/hsi_google/hsi_5_0718_211_002_main.json
# {"id":249,"result":[{"value":{"start":6.3,"end":7.2,"channel":0,"text":["now, I'm looking"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":21.9,"end":22.4,"channel":0,"text":["Yeah."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":23.7,"end":25.6,"channel":0,"text":["Oh nice. There's a"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":36.0,"end":42.2,"channel":0,"text":["yes, I did actually and I was so, so lucky because, you know,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":43.9,"end":47.6,"channel":0,"text":["just to have this view, you know, you have to pay Fortune but actually"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":49.1,"end":49.5,"channel":0,"text":["I,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":50.4,"end":55.3,"channel":0,"text":["Managed to do it like this. So this used to be my grandmother's apartment."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":56.4,"end":62.4,"channel":0,"text":["and uh so what we did and it's a rental uh but you know, you have to pay"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":63.3,"end":68.1,"channel":0,"text":["a lot of black money for for a place like this, but what"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":72.0,"end":81.3,"channel":0,"text":["No, no, no. It was like this. So what what I think is that this was, was actually the whole area, actually, the the whole building was a factory"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":82.6,"end":85.3,"channel":0,"text":["So, uh, like this window?"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":86.4,"end":90.3,"channel":0,"text":["Its Windows, all the way up to the fourth floor. And"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":91.3,"end":95.1,"channel":0,"text":["That was actually uh there was no floor here."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":96.0,"end":102.1,"channel":0,"text":["So that's they put that in later on. So so it was actually just 4"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":103.4,"end":106.6,"channel":0,"text":["floors. Uh, and they had to"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":107.8,"end":115.2,"channel":0,"text":["Make the floors. So so there was a big uh newspaper here. Uh, and they had the the"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":117.0,"end":118.2,"channel":0,"text":["What is it called? The Press."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":118.9,"end":119.4,"channel":0,"text":["Machine."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":120.2,"end":134.9,"channel":0,"text":["The, the machine that produced the paper, so it was standing somewhere in the middle of the room and it was flying around. So it's and that's why the whole area is called the the magazine. Uh, but so so these are actually"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":136.9,"end":152.8,"channel":0,"text":["Like, they have built walls and and made, uh, apartments in this building. So, it's, uh, and that's why the rooms you, you can see there are no windows in that direction. Uh, and that's because, uh,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":153.4,"end":159.4,"channel":0,"text":["I have rooms there, but uh, the windows is in the apartment. The next apartment."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"st ...
# /Users/joregan/Playing/hsi_google/hsi_5_0718_211_003_main.json
# {"id":246,"result":[{"value":{"start":4.1,"end":4.5,"channel":0,"text":["Yeah."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":11.6,"end":13.6,"channel":0,"text":["interior designer, I think that's"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":30.2,"end":30.5,"channel":0,"text":["yeah."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":36.6,"end":44.1,"channel":0,"text":["yes, I think that, uh, when when you look at it, uh, because you have this wonderful window here,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":44.8,"end":48.7,"channel":0,"text":["and this 1 and uh, I, I"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":50.2,"end":54.1,"channel":0,"text":["think that this is a good placement of the soap, because you can"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":55.8,"end":59.8,"channel":0,"text":["See outside but I really think you should have."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":61.6,"end":63.2,"channel":0,"text":["That we should make something here."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":64.2,"end":71.1,"channel":0,"text":["Uh, like a place where you could sit and relax. So it could be a cushion all the way there."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":72.3,"end":75.3,"channel":0,"text":["and, and then you could uh,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":77.6,"end":78.3,"channel":0,"text":["yes, but"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":79.5,"end":81.2,"channel":0,"text":["When when you have this View."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":82.0,"end":89.0,"channel":0,"text":["Uh, imagine sitting here reading a book. Uh, the sofa is more for television and and uh"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":93.6,"end":102.0,"channel":0,"text":["Yes, of course you you I think I think maybe you could do something like um, since it is an old factory."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":102.9,"end":103.8,"channel":0,"text":["If we made it."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":104.9,"end":105.6,"channel":0,"text":["a bit, uh,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":108.8,"end":118.2,"channel":0,"text":["We could make it like to look like boxes, the the but I I think you should have something that was about this High 20 cm."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":119.3,"end":122.9,"channel":0,"text":["Uh, and then uh, thick, uh, cushion."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":129.4,"end":139.4,"channel":0,"text":["It depends on if we if we like that 1, the pink 1, the light 1 but uh that depends. And then of course, uh,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":143.5,"end":144.6,"channel":0,"text":["It's a nice room."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":144.8,"end":147.6,"channel":0,"text":["And then you, of course you have this room as well. So"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":149.0,"end":150.3,"channel":0,"text":["if, if you could"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":152.1,"end":159.0,"channel":0,"text":["You in some way? Would you do you know if the wall is uh, a bearing wall?"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value" ...
# /Users/joregan/Playing/hsi_google/hsi_5_0718_222_002_main.json
# /Users/joregan/Playing/hsi_google/hsi_5_0718_222_003_main.json
# {"id":247,"result":[{"value":{"start":48.5,"end":50.4,"channel":0,"text":["and then I, with the arms or"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":52.2,"end":54.3,"channel":0,"text":["Oh, I don't even have to watch the ball."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":55.0,"end":55.3,"channel":0,"text":["Thank you."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":68.8,"end":71.1,"channel":0,"text":["That's fine."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":77.4,"end":80.2,"channel":0,"text":["Okay. Uh,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":82.1,"end":90.8,"channel":0,"text":["I I really don't want to create a situation here. But what the hell has happened to the carpet?"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":92.2,"end":94.6,"channel":0,"text":["But what there are stains on the carpet."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":96.6,"end":99.5,"channel":0,"text":["No, it's not a pattern. If you look there."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":100.4,"end":101.5,"channel":0,"text":["There's stains."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":102.3,"end":104.1,"channel":0,"text":["Uh, where do they come from?"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":106.6,"end":107.5,"channel":0,"text":["Yeah, but what"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":108.6,"end":108.9,"channel":0,"text":["this is,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":111.3,"end":111.7,"channel":0,"text":["this is,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":113.0,"end":118.2,"channel":0,"text":["An antique carpet. And I told you that when you moved in,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":119.0,"end":119.7,"channel":0,"text":["uh,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":121.6,"end":123.2,"channel":0,"text":["what you going to tell me about it?"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":126.8,"end":132.9,"channel":0,"text":["Yeah, baby. I don't care if you did it. Like the, the sofa here. Uh,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":134.2,"end":137.7,"channel":0,"text":["I I I see that. Oh my God, I'm so"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":138.8,"end":139.4,"channel":0,"text":["disappointed."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":141.0,"end":145.2,"channel":0,"text":["Uh, but we will have to do that. But okay, um,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":148.1,"end":148.7,"channel":0,"text":["Fuck."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":149.6,"end":150.5,"channel":0,"text":["Um,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":151.5,"end":155.2,"channel":0,"text":["All right, let me just take uh, a moment."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":163.2,"end":164.2,"channel":0,"text":["There. Okay."]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":165.6,"end":167.9,"channel":0,"text":["so, apart from the stain,"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":169.0,"end":169.5,"channel":0,"text":["How?"]},"from_name":"transcription","to_name":"audio","type":"textarea"},{"value":{"start":170.8,"e ...
# /Users/joregan/Playing/hsi_google/hsi_5_0718_227_001_main.json
# /Users/joregan/Playing/hsi_google/hsi_5_0718_227_002_main.json

# %%
tmap = {}
count = 99
for task in mapping:
    tmap[task] = count
    count += 1

# %%
from pathlib import Path

for file in Path(input_dir).glob("*.json"):
    wavfile = file.stem + ".wav"
    if wavfile in mapping:
        print(wavfile, mapping[wavfile])
# Out:
# hsi_5_0718_210_002_main.wav 88
# hsi_5_0718_210_003_main.wav 89
# hsi_5_0718_211_003_main.wav 91
# hsi_5_0718_222_003_main.wav 93
# hsi_5_0718_210_001_main.wav 87
# hsi_5_0718_211_002_main.wav 90
