# %%
import json

in_path = "/Users/joregan/Playing/nst_swedish_tts/whisper-v3-aligned-to-sw_all.json"
out_path = "/Users/joregan/Playing/nst_swedish_tts/whisper-v3-aligned-to-sw_all_ordered.json"

with open(in_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# Map int → (original_key, value)
items = [(int(k), v) for k, v in data.items()]
items.sort(key=lambda x: x[0])

# Reconstruct with the original (possibly zero-padded) key strings
ordered = {str(k).zfill(len(items[0][0].__str__())): v for k, v in items}

with open(out_path, "w", encoding="utf-8") as f:
    json.dump(ordered, f, ensure_ascii=False, indent=2)

print(f"✅ Ordered JSON written to {out_path}")
# Out:
# ✅ Ordered JSON written to /Users/joregan/Playing/nst_swedish_tts/whisper-v3-aligned-to-sw_all_ordered.json

# %%
# !pip install num2words

# %%
from num2words import num2words

def approx_num(raw_number, text):
    try:
        number = int(raw_number)
    except ValueError:
        return False
    forms = set()
    if len(raw_number) == 4:
        a = num2words(int(number[0:2]), lang='sv')
        b = num2words(int(number[2]), lang='sv')
        forms.add(f"{a} hundra {b}")
        forms.add(f"{a}hundra {b}")
        forms.add(f"{a}hundra{b}")
    card = num2words(number, lang='sv', to='cardinal')
    ord = num2words(number, lang='sv', to='ordinal')
    forms.add(card)
    forms.add(ord)
    for inner in ["tusen", "hundra"]:
        if inner in card:
            forms.add(card.replace(inner, inner + " "))
            forms.add(card.replace(inner, " " + inner))
            forms.add(card.replace(inner, " " + inner + " "))
        if inner in ord:
            forms.add(ord.replace(inner, inner + " "))
            forms.add(ord.replace(inner, " " + inner))
            forms.add(ord.replace(inner, " " + inner + " "))
    for form in forms:
        if form in text:
            return True
    return False

# %%
OFFSETS = {
    4155: 1,
    5144: 2,
}

rejigged = {}

offset = 0
for k_str, v in ordered.items():
    k = int(k_str)
    if k > 5277:
        break
    if k in OFFSETS:
        offset = OFFSETS[k]
    new_k = k + offset
    rejigged[k_str.zfill(4)] = {
        "res": v["res"],
        "orig": ordered[str(new_k)]["orig"]
    }

# %%
for item in rejigged:
    res = rejigged[item]["res"]
    orig = rejigged[item]["orig"]
    if res == orig.replace("_", " "):
        rejigged[item]["norm"] = res
    else:
        norm_simple = res.replace(".", "").replace(",", "").replace("?", "").replace("!", "").lower()
        if orig == norm_simple:
            rejigged[item]["norm"] = res

# %%
def simple_norm(res):
    return res.replace(".", "").replace(",", "").replace("?", "").replace("!", "").lower()

# %%
import re

def check_numbers_match(res, orig):
    res_norm = simple_norm(res)
    res_words = res_norm.split()

    for word in res_words:
        if re.fullmatch(r'^\d+$', word):
            if approx_num(word, orig):
                return True
    return False

# %%
def capitalize_and_punctuate(text, punct="."):
    if not text:
        return text
    text = text[0].upper() + text[1:]
    text += punct
    return text

# %%
OK_WHISPER = [
    "0004", "0111", "3956", "4811", "4699", "4676", "4665", "4651",
    "0172", "0348", "0442", "0738", "0799", "0880", "0999", "1031",
    "1075", "1098", "1177", "1279", "1320", "1441", "1493", "1501",
    "1508", "1511", "1513", "1514", "1516", "1518", "1519", "1520",
    "1524", "1090", "1917"
]
UC_WHISPER = ["0079", "2537"]
PUNCT_WHISPER = ["0085", "4838", "0672", "1498", "1499", "1517", "1526", "1528", "1530", "1531", "1533", "1535"]
ORIG_UC_FS = [
    "0001", "0011", "0045", "0052", "0064", "0065", "0063", "0070", "0080", "0084", "0113", "0123",
    "0125", "0104", "0127", "2543", "3748", "0143", "0145", "5030", "5060", "5080", "5117", "5123",
    "4858", "4717", "4707", "4703", "4695", "4576", "4484", "0158", "0129", "0151", "0165", "0171",
    "0173", "1365", "1366"
]
FULL_NORM = {
    "0112": "Jag vill ta en titt i ert gevärsskåp. Det är allt.",
    "5202": "Per Henricson.",
    "5203": "Westergren presstödsnämnden.",
    "5208": "Actinvest är ett seriöst bolag, säger en analytiker i Milano.",
    "5185": "Microsoft-mus ingår.",
    "5147": "Skalbarhet under Windows NT har förut varit en black om foten.",
    "5138": "Palmquist som är vd på UB Networks i Sverige.",
    "5143": "Henrik Lind har anställts som utvecklingschef på Living Questions.",
    "3881": "I det nya EU är detta en omöjlighet.",
    "4869": "ModelQuest Expert och kan hantera upp till 60 olika indata.",
    "4728": "Norden Rolf Hallencreutz.",
    "4726": "Lars Öquist, vd, TCM.",
    "4706": "Lärarförbundets ordförande Christer Romilson.",
    "4581": "Med vänliga hälsningar två Vilhelminabor.",
    "5275": "Det gällde både konst, arkitektur, litteratur, musik, filosofi och vetenskap.",
    "0128": "Han var fullblodspolitikern, rutinerad och oöm.",
}

# %%
a = """0672
1498
1499
1517
1526
1528
1530
1531
1533
1535""".split("\n")
print(", ".join(['"' + x + '"' for x in a]))
# Out:
# "0672", "1498", "1499", "1517", "1526", "1528", "1530", "1531", "1533", "1535"

# %%
for item in rejigged:
    if "norm" not in rejigged[item]:
        orig = rejigged[item]["orig"]
        orig = orig.replace("_", " ")
        res = rejigged[item]["res"]
        if item in OK_WHISPER:
            rejigged[item]["norm"] = res
        elif item in UC_WHISPER:
            rejigged[item]["norm"] = capitalize_and_punctuate(res, "")
        elif item in PUNCT_WHISPER:
            rejigged[item]["norm"] = capitalize_and_punctuate(res)
        elif item in ORIG_UC_FS:
            rejigged[item]["norm"] = capitalize_and_punctuate(orig)
        elif item in FULL_NORM:
            rejigged[item]["norm"] = FULL_NORM[item]
        else:
            print(f"⚠️  Mismatch at item {item}:")
            print(f"    res:  '{res}'")
            print(f"    orig: '{orig}'")
            print(f".   \"{item}\": \"{orig}\",")
# Out:
# ⚠️  Mismatch at item 0042:
#     res:  'Ett nytt landskap möter du bakom varje krön.'
#     orig: 'ett nytt landskap möter bakom varje krön'
# .   "0042": "ett nytt landskap möter bakom varje krön",
# ⚠️  Mismatch at item 0095:
#     res:  'Larmen saligförs med fem års trygghetsförsäkring.'
#     orig: 'larmen saluförs med fem års trygghetsförsäkring'
# .   "0095": "larmen saluförs med fem års trygghetsförsäkring",
# ⚠️  Mismatch at item 0106:
#     res:  'Magsjuka är ett problem att ta på allvar.'
#     orig: 'magsjuka ett problem att ta på allvar'
# .   "0106": "magsjuka ett problem att ta på allvar",
# ⚠️  Mismatch at item 0136:
#     res:  'Han efterlyser i samarbete med tull, sjukvård och skola.'
#     orig: 'han efterlyser samarbete med tull sjukvård och skola'
# .   "0136": "han efterlyser samarbete med tull sjukvård och skola",
# ⚠️  Mismatch at item 0174:
#     res:  'Den goda morotsoppan med de asiatiska kryddorna citrongräs, chili och färsk ingefära.'
#     orig: 'den goda morotssoppan med de asiatiska kryddorna citrongräs chili och färsk ingefära'
# .   "0174": "den goda morotssoppan med de asiatiska kryddorna citrongräs chili och färsk ingefära",
# ⚠️  Mismatch at item 0177:
#     res:  'Ett var att gifta in sig i Adam'
#     orig: 'ett var att gifta in sig i adeln'
# .   "0177": "ett var att gifta in sig i adeln",
# ⚠️  Mismatch at item 0184:
#     res:  'Också på de övriga borsorna i regionen sjönk kurserna.'
#     orig: 'också på de övriga börserna i regionen sjönk kurserna'
# .   "0184": "också på de övriga börserna i regionen sjönk kurserna",
# ⚠️  Mismatch at item 0185:
#     res:  'Blåvitt fick varma hyllningar från de orange-svarta supportarna'
#     orig: 'blåvitt fick varma hyllningar från de orangesvarta supportrarna'
# .   "0185": "blåvitt fick varma hyllningar från de orangesvarta supportrarna",
# ⚠️  Mismatch at item 0186:
#     res:  'Inom homeopatin används myrsyra mot ryggont, ledverk och allergier.'
#     orig: 'inom homeopatin används myrsyra mot ryggont ledvärk och allergier'
# .   "0186": "inom homeopatin används myrsyra mot ryggont ledvärk och allergier",
# ⚠️  Mismatch at item 0187:
#     res:  'Affärsbankerna och Bolåningsinstitut höjde överlag på måndagen sina boräntor.'
#     orig: 'affärsbankerna och bolåneinstitut höjde överlag på måndagen sina boräntor'
# .   "0187": "affärsbankerna och bolåneinstitut höjde överlag på måndagen sina boräntor",
# ⚠️  Mismatch at item 0190:
#     res:  'Hans tidigare daghem har blivit nedlagda.'
#     orig: 'hans tidigare daghem har blivit nerlagda'
# .   "0190": "hans tidigare daghem har blivit nerlagda",
# ⚠️  Mismatch at item 0195:
#     res:  'På myren är djungpipare och ängspipare karaktärsfåglar.'
#     orig: 'på myren är ljungpipare och ängspipare karaktärsfåglar'
# .   "0195": "på myren är ljungpipare och ängspipare karaktärsfåglar",
# ⚠️  Mismatch at item 0196:
#     res:  'Portien räckte mig nyckeln medan han fortfarande stirrade på dem'
#     orig: 'portiern räckte mig nyckeln medan han fortfarande stirrade på dem'
# .   "0196": "portiern räckte mig nyckeln medan han fortfarande stirrade på dem",
# ⚠️  Mismatch at item 0200:
#     res:  'Jag fick bo på övervåningen där spädbanan fanns'
#     orig: 'jag fick bo på övervåningen där spädbarnen fanns'
# .   "0200": "jag fick bo på övervåningen där spädbarnen fanns",
# ⚠️  Mismatch at item 0201:
#     res:  'Nu satte det fart med järnvägstunneln.'
#     orig: 'nu satte de fart med järnvägstunneln'
# .   "0201": "nu satte de fart med järnvägstunneln",
# ⚠️  Mismatch at item 0209:
#     res:  'Hyvla över smöret och strä på sockret.'
#     orig: 'hyvla över smöret och strö på sockret'
# .   "0209": "hyvla över smöret och strö på sockret",
# ⚠️  Mismatch at item 0210:
#     res:  'Hon ställde sig vid ingången halv åtta'
#     orig: 'hon ställde sig vid ingången halvåtta'
# .   "0210": "hon ställde sig vid ingången halvåtta",
# ⚠️  Mismatch at item 0211:
#     res:  'Geleehallon och lakritsbåtar var också gott.'
#     orig: 'geléhallon och lakritsbåtar var också gott'
# .   "0211": "geléhallon och lakritsbåtar var också gott",
# ⚠️  Mismatch at item 0212:
#     res:  'Vanlig materia utgör bara en miljarddel av antalet partiklar i universum idag.'
#     orig: 'vanlig materia utgör bara en miljarddel av antalet partiklar i universum i dag'
# .   "0212": "vanlig materia utgör bara en miljarddel av antalet partiklar i universum i dag",
# ⚠️  Mismatch at item 0213:
#     res:  'Nypremiären tillkommer för att fira tioårsjubileet av originalfilmen.'
#     orig: 'nypremiären tillkommer för att fira tioårsjubiléet av originalfilmen'
# .   "0213": "nypremiären tillkommer för att fira tioårsjubiléet av originalfilmen",
# ⚠️  Mismatch at item 0217:
#     res:  'Han vill vidga sina vyer och också ta ett huv med sina egna fördomar'
#     orig: 'han vill vidga sina vyer och också ta itu med sina egna fördomar'
# .   "0217": "han vill vidga sina vyer och också ta itu med sina egna fördomar",
# ⚠️  Mismatch at item 0220:
#     res:  'Skidåkare är inte bara intresserade av blåbärshoppa.'
#     orig: 'skidåkare är inte bara intresserade av blåbärssoppa'
# .   "0220": "skidåkare är inte bara intresserade av blåbärssoppa",
# ⚠️  Mismatch at item 0235:
#     res:  'TR av dessa örter lindrar din förkylning.'
#     orig: 'teer av dessa örter lindrar din förkylning'
# .   "0235": "teer av dessa örter lindrar din förkylning",
# ⚠️  Mismatch at item 0237:
#     res:  'Då forcerar de dörren till bussen.'
#     orig: 'då forcerade de dörren till bussen'
# .   "0237": "då forcerade de dörren till bussen",
# ⚠️  Mismatch at item 0238:
#     res:  'Är inte det ett pysslig, förstår du?'
#     orig: 'är inte direkt pysslig förstår du'
# .   "0238": "är inte direkt pysslig förstår du",
# ⚠️  Mismatch at item 0242:
#     res:  'För stulet tog jag ett steg in i omklädningsrummet.'
#     orig: 'förstulet tog jag ett steg in i omklädningsrummet'
# .   "0242": "förstulet tog jag ett steg in i omklädningsrummet",
# ⚠️  Mismatch at item 0246:
#     res:  'Högt uppe i några träkronor börjar några gibbonapor sjunga.'
#     orig: 'högt uppe i några trädkronor börjar några gibbonapor sjunga'
# .   "0246": "högt uppe i några trädkronor börjar några gibbonapor sjunga",
# ⚠️  Mismatch at item 0248:
#     res:  'Kanske kan hon dra igång en ny förnyelsedebatt'
#     orig: 'kanske kan hon dra i gång en ny förnyelsedebatt'
# .   "0248": "kanske kan hon dra i gång en ny förnyelsedebatt",
# ⚠️  Mismatch at item 0253:
#     res:  'Principiellt tycker han att brott ska anmälas Men'
#     orig: 'principiellt tycker han att brott ska anmälas'
# .   "0253": "principiellt tycker han att brott ska anmälas",
# ⚠️  Mismatch at item 0263:
#     res:  'Hon vet ju hur dant det var'
#     orig: 'hon vet ju hurdant det var'
# .   "0263": "hon vet ju hurdant det var",
# ⚠️  Mismatch at item 0266:
#     res:  'Solen gassar från en klar blå himmel.'
#     orig: 'solen gassar från en klarblå himmel'
# .   "0266": "solen gassar från en klarblå himmel",
# ⚠️  Mismatch at item 0271:
#     res:  'Då kämpade jag mot en massa prestige och åldersnöja'
#     orig: 'då kämpade jag mot en massa prestige och åldersnoja'
# .   "0271": "då kämpade jag mot en massa prestige och åldersnoja",
# ⚠️  Mismatch at item 0272:
#     res:  'En vätatom har frigjort sig från vattenmolekylen.'
#     orig: 'en väteatom har frigjort sig från vattenmolekylen'
# .   "0272": "en väteatom har frigjort sig från vattenmolekylen",
# ⚠️  Mismatch at item 0280:
#     res:  'Bamboo kan till och med ätas.'
#     orig: 'bambu kan till och med ätas'
# .   "0280": "bambu kan till och med ätas",
# ⚠️  Mismatch at item 0281:
#     res:  'Vi hävdar ju inte att alla ansökerländer ska bli medlemmar samtidigt.'
#     orig: 'vi hävdar ju inte att alla ansökarländer ska bli medlemmar samtidigt'
# .   "0281": "vi hävdar ju inte att alla ansökarländer ska bli medlemmar samtidigt",
# ⚠️  Mismatch at item 0294:
#     res:  'De senaste två omgångarna har dock givit två poängare'
#     orig: 'de senaste två omgångarna har dock givit tvåpoängare'
# .   "0294": "de senaste två omgångarna har dock givit tvåpoängare",
# ⚠️  Mismatch at item 0296:
#     res:  'Istället ska juridik och beteendevetenskap ingå i utbildningen på polishögskolan.'
#     orig: 'i stället ska juridik och beteendevetenskap ingå i utbildningen på polishögskolan'
# .   "0296": "i stället ska juridik och beteendevetenskap ingå i utbildningen på polishögskolan",
# ⚠️  Mismatch at item 0298:
#     res:  'Det kan vara yoghurt eller möjligen melling.'
#     orig: 'det kan vara youghurt eller möjligen välling'
# .   "0298": "det kan vara youghurt eller möjligen välling",
# ⚠️  Mismatch at item 0300:
#     res:  'Omsider bjöd Jalen godnatt och försvann till sitt nattkvarter'
#     orig: 'omsider bjöd jarlen godnatt och försvann till sitt nattkvarter'
# .   "0300": "omsider bjöd jarlen godnatt och försvann till sitt nattkvarter",
# ⚠️  Mismatch at item 0301:
#     res:  'Denna utveckling har varit positiv ur välfärdsynpunkt.'
#     orig: 'denna utveckling har varit positiv ur välfärdssynpunkt'
# .   "0301": "denna utveckling har varit positiv ur välfärdssynpunkt",
# ⚠️  Mismatch at item 0309:
#     res:  'Näsbjörns ungar tittade forskande upp ur varje bo'
#     orig: 'näsbjörnsungar tittade forskande upp ur varje bo'
# .   "0309": "näsbjörnsungar tittade forskande upp ur varje bo",
# ⚠️  Mismatch at item 0314:
#     res:  'De tre oktoberdagarna vore hon alltid lika efterlängtade runt sjön.'
#     orig: 'de tre oktoberdagarna voro alltid lika efterlängtade runt sjön'
# .   "0314": "de tre oktoberdagarna voro alltid lika efterlängtade runt sjön",
# ⚠️  Mismatch at item 0322:
#     res:  'Någon ny bankkris ska vi inte ha'
#     orig: 'någon ny bankkris skall vi inte ha'
# .   "0322": "någon ny bankkris skall vi inte ha",
# ⚠️  Mismatch at item 0323:
#     res:  'Vid de andra automaterna sitter få ordiga män.'
#     orig: 'vid de andra automaterna sitter fåordiga män'
# .   "0323": "vid de andra automaterna sitter fåordiga män",
# ⚠️  Mismatch at item 0326:
#     res:  'Vila ner mycket tid på layouten'
#     orig: 'vi la ner mycket tid på layouten'
# .   "0326": "vi la ner mycket tid på layouten",
# ⚠️  Mismatch at item 0327:
#     res:  'Skärmfullt men svårbedömt som ett modernt verk'
#     orig: 'charmfullt men svårbedömt som ett modernt verk'
# .   "0327": "charmfullt men svårbedömt som ett modernt verk",
# ⚠️  Mismatch at item 0334:
#     res:  'Det få ombord klarade sig oskadda.'
#     orig: 'de två ombord klarade sig oskadda'
# .   "0334": "de två ombord klarade sig oskadda",
# ⚠️  Mismatch at item 0337:
#     res:  'Lusekoftan är en särskild symbol för detta, en mönsterstickad yllekofta av almogtyp.'
#     orig: 'lusekoftan är en särskild symbol för detta en mönsterstickad yllekofta av allmogetyp'
# .   "0337": "lusekoftan är en särskild symbol för detta en mönsterstickad yllekofta av allmogetyp",
# ⚠️  Mismatch at item 0347:
#     res:  'Massan ska i huvudsak tillverkas av eukalyptus träd.'
#     orig: 'massan ska i huvudsak tillverkas av eukalyptusträd'
# .   "0347": "massan ska i huvudsak tillverkas av eukalyptusträd",
# ⚠️  Mismatch at item 0350:
#     res:  'För att byta e-leverantör krävs också installation av en ny elmätare för timvis mätning.'
#     orig: 'för att byta elleverantör krävs också installation av en ny elmätare för timvis mätning'
# .   "0350": "för att byta elleverantör krävs också installation av en ny elmätare för timvis mätning",
# ⚠️  Mismatch at item 0357:
#     res:  'Bilden snurrar växelvis med sols och mot sols.'
#     orig: 'bilden snurrar växelvis medsols och motsols'
# .   "0357": "bilden snurrar växelvis medsols och motsols",
# ⚠️  Mismatch at item 0363:
#     res:  'Idag styrs subventionerna hårt av politiker och tjänstemän.'
#     orig: 'i dag styrs subventionerna hårt av politiker och tjänstemän'
# .   "0363": "i dag styrs subventionerna hårt av politiker och tjänstemän",
# ⚠️  Mismatch at item 0380:
#     res:  'Själv var han nyförlovade och ville egentligen inte gå ut'
#     orig: 'själv var han nyförlovad och ville egentligen inte gå ut'
# .   "0380": "själv var han nyförlovad och ville egentligen inte gå ut",
# ⚠️  Mismatch at item 0382:
#     res:  'I båda fallen blev det oskyldiga offren.'
#     orig: 'i båda fallen blev de oskyldiga offren'
# .   "0382": "i båda fallen blev de oskyldiga offren",
# ⚠️  Mismatch at item 0388:
#     res:  'Det visade sig då att flera chefspersoner fått mer än två årslöner i avgångsvedelag.'
#     orig: 'det visade sig då att flera chefspersoner fått mer än två årslöner i avgångsvederlag'
# .   "0388": "det visade sig då att flera chefspersoner fått mer än två årslöner i avgångsvederlag",
# ⚠️  Mismatch at item 0393:
#     res:  'Jag vill inte förstöra vårt ömtåliga, nyvunna förhållande.'
#     orig: 'jag ville inte förstöra vårt ömtåliga nyvunna förhållande'
# .   "0393": "jag ville inte förstöra vårt ömtåliga nyvunna förhållande",
# ⚠️  Mismatch at item 0403:
#     res:  'Redan idag är vi en utflyttningskommun.'
#     orig: 'redan i dag är vi en utflyttningskommun'
# .   "0403": "redan i dag är vi en utflyttningskommun",
# ⚠️  Mismatch at item 0409:
#     res:  'Kungsörnen är fridlyst men har hotats av rovfågelsmugglingen.'
#     orig: 'kungsörnen är fridlyst men har hotats av rovfågelssmugglingen'
# .   "0409": "kungsörnen är fridlyst men har hotats av rovfågelssmugglingen",
# ⚠️  Mismatch at item 0410:
#     res:  'Med den sågs breda meanderslingor i dalen nedanför mig.'
#     orig: 'med ens sågs breda meanderslingor i dalen nedanför mig'
# .   "0410": "med ens sågs breda meanderslingor i dalen nedanför mig",
# ⚠️  Mismatch at item 0418:
#     res:  'Grovt hackade valnätkärnor är ett annat förslag.'
#     orig: 'grovt hackade valnötskärnor är ett annat förslag'
# .   "0418": "grovt hackade valnötskärnor är ett annat förslag",
# ⚠️  Mismatch at item 0427:
#     res:  'Då har också sjumarna lagen en chans att vinna.'
#     orig: 'då har också sjumannalagen en chans att vinna'
# .   "0427": "då har också sjumannalagen en chans att vinna",
# ⚠️  Mismatch at item 0441:
#     res:  'Hon är onekligen en förebild för många'
#     orig: 'hon är ju onekligen en förebild för många'
# .   "0441": "hon är ju onekligen en förebild för många",
# ⚠️  Mismatch at item 0447:
#     res:  'Ta in dem är du snäll'
#     orig: 'ta in dom är du snäll'
# .   "0447": "ta in dom är du snäll",
# ⚠️  Mismatch at item 0448:
#     res:  'Jag hörde floden stilla sål längs stranden.'
#     orig: 'jag hörde flodens stilla sorl längs stranden'
# .   "0448": "jag hörde flodens stilla sorl längs stranden",
# ⚠️  Mismatch at item 0450:
#     res:  'En av de där hundarna måste ha vägt 40 kilo.'
#     orig: 'en av de där hundarna måste ha vägt fyrtio kilo'
# .   "0450": "en av de där hundarna måste ha vägt fyrtio kilo",
# ⚠️  Mismatch at item 0454:
#     res:  'I svepande sidanskjol med bikinitopp och kort jacka.'
#     orig: 'i svepande sidenkjol med bikinitopp och kort jacka'
# .   "0454": "i svepande sidenkjol med bikinitopp och kort jacka",
# ⚠️  Mismatch at item 0456:
#     res:  'Först kommer alla yttre grejer, sedan de mindre.'
#     orig: 'först kommer alla yttre grejer sedan de inre'
# .   "0456": "först kommer alla yttre grejer sedan de inre",
# ⚠️  Mismatch at item 0458:
#     res:  'Som ikon och affischgudinna är hon nästintill perfekt.'
#     orig: 'som ikon och affischgudinna är hon näst intill perfekt'
# .   "0458": "som ikon och affischgudinna är hon näst intill perfekt",
# ⚠️  Mismatch at item 0460:
#     res:  'Miljön och det aktivas åsikt var ointressant.'
#     orig: 'miljön och de aktivas åsikt var ointressant'
# .   "0460": "miljön och de aktivas åsikt var ointressant",
# ⚠️  Mismatch at item 0462:
#     res:  'Råvaror som måste ingå var rostbiff, kongryn och diverse mejeriprodukter.'
#     orig: 'råvaror som måste ingå var rostbiff korngryn och diverse mejeriprodukter'
# .   "0462": "råvaror som måste ingå var rostbiff korngryn och diverse mejeriprodukter",
# ⚠️  Mismatch at item 0467:
#     res:  'De flesta svenskarna är ju offensivt lagda. Ja.'
#     orig: 'de flesta svenskarna är ju offensivt lagda'
# .   "0467": "de flesta svenskarna är ju offensivt lagda",
# ⚠️  Mismatch at item 0468:
#     res:  'Denna värld att se ändå.'
#     orig: 'den är värd att se ändå'
# .   "0468": "den är värd att se ändå",
# ⚠️  Mismatch at item 0476:
#     res:  'Nu är Carl avundsjuk på mig'
#     orig: 'nu är karln avundsjuk på mig'
# .   "0476": "nu är karln avundsjuk på mig",
# ⚠️  Mismatch at item 0478:
#     res:  'och man ville behålla det fantasiägande skimret av övergivenhet och förfall.'
#     orig: 'man ville behålla det fantasieggande skimret av övergivenhet och förfall'
# .   "0478": "man ville behålla det fantasieggande skimret av övergivenhet och förfall",
# ⚠️  Mismatch at item 0480:
#     res:  'Ägarna ertappar dem när de länsar i kassaskåpet'
#     orig: 'ägarna ertappar dem när de länsar kassaskåpet'
# .   "0480": "ägarna ertappar dem när de länsar kassaskåpet",
# ⚠️  Mismatch at item 0481:
#     res:  'Han rådnade och en åder i hans tinning tjocknade'
#     orig: 'han rodnade och en åder i hans tinning tjocknade'
# .   "0481": "han rodnade och en åder i hans tinning tjocknade",
# ⚠️  Mismatch at item 0492:
#     res:  'De tre gommorna i den lilla träkyrkan är klädda i svart.'
#     orig: 'de tre gummorna i den lilla träkyrkan är klädda i svart'
# .   "0492": "de tre gummorna i den lilla träkyrkan är klädda i svart",
# ⚠️  Mismatch at item 0499:
#     res:  'Det är inte många europeer som hamnar på listan.'
#     orig: 'det är inte många européer som hamnar på listan'
# .   "0499": "det är inte många européer som hamnar på listan",
# ⚠️  Mismatch at item 0502:
#     res:  'Ingen stoppar det på mitten och bygger ett fyrtorn istället.'
#     orig: 'ingen stoppar det på mitten och bygger ett fyrtorn i stället'
# .   "0502": "ingen stoppar det på mitten och bygger ett fyrtorn i stället",
# ⚠️  Mismatch at item 0510:
#     res:  'Kjut inte här ute i trappan'
#     orig: 'tjut inte här ute i trappan'
# .   "0510": "tjut inte här ute i trappan",
# ⚠️  Mismatch at item 0520:
#     res:  'Influensaviruset slås ut och symptomen försvinner.'
#     orig: 'influensaviruset slås ut och symtomen försvinner'
# .   "0520": "influensaviruset slås ut och symtomen försvinner",
# ⚠️  Mismatch at item 0523:
#     res:  'Han klär vinn genom vår port.'
#     orig: 'han klev in genom vår port'
# .   "0523": "han klev in genom vår port",
# ⚠️  Mismatch at item 0532:
#     res:  'Istället får du nu ingenting'
#     orig: 'i stället får de nu ingenting'
# .   "0532": "i stället får de nu ingenting",
# ⚠️  Mismatch at item 0535:
#     res:  'Det gjorde honom till resistregimens farligaste fiende'
#     orig: 'det gjorde honom till rasistregimens farligaste fiende'
# .   "0535": "det gjorde honom till rasistregimens farligaste fiende",
# ⚠️  Mismatch at item 0548:
#     res:  'En ensam säckpiperblåsare ska då framföra en klagovisa.'
#     orig: 'en ensam säckpipeblåsare ska då framföra en klagovisa'
# .   "0548": "en ensam säckpipeblåsare ska då framföra en klagovisa",
# ⚠️  Mismatch at item 0549:
#     res:  'Där avancerade han snart till chef för kassavdelningen.'
#     orig: 'där avancerade han snart till chef för kassaavdelningen'
# .   "0549": "där avancerade han snart till chef för kassaavdelningen",
# ⚠️  Mismatch at item 0550:
#     res:  'Strö över älsklingsortkryddan helst färsk och finhackad.'
#     orig: 'strö över älsklingsörtkryddan helst färsk och finhackad'
# .   "0550": "strö över älsklingsörtkryddan helst färsk och finhackad",
# ⚠️  Mismatch at item 0555:
#     res:  'Vid behov kunde han kalla in extra personal.'
#     orig: 'vid behov kunde han kalla in extrapersonal'
# .   "0555": "vid behov kunde han kalla in extrapersonal",
# ⚠️  Mismatch at item 0564:
#     res:  'Jag kan gräma mig än idag'
#     orig: 'jag kan gräma mig än i dag'
# .   "0564": "jag kan gräma mig än i dag",
# ⚠️  Mismatch at item 0565:
#     res:  'Jo, men det kan ju allt bli.'
#     orig: 'jo men det kan jag allt bli'
# .   "0565": "jo men det kan jag allt bli",
# ⚠️  Mismatch at item 0573:
#     res:  'Jag tog fram mitt cigarettet och i, öppnade det och höll fram det'
#     orig: 'jag tog fram mitt cigarrettetui öppnade det och höll fram det'
# .   "0573": "jag tog fram mitt cigarrettetui öppnade det och höll fram det",
# ⚠️  Mismatch at item 0589:
#     res:  'Vi var fångare i vårt eget hem'
#     orig: 'vi var fångar i vårt eget hem'
# .   "0589": "vi var fångar i vårt eget hem",
# ⚠️  Mismatch at item 0601:
#     res:  'Det var början till ett inbadeskrig.'
#     orig: 'det var början till ett inbördeskrig'
# .   "0601": "det var början till ett inbördeskrig",
# ⚠️  Mismatch at item 0602:
#     res:  'Världens minsta skovväljul mäter ett par millimeter i diameter.'
#     orig: 'världens minsta skovelhjul mäter ett par millimeter i diameter'
# .   "0602": "världens minsta skovelhjul mäter ett par millimeter i diameter",
# ⚠️  Mismatch at item 0606:
#     res:  'De gjorde upp om priset åkte iväg.'
#     orig: 'de gjorde upp om priset och åkte iväg'
# .   "0606": "de gjorde upp om priset och åkte iväg",
# ⚠️  Mismatch at item 0608:
#     res:  'Väl där har de bokat rum i lyxhotell som inte finns i chartens utbud.'
#     orig: 'väl där har de bokat rum i lyxhotell som inte finns i charterns utbud'
# .   "0608": "väl där har de bokat rum i lyxhotell som inte finns i charterns utbud",
# ⚠️  Mismatch at item 0618:
#     res:  'det onda fanns där också i mängd'
#     orig: 'de onda fanns där också i mängd'
# .   "0618": "de onda fanns där också i mängd",
# ⚠️  Mismatch at item 0630:
#     res:  'Vi låtsas att kuppäventyr är fjant'
#     orig: 'vi låtsas att cupäventyr är fjant'
# .   "0630": "vi låtsas att cupäventyr är fjant",
# ⚠️  Mismatch at item 0634:
#     res:  'Tre tjejseliga ryttare dök nu upp.'
#     orig: 'tre kejserliga ryttare dök nu upp'
# .   "0634": "tre kejserliga ryttare dök nu upp",
# ⚠️  Mismatch at item 0636:
#     res:  'Klubbarna kom överens igår kväll.'
#     orig: 'klubbarna kom överens i går kväll'
# .   "0636": "klubbarna kom överens i går kväll",
# ⚠️  Mismatch at item 0641:
#     res:  'Jag vet att du kan vara båda dera.'
#     orig: 'jag vet att du kan vara bådadera'
# .   "0641": "jag vet att du kan vara bådadera",
# ⚠️  Mismatch at item 0642:
#     res:  'Idag är den anklagade rent vådd.'
#     orig: 'i dag är den anklagade rentvådd'
# .   "0642": "i dag är den anklagade rentvådd",
# ⚠️  Mismatch at item 0643:
#     res:  'Bord diknade under massor av mat'
#     orig: 'bord dignade under massor av mat'
# .   "0643": "bord dignade under massor av mat",
# ⚠️  Mismatch at item 0648:
#     res:  'Han är inte dugg imponerad.'
#     orig: 'han är inte ett dugg imponerad'
# .   "0648": "han är inte ett dugg imponerad",
# ⚠️  Mismatch at item 0651:
#     res:  'Det klasssegregerade samhället blir då också könssegregerat.'
#     orig: 'det klassegregerade samhället blir då också könssegregerat'
# .   "0651": "det klassegregerade samhället blir då också könssegregerat",
# ⚠️  Mismatch at item 0652:
#     res:  'Kanske inte för att det skulle vara något fult med hög teknologi.'
#     orig: 'kanske inte för att det skulle vara något fult med högteknologi'
# .   "0652": "kanske inte för att det skulle vara något fult med högteknologi",
# ⚠️  Mismatch at item 0654:
#     res:  'De ska också ha ly och grävmöjligheter.'
#     orig: 'de ska också ha lya och grävmöjligheter'
# .   "0654": "de ska också ha lya och grävmöjligheter",
# ⚠️  Mismatch at item 0656:
#     res:  'Vår hede satt med slutna ögon'
#     orig: 'vår herde satt med slutna ögon'
# .   "0656": "vår herde satt med slutna ögon",
# ⚠️  Mismatch at item 0670:
#     res:  'Ingen av de tre bilkjuvarna har körkort.'
#     orig: 'ingen av de tre biltjuvarna har körkort'
# .   "0670": "ingen av de tre biltjuvarna har körkort",
# ⚠️  Mismatch at item 0674:
#     res:  'Som essayist står man inför ett val.'
#     orig: 'som essäist står man inför ett val'
# .   "0674": "som essäist står man inför ett val",
# ⚠️  Mismatch at item 0682:
#     res:  'Så här är det varje dag nu för tiden'
#     orig: 'så här är det varje dag nuförtiden'
# .   "0682": "så här är det varje dag nuförtiden",
# ⚠️  Mismatch at item 0692:
#     res:  'Försöksvarkosten ska i luften i dagarna'
#     orig: 'försöksfarkosten ska i luften i dagarna'
# .   "0692": "försöksfarkosten ska i luften i dagarna",
# ⚠️  Mismatch at item 0693:
#     res:  'Vintercharten var länge en förlustaffär för resarrangörer och flygbolag.'
#     orig: 'vinterchartern var länge en förlustaffär för researrangörer och flygbolag'
# .   "0693": "vinterchartern var länge en förlustaffär för researrangörer och flygbolag",
# ⚠️  Mismatch at item 0695:
#     res:  'En kvarndam vittnar om gamla tider'
#     orig: 'en kvarndamm vittnar om gamla tider'
# .   "0695": "en kvarndamm vittnar om gamla tider",
# ⚠️  Mismatch at item 0698:
#     res:  'Jag får jätteont i huvudet och mår illa'
#     orig: 'jag får jätteont i huvet och mår illa'
# .   "0698": "jag får jätteont i huvet och mår illa",
# ⚠️  Mismatch at item 0710:
#     res:  'Han gick helhjärtat inför sin roll'
#     orig: 'han gick helhjärtat in för sin roll'
# .   "0710": "han gick helhjärtat in för sin roll",
# ⚠️  Mismatch at item 0715:
#     res:  'Priserna på bärbörsen åker upp och ner.'
#     orig: 'priserna på bärbörsen åker upp och ned'
# .   "0715": "priserna på bärbörsen åker upp och ned",
# ⚠️  Mismatch at item 0724:
#     res:  'Har du problem med ryggen kan speciell rygggympa eller vattengympa vara bra.'
#     orig: 'har du problem med ryggen kan speciell ryggympa eller vattengympa vara bra'
# .   "0724": "har du problem med ryggen kan speciell ryggympa eller vattengympa vara bra",
# ⚠️  Mismatch at item 0735:
#     res:  'Nivån har justerats i en delfall.'
#     orig: 'nivån har justerats i en del fall'
# .   "0735": "nivån har justerats i en del fall",
# ⚠️  Mismatch at item 0737:
#     res:  'Istället tillsätts en ny utredning.'
#     orig: 'i stället tillsätts en ny utredning'
# .   "0737": "i stället tillsätts en ny utredning",
# ⚠️  Mismatch at item 0744:
#     res:  'I förlängningen kan dekoden även brukas för inköp, bankärenden och spel.'
#     orig: 'i förlängningen kan dekodern även brukas för inköp bankärenden och spel'
# .   "0744": "i förlängningen kan dekodern även brukas för inköp bankärenden och spel",
# ⚠️  Mismatch at item 0752:
#     res:  'Idag bebos trakten av en beduinstam.'
#     orig: 'i dag bebos trakten av en beduinstam'
# .   "0752": "i dag bebos trakten av en beduinstam",
# ⚠️  Mismatch at item 0763:
#     res:  'Idag har den siffran sjufaldigats.'
#     orig: 'i dag har den siffran sjufaldigats'
# .   "0763": "i dag har den siffran sjufaldigats",
# ⚠️  Mismatch at item 0766:
#     res:  'I tingsätten fick han ett raseriutbrott.'
#     orig: 'i tingsrätten fick han ett raseriutbrott'
# .   "0766": "i tingsrätten fick han ett raseriutbrott",
# ⚠️  Mismatch at item 0769:
#     res:  'Varför det på detta sätt är jävla okänt'
#     orig: 'varför det är på detta sätt är ännu okänt'
# .   "0769": "varför det är på detta sätt är ännu okänt",
# ⚠️  Mismatch at item 0770:
#     res:  'I så fall skulle orkestern återfå en ledare.'
#     orig: 'i så fall skulle orkestern åter få en ledare'
# .   "0770": "i så fall skulle orkestern åter få en ledare",
# ⚠️  Mismatch at item 0780:
#     res:  'Idag begärs ytterligare en kvinna häktad.'
#     orig: 'i dag begärs ytterligare en kvinna häktad'
# .   "0780": "i dag begärs ytterligare en kvinna häktad",
# ⚠️  Mismatch at item 0782:
#     res:  'Perlhandlaren har fått dem att lyssna'
#     orig: 'pärlhandlaren har fått dem att lyssna'
# .   "0782": "pärlhandlaren har fått dem att lyssna",
# ⚠️  Mismatch at item 0785:
#     res:  'Jag är laddad och lite revanschugen också.'
#     orig: 'jag är laddad och lite revanschsugen också'
# .   "0785": "jag är laddad och lite revanschsugen också",
# ⚠️  Mismatch at item 0788:
#     res:  'Sommarvärmen knäckte många kantareller men Carl Johan har legat i marken och lurat.'
#     orig: 'sommarvärmen knäckte många kantareller men karljohan har legat i marken och lurat'
# .   "0788": "sommarvärmen knäckte många kantareller men karljohan har legat i marken och lurat",
# ⚠️  Mismatch at item 0793:
#     res:  'Jag är av den äventyrliga sorten.'
#     orig: 'jag är av den där äventyrliga sorten'
# .   "0793": "jag är av den där äventyrliga sorten",
# ⚠️  Mismatch at item 0795:
#     res:  'Hinnan är tillverkad direkt på ett kiselkips.'
#     orig: 'hinnan är tillverkad direkt på ett kiselchips'
# .   "0795": "hinnan är tillverkad direkt på ett kiselchips",
# ⚠️  Mismatch at item 0796:
#     res:  'Det bildade små rynkor vid ögonvråna.'
#     orig: 'det bildades små rynkor vid ögonvrårna'
# .   "0796": "det bildades små rynkor vid ögonvrårna",
# ⚠️  Mismatch at item 0798:
#     res:  'Stadsduman har inte så alldeles fel.'
#     orig: 'statsduman har inte så alldeles fel'
# .   "0798": "statsduman har inte så alldeles fel",
# ⚠️  Mismatch at item 0801:
#     res:  'Hon såg på mig med sina havsblåa ögon.'
#     orig: 'hon såg på mig med sina havsblå ögon'
# .   "0801": "hon såg på mig med sina havsblå ögon",
# ⚠️  Mismatch at item 0803:
#     res:  'Det är dags för en tusenmila service.'
#     orig: 'det är dags för en tusenmilaservice'
# .   "0803": "det är dags för en tusenmilaservice",
# ⚠️  Mismatch at item 0804:
#     res:  'Nästa vinter följde mycket snö igen'
#     orig: 'nästa vinter föll det mycket snö igen'
# .   "0804": "nästa vinter föll det mycket snö igen",
# ⚠️  Mismatch at item 0809:
#     res:  'Tyastor är ett importerat landskap.'
#     orig: 'ty jag står i ett importerat landskap'
# .   "0809": "ty jag står i ett importerat landskap",
# ⚠️  Mismatch at item 0810:
#     res:  'Jag sov av med bedövningen men var fortfarande lite groggy när jag vaknade'
#     orig: 'jag sov av mig bedövningen men var fortfarande litet groggy när jag vaknade'
# .   "0810": "jag sov av mig bedövningen men var fortfarande litet groggy när jag vaknade",
# ⚠️  Mismatch at item 0814:
#     res:  'Huvudet kröntes av en björnskinsmässa med hakräm'
#     orig: 'huvudet kröntes av en björnskinnsmössa med hakrem'
# .   "0814": "huvudet kröntes av en björnskinnsmössa med hakrem",
# ⚠️  Mismatch at item 0815:
#     res:  'Hon vill ägna mer tid åt maken och sin nyfödda baby'
#     orig: 'hon ville ägna mer tid åt maken och sin nyfödda baby'
# .   "0815": "hon ville ägna mer tid åt maken och sin nyfödda baby",
# ⚠️  Mismatch at item 0824:
#     res:  'Då avslöjas man ju inför familj och vänner Och då är det ju så att man inte har någon'
#     orig: 'då avslöjas man ju inför familj och vänner'
# .   "0824": "då avslöjas man ju inför familj och vänner",
# ⚠️  Mismatch at item 0828:
#     res:  'Sermonin kan pågå upp till fyra timmar.'
#     orig: 'ceremonin kan pågå upp till fyra timmar'
# .   "0828": "ceremonin kan pågå upp till fyra timmar",
# ⚠️  Mismatch at item 0846:
#     res:  'Tre tjejer i en studentlia blir senare två.'
#     orig: 'tre tjejer i en studentlya blir senare två'
# .   "0846": "tre tjejer i en studentlya blir senare två",
# ⚠️  Mismatch at item 0849:
#     res:  'Hon ville se något nytt, något icke-europeiskt'
#     orig: 'hon ville se något nytt något ickeeuropeiskt'
# .   "0849": "hon ville se något nytt något ickeeuropeiskt",
# ⚠️  Mismatch at item 0861:
#     res:  'Han har vunnit fem europeiska kupptitlar.'
#     orig: 'han har vunnit fem europeiska cuptitlar'
# .   "0861": "han har vunnit fem europeiska cuptitlar",
# ⚠️  Mismatch at item 0863:
#     res:  'Lägg skivorna i en lättsmod, unsäker form.'
#     orig: 'lägg skivorna i en lättsmord ugnssäker form'
# .   "0863": "lägg skivorna i en lättsmord ugnssäker form",
# ⚠️  Mismatch at item 0865:
#     res:  'Det blir långlunch på värdshuset istället.'
#     orig: 'det blir långlunch på värdshuset i stället'
# .   "0865": "det blir långlunch på värdshuset i stället",
# ⚠️  Mismatch at item 0866:
#     res:  'Jag skulle ha velat ha en reservoirpenna.'
#     orig: 'jag skulle ha velat ha en reservoarpenna'
# .   "0866": "jag skulle ha velat ha en reservoarpenna",
# ⚠️  Mismatch at item 0867:
#     res:  'En andra artikel publiceras imorgon torsdag.'
#     orig: 'en andra artikel publiceras i morgon torsdag'
# .   "0867": "en andra artikel publiceras i morgon torsdag",
# ⚠️  Mismatch at item 0876:
#     res:  'som ett gammalt bymöte med älsten i mitten.'
#     orig: 'som ett gammalt bymöte med äldsten i mitten'
# .   "0876": "som ett gammalt bymöte med äldsten i mitten",
# ⚠️  Mismatch at item 0879:
#     res:  'Det var sannoliken förstinnan som talade.'
#     orig: 'det var sannerligen furstinnan som talade'
# .   "0879": "det var sannerligen furstinnan som talade",
# ⚠️  Mismatch at item 0882:
#     res:  'Därför bygger syssan sin egen högtalare.'
#     orig: 'därför bygger syrsan sin egen högtalare'
# .   "0882": "därför bygger syrsan sin egen högtalare",
# ⚠️  Mismatch at item 0889:
#     res:  'Hon är väl ett slags kameljont antar jag'
#     orig: 'hon är väl ett slags kameleont antar jag'
# .   "0889": "hon är väl ett slags kameleont antar jag",
# ⚠️  Mismatch at item 0897:
#     res:  'Hustrun och dottern ger ut varsin bok i oktober'
#     orig: 'hustrun och dottern ger ut var sin bok i oktober'
# .   "0897": "hustrun och dottern ger ut var sin bok i oktober",
# ⚠️  Mismatch at item 0910:
#     res:  'För mig är det mest förstörelse att se sånt.'
#     orig: 'för mig är det mest förströelse att se sånt'
# .   "0910": "för mig är det mest förströelse att se sånt",
# ⚠️  Mismatch at item 0912:
#     res:  'Instituten ringde runt till sommartoma hem.'
#     orig: 'instituten ringde runt till sommartomma hem'
# .   "0912": "instituten ringde runt till sommartomma hem",
# ⚠️  Mismatch at item 0927:
#     res:  'Det påstods att det mest ögonfallande abstinenssymptomet var darningar och svettning.'
#     orig: 'det påstods att det mest iögonenfallande abstinenssymtomet var darrningar och svettning'
# .   "0927": "det påstods att det mest iögonenfallande abstinenssymtomet var darrningar och svettning",
# ⚠️  Mismatch at item 0931:
#     res:  'Det är en blyertsskiss av en flicka framför ett stafli.'
#     orig: 'det är en blyertsskiss av en flicka framför ett staffli'
# .   "0931": "det är en blyertsskiss av en flicka framför ett staffli",
# ⚠️  Mismatch at item 0940:
#     res:  'Jag gillar att späxa och klä ut mig, säger hon.'
#     orig: 'jag gillar att spexa och klä ut mig säger hon'
# .   "0940": "jag gillar att spexa och klä ut mig säger hon",
# ⚠️  Mismatch at item 0945:
#     res:  'Medieuppådet är henne i hälarna mest hela tiden.'
#     orig: 'medieuppbådet är henne i hälarna mest hela tiden'
# .   "0945": "medieuppbådet är henne i hälarna mest hela tiden",
# ⚠️  Mismatch at item 0949:
#     res:  'Jag sprang ut efter ån och försökte fånga in den'
#     orig: 'jag sprang utefter ån och försökte fånga in den'
# .   "0949": "jag sprang utefter ån och försökte fånga in den",
# ⚠️  Mismatch at item 0952:
#     res:  'En frukt om dagen och tre deciliter lättfil eller lätt yoghurt.'
#     orig: 'en frukt om dagen och tre deciliter lättfil eller lättyoghurt'
# .   "0952": "en frukt om dagen och tre deciliter lättfil eller lättyoghurt",
# ⚠️  Mismatch at item 0959:
#     res:  'Detta är min andra arbetsvecka sedan semestern.'
#     orig: 'detta är min andra arbetsvecka sen semestern'
# .   "0959": "detta är min andra arbetsvecka sen semestern",
# ⚠️  Mismatch at item 0970:
#     res:  'Då skulle ju alla jädror ha ungefär samma halter.'
#     orig: 'då skulle ju alla gäddor ha ungefär samma halter'
# .   "0970": "då skulle ju alla gäddor ha ungefär samma halter",
# ⚠️  Mismatch at item 0971:
#     res:  'Träkonstruktionen har hållits samman av järnitarna vilket nog var en ny byggmetod i detta sammanhang.'
#     orig: 'träkonstruktionen har hållits samman av järnnitarna vilket nog var en ny byggmetod i detta sammanhang'
# .   "0971": "träkonstruktionen har hållits samman av järnnitarna vilket nog var en ny byggmetod i detta sammanhang",
# ⚠️  Mismatch at item 0982:
#     res:  'Mannen har också fått en villkorlig dom förstöld'
#     orig: 'mannen har också fått en villkorlig dom för stöld'
# .   "0982": "mannen har också fått en villkorlig dom för stöld",
# ⚠️  Mismatch at item 0990:
#     res:  'Det fick bli skjutdörrar med riktigt trä istället.'
#     orig: 'det fick bli skjutdörrar med riktigt trä i stället'
# .   "0990": "det fick bli skjutdörrar med riktigt trä i stället",
# ⚠️  Mismatch at item 0991:
#     res:  'Hotellen heter numera något bizarrt klumpigt.'
#     orig: 'hotellen heter numera något bisarrt klumpigt'
# .   "0991": "hotellen heter numera något bisarrt klumpigt",
# ⚠️  Mismatch at item 0997:
#     res:  'Idag finns det information och kunskap överallt.'
#     orig: 'i dag finns det information och kunskap överallt'
# .   "0997": "i dag finns det information och kunskap överallt",
# ⚠️  Mismatch at item 1002:
#     res:  'Här är det sprutande kolstyb som är idrott nummer ett.'
#     orig: 'här är det sprutande kolstybb som är idrott nummer ett'
# .   "1002": "här är det sprutande kolstybb som är idrott nummer ett",
# ⚠️  Mismatch at item 1003:
#     res:  'Jag vill inte ta med sjalen för att få svenska vänner.'
#     orig: 'jag vill inte ta av mig sjalen för att få svenska vänner'
# .   "1003": "jag vill inte ta av mig sjalen för att få svenska vänner",
# ⚠️  Mismatch at item 1004:
#     res:  'På sommaren ska det finnas möjligheter att spela boll.'
#     orig: 'på sommaren ska det finnas möjligheter att spela boule'
# .   "1004": "på sommaren ska det finnas möjligheter att spela boule",
# ⚠️  Mismatch at item 1005:
#     res:  'Det är efterfrågeöverskott som då uppstår pressar upp priset.'
#     orig: 'det efterfrågeöverskott som då uppstår pressar upp priset'
# .   "1005": "det efterfrågeöverskott som då uppstår pressar upp priset",
# ⚠️  Mismatch at item 1006:
#     res:  'Nymfparakeiten är ett flock djur med rikt socialt beteende.'
#     orig: 'nymfparakiten är ett flockdjur med rikt socialt beteende'
# .   "1006": "nymfparakiten är ett flockdjur med rikt socialt beteende",
# ⚠️  Mismatch at item 1008:
#     res:  'En idé som ännu inte har lämnat förslagstadiet.'
#     orig: 'en idé som ännu inte har lämnat förslagsstadiet'
# .   "1008": "en idé som ännu inte har lämnat förslagsstadiet",
# ⚠️  Mismatch at item 1023:
#     res:  'Följden är trafikkaos modell större i rusningstid.'
#     orig: 'följden är ett trafikkaos modell större i rusningstid'
# .   "1023": "följden är ett trafikkaos modell större i rusningstid",
# ⚠️  Mismatch at item 1025:
#     res:  'Maskaran rann och hon gjorde av med åtskilliga pappersnästukar.'
#     orig: 'maskaran rann och hon gjorde av med åtskilliga pappersnäsdukar'
# .   "1025": "maskaran rann och hon gjorde av med åtskilliga pappersnäsdukar",
# ⚠️  Mismatch at item 1026:
#     res:  'Modernismens byggnader behöver också det sitt skydd'
#     orig: 'modernismens byggnader behöver också de sitt skydd'
# .   "1026": "modernismens byggnader behöver också de sitt skydd",
# ⚠️  Mismatch at item 1028:
#     res:  'Då fick jag överta arendet så vi kunde bo kvar här'
#     orig: 'då fick jag överta arrendet så vi kunde bo kvar här'
# .   "1028": "då fick jag överta arrendet så vi kunde bo kvar här",
# ⚠️  Mismatch at item 1032:
#     res:  'Igår fick bytet plötsligt ovanade konsekvenser.'
#     orig: 'i går fick bytet plötsligt oanade konsekvenser'
# .   "1032": "i går fick bytet plötsligt oanade konsekvenser",
# ⚠️  Mismatch at item 1035:
#     res:  'så hon och några väninnor brukar ha syunta tillsammans.'
#     orig: 'så hon och några väninnor brukar ha syjunta tillsammans'
# .   "1035": "så hon och några väninnor brukar ha syjunta tillsammans",
# ⚠️  Mismatch at item 1036:
#     res:  'En blev sommarnöje för honom och hans stora familj'
#     orig: 'ön blev sommarnöje för honom och hans stora familj'
# .   "1036": "ön blev sommarnöje för honom och hans stora familj",
# ⚠️  Mismatch at item 1045:
#     res:  'Bästa sättet att behandla avfallet är att återvinna blyt.'
#     orig: 'bästa sättet att behandla avfallet är att återvinna blyet'
# .   "1045": "bästa sättet att behandla avfallet är att återvinna blyet",
# ⚠️  Mismatch at item 1061:
#     res:  'Det låter som en trygg vecka, åtminstone på pappret.'
#     orig: 'det låter som en trygg vecka åtminstone på papperet'
# .   "1061": "det låter som en trygg vecka åtminstone på papperet",
# ⚠️  Mismatch at item 1062:
#     res:  'Först som 30-åring får granen sina första blommor.'
#     orig: 'först som trettioåring får granen sina första blommor'
# .   "1062": "först som trettioåring får granen sina första blommor",
# ⚠️  Mismatch at item 1065:
#     res:  'Han slår ut med händerna och ser närmast för lägen ut'
#     orig: 'han slår ut med händerna och ser närmast förlägen ut'
# .   "1065": "han slår ut med händerna och ser närmast förlägen ut",
# ⚠️  Mismatch at item 1087:
#     res:  'Istället hamnar den via mellanhänder hos villaägarna.'
#     orig: 'i stället hamnar den via mellanhänder hos villaägarna'
# .   "1087": "i stället hamnar den via mellanhänder hos villaägarna",
# ⚠️  Mismatch at item 1091:
#     res:  'Upprörda åskådare vänder sig om och hyrschar åt fridstöraren'
#     orig: 'upprörda åskådare vänder sig om och hyssjar åt fridstöraren'
# .   "1091": "upprörda åskådare vänder sig om och hyssjar åt fridstöraren",
# ⚠️  Mismatch at item 1106:
#     res:  'Rätt som det smiter de iväg utan att någon saknar dem'
#     orig: 'rätt som det är smiter de iväg utan att någon saknar dem'
# .   "1106": "rätt som det är smiter de iväg utan att någon saknar dem",
# ⚠️  Mismatch at item 1108:
#     res:  'Båda försökte det motsvara en image som pressen skapat'
#     orig: 'båda försökte de motsvara en image som pressen skapat'
# .   "1108": "båda försökte de motsvara en image som pressen skapat",
# ⚠️  Mismatch at item 1110:
#     res:  'När kraven ställs ska också en förlikningsnämnd utses.'
#     orig: 'när kraven ställs skall också en förlikningsnämnd utses'
# .   "1110": "när kraven ställs skall också en förlikningsnämnd utses",
# ⚠️  Mismatch at item 1115:
#     res:  'Chefen för en sådan myndighet är då istället kanslichef.'
#     orig: 'chefen för en sådan myndighet är då i stället kanslichef'
# .   "1115": "chefen för en sådan myndighet är då i stället kanslichef",
# ⚠️  Mismatch at item 1127:
#     res:  'Jag tror att det kommer att göras en ny avstämning före årsskiftet.'
#     orig: 'jag tror att det kommer och göras en ny avstämning före årsskiftet'
# .   "1127": "jag tror att det kommer och göras en ny avstämning före årsskiftet",
# ⚠️  Mismatch at item 1138:
#     res:  'Kvinnan hade inte laga för fall att utebli ansåg hovrätten'
#     orig: 'kvinnan hade inte laga förfall att utebli ansåg hovrätten'
# .   "1138": "kvinnan hade inte laga förfall att utebli ansåg hovrätten",
# ⚠️  Mismatch at item 1139:
#     res:  'Sedan fortsatte hon utan ett ord in mellan hus, ner mot floden'
#     orig: 'sedan fortsatte hon utan ett ord in mellan hus ned mot floden'
# .   "1139": "sedan fortsatte hon utan ett ord in mellan hus ned mot floden",
# ⚠️  Mismatch at item 1146:
#     res:  'Han hade satt vässkötarna till att reparera stadens söndriga murar.'
#     orig: 'han hade satt västgötarna till att reparera stadens söndriga murar'
# .   "1146": "han hade satt västgötarna till att reparera stadens söndriga murar",
# ⚠️  Mismatch at item 1151:
#     res:  'På skolgården strömmar tjejerna förbi i stretchjeans, tajta ylletröjor och gympadojor.'
#     orig: 'på skolgården strömmar tjejerna förbi i stretchjeans tighta ylletröjor och gympadojor'
# .   "1151": "på skolgården strömmar tjejerna förbi i stretchjeans tighta ylletröjor och gympadojor",
# ⚠️  Mismatch at item 1152:
#     res:  'Om några dagar ska jag visa dig var nattvardsvägaren ligger gömd.'
#     orig: 'om några dagar ska jag visa dig var nattvardsbägaren ligger gömd'
# .   "1152": "om några dagar ska jag visa dig var nattvardsbägaren ligger gömd",
# ⚠️  Mismatch at item 1153:
#     res:  'En annan metod är att jämföra enägstvillingar och tvåägstvillingar.'
#     orig: 'en annan metod är att jämföra enäggstvillingar och tvåäggstvillingar'
# .   "1153": "en annan metod är att jämföra enäggstvillingar och tvåäggstvillingar",
# ⚠️  Mismatch at item 1154:
#     res:  'Sätt klockan på halv sju även om du bara fått några timmar sömn.'
#     orig: 'sätt klockan på halv sju även om du bara fått några timmars sömn'
# .   "1154": "sätt klockan på halv sju även om du bara fått några timmars sömn",
# ⚠️  Mismatch at item 1156:
#     res:  'Förundersökningen visar att åklagaren skjutit från häften.'
#     orig: 'förundersökningen visar att åklagaren skjutit från höften'
# .   "1156": "förundersökningen visar att åklagaren skjutit från höften",
# ⚠️  Mismatch at item 1158:
#     res:  'Lyön ligger helt nära ett berg där Kungsörn ofta patrullerar.'
#     orig: 'lyan ligger helt nära ett berg där kungsörn ofta patrullerar'
# .   "1158": "lyan ligger helt nära ett berg där kungsörn ofta patrullerar",
# ⚠️  Mismatch at item 1159:
#     res:  'Det kan handla om siffernötter eller berömda matematiska problem.'
#     orig: 'de kan handla om siffernötter eller berömda matematiska problem'
# .   "1159": "de kan handla om siffernötter eller berömda matematiska problem",
# ⚠️  Mismatch at item 1162:
#     res:  'Ta ostronen ur snäckorna och arrangera dem på en smod bakplåt.'
#     orig: 'ta ostronen ur snäckorna och arrangera dem på en smord bakplåt'
# .   "1162": "ta ostronen ur snäckorna och arrangera dem på en smord bakplåt",
# ⚠️  Mismatch at item 1181:
#     res:  'Omfattande miljöåtgärder ska skydda omkringliggande vattentäkter.'
#     orig: 'omfattande miljöåtgärder skall skydda omkringliggande vattentäkter'
# .   "1181": "omfattande miljöåtgärder skall skydda omkringliggande vattentäkter",
# ⚠️  Mismatch at item 1184:
#     res:  'Inte undra på att det blir många cigaretter och en förfärlig rethosta.'
#     orig: 'inte undra på att det blir många cigarretter och en förfärlig rethosta'
# .   "1184": "inte undra på att det blir många cigarretter och en förfärlig rethosta",
# ⚠️  Mismatch at item 1185:
#     res:  'I ett sådant molekylmoln har solen och planetsystemet en gång födts.'
#     orig: 'i ett sådant molekylmoln har solen och planetsystemet en gång fötts'
# .   "1185": "i ett sådant molekylmoln har solen och planetsystemet en gång fötts",
# ⚠️  Mismatch at item 1187:
#     res:  'Gränsen för så kallad hobbyodling går idag vid tio bisamhällen.'
#     orig: 'gränsen för så kallad hobbyodling går i dag vid tio bisamhällen'
# .   "1187": "gränsen för så kallad hobbyodling går i dag vid tio bisamhällen",
# ⚠️  Mismatch at item 1197:
#     res:  'Under måligt och onyanserat är kommunpolitikernas samlade omdöme.'
#     orig: 'undermåligt och onyanserat är kommunpolitikernas samlade omdöme'
# .   "1197": "undermåligt och onyanserat är kommunpolitikernas samlade omdöme",
# ⚠️  Mismatch at item 1198:
#     res:  'Så här dagen före ödestunden verkar det en aning överdrivet.'
#     orig: 'så här dagen före ödesstunden verkar det en aning överdrivet'
# .   "1198": "så här dagen före ödesstunden verkar det en aning överdrivet",
# ⚠️  Mismatch at item 1200:
#     res:  'En del låtar är lite jazzinfluerade, andra är åt country-hållet.'
#     orig: 'en del låtar är lite jazzinfluerade andra är åt countryhållet'
# .   "1200": "en del låtar är lite jazzinfluerade andra är åt countryhållet",
# ⚠️  Mismatch at item 1201:
#     res:  'De känner sig osidosatta och anser att kursomläggningen var dåligt förankrad.'
#     orig: 'de känner sig åsidosatta och anser att kursomläggningen var dåligt förankrad'
# .   "1201": "de känner sig åsidosatta och anser att kursomläggningen var dåligt förankrad",
# ⚠️  Mismatch at item 1205:
#     res:  'Den svenska fastighetsskatten saknar denna förutsägbarhet.'
#     orig: 'den svenska fastighetsskatten saknar denna förutsebarhet'
# .   "1205": "den svenska fastighetsskatten saknar denna förutsebarhet",
# ⚠️  Mismatch at item 1219:
#     res:  'Tvärt emot vad många tror avlastar samboende inte hemarbetet.'
#     orig: 'tvärtemot vad många tror avlastar samboende inte hemarbetet'
# .   "1219": "tvärtemot vad många tror avlastar samboende inte hemarbetet",
# ⚠️  Mismatch at item 1222:
#     res:  'Jag gillar svensk slager jättemycket. Melodifestivalen är en höjdare för mig.'
#     orig: 'jag gillar svensk schlager jättemycket melodifestivalen är en höjdare för mig'
# .   "1222": "jag gillar svensk schlager jättemycket melodifestivalen är en höjdare för mig",
# ⚠️  Mismatch at item 1224:
#     res:  'Advokaten harklade sig och nio Polisen höjde frågande på ögonbrynen'
#     orig: 'advokaten harklade sig ånyo polisen höjde frågande på ögonbrynen'
# .   "1224": "advokaten harklade sig ånyo polisen höjde frågande på ögonbrynen",
# ⚠️  Mismatch at item 1226:
#     res:  'Den var svår att färgbestämma på grund av alla extra erbjudanden.'
#     orig: 'den var svår att färgbestämma på grund av alla extraerbjudanden'
# .   "1226": "den var svår att färgbestämma på grund av alla extraerbjudanden",
# ⚠️  Mismatch at item 1228:
#     res:  'I slutet av den här månaden skulle minnesfri märket ha givits ut.'
#     orig: 'i slutet av den här månaden skulle minnesfrimärket ha givits ut'
# ...
# ⚠️  Mismatch at item 4847:
#     res:  'Potebo, en av de lättaste bärbara datorerna just nu.'
#     orig: 'portable en av de lättaste bärbara datorerna just nu'
# .   "4847": "portable en av de lättaste bärbara datorerna just nu",
# ⚠️  Mismatch at item 4851:
#     res:  'Linux-distributören och utvecklaren Red Hat.'
#     orig: 'linuxdistributören och utvecklaren red hat'
# .   "4851": "linuxdistributören och utvecklaren red hat",
# ⚠️  Mismatch at item 4857:
#     res:  'Thomas Nerer är polisassistent i Västerås.'
#     orig: 'thomas nehrer är polisassistent i västerås'
# .   "4857": "thomas nehrer är polisassistent i västerås",
# ⚠️  Mismatch at item 4873:
#     res:  'Unix-säljare på Datapoint'
#     orig: 'unixsäljare på datapoint'
# .   "4873": "unixsäljare på datapoint",
# ⚠️  Mismatch at item 4878:
#     res:  'Medelmottorna trivs i detta system, sade Alexander Bard.'
#     orig: 'medelmåttorna trivs i detta system sade alexander bard'
# .   "4878": "medelmåttorna trivs i detta system sade alexander bard",
# ⚠️  Mismatch at item 4880:
#     res:  'David Tring har anställt som varumärkesansvarig på Dressmart.'
#     orig: 'david tring har anställts som varumärkesansvarig på dressmart'
# .   "4880": "david tring har anställts som varumärkesansvarig på dressmart",
# ⚠️  Mismatch at item 4884:
#     res:  'Andersson, teknikstabschef på Volvo Data.'
#     orig: 'andersson teknikstabsschef på volvo data'
# .   "4884": "andersson teknikstabsschef på volvo data",
# ⚠️  Mismatch at item 4889:
#     res:  'Det är inte den enda förklaringen.'
#     orig: 'det är inte enda förklaringen'
# .   "4889": "det är inte enda förklaringen",
# ⚠️  Mismatch at item 4892:
#     res:  'Överföringen mellan kamera och dator är ytterligare en Achilleshäl.'
#     orig: 'överföringen mellan kamera och dator är ytterligare en akilleshäl'
# .   "4892": "överföringen mellan kamera och dator är ytterligare en akilleshäl",
# ⚠️  Mismatch at item 4898:
#     res:  'ATM – utan att behöva göra ändringar i program eller protokoll'
#     orig: 'atm utan att behöva göra ändringar i program eller protokoll'
# .   "4898": "atm utan att behöva göra ändringar i program eller protokoll",
# ⚠️  Mismatch at item 4903:
#     res:  'Beta-testningen är över.'
#     orig: 'betatestningen är över'
# .   "4903": "betatestningen är över",
# ⚠️  Mismatch at item 4904:
#     res:  'Mega Hatch Mobile Pentium'
#     orig: 'megahertz mobile pentium'
# .   "4904": "megahertz mobile pentium",
# ⚠️  Mismatch at item 4906:
#     res:  'Även Capgemini hoppas på en ökning av omsättningen i USA.'
#     orig: 'även cap gemini hoppas på en ökning av omsättningen i usa'
# .   "4906": "även cap gemini hoppas på en ökning av omsättningen i usa",
# ⚠️  Mismatch at item 4910:
#     res:  'Bjelke – ansvarig för PC-Lans affärsområde Server & Storage'
#     orig: 'bjelke ansvarig för pc lans affärsområde server and storage'
# .   "4910": "bjelke ansvarig för pc lans affärsområde server and storage",
# ⚠️  Mismatch at item 4913:
#     res:  'En annan gång tar vi ett annat grepp.'
#     orig: 'viktor hade skickat ut det innan novell sålde unixware till sco'
# .   "4913": "viktor hade skickat ut det innan novell sålde unixware till sco",
# ⚠️  Mismatch at item 4931:
#     res:  'Trots detta har aktien inte pignat till på börsen.'
#     orig: 'trots detta har aktien inte piggnat till på börsen'
# .   "4931": "trots detta har aktien inte piggnat till på börsen",
# ⚠️  Mismatch at item 4933:
#     res:  'Gustav Ekeberg på Europolitan är inne på samma linje.'
#     orig: 'gustaf ekeberg på europolitan är inne på samma linje'
# .   "4933": "gustaf ekeberg på europolitan är inne på samma linje",
# ⚠️  Mismatch at item 4942:
#     res:  'Ralfs pappa kopplade ner videofonen.'
#     orig: 'ralphs pappa kopplade ned videofonen'
# .   "4942": "ralphs pappa kopplade ned videofonen",
# ⚠️  Mismatch at item 4944:
#     res:  'Computer Swedenjord'
#     orig: 'computer sweden gjort'
# .   "4944": "computer sweden gjort",
# ⚠️  Mismatch at item 4945:
#     res:  'Det är inte så lätt att vara kossör.'
#     orig: 'det är inte så lätt att vara kåsör'
# .   "4945": "det är inte så lätt att vara kåsör",
# ⚠️  Mismatch at item 4947:
#     res:  'Stort intresse från Linux-utvecklare anges som orsak.'
#     orig: 'stort intresse från linuxutvecklare anges som orsak'
# .   "4947": "stort intresse från linuxutvecklare anges som orsak",
# ⚠️  Mismatch at item 4949:
#     res:  'Jan Frese'
#     orig: 'jan freese'
# .   "4949": "jan freese",
# ⚠️  Mismatch at item 4951:
#     res:  'Kompax kräftgång på marknaden beror delvis på leveransproblem.'
#     orig: 'compaqs kräftgång på marknaden beror delvis på leveransproblem'
# .   "4951": "compaqs kräftgång på marknaden beror delvis på leveransproblem",
# ⚠️  Mismatch at item 4956:
#     res:  'US-dollar med god vinst'
#     orig: 'us dollar med god vinst'
# .   "4956": "us dollar med god vinst",
# ⚠️  Mismatch at item 4958:
#     res:  'Information Highways vd Göran Vågström vid torsdagens presskonferens.'
#     orig: 'information highways vd göran wågström vid torsdagens presskonferens'
# .   "4958": "information highways vd göran wågström vid torsdagens presskonferens",
# ⚠️  Mismatch at item 4959:
#     res:  'Hanstorp vd Teknia Sverige'
#     orig: 'hanstorp vd technia sverige'
# .   "4959": "hanstorp vd technia sverige",
# ⚠️  Mismatch at item 4961:
#     res:  'Omni-gate varje gång ett brev ska skickas.'
#     orig: 'omnigate varje gång ett brev ska skickas'
# .   "4961": "omnigate varje gång ett brev ska skickas",
# ⚠️  Mismatch at item 4979:
#     res:  'Douglas Börjman på Informix'
#     orig: 'douglas burgman på informix'
# .   "4979": "douglas burgman på informix",
# ⚠️  Mismatch at item 4986:
#     res:  'Det var den häftigaste resan jag har gjort.'
#     orig: 'det var den häftigaste resa jag har gjort'
# .   "4986": "det var den häftigaste resa jag har gjort",
# ⚠️  Mismatch at item 4987:
#     res:  'Windows och Enförprogram'
#     orig: 'windows och en för program'
# .   "4987": "windows och en för program",
# ⚠️  Mismatch at item 4998:
#     res:  'Tidigare jobbade han för Hogea fastighetssystem.'
#     orig: 'tidigare jobbade han för hogia fastighetssystem'
# .   "4998": "tidigare jobbade han för hogia fastighetssystem",
# ⚠️  Mismatch at item 4999:
#     res:  'Nasser Faridoun'
#     orig: 'nasser faridoon'
# .   "4999": "nasser faridoon",
# ⚠️  Mismatch at item 5002:
#     res:  'säga vad man vill om bo.'
#     orig: 'säga vad man vill om boo'
# .   "5002": "säga vad man vill om boo",
# ⚠️  Mismatch at item 5013:
#     res:  'Europa är på väg i fatt USA enligt konsultjätten Anderson Consulting.'
#     orig: 'europa är på väg ifatt usa enligt konsultjätten andersen consulting'
# .   "5013": "europa är på väg ifatt usa enligt konsultjätten andersen consulting",
# ⚠️  Mismatch at item 5017:
#     res:  'Krister Marking'
#     orig: 'christer marking'
# .   "5017": "christer marking",
# ⚠️  Mismatch at item 5020:
#     res:  'Let's Buy It's grundare'
#     orig: 'letsbuyits grundare'
# .   "5020": "letsbuyits grundare",
# ⚠️  Mismatch at item 5042:
#     res:  'Simens, Soni och Alcatel'
#     orig: 'siemens sony och alcatel'
# .   "5042": "siemens sony och alcatel",
# ⚠️  Mismatch at item 5046:
#     res:  'Projektet drivs av toppledarforum och kostar 2 miljoner kronor.'
#     orig: 'projektet drivs av toppledarforum och kostar två miljoner kronor'
# .   "5046": "projektet drivs av toppledarforum och kostar två miljoner kronor",
# ⚠️  Mismatch at item 5058:
#     res:  'Det är som de sa i lumpen självmarkerande'
#     orig: 'det är som dom sa i lumpen självmarkerande'
# .   "5058": "det är som dom sa i lumpen självmarkerande",
# ⚠️  Mismatch at item 5061:
#     res:  'CooperNIC som automatiskt utför sökningar på flera sökmaskiner.'
#     orig: 'copernic som automatiskt utför sökningar på flera sökmaskiner'
# .   "5061": "copernic som automatiskt utför sökningar på flera sökmaskiner",
# ⚠️  Mismatch at item 5065:
#     res:  'En bättre, mer entusiastisk hund har nog aldrig skådats.'
#     orig: 'en bättre mer entusiastisk kund har nog aldrig skådats'
# .   "5065": "en bättre mer entusiastisk kund har nog aldrig skådats",
# ⚠️  Mismatch at item 5067:
#     res:  'Networx bland andra siktar också högt inför nästa lansering.'
#     orig: 'networks bland andra siktar också högt inför nästa lansering'
# .   "5067": "networks bland andra siktar också högt inför nästa lansering",
# ⚠️  Mismatch at item 5071:
#     res:  'Elisabeth Järrestrand'
#     orig: 'elisabeth järestrand'
# .   "5071": "elisabeth järestrand",
# ⚠️  Mismatch at item 5076:
#     res:  'X-Bug läses in.'
#     orig: 'exebug läses in'
# .   "5076": "exebug läses in",
# ⚠️  Mismatch at item 5078:
#     res:  'Det kan användas även i Lotus-programpaket SmartSuit.'
#     orig: 'det kan användas även i lotus programpaket smartsuite'
# .   "5078": "det kan användas även i lotus programpaket smartsuite",
# ⚠️  Mismatch at item 5085:
#     res:  'Han kallar informentor för ett nätverk snarare än ett företag.'
#     orig: 'han kallar informentor för ett nätverk snarare än företag'
# .   "5085": "han kallar informentor för ett nätverk snarare än företag",
# ⚠️  Mismatch at item 5098:
#     res:  'Web-teknik i termer som första sida, antal klick och länkar.'
#     orig: 'webteknik i termer som första sida antal klick och länkar'
# .   "5098": "webteknik i termer som första sida antal klick och länkar",
# ⚠️  Mismatch at item 5120:
#     res:  'ICSA är drift hos Europolitan.'
#     orig: 'icsa i drift hos europolitan'
# .   "5120": "icsa i drift hos europolitan",
# ⚠️  Mismatch at item 5125:
#     res:  'Carol Brigham, analytiker på ICD i USA'
#     orig: 'carol briggon analytiker på icd i usa'
# .   "5125": "carol briggon analytiker på icd i usa",
# ⚠️  Mismatch at item 5129:
#     res:  'Ernst & Young i Bryssel'
#     orig: 'ernst and young i bryssel'
# .   "5129": "ernst and young i bryssel",
# ⚠️  Mismatch at item 5142:
#     res:  'Eva Salander har anställt som mediekonsult på MessagePlus Media.'
#     orig: 'eva zahlander har anställts som mediekonsult på message plus media'
# .   "5142": "eva zahlander har anställts som mediekonsult på message plus media",
# ⚠️  Mismatch at item 5149:
#     res:  'Det följer med ljudkort från Creative men inga högtalare.'
#     orig: 'det följer med ett ljudkort från creative men inga högtalare'
# .   "5149": "det följer med ett ljudkort från creative men inga högtalare",
# ⚠️  Mismatch at item 5159:
#     res:  'Outlook som tog bort problemet innan Bubble Boy började spridas.'
#     orig: 'outlook som tog bort problemet innan bubbleboy började spridas'
# .   "5159": "outlook som tog bort problemet innan bubbleboy började spridas",
# ⚠️  Mismatch at item 5160:
#     res:  'Vanliga Java-program ska kunna fungera i realtids-Java-miljön.'
#     orig: 'vanliga javaprogram ska kunna fungera i realtidsjavamiljön'
# .   "5160": "vanliga javaprogram ska kunna fungera i realtidsjavamiljön",
# ⚠️  Mismatch at item 5169:
#     res:  'Centrala Europa samt i Medelhavsområdet'
#     orig: 'centraleuropa samt i medelhavsområdet'
# .   "5169": "centraleuropa samt i medelhavsområdet",
# ⚠️  Mismatch at item 5183:
#     res:  'Unix-maskiner och stordatorer'
#     orig: 'unixmaskiner och stordatorer'
# .   "5183": "unixmaskiner och stordatorer",
# ⚠️  Mismatch at item 5204:
#     res:  'Kai Mortensson, vd vid Institutet för livsmedelsforskning'
#     orig: 'kaj mårtensson vd vid institutet för livsmedelsforskning'
# .   "5204": "kaj mårtensson vd vid institutet för livsmedelsforskning",
# ⚠️  Mismatch at item 5210:
#     res:  'Den som har högre eget kapital får göra positiv räntefördelning. Räntefördelning'
#     orig: 'den som har högre eget kapital får göra positiv räntefördelning'
# .   "5210": "den som har högre eget kapital får göra positiv räntefördelning",
# ⚠️  Mismatch at item 5213:
#     res:  'HAUF – VD för Scandiabanken Fonder'
#     orig: 'hauff vd för skandiabanken fonder'
# .   "5213": "hauff vd för skandiabanken fonder",
# ⚠️  Mismatch at item 5214:
#     res:  'Henne som Maurits gör tummen upp för julhanden så här långt.'
#     orig: 'hennes och mauritz gör tummen upp för julhandeln så här långt'
# .   "5214": "hennes och mauritz gör tummen upp för julhandeln så här långt",
# ⚠️  Mismatch at item 5215:
#     res:  'Ju före desto bättre säger han bara'
#     orig: 'ju förr desto bättre säger han bara'
# .   "5215": "ju förr desto bättre säger han bara",
# ⚠️  Mismatch at item 5217:
#     res:  'En budplikt kommer att sänka aktiekurserna, säger Claes Bergström.'
#     orig: 'en budplikt kommer att sänka aktiekurserna säger clas bergström'
# .   "5217": "en budplikt kommer att sänka aktiekurserna säger clas bergström",
# ⚠️  Mismatch at item 5219:
#     res:  'Lomsdalen förvaltare på Svesia'
#     orig: 'lomsdalen förvaltare på svecia'
# .   "5219": "lomsdalen förvaltare på svecia",
# ⚠️  Mismatch at item 5220:
#     res:  'Den senaste Tristar väger 12 gram.'
#     orig: 'den senaste tri star väger tolv gram'
# .   "5220": "den senaste tri star väger tolv gram",
# ⚠️  Mismatch at item 5223:
#     res:  'Detta dementeras inte av vd Ulf Törnqvist.'
#     orig: 'detta dementeras inte av vd ulf thörnqvist'
# .   "5223": "detta dementeras inte av vd ulf thörnqvist",
# ⚠️  Mismatch at item 5234:
#     res:  'Kvalster, spindlar, hoppskärtar, vivlar och jordlöpare Hör till de arter som trivs bra på granar'
#     orig: 'kvalster spindlar hoppstjärtar vivlar och jordlöpare hör till de arter som trivs bra på granar'
# .   "5234": "kvalster spindlar hoppstjärtar vivlar och jordlöpare hör till de arter som trivs bra på granar",
# ⚠️  Mismatch at item 5241:
#     res:  'Symptom på den första smittan är feber, halsont, ljusskygghet, illamående, led och muskelvärk, utslag eller diarreer.'
#     orig: 'symtom på den första smittan är feber halsont ljusskygghet illamående led- och muskelvärk utslag eller diarréer'
# .   "5241": "symtom på den första smittan är feber halsont ljusskygghet illamående led- och muskelvärk utslag eller diarréer",
# ⚠️  Mismatch at item 5242:
#     res:  'Tipskatalogen innehöll ett stort urval av läromedel, litteratur, filmer, hemsidor.'
#     orig: 'tipskatalogen innehåller ett urval av läromedel litteratur filmer hemsidor'
# .   "5242": "tipskatalogen innehåller ett urval av läromedel litteratur filmer hemsidor",
# ⚠️  Mismatch at item 5245:
#     res:  'Vi får se kungen som barn, scout, monark, bandispelare och jägare.'
#     orig: 'vi får se kungen som barn scout monark bandyspelare och jägare'
# .   "5245": "vi får se kungen som barn scout monark bandyspelare och jägare",
# ⚠️  Mismatch at item 5246:
#     res:  'Över hundra musiker, dansare, skådespelare, proseister och poeter bjöd på hög klass i de enskilda inslagen.'
#     orig: 'över hundra musiker dansare skådespelare prosaister och poeter bjöd på hög klass i de enskilda inslagen'
# .   "5246": "över hundra musiker dansare skådespelare prosaister och poeter bjöd på hög klass i de enskilda inslagen",
# ⚠️  Mismatch at item 5251:
#     res:  'Litteratur, musik, band, glass. Rubbet för hela avdelningen, berättar Ingvar.'
#     orig: 'litteratur musikband glass rubbet för hela avdelningen berättar ingvar'
# .   "5251": "litteratur musikband glass rubbet för hela avdelningen berättar ingvar",
# ⚠️  Mismatch at item 5252:
#     res:  'Man kan samla på frimärken, suddgummin, bokmärken, skivor, tändstiksaskar, vykort, autografer.'
#     orig: 'man kan samla på frimärken suddgummin bokmärken skivor tändsticksaskar vykort autografer'
# .   "5252": "man kan samla på frimärken suddgummin bokmärken skivor tändsticksaskar vykort autografer",
# ⚠️  Mismatch at item 5262:
#     res:  'Svag spansk brytning, ljushy, mager, stilig, med en liten mustasch under en örnäsa.'
#     orig: 'svag spansk brytning ljus hy mager stilig med en liten mustasch under en örnnäsa'
# .   "5262": "svag spansk brytning ljus hy mager stilig med en liten mustasch under en örnnäsa",
# ⚠️  Mismatch at item 5273:
#     res:  'Sjukvårdsbiträden, hembiträden, lärare, en kyrkvaktmästare, en dagisfröken, en bussförare, en elvabarnsmamma, en chefsekreterare och många fler.'
#     orig: 'sjukvårdsbiträden hembiträden lärare en kyrkvaktmästare en dagisfröken en bussförare en elvabarnsmamma en chefssekreterare och många fler'
# .   "5273": "sjukvårdsbiträden hembiträden lärare en kyrkvaktmästare en dagisfröken en bussförare en elvabarnsmamma en chefssekreterare och många fler",
