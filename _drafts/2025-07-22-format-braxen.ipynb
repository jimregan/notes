# %%
BRAXEN_DIR = "/Users/joregan/Playing/braxen/"

# %%
BRAXEN_IPA_RAW = """
p	p
b	b
t	t
rt	ʈ
d	d
rd	ɖ
k	k
g	ɡ
g	g
f	f
v	v
s	s
rs	ʂ
sh	ʃ
zh	ʒ
z	z
dh	ð
th	θ
h	h
x	ɧ
xx	x
c	ɕ
tc	t͡ʃ
dj	d͡ʒ
m	m
n	n
rn	ɳ
ng	ŋ
r	r
l	l
rl	ɭ
j	j
w	w
rh	ɾ
r0	r0
rx	ʀ
i:	iː
i	ɪ
ih	ɪ̯
y:	yː
y	ʏ
e:	eː
e	e
eh	e̝
ex	ə
ä:	ɛː
ä	ɛ
ae:	æː
ae	æ
ö:	øː
ö	ø
oe:	ɶː
oe	ɶ
u:	uː
u	u
oh	o
o:	oː
o	ɔ
uu:	ʉː
uu	ɵ
uuh	ʉ
uw:	ʊː
uw	ʊ
a:	ɑː
a	a
aa:	aː
au	aʊ
eu	ɛʊ
ei	eɪ
ai	aɪ
oi	ɔɪ
ou	əʊ
eex	eə
iex	ɪə
uex	ʊə
an	ã
en	ɛ̃
on	õ
un	œ̃
.	.
"""

# %%
BRAXEN_IPA = {}
for line in BRAXEN_IPA_RAW.strip().split("\n"):
    if not line.strip():
        continue
    parts = line.split("\t")
    if len(parts) != 2:
        continue
    BRAXEN_IPA[parts[0]] = parts[1]

# %%
def braxen_encode(phoneme_string, phoneme_to_ipa, strictly_braxen=False, stress_type=None):
    """
    Convert a string of symbolic phonemes to IPA using stress handling.
    
    Args:
        phoneme_string (str): e.g., "'a: . r ex n"
        phoneme_to_ipa (dict): mapping of phoneme symbols to IPA
        
    Returns:
        str: IPA transcription
    """
    # Replace morpheme/compound boundaries with syllable breaks
    phoneme_string = phoneme_string.replace('-', '.').replace('~', '.').replace('|', '.')
    if not strictly_braxen:
        BRAXEN_IPA['r0'] = 'ɹ'

    ipa_output = []

    for p in phoneme_string.strip().split():
        stress = None

        if strictly_braxen:
            if p == 'r0':
                continue

            # Handle stress markers
            if p.startswith("'"):
                stress = 'ˈ́'
                p = p[1:]
            elif p.startswith('"'):
                stress = 'ˈ̀'
                p = p[1:]
            elif p.startswith(','):
                stress = 'ˌ'
                p = p[1:]
        elif stress_type and stress_type == 'wiktionary':
            if p.startswith("'"):
                stress = '¹'
                p = p[1:]
            elif p.startswith('"'):
                stress = '²'
                p = p[1:]
            elif p.startswith(','):
                stress = 'ˌ'
                p = p[1:]
        else:
            if p.startswith("'"):
                stress = 'ˈ'
                p = p[1:]
            elif p.startswith('"'):
                stress = 'ˈ'
                p = p[1:]
            elif p.startswith(','):
                stress = 'ˌ'
                p = p[1:]

        if p in phoneme_to_ipa:
            ipa = phoneme_to_ipa[p]
            if stress:
                ipa = stress + ipa
            ipa_output.append(ipa)
        else:
            print(f"[WARN] No match for phoneme: {p}")
    
    return ''.join(ipa_output)

# %%
assert braxen_encode("""g rh 'ae n d ~ m a: . s t ex r0""", BRAXEN_IPA) == 'gɾˈænd.mɑː.stəɹ'

# %%
from pathlib import Path

DICT_PATH = Path(BRAXEN_DIR) / "dict" / "braxen-sv.tsv"

with open(DICT_PATH, 'r', encoding='utf-8') as f:
    for line in f.readlines():
        if line.startswith("#") or not line.strip():
            continue
        parts = line.strip().split("\t")
        word = parts[0]
        transcription = parts[1]
        pos_tags = parts[2]
        lang = parts[3] if len(parts) > 3 else "swe"
        ipa = braxen_encode(transcription, BRAXEN_IPA, strictly_braxen=False)
        if lang == "pol":
            print(f"{word}\t{ipa}\t{pos_tags}\t{lang}")
# Out:
# Achruk	ˈaɧ.ruk	PM NOM	pol
# Adamczyk	a.dˈam.t͡ʃɪk	PM NOM	pol
# Adamek	a.dˈaː.mək	PM NOM	pol
# Adamowicz	a.da.mˈoː.vɪt͡ʃ	PM NOM	pol
# Ahura	a.hˈʉː.ra	PM NOM	pol
# Ailton	a.ˈiːl.tɔn	PM NOM	pol
# Anderszewski	an.dər.ʂˈev.skɪ	PM NOM	pol
# Andrasz	ˈan.draʂ	PM NOM	pol
# Andrzej	ˈand.ʂəj	PM NOM	pol
# Andrzejczak	aɳɖ.ʂˈej.t͡ʃak	PM NOM	pol
# Andzejs	and.sˈejs	PM NOM	pol
# Antonczyk	an.tˈɔn.t͡ʃɪk	PM NOM	pol
# Arek	ˈa.rək	PM NOM	pol
# Areks	ˈa.rəks	PM GEN	pol
# Arkadiusz	ar.kˈad.juʂ	PM NOM	pol
# Azoty-Pulawy	a.sɔ.tɪ.po.wˈaː.vɪ	PM NOM	pol
# Bacewicz	bˈat.sə.vɪt͡ʃ	PM NOM	pol
# Bacewiczs	bˈat.sə.vɪt͡ʃs	PM GEN	pol
# Balicki	ba.lˈɪt.skɪ	PM NOM	pol
# Bartlomiej	bart.lˈoː.mɪ̯.ej	PM NOM	pol
# Bednarczuk	bed.nˈar.t͡ʃuk	PM NOM	pol
# Bednarski	bed.nˈa.ʂkɪ	PM NOM	pol
# Bemowo	be̝.mˈɔ.vɔ	PM NOM	pol
# Bereszynski	be.rə.ʂˈɪn.skɪ	PM NOM	pol
# Berkowicz	bær.kˈoː.vɪt͡ʃ	PM NOM	pol
# Bialecka	bɪ.a.lˈet.ska	PM NOM	pol
# Bialowieza	biː.a.vɔv.jˈeː.ʂa	PM NOM	pol
# Bialowiezas	biː.a.vɔv.jˈeː.ʂas	PM GEN	pol
# Bialystok	bja.wˈɪ.stɔk	PM NOM	pol
# Bielecki	bje̝.lˈet.skɪ	PM NOM	pol
# Bielenia	be̝.lˈe.nɪ̯.a	PM NOM	pol
# Bienkowska	bjeŋ.kˈɔf.ska	PM NOM	pol
# Blachowicz	bwa.ɧˈoː.vɪt͡ʃ	PM NOM	pol
# Blaszczak	bwˈaʂ.t͡ʃak	PM NOM	pol
# Blaszczykowski	bwaʂ.t͡ʃɪ.kˈɔv.skɪ	PM NOM	pol
# Blechacz	blˈɛ.ɧat͡ʃ	PM NOM	pol
# Bochenski	bo.ɧˈeŋ.skɪ	PM NOM	pol
# Bochynek	bo.ɧˈɪ.nək	PM NOM	pol
# Bogdanowicz	bɔg.da.nˈoː.vɪt͡ʃ	PM NOM	pol
# Bogdanska	bɔg.dˈan.ska	PM NOM	pol
# Boguslaw	bo.gˈu.swav	PM NOM	pol
# Borkowski	bɔr.kˈɔv.skɪ	PM NOM	pol
# Borkowskis	bɔr.kˈɔv.skɪs	PM GEN	pol
# Borowiak	bo.rˈoː.vɪ̯.ak	PM NOM	pol
# Borowicz	bɔ.rˈoː.vɪt͡ʃ	PM NOM	pol
# Brodecki	bro.dˈɛt.skɪ	PM NOM	pol
# Brodetsky	bro.dˈet.skɪ	PM NOM	pol
# Brodka	brˈɔt.ka	PM NOM	pol
# Brzezinska	bʂə.ʂˈiːn.ska	PM NOM	pol
# Brzezinskas	bʂə.ʂˈiːn.skas	PM GEN	pol
# Brzoskowski	brə.so.skˈoːv.skɪ	PM NOM	pol
# Buczek	bˈu.t͡ʃək	PM NOM	pol
# Budryk	bˈu.drɪk	PM NOM	pol
# Bujak	bˈu.jak	PM NOM	pol
# Bukowiecki	bu.kɔv.jˈet.skɪ	PM NOM	pol
# Buzka	bˈu.ʂka	PM NOM	pol
# Bydgoszcz	bˈɪd.gɔʂʈʂ	PM NOM	pol
# Bydgoszsz	bˈɪd.dɔʂʈʂ	PM NOM	pol
# Byzdra	bˈɪs.dra	PM NOM	pol
# Cegielski	tsəg.jˈel.skɪ	PM NOM	pol
# Cezary	se̝.sˈɑː.rɪ	PM NOM	pol
# Cherson	ɧær.sˈɔn	PM NOM	pol
# Chersons	ɧær.sˈɔns	PM GEN	pol
# Chmielewski	ɧmɪ.lˈev.skɪ	PM NOM	pol
# Chorzow	xˈɔr.sɔv	PM NOM	pol
# Chorzów	ɧˈɔr.sɔv	PM NOM	pol
# Chrapkowska	ɧrap.kˈɔv.ska	PM NOM	pol
# Chrzanowski	ʂa.nˈɔv.skɪ	PM NOM	pol
# Cichocka	tsɪ.ɧˈɔt.ska	PM NOM	pol
# Cienciala	t͡ʃɪ.ən.t͡ʃɪ.ˈaʊ.a	PM NOM	pol
# Ciesielska	tsɪ.sɪ.ˈel.ska	PM NOM	pol
# Cieslak	tsˈiː.slak	PM NOM	pol
# Cieszanów	t͡ʃe̝.sˈaː.nɔv	PM NOM	pol
# Comarch	kˈɔ.marɧ	PM NOM	pol
# Comarchs	kˈɔ.marɧs	PM GEN	pol
# Cracovia	kra.kˈɔ.vɪ̯.a	PM NOM	pol
# Cyfer	tsˈiː.fər	PM NOM	pol
# Czaja	t͡ʃˈa.ja	PM NOM	pol
# Czapla	t͡ʃˈa.pla	PM NOM	pol
# Czarna	t͡ʃˈar.na	PM NOM	pol
# Czarnecki	ʂar.nˈet.skɪ	PM NOM	pol
# Czarneckis	ʂar.nˈet.skɪs	PM GEN	pol
# Czarnowski	t͡ʃar.nˈɔv.skɪ	PM NOM	pol
# Czerapowicz	t͡ʃe.ra.pˈoː.vɪt͡ʃ	PM NOM	pol
# Czeslaw	t͡ʃˈe.slaf	PM NOM	pol
# Czestochowa	t͡ʃe.sto.hˈɔ.va	PM NOM	pol
# Dabrowa	da.brˈoː.va	PM NOM	pol
# Dabrowska	dɔm.brˈɔv.ska	PM NOM	pol
# Daleszczyk	da.lˈeʂ.t͡ʃɪk	PM NOM	pol
# Darlowo	dar.lˈoː.vu	PM NOM	pol
# Daszek	dˈɑː.ʂək	PM NOM	pol
# Dawidowicz	da.vɪ.dˈoː.vɪt͡ʃ	PM NOM	pol
# Dawydzik	da.vˈɪ.d͡ʒɪk	PM NOM	pol
# Debicki	de̝.bˈɪt.skɪ	PM NOM	pol
# Debickis	de̝.bˈɪt.skɪs	PM GEN	pol
# Dluzewski	dwo.ʂˈev.skɪ	PM NOM	pol
# Dolhinow	dˈəʊ.hiː.nɔf	PM NOM	pol
# Dorota	do.rˈoː.ta	PM NOM	pol
# Drozda	drˈɔs.da	PM NOM	pol
# Duszniki	do.ʂɳˈiː.kɪ	PM NOM	pol
# Duszniki-Zdroj	do.ʂɳˈɪ.kɪ.strˈɔj	PM NOM	pol
# Dusznikis	do.ʂɳˈɪ.kɪs	PM GEN	pol
# Duszny	dˈu.ʂɳɪ	PM NOM	pol
# Dutkiewicz	dutk.jˈeː.vɪt͡ʃ	PM NOM	pol
# Dybala	dɪ.bˈaʊ.a	PM NOM	pol
# Dyjas	dˈiː.jas	PM NOM	pol
# Dziadek	d͡ʒˈa.dək	PM NOM	pol
# Dziadeks	d͡ʒˈa.dəks	PM GEN	pol
# Dziarnowska	də.sɪ̯.ar.nˈɔv.ska	PM NOM	pol
# Dziedzic	d͡ʒˈɪ.d͡ʒɪts	PM NOM	pol
# Dzieweczynski	d͡ʒe.ve̝.t͡ʃˈɪn.skɪ	PM NOM	pol
# Fakty	fˈak.tɪ	PM NOM	pol
# Fedorczyk	fe̝.dˈɔrt.ʂɪk	PM NOM	pol
# Felczak	fˈel.t͡ʃak	PM NOM	pol
# Florkiewicz	flɔrk.jˈeː.vɪt͡ʃ	PM NOM	pol
# Franciszek	fran.t͡ʃˈɪ.ʂək	PM NOM	pol
# Fundacja	fun.dˈɑːts.ja	PM NOM	pol
# Fàbregas	fˈaː.brə.gas	PM NOM	pol
# Gajewska	ga.jˈev.ska	PM NOM	pol
# Gajowniczek	ga.jˈɔv.nɪ.t͡ʃək	PM NOM	pol
# Galecki	ga.lˈet.skɪ	PM NOM	pol
# Galewicz	ga.lˈeː.vɪt͡ʃ	PM NOM	pol
# Gasienica-Daniel	ga.ʂɪ.nˈɪt.sa.dˈɑː.nˌɪ.əl	PM NOM	pol
# Gaszynski	ga.ʂˈɪn.skɪ	PM NOM	pol
# Gdanski	gə.dˈan.skɪ	PM NOM	pol
# Gerejczyk	ge̝.rˈej.t͡ʃɪk	PM NOM	pol
# Gerwazy	gær.vˈɑː.sɪ	PM NOM	pol
# Giedroyc	gjˈeː.drɔjt͡ʃ	PM NOM	pol
# Ginczek	gˈɪn.t͡ʃək	PM NOM	pol
# Gliszczynska	glɪt͡ʃ.ʂˈɪn.ska	PM NOM	pol
# Gliwice	glɪ.vˈɪt.sə	PM NOM	pol
# Gloc-Kudlacz	glˈɔk.kˈud.wat͡ʃ	PM NOM	pol
# Gojowczyk	go.jˈɔwʈ.ʂɪk	PM NOM	pol
# Gombrowicz	gɔm.brˈoː.vɪt͡ʃ	PM NOM	pol
# Gomolski	go.mˈɔl.skɪ	PM NOM	pol
# Gorczycki	gɔr.t͡ʃˈɪt.skɪ	PM NOM	pol
# Gorecka	go.rˈet.ska	PM NOM	pol
# Goreckas	go.rˈet.skas	PM GEN	pol
# Gornicza	gur.nˈɪ.t͡ʃa	PM NOM	pol
# Gostkowski	gɔst.kˈɔv.skɪ	PM NOM	pol
# Gowin	gˈɔ.vɪn	PM NOM	pol
# Grabarczyk	gra.bˈar.t͡ʃɪk	PM NOM	pol
# Grabarz	grˈa.baʂ	PM NOM	pol
# Gracza	grˈa.t͡ʃa	PM NOM	pol
# Grazyna	grˈaː.sɪ.na	PM NOM	pol
# Grodnos	grˈɔd.nɔs	PM GEN	pol
# Grodzka	grˈɔt.ska	PM NOM	pol
# Gromysz	grˈoː.mɪʂ	PM NOM	pol
# Gronkowski	grɔŋ.kˈɔv.skɪ	PM NOM	pol
# Grosicki	gro.sˈɪt.skɪ	PM NOM	pol
# Gryszkiewicz	grɪʂk.jeː.vˈɪt͡ʃ	PM NOM	pol
# Grzegors	gʂˈe.gɔrs	PM NOM	pol
# Grzelak	t͡ʃˈeː.lak	PM NOM	pol
# Grzyb	gə.ʂˈɪb	PM NOM	pol
# Grzywinska	grsɪ.vˈɪn.ska	PM NOM	pol
# Gudowski	go.dˈɔv.skɪ	PM NOM	pol
# Guilherme	gɪ.lˈær.mə	PM NOM	pol
# Guzik	gˈu.ʂɪk	PM NOM	pol
# Gwizdon	gvɪs.dˈɔn	PM NOM	pol
# Hajdamowicz	haj.da.mˈɔ.vɪt͡ʃ	PM NOM	pol
# Heweliusz	he̝.vˈeː.lɪ̯.uʂ	PM NOM	pol
# Hiryciuk	hɪ.rˈɪ.t͡ʃɵk	PM NOM	pol
# Hojnisz-Starega	hˈɔj.nɪʂ.sta.rˈe.ga	PM NOM	pol
# Holowczyc	ho.lˈɔv.t͡ʃɪts	PM NOM	pol
# Holub-Kowalik	hˈɔ.wup.ko.vˈa.lɪk	PM NOM	pol
# Huczkowski	hut͡ʃ.kˈɔv.skɪ	PM NOM	pol
# Hurkacz	hˈur.kat͡ʃ	PM NOM	pol
# Hurkaczs	hˈur.kat͡ʃs	PM GEN	pol
# Jablonski	ja.blˈɔn.skɪ	PM NOM	pol
# Jablonskis	ja.blˈɔn.skɪs	PM GEN	pol
# Jachimowicz	ja.ɧɪ.mˈoː.vɪt͡ʃ	PM NOM	pol
# Jagiello	jag.jˈɛʊ.u	PM NOM	pol
# Jakubowskis	ja.ko.bˈɔf.skɪs	PM GEN	pol
# Jancarz	jˈan.tsaʂ	PM NOM	pol
# Janczyk	jˈan.t͡ʃɪk	PM NOM	pol
# Jankowska	jaŋ.kˈɔv.ska	PM NOM	pol
# Janosik	ja.nˈɔ.ʂɪk	PM NOM	pol
# Januszewski	ja.nʉ.ʂˈev.skɪ	PM NOM	pol
# Jarosław	ja.rˈɔ.svav	PM NOM	pol
# Jaruzelski	ja.ro.sˈel.skɪ	PM NOM	pol
# Jarzabkowski	ja.ʂap.kˈɔf.skɪ	PM NOM	pol
# Jaskowiec	ja.skˈoː.vɪ̯.ets	PM NOM	pol
# Jasna	jˈa.sna	PM NOM	pol
# Jastrzebie	jast.ʂˈe.bɪ̯.ə	PM NOM	pol
# Jaszczuk	jˈaʂ.t͡ʃuk	PM NOM	pol
# Jaszka	ɧˈa.ʂka	PM NOM	pol
# Jedrzejak	jen.d͡ʒˈe.jak	PM NOM	pol
# Jedrzejczyk	jend.jˈɛj.t͡ʃɪk	PM NOM	pol
# Jedwabne	jed.vˈab.nə	PM NOM	pol
# Jeleniewski	je.le.nɪ.ˈev.skɪ	PM NOM	pol
# Jerzak	jˈær.sak	PM NOM	pol
# Jodlowiec	jɔd.wˈoː.vɪ̯.əts	PM NOM	pol
# Josefowicz	ju.sə.fˈoː.vɪt͡ʃ	PM NOM	pol
# Jozwiak	jˈuː.ʂvɪ̯.ak	PM NOM	pol
# Juraszek	jo.rˈɑː.ʂək	PM NOM	pol
# Jurkowski	jur.kˈɔv.skɪ	PM NOM	pol
# Jósefów	jo.zˈe.fɔf	PM NOM	pol
# Jósefóws	jo.zˈe.fɔfs	PM GEN	pol
# Kaczmarek	kat͡ʃ.mˈa.rək	PM NOM	pol
# Kaczyński	ka.t͡ʃˈɪn.skɪ	PM NOM	pol
# Kajetanowicz	ka.jə.ta.nˈoː.vɪt͡ʃ	PM NOM	pol
# Kalisz	kˈa.lɪʂ	PM NOM	pol
# Kality	ka.lˈiː.tɪ	PM NOM	pol
# Kamieniarczyk	ka.mɪ̯.ə.nɪ.ˈar.t͡ʃɪk	PM NOM	pol
# Kanikowski	ka.nɪ.kˈɔv.skɪ	PM NOM	pol
# Kapustka	ka.pˈust.ka	PM NOM	pol
# Karsin	kˈar.ɕɪn	PM NOM	pol
# Karsins	kˈar.ɕɪns	PM GEN	pol
# Kasprzak	kˈasp.ʂak	PM NOM	pol
# Kasprzycka	kasp.ʂˈɪ.ka	PM NOM	pol
# Katarzyna	ka.tar.ʂˈiː.na	PM NOM	pol
# Katowice	kˈa.tu.vɪt.sə	PM NOM	pol
# Katowices	ka.to.vˈɪt.səs	PM GEN	pol
# Kawalec	ka.vˈa.ləts	PM NOM	pol
# Kawalsky	ka.vˈal.skɪ	PM NOM	pol
# Kawecki	ka.vˈet.skɪ	PM NOM	pol
# Kazimiera	ka.sɪ.mɪ.ˈeː.ra	PM NOM	pol
# Kazimierz	ka.ʂˈiː.mjiːrʂ	PM NOM	pol
# Kielce	kjˈelt.sə	PM NOM	pol
# Kielces	kjˈelt.səs	PM GEN	pol
# Kieslowskis	kɪ.slˈɔf.skɪs	PM GEN	pol
# Kinicki	kɪ.nˈɪt.skɪ	PM NOM	pol
# Kiszakiewicz	kɪ.ʂa.kjˈeː.vɪʂ	PM NOM	pol
# Klata	klˈɑː.ta	PM NOM	pol
# Klepac	klˈeː.pat͡ʃ	PM NOM	pol
# Klepacka	kle̝.pˈa.ka	PM NOM	pol
# Klimecki	klɪ.mˈet.skɪ	PM NOM	pol
# Kluszczynski	kluʂ.t͡ʃˈɪn.skɪ	PM NOM	pol
# Kobylinska	kɔ.bɪ.lˈɪn.ska	PM NOM	pol
# Kocela	kɔt.sˈe.la	PM NOM	pol
# Koczak	kˈɔr.t͡ʃak	PM NOM	pol
# Kokocinski	kɔ.ko.ɕˈɪn.skɪ	PM NOM	pol
# Kolczynski	kɔl.t͡ʃˈɪn.skɪ	PM NOM	pol
# Koleczek	ko.lˈe.t͡ʃək	PM NOM	pol
# Kolobrzeg	kˈoː.lɔb.ʂəg	PM NOM	pol
# Kolodziej	ko.wˈɔ.d͡ʒej	PM NOM	pol
# Komeda	ko.mˈeː.da	PM NOM	pol
# Komorowski	kɔ.mo.rˈɔv.skɪ	PM NOM	pol
# Konecki	kɔ.nˈet.skɪ	PM NOM	pol
# Koneckis	kɔ.nˈet.skɪs	PM GEN	pol
# Konieczny	ko.njˈet͡ʃ.nʏ	PM NOM	pol
# Koniuszaniec	kɔ.nʉ.ʂˈa.nət͡ʃ	PM NOM	pol
# Koprowska	ko.prˈɔf.ska	PM NOM	pol
# Koraszewska	kɔ.ra.ʂˈev.ska	PM NOM	pol
# Korczaks	kˈɔr.t͡ʃaks	PM GEN	pol
# Korwin-Mikke	kˈɔr.vɪn.mˈɪ.kə	PM NOM	pol
# Korzonek	kˈɔr.ʂu.nək	PM NOM	pol
# Koscielny	ko.t͡ʃˈel.nɪ	PM NOM	pol
# Kosciuch	kɔʂt.sˈɪ.uʂ	PM NOM	pol
# Kosinski	ko.sˈɪn.skɪ	PM NOM	pol
# Kovaleski	kɔ.va.lˈe.skɪ	PM NOM	pol
# Kownacki	kɔv.nˈat.skɪ	PM NOM	pol
# Kozienicki	kɔʂ.jə.nˈɪt.skɪ	PM NOM	pol
# Kraczkowski	krat͡ʃ.kˈɔv.skɪ	PM NOM	pol
# Krajewski	kra.jˈev.skɪ	PM NOM	pol
# Krakowiak	kra.kˈoː.vɪ̯.ak	NN	pol
# Kraków	krˈaː.kɔv	PM NOM	pol
# Kraków-Malopolska	krˈaː.kɔv.maʊ.o.pˈɔl.ska	PM NOM	pol
# Kramarz	krˈɑː.maʂ	PM NOM	pol
# Krasznapolski	kra.sna.pˈɔl.skɪ	PM NOM	pol
# Krawczyk	krˈaf.t͡ʃɪk	PM NOM	pol
# Kroplewski	kro.plˈev.skɪ	PM NOM	pol
# Krychowiak	krɪ.ɧˈɔ.vɪ̯.ak	PM NOM	pol
# Krystztof	krˈɪst.stɔf	PM NOM	pol
# Krzeszowic	kʂˈe.ʂu.vɪts	PM NOM	pol
# Krzymowska	kʂɪ.mˈɔf.ska	PM NOM	pol
# Krzysiek	kʂˈɪ.ʂək	PM NOM	pol
# Krzywak	kʂˈɪ.vak	PM NOM	pol
# Krzyzaniek	kʂɪ.sˈa.nɪ̯.ək	PM NOM	pol
# Krákow	krˈɑː.kɔv	PM NOM	pol
# Ksawery	ksa.vˈe.rɪ	PM NOM	pol
# Ksiazek	ksjˈoːŋ.sək	PM NOM	pol
# Ksiazkiewicz	kʂuŋʂ.kjˈeː.vɪt͡ʃ	PM NOM	pol
# Kszczot	kə.ʂʈˈɔt	PM NOM	pol
# Kubacki	ko.bˈat.skɪ	PM NOM	pol
# Kubot	kˈuː.bɔt	PM NOM	pol
# Kuchczynski	ko.t͡ʃˈɪn.skɪ	PM NOM	pol
# Kuciapski	ku.t͡ʃɪ.ˈap.skɪ	PM NOM	pol
# Kuczynski	ko.t͡ʃˈɪn.skɪ	PM NOM	pol
# Kuczynskis	ko.t͡ʃˈɪn.skɪs	PM GEN	pol
# Kudlacz-Gloc	kˈu.dɵ.at͡ʃ.glˈɔk	PM NOM	pol
# Kulczycki	kul.t͡ʃˈɪt.skɪ	PM NOM	pol
# Kulwinska	kɵl.vˈɪn.ska	PM NOM	pol
# Kuniewicz	ko.njˈeː.vɪt͡ʃ	PM NOM	pol
# Kurowska	ko.rˈɔv.ska	PM NOM	pol
# Kuznice	ko.snˈɪt.sə	PM NOM	pol
# Kwasniewski	kva.snɪ.ˈev.skɪ	PM NOM	pol
# Kwiatkowski	kvjat.kˈɔv.skɪ	PM NOM	pol
# Kłos	kwˈɔs	PM NOM	pol
# Lafazanis	la.fa.sˈɑː.nɪs	PM NOM	pol
# Lameiras	la.mˈej.ras	PM NOM	pol
# Lampart	lˈam.part	PM NOM	pol
# Latosz	lˈa.tɔʂ	PM NOM	pol
# Lebedynski	le.be̝.dˈɪn.skɪ	PM NOM	pol
# Legnica	le̝.gnˈɪt.sa	PM NOM	pol
# Lepik	le̝.pˈɪk	PM NOM	pol
# Leslaw	lˈes.waf	PM NOM	pol
# Leszek	lˈe.ʂək	PM NOM	pol
# Lew	lˈev	PM NOM	pol
# Lewica	le̝.vˈɪt.sa	PM NOM	pol
# Lewicki	le̝.vˈɪt.skɪ	PM NOM	pol
# Lewickis	le̝.vˈɪt.skɪs	PM GEN	pol
# Lewkowiez	lˈev.kɔ.vɪt͡ʃ	PM NOM	pol
# Lewkowiezs	lˈev.kɔ.vɪt͡ʃs	PM GEN	pol
# Licwinko	lɪt͡ʃ.vˈɪŋ.ku	PM NOM	pol
# Ligienza	lɪ.gɪ.ˈen.sa	PM NOM	pol
# Lijewski	lɪ.jˈev.skɪ	PM NOM	pol
# Linetty	lɪ.nˈe.tɪ	PM NOM	pol
# Lisek	lˈɪ.sek	PM NOM	pol
# Liseks	lˈɪ.seks	PM GEN	pol
# Lisiewicz	lɪ.ɕˈeː.vɪt͡ʃ	PM NOM	pol
# Liskowsky	lɪ.skˈɔv.skɪ	PM NOM	pol
# Lisowska	lɪ.sˈɔf.ska	PM NOM	pol
# Lispectors	lɪ.spˈek.tuʂ	PM GEN	pol
# Lodz	wˈut͡ʃ	PM NOM	pol
# Lubaczów	lo.bˈaː.t͡ʃɔv	PM NOM	pol
# Lulek	lˈuː.lək	PM NOM	pol
# Lutoslawski	lʉː.to.slˈav.skɪ	PM NOM	pol
# Lviv	lə.vˈiːv	PM NOM	pol
# Lwow	le̝.vˈuf	PM NOM	pol
# Lwów	le̝.vˈuf	PM NOM	pol
# Lódz	wˈɵt͡ʃ	PM NOM	pol
# MADEJ	mˈa.dej	PM NOM	pol
# Machcewicz	maɧ.sˈeː.vɪt͡ʃ	PM NOM	pol
# Maciej	mˈa.t͡ʃəj	PM NOM	pol
# Maczynski	man.t͡ʃˈɪn.skɪ	PM NOM	pol
# Majcherek	maj.ʂˈe.rək	PM NOM	pol
# Majchrzak	mˈaj.ʂak	PM NOM	pol
# Malgorzata	mal.gɔr.sˈɑː.ta	PM NOM	pol
# Malinka	ma.lˈɪŋ.ka	PM NOM	pol
# Malwina	mal.vˈiː.na	PM NOM	pol
# Malysz	mˈa.lɪʂ	PM NOM	pol
# Mamona	ma.mˈoː.na	PM NOM	pol
# Marciniak	mˈar.t͡ʃɪ.njak	PM NOM	pol
# Marcinkowska	mar.t͡ʃɪn.kˈɔv.ska	PM NOM	pol
# Marcinkowskas	mar.t͡ʃɪn.kˈɔv.skas	PM GEN	pol
# Marcisz	mˈar.t͡ʃɪʂ	PM NOM	pol
# Marczak	mˈar.t͡ʃak	PM NOM	pol
# Marczewski	mar.t͡ʃˈev.skɪ	PM NOM	pol
# Marczynski	mar.t͡ʃˈɪn.skɪ	PM NOM	pol
# Markiewicz	mark.jˈeː.vɪt͡ʃ	PM NOM	pol
# Markowa	mar.kˈoː.va	PM NOM	pol
# Marusarz	ma.rˈuː.saʂ	PM NOM	pol
# Maryja	ma.rˈiː.a	PM NOM	pol
# Maslowski	ma.slˈɔv.skɪ	PM NOM	pol
# Mateusz	ma.tˈe.uʂ	PM NOM	pol
# Matkowski	mat.kˈɔv.skɪ	PM NOM	pol
# Matuszczyk	ma.tˈuʂ.t͡ʃɪk	PM NOM	pol
# Medyka	me̝.dˈɪ.ka	PM NOM	pol
# Medykas	me̝.dˈɪ.kas	PM GEN	pol
# Melikas	me̝.lˈiː.kas	PM GEN	pol
# Melzacka	mel.sˈa.ka	PM NOM	pol
# Meronk	mˈe.rɔŋk	PM NOM	pol
# Michalski	mɪ.ɧˈal.skɪ	PM NOM	pol
# Mickiewicz	mɪt.skˈe.vɪt͡ʃ	PM NOM	pol
# Mieczyslaw	mjˈe.t͡ʃɪ.saʊv	PM NOM	pol
# Mieczysław	mje̝.t͡ʃˈɪ.swav	PM NOM	pol
# Mietek	mjˈeː.tək	PM NOM	pol
# Mieteks	mjˈeː.təks	PM GEN	pol
# Mikolaj	mɪ.ko.lˈaj	PM NOM	pol
# Mikolajczyk	mɪ.ko.wˈaj.t͡ʃɪk	PM NOM	pol
# Mikulowski	mɪ.ko.lˈɔv.skɪ	PM NOM	pol
# Milewczyk	ma.lˈev.t͡ʃɪk	PM NOM	pol
# Mirga-Tas	mˈɪr.ga.tˈaːs	PM NOM	pol
# Miskowiak	mɪ.ʂkˈoː.vɪ̯.ak	PM NOM	pol
# Miłosz	mˈiː.wɔʂ	PM NOM	pol
# Mlynkova	mlɪŋ.kˈɔ.va	PM NOM	pol
# Mlynková	mlɪŋ.kˈoː.va	PM NOM	pol
# Morawiecki	mɔ.ra.vɪ.ˈeːt.skɪ	PM NOM	pol
# Morawieckis	mɔ.ra.vɪ.ˈeːt.skɪs	PM GEN	pol
# Morawski	mo.rˈav.skɪ	PM NOM	pol
# Mularczyk	mo.lˈar.t͡ʃɪk	PM NOM	pol
# Muranka	mo.rˈaŋ.ka	PM NOM	pol
# Murzyn	mˈur.ʂɪn	PM NOM	pol
# Muszka	mˈu.ʂka	PM NOM	pol
# Myszka	mˈɪ.ʂka	PM NOM	pol
# Nalkowska	naʊ.kˈɔv.ska	PM NOM	pol
# Nedzewicz	nˈed.sə.vɪt͡ʃ	PM NOM	pol
# Niedzwiedz	njˈeɖ.ʂvɪ̯.ət͡ʃ	PM NOM	pol
# Niedzwiedzki	njedsv.jˈetsk.jɪ	PM NOM	pol
# Niewiadoma	njev.ja.dˈoː.ma	PM NOM	pol
# Nosek	nˈoː.sək	PM NOM	pol
# Nowa	nˈɔ.va	PM NOM	pol
# Nowakowska	noː.va.kˈɔv.ska	PM NOM	pol
# Nowakowska-Ziemniak	nɔ.va.kˈɔf.ska.ʂˈem.nɪ̯.ak	PM NOM	pol
# Nowicka	no.vˈɪ.ska	PM NOM	pol
# Nowicki	no.vˈɪt.skɪ	PM NOM	pol
# Ochman	ˈɔɧ.man	PM NOM	pol
# Okoniewski	ɔ.ko.njˈef.skɪ	PM NOM	pol
# Olczak	ˈɔl.t͡ʃak	PM NOM	pol
# Omelko	o.mˈel.ku	PM NOM	pol
# Orzechowski	ɔr.se̝.kˈɔv.skɪ	PM NOM	pol
# Oswiecim	ɔ.svɪ.ˈet.sɪm	PM NOM	pol
# Oświęcim	ɔʂv.jˈeː.t͡ʃɪm	PM NOM	pol
# Padalecki	pa.da.lˈet.skɪ	PM NOM	pol
# Paleski	pa.lˈet.skɪ	PM NOM	pol
# Paleskis	pa.lˈet.skɪs	PM GEN	pol
# Palicki	pa.lˈɪt.skɪ	PM NOM	pol
# Panasiuk	pa.nˈa.ʂuk	PM NOM	pol
# Pankowski	paŋ.kˈɔv.skɪ	PM NOM	pol
# Panufnik	pa.nˈuː.fnɪk	PM NOM	pol
# Papusza	pa.pˈu.ʂa	PM NOM	pol
# Pasieka	pa.ʂˈeː.ka	PM NOM	pol
# Pasiekas	pa.ʂˈeː.kas	PM GEN	pol
# Pasikowski	pa.sɪ.kˈɔv.skɪ	PM NOM	pol
# Paszek	pˈa.ʂək	PM NOM	pol
# Paterski	pa.tˈær.skɪ	PM NOM	pol
# Patrycja	pa.trˈɪts.ja	PM NOM	pol
# Patryks	pˈa.trɪks	PM GEN	pol
# Pawlick	pˈav.lɪtsk	PM NOM	pol
# Pawlikowski	pav.lɪ.kˈɔf.skɪ	PM NOM	pol
# Pawlowski	pav.lˈɔv.skɪ	PM NOM	pol
# Pazdan	pˈɑːs.dan	PM NOM	pol
# Peczenik	pe̝.ʂˈe.nɪk	PM NOM	pol
# Peczeniks	pe̝.ʂˈe.nɪks	PM GEN	pol
# Penderecki	pen.de̝.rˈet.skɪ	PM NOM	pol
# Peszko	pˈe.ʂku	PM NOM	pol
# Petrowskaja	pe̝.trˈɔv.ska.ja	PM NOM	pol
# Pewik	pˈe.vɪk	PM NOM	pol
# Pewiks	pˈe.vɪks	PM GEN	pol
# Piatek	pjˈan.tək	PM NOM	pol
# Piechaczek	pje̝.ɧˈa.t͡ʃek	PM NOM	pol
# Pieczywek	pjet.sˈiː.vək	PM NOM	pol
# Pielak	pjˈe.lak	PM NOM	pol
# Pieszczek	pjˈeʂ.t͡ʃək	PM NOM	pol
# Pietrzak	pjˈeːʈ.ʂak	PM NOM	pol
# Pilecki	pɪ.lˈet.skɪ	PM NOM	pol
# Piskorska	pɪ.skˈɔr.ska	PM NOM	pol
# Pjotr	pjˈoː.tər	PM NOM	pol
# Plewka	plˈef.ka	PM NOM	pol
# Podatek	po.dˈaː.tək	NN	pol
# Polewka	po.lˈev.ka	PM NOM	pol
# Polkowice	pɔl.ko.vˈɪt.sə	PM NOM	pol
# Polski	pˈɔl.skɪ	JJ	pol
# Poprawa	pɔ.prˈaː.va	PM NOM	pol
# Porebski	po.rˈeb.skɪ	PM NOM	pol
# Povrzanović	pɔ.vərt.sˈa.nɔ.vɪts	PM NOM	pol
# Powidz	pˈɔ.vɪd͡ʒ	PM NOM	pol
# Powidzki	po.vˈɪd.skɪ	PM NOM	pol
# Powiecki	pɔ.vjˈet.skɪ	PM NOM	pol
# Prawo	prˈa.vu	PM NOM	pol
# Przedpelski	pʂed.pˈel.skɪ	PM NOM	pol
# Przedpelskis	pʂed.pˈel.skɪs	PM GEN	pol
# Przemek	pʂˈe.mək	PM NOM	pol
# Przemysl	pʂˈe.mɪʂɭ	PM NOM	pol
# Przemyslaw	pʂˈe.mɪs.wav	PM NOM	pol
# Przemyslaws	pʂˈe.mɪs.wavs	PM GEN	pol
# Przemysls	pʂˈɛː.mə.sus	PM GEN	pol
# Przeszlo	pʂˈeʂ.wu	PM NOM	pol
# Przewodów	pre.sə.vˈɔ.dɔv	PM NOM	pol
# Przewodóws	pre.sə.vˈɔ.dɔvs	PM GEN	pol
# Przeworski	pʂe̝.vˈɔr.skɪ	PM NOM	pol
# Przeworskis	pʂe̝.vˈɔr.skɪs	PM GEN	pol
# Przybyszewski	pʂɪ.bɪ.ʂˈev.skɪ	PM NOM	pol
# Przybytek	pʂɪ.bˈɪ.tək	PM NOM	pol
# Przygonski	pʂɪ.gˈɔn.skɪ	PM NOM	pol
# Przyjemski	prsɪ.jˈem.skɪ	PM NOM	pol
# Przysiezny	pʂɪ.ɕˈe.snɪ	PM NOM	pol
# Pulawska	po.ˈaʊv.ska	PM NOM	pol
# Pulawy	po.wˈaː.vɪ	PM NOM	pol
# Pyry	pˈɪ.rɪ	PM NOM	pol
# Rachunek	rˈa.ru.nək	PM NOM	pol
# Radetzky	ra.dˈet.skɪ	PM NOM	pol
# Radom	rˈɑː.dɔm	PM NOM	pol
# Rakow	rˈa.kɔv	PM NOM	pol
# Rojewski	ro.jˈev.skɪ	PM NOM	pol
# Ronina	ro.nˈiː.na	PM NOM	pol
# Rosolski	ro.sˈɔl.skɪ	PM NOM	pol
# Rybicka	rɪ.bˈɪt.ska	PM NOM	pol
# Rydzek	rˈɪd.sek	PM NOM	pol
# Rzepka	ʂˈep.ka	PM NOM	pol
# Rzeszow	ʂˈe.ʂuv	PM NOM	pol
# Rzeszów	ʂˈe.ʂɵf	PM NOM	pol
# Rózewicz	ro.sˈeː.vɪt͡ʃ	PM NOM	pol
# Różewicz	ro.sˈeː.vɪt͡ʃ	PM NOM	pol
# Sadzak	sˈad.sak	PM NOM	pol
# Salancik	sa.lˈant.sɪk	PM NOM	pol
# Salanciks	sa.lˈant.sɪks	PM GEN	pol
# Sapkowski	sap.kˈɔf.skɪ	PM NOM	pol
# Sarnecki	sar.nˈet.skɪ	PM NOM	pol
# Sederowsky	se.də.rˈɔv.skɪ	PM NOM	pol
# Siemiatkowski	sje.mjɔnt.kˈɔf.skɪ	PM NOM	pol
# Siemiatkowskis	sje.mjɔnt.kˈɔf.skɪs	PM GEN	pol
# Sienkiewicz	ʂɪŋ.kˈeː.vɪt͡ʃ	PM NOM	pol
# Sieradzki	ʂɪ.rˈɑːd.kɪ	PM NOM	pol
# Sikora	ʂɪ.kˈoː.ra	PM NOM	pol
# Skarbowej	skar.bˈoː.vej	PM NOM	pol
# Skolimowski	skɔ.lɪ.mˈɔv.skɪ	PM NOM	pol
# Skrzyczynski	skʂɪ.t͡ʃˈɪn.skɪ	PM NOM	pol
# Skrzynecki	skʂɪ.nˈet.skɪ	PM NOM	pol
# Skrzypulec	skʂɪ.pˈuː.lək	PM NOM	pol
# Slaski-stadion	ʂɭˈɑː.skɪ.stˌɑː.dɪ̯.ɔn	NN UTR SIN IND NOM	pol
# Slawomir	swa.vˈɔ.mɪr	PM NOM	pol
# Slawomirski	swa.vo.mˈɪr.skɪ	PM NOM	pol
# Slifirczyk	ʂɭɪ.fˈɪr.t͡ʃɪk	PM NOM	pol
# Slobodzianek	swɔ.bo.d͡ʒˈɑː.nək	PM NOM	pol
# Slubice	swo.bˈɪt.sə	PM NOM	pol
# Smektala	smek.tˈɑː.la	PM NOM	pol
# Smyczek	smˈʏ.t͡ʃek	PM NOM	pol
# Sokolnicki	sɔ.kɔl.nˈɪt.skɪ	PM NOM	pol
# Solowow	so.wˈɔ.vɔv	PM NOM	pol
# Sopot	sˈɔ.pɔt	PM NOM	pol
# Sopots	sˈɔ.pɔts	PM GEN	pol
# Soċjetajiet	sɔts.jˈɛː.ta.jət	NN	pol
# Stanicky	sta.nˈɪt.skɪ	PM NOM	pol
# Stanickys	sta.nˈɪt.skɪs	PM GEN	pol
# Stankiewicz	stˈaŋ.kə.vɪt͡ʃ	PM NOM	pol
# Stanulewicz	sta.no.lˈe.vɪt͡ʃ	PM NOM	pol
# Starega	sta.rˈeŋ.ga	PM NOM	pol
# Starogard	sta.rˈoː.gard	PM NOM	pol
# Starzynski	star.sˈɪn.skɪ	PM NOM	pol
# Stasiuk	stˈaː.ʂuk	PM NOM	pol
# Stasiuks	stˈaː.ʂuks	PM GEN	pol
# Stemplowska	stem.plˈɔfs.ka	PM NOM	pol
# Stepaniuk	ste̝.pˈa.njuk	PM NOM	pol
# Stepien	stˈe.pɪ̯.ən	PM NOM	pol
# Stoczniowiec	stɔt͡ʃ.nɪ.ˈoː.vɪk	PM NOM	pol
# Stolc	stˈɔlts	PM NOM	pol
# Strugala	stro.gˈaʊ.a	PM NOM	pol
# Strzegom	ʂʈʂˈe.gɔm	PM NOM	pol
# Sucha	sˈu.ɧa	PM NOM	pol
# Sulocki	so.lˈɔt.skɪ	PM NOM	pol
# Surowiecki	sɵ.ro.vˈet.skɪ	PM NOM	pol
# Swiatek	ʂvɪ.ˈɑːn.tək	PM NOM	pol
# Swiety	svɪ.ˈeː.tɪ	PM NOM	pol
# Swiety-Ersetic	ʂvɪ.ˈen.tɪ.er.sˈe.tɪts	PM NOM	pol
# Swinoujsce	ʂvɪ.nɔ.ˈuːj.ʂə	PM NOM	pol
# Swinoujscie	ʂvɪ.no.ˈujʂ.t͡ʃə	PM NOM	pol
# Switkowski	svɪt.kˈɔv.skɪ	PM NOM	pol
# Swoboda	sva.bˈoː.da	PM NOM	pol
# Syldatk	sˈɪl.datk	PM NOM	pol
# Sypniewski	sɪp.njˈev.skɪ	PM NOM	pol
# Syprzak	sˈɪp.ʂak	PM NOM	pol
# Szapocznikow	ʂa.pˈɔt͡ʃ.nɪ.kɔf	PM NOM	pol
# Szarkowski	ʂar.kˈɔv.skɪ	PM NOM	pol
# Szczecin	ʂt͡ʃˈeː.t͡ʃɪn	PM NOM	pol
# Szczepaniak	ʂt͡ʃe̝.pˈa.njak	PM NOM	pol
# Szczepanski	ʂt͡ʃe̝.pˈan.skɪ	PM NOM	pol
# Szczesny	ʂt͡ʃˈe.snɪ	PM NOM	pol
# Szklarski	ʂklˈar.skɪ	PM NOM	pol
# Szklarskis	ʂklˈar.skɪs	PM GEN	pol
# Szkola	ʂkˈɔ.wa	PM NOM	pol
# Szmal	ʂmˈal	PM NOM	pol
# Szpakowski	spa.kˈɔf.skɪ	PM NOM	pol
# Szreter	ʂrˈeː.tər	PM NOM	pol
# Szwoch	svˈɔʂ	PM NOM	pol
# Szyba	ʂˈɪ.ba	PM NOM	pol
# Szybers	ʂˈɪ.bərs	PM GEN	pol
# Szydlo	ʂˈɪd.vɔ	PM NOM	pol
# Szymaniak	ʂɪ.mˈɑː.nɪ̯.ak	PM NOM	pol
# Szymanowski	ʂɪ.ma.nˈɔv.skɪ	PM NOM	pol
# Szymanowskis	ʂɪ.ma.nˈɔv.skɪs	PM GEN	pol
# Szymanska	ʂɪ.mˈan.ska	PM NOM	pol
# Szymkowiak	ʂˈɪm.kɔv.jak	PM NOM	pol
# Tadeusz	ta.dˈeː.uʂ	PM NOM	pol
# Tarnacki	tar.nˈa.skɪ	PM NOM	pol
# Tarnowski	tar.nˈɔv.skɪ	PM NOM	pol
# Tchorz	t͡ʃˈɔʂ	PM NOM	pol
# Tkacz	tə.kˈat͡ʃ	PM NOM	pol
# Tobiasz	tˈoː.bɪ̯.aʂ	PM NOM	pol
# Tokarczuk	tɔ.kˈar.ʂɔk	PM NOM	pol
# Tokarczuks	to.kˈar.t͡ʃuks	PM GEN	pol
# Tomczak	tˈɔm.t͡ʃak	PM NOM	pol
# Tomek	tˈɔ.mək	PM NOM	pol
# Toporski	to.pˈɔ.ʂkɪ	PM NOM	pol
# Trawertyn	tra.vˈæ.ʈɪn	NN	pol
# Trocinski	tro.t͡ʃˈɪ.skɪ	PM NOM	pol
# Trojanow	trɔ.jˈaː.nɔf	PM NOM	pol
# Trojanows	trɔ.jˈaː.nɔfs	PM GEN	pol
# Trzaskowski	ʈʂa.skˈɔv.skɪ	PM NOM	pol
# Trzaskowskis	ʈʂa.skˈɔv.skɪs	PM GEN	pol
# Trzebinia	tʂe̝.bˈɪ.nja	PM NOM	pol
# Trzebuchowska	t͡ʃe.bo.ɧˈɔv.ska	PM NOM	pol
# Trzesniewski	tres.njˈev.skɪ	PM NOM	pol
# Turowski	tʉ.rˈɔv.skɪ	PM NOM	pol
# Tusks	tˈusks	PM GEN	pol
# Tychy	tˈɪ.ɧɪ	PM NOM	pol
# Tychys	tˈɪ.ɧɪs	PM GEN	pol
# Tyton	tˈɪ.tɔnj	PM NOM	pol
# Ulamek	ˈuː.la.mək	PM NOM	pol
# Ulica	o.lˈiːt.sa	NN	pol
# Urbanek	ur.bˈaː.nək	PM NOM	pol
# Vaculiks	vˈat.su.lɪks	PM GEN	pol
# Wachowskis	va.ɧˈɔv.skɪs	PM GEN	pol
# Wajda	vˈaj.da	PM NOM	pol
# Walasek	wa.lˈa.sək	PM NOM	pol
# Walbrzych	vˈal.brə.ʂəʂ	PM NOM	pol
# Walczykiewicz	val.t͡ʃɪk.jˈeː.vɪt͡ʃ	PM NOM	pol
# Walczykiewiczs	valt.sɪ.kjˈeː.vɪt͡ʃs	PM GEN	pol
# Walentowicz	va.lən.tˈoː.vɪt͡ʃ	PM NOM	pol
# Walesa	va.lˈen.sa	PM NOM	pol
# Walesas	va.lˈen.sas	PM GEN	pol
# Walewska	va.lˈef.ska	PM NOM	pol
# Walfisz	vˈal.fɪʂ	PM NOM	pol
# Walukiewicz	va.lo.kjˈeː.vɪt͡ʃ	PM NOM	pol
# Walukiewiczs	va.lo.kjˈeː.vɪt͡ʃs	PM GEN	pol
# Wandzia	vˈan.d͡ʒa	PM NOM	pol
# Warszewicki	va.ʂe̝.vˈɪt.skɪ	PM NOM	pol
# Warszewickis	va.ʂe̝.vˈɪt.skɪs	PM GEN	pol
# Wasick	vˈa.sɪtsk	PM NOM	pol
# Wasicks	vˈa.sɪtsks	PM GEN	pol
# Wasik	vˈa.ʂɪk	PM NOM	pol
# Wasikowska	va.sɪ.kˈɔf.ska	PM NOM	pol
# Wasilewski	va.ʂɪ.lˈev.skɪ	PM NOM	pol
# Wasowicz	va.sˈoː.vɪt͡ʃ	PM NOM	pol
# Watzlawick	vˈat.sla.vɪk	PM NOM	pol
# Wawrinka	va.vrˈɪŋ.ka	PM NOM	pol
# Wałęsa	vaʊ.ˈen.sa	PM NOM	pol
# Wieckiewicz	vjetsk.jˈe.vɪt͡ʃ	PM NOM	pol
# Wierzbicka	vjæʂ.bˈɪt.ska	PM NOM	pol
# Wierzbicki	vɪrs.bˈɪt.skɪ	PM NOM	pol
# Wiesiolek	vje̝.ʂˈɔ.wək	PM NOM	pol
# Wieslaw	vˈɪ.slav	PM NOM	pol
# Wieslawa	vˈɪ.sla.va	PM NOM	pol
# Wieslaws	vˈɪ.slavs	PM GEN	pol
# Wilczynska	vɪl.t͡ʃˈɪn.ska	PM NOM	pol
# Winczo	vˈɪn.t͡ʃɔ	PM NOM	pol
# Wislocka	vɪ.swˈɔt.ska	PM NOM	pol
# Wisniewska	vɪs.njˈef.ska	PM NOM	pol
# Wisocky	vɪ.sˈɔt.skɪ	PM NOM	pol
# Witold	vˈɪ.tɔlt	PM NOM	pol
# Wladyslaw	vwa.dˈɪ.swav	PM NOM	pol
# Wlodarczyk	vo.dˈar.ɕɪk	PM NOM	pol
# Wlodek	vˈoː.dək	PM NOM	pol
# Wloszczowska	vɔs.t͡ʃˈɔv.ska	PM NOM	pol
# Wojciech	vˈɔj.t͡ʃeɧ	PM NOM	pol
# Wojciechowski	vɔj.t͡ʃiː.ɧˈɔv.skɪ	PM NOM	pol
# Wojdak	vˈɔj.dak	PM NOM	pol
# Wojdaks	vˈɔj.daks	PM GEN	pol
# Wojdylo	vɔj.dˈiː.wu	PM NOM	pol
# Wojdynski	vɔj.dˈɪn.skɪ	PM NOM	pol
# Wojnicz	vˈɔj.nɪt͡ʃ	PM NOM	pol
# Wojtek	vˈɔj.tek	PM NOM	pol
# Wojtyla	vˈɔj.tɪ.la	PM NOM	pol
# Wolak	vˈɔ.lak	PM NOM	pol
# Wolski	vˈɔl.skɪ	PM NOM	pol
# Woryna	vo.rˈiː.na	PM NOM	pol
# Worynas	vo.rˈiː.nas	PM GEN	pol
# Wozniacki	vɔ.snɪ.ˈat.skɪ	PM NOM	pol
# Wozniackis	vɔ.snɪ.ˈat.skɪs	PM GEN	pol
# Wozzeck	vˈɔt.sək	PM NOM	pol
# Wroblewski	vro.blˈef.skɪ	PM NOM	pol
# Wroclaw	vrˈɔts.waf	PM NOM	pol
# Wroclaws	vrˈɔts.wafs	PM GEN	pol
# Wszolek	vʂˈaʊ.ək	PM NOM	pol
# Wujek	vˈu.jek	PM NOM	pol
# Wyborcza	vɪ.bˈɔr.t͡ʃa	PM NOM	pol
# Wyciszkiewicz	vɪt.sɪsk.jˈeː.vɪt͡ʃ	PM NOM	pol
# Wydrzynska	vɪdr.sˈɪn.ska	PM NOM	pol
# Wyszomirski	vɪ.ʂo.mˈɪr.skɪ	PM NOM	pol
# Wyszynska	vɪ.ʂˈɪn.ska	PM NOM	pol
# Zabia	ʂˈa.bɪ̯.a	PM NOM	pol
# Zaborowski	sa.bo.rˈɔv.skɪ	PM NOM	pol
# Zadymka	sa.dˈɪm.ka	PM NOM	pol
# Zakopane	sa.ko.pˈaː.nə	PM NOM	pol
# Zalewska	sa.lˈev.ska	PM NOM	pol
# Zalewski	sa.lˈev.skɪ	PM NOM	pol
# Zaneta	ʂa.nˈeː.ta	PM NOM	pol
# Zaplac	sˈap.wat͡ʃ	PM NOM	pol
# Zbigniew	sbˈɪg.njəf	PM NOM	pol
# Zdroj	strˈɔj	PM NOM	pol
# Zdrojs	strˈɔjs	PM GEN	pol
# Zielkowski	sɪ.əl.kˈɔv.skɪ	PM NOM	pol
# Zienkiewicz	ʂeŋk.jˈeː.vɪt͡ʃ	PM NOM	pol
# Zienkiewiczs	ʂˈeŋ.kə.vɪt͡ʃs	PM GEN	pol
# Zjitnikov	sjɪt.nˈiː.kɔv	PM NOM	pol
# Zmarzlik	smˈart.slɪk	PM NOM	pol
# Zmarzliks	smˈar.slɪks	PM GEN	pol
# Zmigrod	ʂmˈiː.groːd	PM NOM	pol
# Zmigrods	ʂmˈiː.groːds	PM GEN	pol
# Znaniecki	sna.njˈet.skɪ	PM NOM	pol
# Znanieckis	sna.njˈet.skɪs	PM GEN	pol
# Zoladz	sˈoː.lats	PM NOM	pol
# Zowczak	sˈɔv.t͡ʃak	PM NOM	pol
# Zurawski	ʂo.rˈaf.skɪ	PM NOM	pol
# Zurek	sˈuː.rək	PM NOM	pol
# Zwirydowska	svɪ.rɪ.dˈɔv.ska	PM NOM	pol
# Zygmunt	sˈɪg.munt	PM NOM	pol
# Zytomierska	sɪ.to.mjˈær.ska	PM NOM	pol
# Zytomierskas	sɪ.to.mjˈær.skas	PM GEN	pol
# bachleda-curus	baɧ.lˈeː.da.tsˈuː.ruʂ	PM NOM	pol
# barszcz	bˈarʂ	NN	pol
# [WARN] No match for phoneme: tvo
# dwomiczka	dvˈɔ.mɪ.ʂka	NN	pol
# dziewczyny	d͡ʒɪf.t͡ʃˈɪ.nɪ	NN	pol
# ekstraklasa	ˈek.stra.klɑː.sa	PM NOM	pol
# folwark	fˈɔl.vark	NN	pol
# folwarker	fˈɔl.var.kər	NN	pol
# jazzowa	jˈa.sɔ.va	NN	pol
# josek	jˈɔ.sək	PM NOM	pol
# józef	jˈoː.səf	PM NOM	pol
# larysa	la.rˈɪ.sa	PM NOM	pol
# madziarowicz	mads.ja.rˈoː.vɪt͡ʃ	PM NOM	pol
# mizeria	mɪ.sə.rˈiː.a	NN	pol
# oliwa	o.lˈɪ.va	PM NOM	pol
# orlinski	ɔr.lˈiːn.skɪ	PM NOM	pol
# pendereckis	pen.də.rˈet.skɪs	PM GEN	pol
# pięć	pjˈet͡ʃ	NN	pol
# radecka	ra.dˈet.ska	PM NOM	pol
# rudyk	rˈu.dɪk	PM NOM	pol
# ryba	rˈɪ.ba	PM NOM	pol
# slawuta	swa.vˈuː.ta	PM NOM	pol
# szymanski	ʂɪ.mˈan.skɪ	PM NOM	pol
# zbynek	sbˈɪ.nək	PM NOM	pol
# zlotkowska	slɔt.kˈɔf.ska	PM NOM	pol
# Štépnička	step.nˈɪt.ska	PM NOM	pol
# Štépničkas	step.nˈɪt.skas	PM GEN	pol
