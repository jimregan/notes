# %%
# %%capture
# !pip install youtube-dl

# %%
# !youtube-dl -f bestaudio PLtVSQEQG0xVHeyao6vZyaY3kXGfbFFiAk
# Out:
# [youtube:tab] PLtVSQEQG0xVHeyao6vZyaY3kXGfbFFiAk: Downloading webpage
# [download] Downloading playlist: Sraith 2 Ros na Rún.
# [youtube:tab] playlist Sraith 2 Ros na Rún.: Downloading 72 videos
# [download] Downloading video 1 of 72
# [youtube] f3wKxcP7hYE: Downloading webpage
# [youtube] f3wKxcP7hYE: Downloading MPD manifest
# [download] Destination: Sraith 2 Eip 1-f3wKxcP7hYE.m4a
# [download] 100% of 20.96MiB in 00:08
# [ffmpeg] Correcting container in "Sraith 2 Eip 1-f3wKxcP7hYE.m4a"
# [download] Downloading video 2 of 72
# [youtube] GWwpQqL4Pxs: Downloading webpage
# [youtube] GWwpQqL4Pxs: Downloading player 3c3086a1
# [youtube] GWwpQqL4Pxs: Downloading MPD manifest
# [download] Destination: Sraith 2 Eip 2-GWwpQqL4Pxs.m4a
# [download] 100% of 20.37MiB in 00:08
# [ffmpeg] Correcting container in "Sraith 2 Eip 2-GWwpQqL4Pxs.m4a"
# [download] Downloading video 3 of 72
# [youtube] hO45b30dmNU: Downloading webpage
# [youtube] hO45b30dmNU: Downloading MPD manifest
# ...

# %%
#!youtube-dl https://www.rte.ie/player/series/ros-na-r%C3%BAn/TG4_076876?epguid=602928
