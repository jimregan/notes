# %%
# !pip install deepspeech
# Out:
# Collecting deepspeech
#   Downloading deepspeech-0.9.3-cp37-cp37m-manylinux1_x86_64.whl (9.2 MB)
#      |▍                               | 102 kB 3.3 MB/s eta 0:00:03
#      |████                            | 1.1 MB 3.3 MB/s eta 0:00:03
#      |████████▊                       | 2.5 MB 3.3 MB/s eta 0:00:03
#      |██████████████▍                 | 4.2 MB 3.3 MB/s eta 0:00:02
#      |█████████████████████▌          | 6.2 MB 3.3 MB/s eta 0:00:01
#      |██████████████████████████████  | 8.6 MB 3.3 MB/s eta 0:00:01
#      |████████████████████████████████| 9.2 MB 3.3 MB/s eta 0:00:01
#      |████████████████████████████████| 9.2 MB 3.3 MB/s
# Requirement already satisfied: numpy>=1.14.5 in /opt/conda/lib/python3.7/site-packages (from deepspeech) (1.19.5)
# Installing collected packages: deepspeech
# Successfully installed deepspeech-0.9.3

# %%
# !for i in ../input/wolne-lektury-audio-zip/b*.zip; do unzip $i; for j in *.mp3; do base=$(basename "$j" ".mp3"); out="$base.wav"; ffmpeg -i $j -acodec pcm_s16le -ac 1 -ar 16000 $out; deepspeech --model ../input/polish-deepspeech-models/output_graph_pl.pbmm --scorer ../input/polish-deepspeech-models/kenlm_pl.scorer --json --audio $out > $base.json; rm $out $j; done; done
# Out:
# Archive:  ../input/wolne-lektury-audio-zip/bajki-i-przypowiesci-dwa-zolwie.zip
#  extracting: ignacy-krasicki-bajki-i-przypowiesci-dwa-zolwie.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# Input #0, mp3, from 'ignacy-krasicki-bajki-i-przypowiesci-dwa-zolwie.mp3':
#   Metadata:
#     title           : Ignacy Krasicki, Bajki i przypowieści, Dwa żółwie
#     artist          : Piotr Głowacki
#     album           : Wolne Lektury
#     encoder         : Lavf53.21.0
#     genre           : Speech
#     comment         : Audiobook nagrany w ramach projektu Czytamy słuchając.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     originator_reference: zmya0cWr1eaaaaGk
#     date            : 2008-09-26
#     performer       : Jakub Kowalski
#     album_artist    : Fundacja Nowoczesna Polska
#     time_reference  : 18717560
#     copyright       : 2008 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://wolnelektury.pl/katalog/lektura/bajki-i-przypowiesci-dwa-zolwie/
#     creation_time   : 0009-36-11
#     encoded_by      : Pro Tools
#     publisher       : Fundacja Nowoczesna Polska
#     id3v2_priv.wolnelektury.pl?project: Czytamy s\xc5\x82uchaj\xc4\x85c
#     id3v2_priv.wolnelektury.pl?funded_by:
#     id3v2_priv.wolnelektury.pl?flac_sha1: 154dc9db580a1d9b5902f9fcf7b45a5d81996f82
#   Duration: 00:00:31.43, start: 0.000000, bitrate: 68 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ignacy-krasicki-bajki-i-przypowiesci-dwa-zolwie.wav':
#   Metadata:
#     INAM            : Ignacy Krasicki, Bajki i przypowieści, Dwa żółwie
#     IART            : Piotr Głowacki
#     IPRD            : Wolne Lektury
#     id3v2_priv.wolnelektury.pl?funded_by:
#     IGNR            : Speech
#     ICMT            : Audiobook nagrany w ramach projektu Czytamy słuchając.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     originator_reference: zmya0cWr1eaaaaGk
#     ICRD            : 2008-09-26
#     performer       : Jakub Kowalski
#     album_artist    : Fundacja Nowoczesna Polska
#     time_reference  : 18717560
#     ICOP            : 2008 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://wolnelektury.pl/katalog/lektura/bajki-i-przypowiesci-dwa-zolwie/
#     id3v2_priv.wolnelektury.pl?flac_sha1: 154dc9db580a1d9b5902f9fcf7b45a5d81996f82
#     ITCH            : Pro Tools
#     publisher       : Fundacja Nowoczesna Polska
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?project: Czytamy s\xc5\x82uchaj\xc4\x85c
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=     983kB time=00:00:31.42 bitrate= 256.2kbits/s speed= 678x
# video:0kB audio:982kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.065632%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 13:56:48.065186: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0234s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.0236s.
# Running inference.
# Inference took 23.618s for 31.425s audio file.
# Archive:  ../input/wolne-lektury-audio-zip/bajki-i-przypowiesci-kulawy-i-slepy.zip
#  extracting: ignacy-krasicki-bajki-i-przypowiesci-kulawy-i-slepy.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# Input #0, mp3, from 'ignacy-krasicki-bajki-i-przypowiesci-kulawy-i-slepy.mp3':
#   Metadata:
#     title           : Ignacy Krasicki, Bajki i przypowieści, Kulawy i ślepy
#     artist          : Piotr Głowacki
#     album           : Wolne Lektury
#     encoder         : Lavf53.21.0
#     genre           : Speech
#     comment         : Audiobook nagrany w ramach projektu Czytamy słuchając.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     originator_reference: c4RuEbWrfioaaaGk
#     date            : 2008-09-26
#     performer       : Jakub Kowalski
#     album_artist    : Fundacja Nowoczesna Polska
#     time_reference  : 11597969
#     copyright       : 2008 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://wolnelektury.pl/katalog/lektura/bajki-i-przypowiesci-kulawy-i-slepy/
#     creation_time   : 0009-35-59
#     encoded_by      : Pro Tools
#     publisher       : Fundacja Nowoczesna Polska
#     id3v2_priv.wolnelektury.pl?flac_sha1: c1ed40e65cbd83df26ddbc9997af798270bb3e9f
#     id3v2_priv.wolnelektury.pl?project: Czytamy s\xc5\x82uchaj\xc4\x85c
#     id3v2_priv.wolnelektury.pl?funded_by:
#   Duration: 00:00:58.70, start: 0.000000, bitrate: 66 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ignacy-krasicki-bajki-i-przypowiesci-kulawy-i-slepy.wav':
#   Metadata:
#     INAM            : Ignacy Krasicki, Bajki i przypowieści, Kulawy i ślepy
#     IART            : Piotr Głowacki
#     IPRD            : Wolne Lektury
#     id3v2_priv.wolnelektury.pl?project: Czytamy s\xc5\x82uchaj\xc4\x85c
#     IGNR            : Speech
#     ICMT            : Audiobook nagrany w ramach projektu Czytamy słuchając.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     originator_reference: c4RuEbWrfioaaaGk
#     ICRD            : 2008-09-26
#     performer       : Jakub Kowalski
#     album_artist    : Fundacja Nowoczesna Polska
#     time_reference  : 11597969
#     ICOP            : 2008 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://wolnelektury.pl/katalog/lektura/bajki-i-przypowiesci-kulawy-i-slepy/
#     id3v2_priv.wolnelektury.pl?funded_by:
#     ITCH            : Pro Tools
#     publisher       : Fundacja Nowoczesna Polska
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?flac_sha1: c1ed40e65cbd83df26ddbc9997af798270bb3e9f
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=    1835kB time=00:00:58.69 bitrate= 256.1kbits/s speed= 928x
# video:0kB audio:1834kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.035457%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 13:57:12.069553: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0134s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.00232s.
# Running inference.
# Inference took 36.031s for 58.697s audio file.
# Archive:  ../input/wolne-lektury-audio-zip/bajki-i-przypowiesci-lew-i-zwierzeta.zip
#  extracting: ignacy-krasicki-bajki-i-przypowiesci-lew-i-zwierzeta.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# [mp3 @ 0x55698c710f80] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'ignacy-krasicki-bajki-i-przypowiesci-lew-i-zwierzeta.mp3':
#   Metadata:
#     title           : Ignacy Krasicki, Bajki i przypowieści, Lew i zwierzęta
#     artist          : Bartosz Mazur
#     album           : Wolne Lektury
#     date            : 2010
#     genre           : Speech
#     copyright       : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/bajki-i-przypowiesci-lew-i-zwierzeta/
#     comment         : Audiobook nagrany w ramach projektu Remiksujemy bibliotekę.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     encoder         : Lavf52.87.1
#     id3v2_priv.wolnelektury.pl?funded_by:
#     id3v2_priv.wolnelektury.pl?flac_sha1: 75256ad162e20c12d823a64205d7f0fa057a35a5
#     id3v2_priv.wolnelektury.pl?project: Remiksujemy bibliotek\xc4\x99
#   Duration: 00:01:12.96, start: 0.000000, bitrate: 65 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ignacy-krasicki-bajki-i-przypowiesci-lew-i-zwierzeta.wav':
#   Metadata:
#     INAM            : Ignacy Krasicki, Bajki i przypowieści, Lew i zwierzęta
#     IART            : Bartosz Mazur
#     IPRD            : Wolne Lektury
#     ICRD            : 2010
#     IGNR            : Speech
#     ICOP            : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/bajki-i-przypowiesci-lew-i-zwierzeta/
#     ICMT            : Audiobook nagrany w ramach projektu Remiksujemy bibliotekę.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?project: Remiksujemy bibliotek\xc4\x99
#     id3v2_priv.wolnelektury.pl?funded_by:
#     id3v2_priv.wolnelektury.pl?flac_sha1: 75256ad162e20c12d823a64205d7f0fa057a35a5
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=    2281kB time=00:01:12.96 bitrate= 256.1kbits/s speed= 842x
# video:0kB audio:2280kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.027926%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 13:57:48.501866: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0147s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.00217s.
# Running inference.
# Inference took 43.453s for 72.960s audio file.
# Archive:  ../input/wolne-lektury-audio-zip/bak-i-pilka.zip
#  extracting: bak-i-pilka.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# Input #0, mp3, from 'bak-i-pilka.mp3':
#   Metadata:
#     title           : Bąk i piłka
#     artist          : Mariusz Rzepka
#     album           : Wolne Lektury
#     date            : 0011-05-2020
#     genre           : Speech
#     encoder         : Lavf57.56.101
#     performer       : Mariusz Rzepka
#     time_reference  : 41966266
#     encoded_by      : iZotope RX 7 Audio Editor
#     album_artist    : Fundacja Nowoczesna Polska
#     publisher       : Fundacja Nowoczesna Polska
#     originator_reference: USIZTC02T4HZ3HX87200634036626664
#     umid            : 0x060A2B340101010501010F1013000000C097F37EE6618000D7E65D83A6992EB4
#     copyright       : 11.05.2020 Fundacja Nowoczesna Polska. Licensed to the public under http://artlibre.org/licence/lal/pl/ verify at https://wolnelektury.pl/katalog/lektura/bak-i-pilka/
#     comment         : Audiobook nagrany w ramach projektu "Czyta: #TataMariusz" i udostępniony na stronie  https://tatamariusz.pl.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     id3v2_priv.wolnelektury.pl?flac_sha1: 0c6ac794233b6448f5798fe60ff7fad1e9c2d38b
#     id3v2_priv.wolnelektury.pl?project: #TataMariusz
#   Duration: 00:06:12.79, start: 0.025057, bitrate: 64 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'bak-i-pilka.wav':
#   Metadata:
#     INAM            : Bąk i piłka
#     IART            : Mariusz Rzepka
#     IPRD            : Wolne Lektury
#     ICRD            : 0011-05-2020
#     IGNR            : Speech
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?project: #TataMariusz
#     performer       : Mariusz Rzepka
#     time_reference  : 41966266
#     ITCH            : iZotope RX 7 Audio Editor
#     album_artist    : Fundacja Nowoczesna Polska
#     publisher       : Fundacja Nowoczesna Polska
#     originator_reference: USIZTC02T4HZ3HX87200634036626664
#     umid            : 0x060A2B340101010501010F1013000000C097F37EE6618000D7E65D83A6992EB4
#     ICOP            : 11.05.2020 Fundacja Nowoczesna Polska. Licensed to the public under http://artlibre.org/licence/lal/pl/ verify at https://wolnelektury.pl/katalog/lektura/bak-i-pilka/
#     ICMT            : Audiobook nagrany w ramach projektu "Czyta: #TataMariusz" i udostępniony na stronie  https://tatamariusz.pl.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     id3v2_priv.wolnelektury.pl?flac_sha1: 0c6ac794233b6448f5798fe60ff7fad1e9c2d38b
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   11650kB time=00:06:12.76 bitrate= 256.0kbits/s speed= 917x
# video:0kB audio:11649kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005533%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 13:58:32.770125: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0138s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.00252s.
# Running inference.
# Inference took 256.701s for 372.764s audio file.
# Archive:  ../input/wolne-lektury-audio-zip/ballada-z-tamtej-strony-ballada-z-tamtej-strony.zip
#  extracting: jozef-czechowicz-ballada-z-tamtej-strony-tomik-ballada-z-tamtej-strony.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# [mp3 @ 0x55f833c95f80] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'jozef-czechowicz-ballada-z-tamtej-strony-tomik-ballada-z-tamtej-strony.mp3':
#   Metadata:
#     title           : Józef Czechowicz, Ballada z tamtej strony
#     artist          : Wiktor Korzeniewski
#     album           : Wolne Lektury
#     date            : 2010
#     genre           : Speech
#     copyright       : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/ballada-z-tamtej-strony-ballada-z-tamtej-strony/
#     comment         : Audiobook nagrany w ramach projektu Audiobooki lektur szkolnych dla Polonii finansowanego przez Senat RP.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     encoder         : Lavf52.87.1
#     id3v2_priv.wolnelektury.pl?flac_sha1: 07d6b277e91447b3bf0868aba695f15ac5e54fa3
#     id3v2_priv.wolnelektury.pl?funded_by: Senat RP
#     id3v2_priv.wolnelektury.pl?project: Audiobooki lektur szkolnych dla Polonii
#   Duration: 00:01:19.07, start: 0.000000, bitrate: 65 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'jozef-czechowicz-ballada-z-tamtej-strony-tomik-ballada-z-tamtej-strony.wav':
#   Metadata:
#     INAM            : Józef Czechowicz, Ballada z tamtej strony
#     IART            : Wiktor Korzeniewski
#     IPRD            : Wolne Lektury
#     ICRD            : 2010
#     IGNR            : Speech
#     ICOP            : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/ballada-z-tamtej-strony-ballada-z-tamtej-strony/
#     ICMT            : Audiobook nagrany w ramach projektu Audiobooki lektur szkolnych dla Polonii finansowanego przez Senat RP.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?project: Audiobooki lektur szkolnych dla Polonii
#     id3v2_priv.wolnelektury.pl?flac_sha1: 07d6b277e91447b3bf0868aba695f15ac5e54fa3
#     id3v2_priv.wolnelektury.pl?funded_by: Senat RP
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=    2472kB time=00:01:19.07 bitrate= 256.1kbits/s speed= 937x
# video:0kB audio:2471kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.027585%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 14:02:49.864311: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0157s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.00301s.
# Running inference.
# Inference took 47.935s for 79.073s audio file.
# Archive:  ../input/wolne-lektury-audio-zip/ballada-z-tamtej-strony-erotyk.zip
#  extracting: jozef-czechowicz-ballada-z-tamtej-strony-tomik-erotyk.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# [mp3 @ 0x562eae968f80] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'jozef-czechowicz-ballada-z-tamtej-strony-tomik-erotyk.mp3':
#   Metadata:
#     title           : Józef Czechowicz, Erotyk
#     artist          : Wiktor Korzeniewski
#     album           : Wolne Lektury
#     date            : 2010
#     genre           : Speech
#     copyright       : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/ballada-z-tamtej-strony-erotyk/
#     comment         : Audiobook nagrany w ramach projektu Audiobooki lektur szkolnych dla Polonii finansowanego przez Senat RP.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     encoder         : Lavf52.87.1
#     id3v2_priv.wolnelektury.pl?funded_by: Senat RP
#     id3v2_priv.wolnelektury.pl?project: Audiobooki lektur szkolnych dla Polonii
#     id3v2_priv.wolnelektury.pl?flac_sha1: 2ee50e2dba6ed9f5340d1b7024a9feb4544f4d85
#   Duration: 00:00:59.09, start: 0.000000, bitrate: 66 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'jozef-czechowicz-ballada-z-tamtej-strony-tomik-erotyk.wav':
#   Metadata:
#     INAM            : Józef Czechowicz, Erotyk
#     IART            : Wiktor Korzeniewski
#     IPRD            : Wolne Lektury
#     ICRD            : 2010
#     IGNR            : Speech
#     ICOP            : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/ballada-z-tamtej-strony-erotyk/
#     ICMT            : Audiobook nagrany w ramach projektu Audiobooki lektur szkolnych dla Polonii finansowanego przez Senat RP.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?flac_sha1: 2ee50e2dba6ed9f5340d1b7024a9feb4544f4d85
#     id3v2_priv.wolnelektury.pl?funded_by: Senat RP
#     id3v2_priv.wolnelektury.pl?project: Audiobooki lektur szkolnych dla Polonii
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=    1847kB time=00:00:59.08 bitrate= 256.1kbits/s speed= 877x
# video:0kB audio:1847kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.035117%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 14:03:38.167335: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0126s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.00196s.
# Running inference.
# Inference took 35.543s for 59.089s audio file.
# Archive:  ../input/wolne-lektury-audio-zip/ballada-z-tamtej-strony-imieniny.zip
#  extracting: jozef-czechowicz-ballada-z-tamtej-strony-tomik-imieniny.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# [mp3 @ 0x563e17af0f80] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'jozef-czechowicz-ballada-z-tamtej-strony-tomik-imieniny.mp3':
#   Metadata:
#     title           : Józef Czechowicz, Imieniny
#     artist          : Wiktor Korzeniewski
#     album           : Wolne Lektury
#     date            : 2010
#     genre           : Speech
#     copyright       : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/ballada-z-tamtej-strony-imieniny/
#     comment         : Audiobook nagrany w ramach projektu Audiobooki lektur szkolnych dla Polonii finansowanego przez Senat RP.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     encoder         : Lavf52.87.1
#     id3v2_priv.wolnelektury.pl?funded_by: Senat RP
#     id3v2_priv.wolnelektury.pl?project: Audiobooki lektur szkolnych dla Polonii
#     id3v2_priv.wolnelektury.pl?flac_sha1: 373f5fed25fa6526033618c709fad2b47383f0fd
#   Duration: 00:00:23.56, start: 0.000000, bitrate: 69 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'jozef-czechowicz-ballada-z-tamtej-strony-tomik-imieniny.wav':
#   Metadata:
#     INAM            : Józef Czechowicz, Imieniny
#     IART            : Wiktor Korzeniewski
#     IPRD            : Wolne Lektury
#     ICRD            : 2010
#     IGNR            : Speech
#     ICOP            : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/ballada-z-tamtej-strony-imieniny/
#     ICMT            : Audiobook nagrany w ramach projektu Audiobooki lektur szkolnych dla Polonii finansowanego przez Senat RP.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?flac_sha1: 373f5fed25fa6526033618c709fad2b47383f0fd
#     id3v2_priv.wolnelektury.pl?funded_by: Senat RP
#     id3v2_priv.wolnelektury.pl?project: Audiobooki lektur szkolnych dla Polonii
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=     737kB time=00:00:23.56 bitrate= 256.2kbits/s speed= 881x
# video:0kB audio:736kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.088594%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 14:04:14.035591: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0146s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.00176s.
# Running inference.
# Inference took 14.701s for 23.562s audio file.
# Archive:  ../input/wolne-lektury-audio-zip/ballada-z-tamtej-strony-melancholia.zip
#  extracting: jozef-czechowicz-ballada-z-tamtej-strony-tomik-melancholia.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# [mp3 @ 0x561635c27f80] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'jozef-czechowicz-ballada-z-tamtej-strony-tomik-melancholia.mp3':
#   Metadata:
#     title           : Józef Czechowicz, Melancholia
#     artist          : Wiktor Korzeniewski
#     album           : Wolne Lektury
#     date            : 2010
#     genre           : Speech
#     copyright       : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/ballada-z-tamtej-strony-melancholia/
#     comment         : Audiobook nagrany w ramach projektu Audiobooki lektur szkolnych dla Polonii finansowanego przez Senat RP.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     encoder         : Lavf52.87.1
#     id3v2_priv.wolnelektury.pl?funded_by: Senat RP
#     id3v2_priv.wolnelektury.pl?project: Audiobooki lektur szkolnych dla Polonii
#     id3v2_priv.wolnelektury.pl?flac_sha1: 5fa9826d5e5dc9c07b0eee5e16f4142504ade50e
#   Duration: 00:01:02.25, start: 0.000000, bitrate: 66 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'jozef-czechowicz-ballada-z-tamtej-strony-tomik-melancholia.wav':
#   Metadata:
#     INAM            : Józef Czechowicz, Melancholia
#     IART            : Wiktor Korzeniewski
#     IPRD            : Wolne Lektury
#     ICRD            : 2010
#     IGNR            : Speech
#     ICOP            : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/ballada-z-tamtej-strony-melancholia/
#     ICMT            : Audiobook nagrany w ramach projektu Audiobooki lektur szkolnych dla Polonii finansowanego przez Senat RP.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?flac_sha1: 5fa9826d5e5dc9c07b0eee5e16f4142504ade50e
#     id3v2_priv.wolnelektury.pl?funded_by: Senat RP
#     id3v2_priv.wolnelektury.pl?project: Audiobooki lektur szkolnych dla Polonii
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=    1946kB time=00:01:02.24 bitrate= 256.1kbits/s speed= 836x
# video:0kB audio:1945kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.033835%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 14:04:29.107813: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0169s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.00252s.
# Running inference.
# Inference took 38.884s for 62.250s audio file.
# Archive:  ../input/wolne-lektury-audio-zip/ballada-z-tamtej-strony-wiezienie.zip
#  extracting: jozef-czechowicz-ballada-z-tamtej-strony-tomik-wiezienie.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# [mp3 @ 0x55954ff1cf80] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'jozef-czechowicz-ballada-z-tamtej-strony-tomik-wiezienie.mp3':
#   Metadata:
#     title           : Józef Czechowicz, Więzienie
#     artist          : Wiktor Korzeniewski
#     album           : Wolne Lektury
#     date            : 2010
#     genre           : Speech
#     copyright       : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/ballada-z-tamtej-strony-wiezienie/
#     comment         : Audiobook nagrany w ramach projektu Audiobooki lektur szkolnych dla Polonii finansowanego przez Senat RP.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     encoder         : Lavf52.87.1
#     id3v2_priv.wolnelektury.pl?funded_by: Senat RP
#     id3v2_priv.wolnelektury.pl?project: Audiobooki lektur szkolnych dla Polonii
#     id3v2_priv.wolnelektury.pl?flac_sha1: 5dfe38874d25c2f6d47485ed866d238dac09199d
#   Duration: 00:01:15.00, start: 0.000000, bitrate: 65 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'jozef-czechowicz-ballada-z-tamtej-strony-tomik-wiezienie.wav':
#   Metadata:
#     INAM            : Józef Czechowicz, Więzienie
#     IART            : Wiktor Korzeniewski
#     IPRD            : Wolne Lektury
#     ICRD            : 2010
#     IGNR            : Speech
#     ICOP            : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/ballada-z-tamtej-strony-wiezienie/
#     ICMT            : Audiobook nagrany w ramach projektu Audiobooki lektur szkolnych dla Polonii finansowanego przez Senat RP.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?flac_sha1: 5dfe38874d25c2f6d47485ed866d238dac09199d
#     id3v2_priv.wolnelektury.pl?funded_by: Senat RP
#     id3v2_priv.wolnelektury.pl?project: Audiobooki lektur szkolnych dla Polonii
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=    2344kB time=00:01:14.99 bitrate= 256.1kbits/s speed= 842x
# video:0kB audio:2344kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.027918%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 14:05:08.383810: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.013s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.00203s.
# Running inference.
# Inference took 46.829s for 74.998s audio file.
# Archive:  ../input/wolne-lektury-audio-zip/ballada-z-tamtej-strony-zdrada.zip
#  extracting: jozef-czechowicz-ballada-z-tamtej-strony-tomik-zdrada.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# [mp3 @ 0x55594facbf80] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'jozef-czechowicz-ballada-z-tamtej-strony-tomik-zdrada.mp3':
#   Metadata:
#     title           : Józef Czechowicz, Zdrada
#     artist          : Wiktor Korzeniewski
#     album           : Wolne Lektury
#     date            : 2010
#     genre           : Speech
# ...
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     encoder         : Lavf53.21.1
#     date            : 2013
#     CONDUCTOR       : Adam Bień
#     PROJECT         : Słuchamy Polski finansowanego przez Ministerstwo Kultury i Dziedzictwa Narodowego
#     TCD             : 75617262132
#     performer       : Adam Bień
#     album_artist    : Fundacja Nowoczesna Polska
#     copyright       : 2013 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://wolnelektury.pl/katalog/lektura/balzac-komedia-ludzka-corka-ewy
#     TRANSLATOR      : Tadeusz Boy-Żeleński
#     encoded_by      : Adam Bień
#     publisher       : Fundacja Nowoczesna Polska
#     id3v2_priv.wolnelektury.pl?flac_sha1: ee42b475f5eddbdda4b9bc6554551d67fce10c52
#     id3v2_priv.wolnelektury.pl?project: S\xc5\x82uchamy  Polski
#     id3v2_priv.wolnelektury.pl?funded_by: Ministerstwo Kultury i Dziedzictwa Narodowego
#   Duration: 00:14:39.15, start: 0.000000, bitrate: 64 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '01-honore-de-balzac-corka-ewy.wav':
#   Metadata:
#     INAM            : Honore Balzac, "Córka Ewy", Część_01_01 (tłum. Tadeusz Boy-Żeleński)
#     IART            : Wiktor Korzeniewski
#     IPRD            : Wolne Lektury
#     IGNR            : 0
#     URL             : http://wolnelektury.pl/katalog/lektura/balzac-komedia-ludzka-corka-ewy
#     ICMT            : Audiobook nagrany w ramach projektu Słuchamy  Polski finansowanego przez Ministerstwo Kultury i Dziedzictwa Narodowego.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     id3v2_priv.wolnelektury.pl?funded_by: Ministerstwo Kultury i Dziedzictwa Narodowego
#     ICRD            : 2013
#     CONDUCTOR       : Adam Bień
#     PROJECT         : Słuchamy Polski finansowanego przez Ministerstwo Kultury i Dziedzictwa Narodowego
#     TCD             : 75617262132
#     performer       : Adam Bień
#     album_artist    : Fundacja Nowoczesna Polska
#     ICOP            : 2013 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://wolnelektury.pl/katalog/lektura/balzac-komedia-ludzka-corka-ewy
#     TRANSLATOR      : Tadeusz Boy-Żeleński
#     ITCH            : Adam Bień
#     publisher       : Fundacja Nowoczesna Polska
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?flac_sha1: ee42b475f5eddbdda4b9bc6554551d67fce10c52
#     id3v2_priv.wolnelektury.pl?project: S\xc5\x82uchamy  Polski
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   11776kB time=00:06:17.75 bitrate= 255.4kbits/s speed= 755x
# size=   23808kB time=00:12:43.08 bitrate= 255.6kbits/s speed= 763x
# size=   27474kB time=00:14:39.15 bitrate= 256.0kbits/s speed= 767x
# video:0kB audio:27473kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.002630%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 21:20:05.741860: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0202s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.0038s.
# Running inference.
# Inference took 824.008s for 879.151s audio file.
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# Input #0, mp3, from '02-honore-de-balzac-corka-ewy.mp3':
#   Metadata:
#     title           : Honore Balzac, "Córka Ewy", Część_02_01 (tłum. Tadeusz Boy-Żeleński)
#     artist          : Wiktor Korzeniewski
#     album           : Wolne Lektury
#     genre           : 0
#     URL             : http://wolnelektury.pl/katalog/lektura/balzac-komedia-ludzka-corka-ewy
#     comment         : Audiobook nagrany w ramach projektu Słuchamy  Polski finansowanego przez Ministerstwo Kultury i Dziedzictwa Narodowego.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     encoder         : Lavf53.21.1
#     date            : 2013
#     CONDUCTOR       : Adam Bień
#     PROJECT         : Słuchamy Polski finansowanego przez Ministerstwo Kultury i Dziedzictwa Narodowego
#     TCD             : 75617262132
#     performer       : Adam Bień
#     album_artist    : Fundacja Nowoczesna Polska
#     copyright       : 2013 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://wolnelektury.pl/katalog/lektura/balzac-komedia-ludzka-corka-ewy
#     TRANSLATOR      : Tadeusz Boy-Żeleński
#     encoded_by      : Adam Bień
#     publisher       : Fundacja Nowoczesna Polska
#     id3v2_priv.wolnelektury.pl?flac_sha1: f2a64a7e72bdb06999e769be7db74e61235e2d60
#     id3v2_priv.wolnelektury.pl?project: S\xc5\x82uchamy  Polski
#     id3v2_priv.wolnelektury.pl?funded_by: Ministerstwo Kultury i Dziedzictwa Narodowego
#   Duration: 00:32:11.00, start: 0.000000, bitrate: 64 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '02-honore-de-balzac-corka-ewy.wav':
#   Metadata:
#     INAM            : Honore Balzac, "Córka Ewy", Część_02_01 (tłum. Tadeusz Boy-Żeleński)
#     IART            : Wiktor Korzeniewski
#     IPRD            : Wolne Lektury
#     IGNR            : 0
#     URL             : http://wolnelektury.pl/katalog/lektura/balzac-komedia-ludzka-corka-ewy
#     ICMT            : Audiobook nagrany w ramach projektu Słuchamy  Polski finansowanego przez Ministerstwo Kultury i Dziedzictwa Narodowego.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     id3v2_priv.wolnelektury.pl?funded_by: Ministerstwo Kultury i Dziedzictwa Narodowego
#     ICRD            : 2013
#     CONDUCTOR       : Adam Bień
#     PROJECT         : Słuchamy Polski finansowanego przez Ministerstwo Kultury i Dziedzictwa Narodowego
#     TCD             : 75617262132
#     performer       : Adam Bień
#     album_artist    : Fundacja Nowoczesna Polska
#     ICOP            : 2013 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://wolnelektury.pl/katalog/lektura/balzac-komedia-ludzka-corka-ewy
#     TRANSLATOR      : Tadeusz Boy-Żeleński
#     ITCH            : Adam Bień
#     publisher       : Fundacja Nowoczesna Polska
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?flac_sha1: f2a64a7e72bdb06999e769be7db74e61235e2d60
#     id3v2_priv.wolnelektury.pl?project: S\xc5\x82uchamy  Polski
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   14336kB time=00:07:43.41 bitrate= 253.4kbits/s speed= 927x
# size=   29440kB time=00:15:42.13 bitrate= 256.0kbits/s speed= 942x
# size=   44032kB time=00:23:33.17 bitrate= 255.2kbits/s speed= 942x
# size=   57856kB time=00:30:52.31 bitrate= 255.9kbits/s speed= 926x
# size=   60344kB time=00:32:10.99 bitrate= 256.0kbits/s speed= 926x
# video:0kB audio:60344kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001198%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 21:33:52.205955: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0157s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.00209s.
# Running inference.
# Inference took 2181.134s for 1930.998s audio file.
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# Input #0, mp3, from '03-honore-de-balzac-corka-ewy.mp3':
#   Metadata:
#     title           : Honore Balzac, "Córka Ewy", Część_03_01 (tłum. Tadeusz Boy-Żeleński)
#     artist          : Wiktor Korzeniewski
#     album           : Wolne Lektury
#     genre           : 0
#     URL             : http://wolnelektury.pl/katalog/lektura/balzac-komedia-ludzka-corka-ewy
#     comment         : Audiobook nagrany w ramach projektu Słuchamy  Polski finansowanego przez Ministerstwo Kultury i Dziedzictwa Narodowego.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     encoder         : Lavf53.21.1
#     date            : 2013
#     CONDUCTOR       : Adam Bień
#     PROJECT         : Słuchamy Polski finansowanego przez Ministerstwo Kultury i Dziedzictwa Narodowego
#     TCD             : 75617262132
#     performer       : Adam Bień
#     album_artist    : Fundacja Nowoczesna Polska
#     copyright       : 2013 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://wolnelektury.pl/katalog/lektura/balzac-komedia-ludzka-corka-ewy
#     TRANSLATOR      : Tadeusz Boy-Żeleński
#     encoded_by      : Adam Bień
#     publisher       : Fundacja Nowoczesna Polska
#     id3v2_priv.wolnelektury.pl?project: S\xc5\x82uchamy  Polski
#     id3v2_priv.wolnelektury.pl?funded_by: Ministerstwo Kultury i Dziedzictwa Narodowego
#     id3v2_priv.wolnelektury.pl?flac_sha1: 2dac8a658cf0c1a1d2e5f1792d6e4169a3f71e60
#   Duration: 00:38:29.62, start: 0.000000, bitrate: 64 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '03-honore-de-balzac-corka-ewy.wav':
#   Metadata:
#     INAM            : Honore Balzac, "Córka Ewy", Część_03_01 (tłum. Tadeusz Boy-Żeleński)
#     IART            : Wiktor Korzeniewski
#     IPRD            : Wolne Lektury
#     IGNR            : 0
#     URL             : http://wolnelektury.pl/katalog/lektura/balzac-komedia-ludzka-corka-ewy
#     ICMT            : Audiobook nagrany w ramach projektu Słuchamy  Polski finansowanego przez Ministerstwo Kultury i Dziedzictwa Narodowego.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     id3v2_priv.wolnelektury.pl?flac_sha1: 2dac8a658cf0c1a1d2e5f1792d6e4169a3f71e60
#     ICRD            : 2013
#     CONDUCTOR       : Adam Bień
#     PROJECT         : Słuchamy Polski finansowanego przez Ministerstwo Kultury i Dziedzictwa Narodowego
#     TCD             : 75617262132
#     performer       : Adam Bień
#     album_artist    : Fundacja Nowoczesna Polska
#     ICOP            : 2013 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://wolnelektury.pl/katalog/lektura/balzac-komedia-ludzka-corka-ewy
#     TRANSLATOR      : Tadeusz Boy-Żeleński
#     ITCH            : Adam Bień
#     publisher       : Fundacja Nowoczesna Polska
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?project: S\xc5\x82uchamy  Polski
#     id3v2_priv.wolnelektury.pl?funded_by: Ministerstwo Kultury i Dziedzictwa Narodowego
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   12800kB time=00:06:55.52 bitrate= 252.3kbits/s speed= 831x
# size=   25856kB time=00:13:53.90 bitrate= 254.0kbits/s speed= 834x
# size=   39168kB time=00:21:00.40 bitrate= 254.6kbits/s speed= 840x
# size=   52480kB time=00:28:01.10 bitrate= 255.7kbits/s speed= 841x
# size=   66048kB time=00:35:15.42 bitrate= 255.8kbits/s speed= 846x
# size=   72176kB time=00:38:29.61 bitrate= 256.0kbits/s speed= 845x
# video:0kB audio:72176kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001001%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 22:10:16.473761: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0165s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.0021s.
# Running inference.
# Inference took 2715.864s for 2309.616s audio file.
