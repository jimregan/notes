# %%
# !pip install deepspeech
# Out:
# Collecting deepspeech
#   Downloading deepspeech-0.9.3-cp37-cp37m-manylinux1_x86_64.whl (9.2 MB)
#      |████████████████████████████████| 9.2 MB 7.3 MB/s
# Requirement already satisfied: numpy>=1.14.5 in /opt/conda/lib/python3.7/site-packages (from deepspeech) (1.19.5)
# Installing collected packages: deepspeech
# Successfully installed deepspeech-0.9.3

# %%
# !for i in ../input/wolne-lektury-audio-zip/a*.zip; do unzip $i; for j in *.mp3; do base=$(basename "$j" ".mp3"); out="$base.wav"; ffmpeg -i $j -acodec pcm_s16le -ac 1 -ar 16000 $out; deepspeech --model ../input/polish-deepspeech-models/output_graph_pl.pbmm --scorer ../input/polish-deepspeech-models/kenlm_pl.scorer --json --audio $out > $base.json; rm $out $j; done; done
# Out:
# Archive:  ../input/wolne-lektury-audio-zip/abuzei-i-tair.zip
#  extracting: ignacy-krasicki-bajki-i-przypowiesci-abuzei-i-tair.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# [mp3 @ 0x557e4892df80] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'ignacy-krasicki-bajki-i-przypowiesci-abuzei-i-tair.mp3':
#   Metadata:
#     title           : Ignacy Krasicki, Bajki i przypowieści, Abuzei i Tair
#     artist          : Bartosz Mazur
#     album           : Wolne Lektury
#     date            : 2010
#     genre           : Speech
#     copyright       : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/abuzei-i-tair/
#     comment         : Audiobook nagrany w ramach projektu Remiksujemy bibliotekę.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     encoder         : Lavf52.87.1
#     id3v2_priv.wolnelektury.pl?funded_by:
#     id3v2_priv.wolnelektury.pl?project: Remiksujemy bibliotek\xc4\x99
#     id3v2_priv.wolnelektury.pl?flac_sha1: 66db29748ebefe975e4db11f2580f19713dbe576
#   Duration: 00:00:41.95, start: 0.000000, bitrate: 67 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ignacy-krasicki-bajki-i-przypowiesci-abuzei-i-tair.wav':
#   Metadata:
#     INAM            : Ignacy Krasicki, Bajki i przypowieści, Abuzei i Tair
#     IART            : Bartosz Mazur
#     IPRD            : Wolne Lektury
#     ICRD            : 2010
#     IGNR            : Speech
#     ICOP            : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/abuzei-i-tair/
#     ICMT            : Audiobook nagrany w ramach projektu Remiksujemy bibliotekę.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?flac_sha1: 66db29748ebefe975e4db11f2580f19713dbe576
#     id3v2_priv.wolnelektury.pl?funded_by:
#     id3v2_priv.wolnelektury.pl?project: Remiksujemy bibliotek\xc4\x99
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=    1312kB time=00:00:41.95 bitrate= 256.1kbits/s speed= 594x
# video:0kB audio:1311kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.046481%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 01:39:26.917987: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0226s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.0276s.
# Running inference.
# Inference took 31.245s for 41.953s audio file.
# Archive:  ../input/wolne-lektury-audio-zip/akslop.zip
#  extracting: milosz-biedrzycki-akslop.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# [mp3 @ 0x55edc0149f80] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'milosz-biedrzycki-akslop.mp3':
#   Metadata:
#     title           : Miłosz Biedrzycki, Akslop
#     artist          : Wiktor Korzeniewski
#     album           : Wolne Lektury
#     date            : 2010
#     genre           : Speech
#     copyright       : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/akslop/
#     comment         : Audiobook nagrany w ramach projektu Audiobooki lektur szkolnych dla Polonii finansowanego przez Senat RP.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     encoder         : Lavf52.87.1
#     id3v2_priv.wolnelektury.pl?funded_by: Senat RP
#     id3v2_priv.wolnelektury.pl?project: Audiobooki lektur szkolnych dla Polonii
#     id3v2_priv.wolnelektury.pl?flac_sha1: a10440b599638046681e166e407f56424a6299a1
#   Duration: 00:00:45.17, start: 0.000000, bitrate: 67 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'milosz-biedrzycki-akslop.wav':
#   Metadata:
#     INAM            : Miłosz Biedrzycki, Akslop
#     IART            : Wiktor Korzeniewski
#     IPRD            : Wolne Lektury
#     ICRD            : 2010
#     IGNR            : Speech
#     ICOP            : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/akslop/
#     ICMT            : Audiobook nagrany w ramach projektu Audiobooki lektur szkolnych dla Polonii finansowanego przez Senat RP.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?flac_sha1: a10440b599638046681e166e407f56424a6299a1
#     id3v2_priv.wolnelektury.pl?funded_by: Senat RP
#     id3v2_priv.wolnelektury.pl?project: Audiobooki lektur szkolnych dla Polonii
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=    1412kB time=00:00:45.16 bitrate= 256.1kbits/s speed= 705x
# video:0kB audio:1411kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.044420%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 01:39:58.613852: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0142s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.00276s.
# Running inference.
# Inference took 30.123s for 45.166s audio file.
# Archive:  ../input/wolne-lektury-audio-zip/andersen-motylek.zip
#  extracting: motylek.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# Input #0, mp3, from 'motylek.mp3':
#   Metadata:
#     title           : Motylek
#     artist          : Mariusz Rzepka
#     album           : Wolne Lektury
#     date            : 0011-05-2020
#     genre           : Speech
#     encoder         : Lavf57.56.101
#     performer       : Mariusz Rzepka
#     time_reference  : 78379930
#     encoded_by      : iZotope RX 7 Audio Editor
#     album_artist    : Fundacja Nowoczesna Polska
#     publisher       : Fundacja Nowoczesna Polska
#     originator_reference: USIZTC02T4HZ3HX87195436076624924
#     umid            : 0x060A2B340101010501010F1013000000A39C41ADE66080005E8C5D83A6992EB4
#     copyright       : 11.05.2020 Fundacja Nowoczesna Polska. Licensed to the public under http://artlibre.org/licence/lal/pl/ verify at https://wolnelektury.pl/katalog/lektura/andersen-motylek/
#     comment         : Audiobook nagrany w ramach projektu "Czyta: #TataMariusz" i udostępniony na stronie  https://tatamariusz.pl.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     id3v2_priv.wolnelektury.pl?flac_sha1: e611918184e79a78d67e3df6a0ca22c3af1384cc
#     id3v2_priv.wolnelektury.pl?project: #TataMariusz
#   Duration: 00:06:15.01, start: 0.025057, bitrate: 64 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'motylek.wav':
#   Metadata:
#     INAM            : Motylek
#     IART            : Mariusz Rzepka
#     IPRD            : Wolne Lektury
#     ICRD            : 0011-05-2020
#     IGNR            : Speech
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?project: #TataMariusz
#     performer       : Mariusz Rzepka
#     time_reference  : 78379930
#     ITCH            : iZotope RX 7 Audio Editor
#     album_artist    : Fundacja Nowoczesna Polska
#     publisher       : Fundacja Nowoczesna Polska
#     originator_reference: USIZTC02T4HZ3HX87195436076624924
#     umid            : 0x060A2B340101010501010F1013000000A39C41ADE66080005E8C5D83A6992EB4
#     ICOP            : 11.05.2020 Fundacja Nowoczesna Polska. Licensed to the public under http://artlibre.org/licence/lal/pl/ verify at https://wolnelektury.pl/katalog/lektura/andersen-motylek/
#     ICMT            : Audiobook nagrany w ramach projektu "Czyta: #TataMariusz" i udostępniony na stronie  https://tatamariusz.pl.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     id3v2_priv.wolnelektury.pl?flac_sha1: e611918184e79a78d67e3df6a0ca22c3af1384cc
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   11718kB time=00:06:14.96 bitrate= 256.0kbits/s speed= 787x
# video:0kB audio:11718kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005484%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 01:40:29.604275: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0161s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.00365s.
# Running inference.
# Inference took 298.004s for 374.969s audio file.
# Archive:  ../input/wolne-lektury-audio-zip/aniol-pasterzom-mowil.zip
#  extracting: autor-nieznany-aniol-pasterzom-mowil.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# Input #0, mp3, from 'autor-nieznany-aniol-pasterzom-mowil.mp3':
#   Metadata:
#     title           : Anioł pasterzom mówił
#     artist          : Studio Accantus
#     track           : 2
#     album           : Wolne Lektury
#     disc            : 1
#     URL             : www.accantus.info/koledy
#     genre           : Speech
#     ENCODER SETTINGS: -compression-level-5
#     comment         : Audiobook nagrany w ramach projektu Kolędy polskie finansowanego przez Stowarzyszenie Wikimedia Polska. Kolęda polska w wykonaniu artystów Studia Accantus powstała we współpracy ze Stowarzyszeniem Wikimedia Polska.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     encoder         : Lavf53.21.1
#     date            : 2014
#     TRACKTOTAL      : 14
#     album_artist    : Fundacja Nowoczesna Polska
#     performer       : Bartłomiej Kozielski - Studio Accantus
#     copyright       : 2014 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://wolnelektury.pl/katalog/lektura/aniol-pasterzom-mowil
#     ACCURATERIPDISCID: 014-00178998-00fc1395-c90ad70e-2
#     ACCURATERIPRESULT: AccurateRip: Not in database   [1C21FAEA]
#     SOURCE          : CD (Lossless)
#     DISCTOTAL       : 1
#     ENCODED BY      : dBpoweramp Release 14.4
#     publisher       : Fundacja Nowoczesna Polska
#     LOCATION        : www.accantus.info/koledy
#     id3v2_priv.wolnelektury.pl?flac_sha1: b65939cf7c7720875ea23fc57be4d0be4588a595
#     id3v2_priv.wolnelektury.pl?funded_by: Stowarzyszenie Wikimedia Polska. Kol\xc4\x99da polska w wykonaniu artyst\xc3\xb3w Studia Accantus powsta\xc5\x82a we wsp\xc3\xb3\xc5\x82pracy ze Stowarzyszeniem Wikimedia Polska
#     id3v2_priv.wolnelektury.pl?project: Kol\xc4\x99dy polskie
#   Duration: 00:03:11.09, start: 0.000000, bitrate: 64 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'autor-nieznany-aniol-pasterzom-mowil.wav':
#   Metadata:
#     INAM            : Anioł pasterzom mówił
#     IART            : Studio Accantus
#     IPRT            : 2
#     IPRD            : Wolne Lektury
#     disc            : 1
#     URL             : www.accantus.info/koledy
#     IGNR            : Speech
#     ENCODER SETTINGS: -compression-level-5
#     ICMT            : Audiobook nagrany w ramach projektu Kolędy polskie finansowanego przez Stowarzyszenie Wikimedia Polska. Kolęda polska w wykonaniu artystów Studia Accantus powstała we współpracy ze Stowarzyszeniem Wikimedia Polska.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     id3v2_priv.wolnelektury.pl?project: Kol\xc4\x99dy polskie
#     ICRD            : 2014
#     TRACKTOTAL      : 14
#     album_artist    : Fundacja Nowoczesna Polska
#     performer       : Bartłomiej Kozielski - Studio Accantus
#     ICOP            : 2014 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://wolnelektury.pl/katalog/lektura/aniol-pasterzom-mowil
#     ACCURATERIPDISCID: 014-00178998-00fc1395-c90ad70e-2
#     ACCURATERIPRESULT: AccurateRip: Not in database   [1C21FAEA]
#     SOURCE          : CD (Lossless)
#     DISCTOTAL       : 1
#     ENCODED BY      : dBpoweramp Release 14.4
#     publisher       : Fundacja Nowoczesna Polska
#     LOCATION        : www.accantus.info/koledy
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?flac_sha1: b65939cf7c7720875ea23fc57be4d0be4588a595
#     id3v2_priv.wolnelektury.pl?funded_by: Stowarzyszenie Wikimedia Polska. Kol\xc4\x99da polska w wykonaniu artyst\xc3\xb3w Studia Accantus powsta\xc5\x82a we wsp\xc3\xb3\xc5\x82pracy ze Stowarzyszeniem Wikimedia Polska
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=    5972kB time=00:03:11.08 bitrate= 256.0kbits/s speed= 793x
# video:0kB audio:5971kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012625%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 01:45:28.238088: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0179s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.00619s.
# Running inference.
# Inference took 128.637s for 191.086s audio file.
# Archive:  ../input/wolne-lektury-audio-zip/aniol.zip
#  extracting: aniol.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# Input #0, mp3, from 'aniol.mp3':
#   Metadata:
#     title           : Anioł
#     artist          : Mariusz Rzepka
#     album           : Wolne Lektury
#     date            : 0011-05-2020
#     genre           : Speech
#     encoder         : Lavf57.56.101
#     performer       : Mariusz Rzepka
#     time_reference  : 24170093
#     encoded_by      : iZotope RX 7 Audio Editor
#     album_artist    : Fundacja Nowoczesna Polska
#     publisher       : Fundacja Nowoczesna Polska
#     originator_reference: USIZTC02T4HZ3HX87195437459111350
#     umid            : 0x060A2B340101010501010F101300000092E0AC9DE660800079BC5D83A6992EB4
#     copyright       : 11.05.2020 Fundacja Nowoczesna Polska. Licensed to the public under http://artlibre.org/licence/lal/pl/ verify at https://wolnelektury.pl/katalog/lektura/aniol/
#     comment         : Audiobook nagrany w ramach projektu "Czyta: #TataMariusz" i udostępniony na stronie  https://tatamariusz.pl.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     id3v2_priv.wolnelektury.pl?flac_sha1: 8590515082f81407cd3e73e00e26c491f530c023
#     id3v2_priv.wolnelektury.pl?project: #TataMariusz
#   Duration: 00:06:40.98, start: 0.025057, bitrate: 64 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'aniol.wav':
#   Metadata:
#     INAM            : Anioł
#     IART            : Mariusz Rzepka
#     IPRD            : Wolne Lektury
#     ICRD            : 0011-05-2020
#     IGNR            : Speech
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?project: #TataMariusz
#     performer       : Mariusz Rzepka
#     time_reference  : 24170093
#     ITCH            : iZotope RX 7 Audio Editor
#     album_artist    : Fundacja Nowoczesna Polska
#     publisher       : Fundacja Nowoczesna Polska
#     originator_reference: USIZTC02T4HZ3HX87195437459111350
#     umid            : 0x060A2B340101010501010F101300000092E0AC9DE660800079BC5D83A6992EB4
#     ICOP            : 11.05.2020 Fundacja Nowoczesna Polska. Licensed to the public under http://artlibre.org/licence/lal/pl/ verify at https://wolnelektury.pl/katalog/lektura/aniol/
#     ICMT            : Audiobook nagrany w ramach projektu "Czyta: #TataMariusz" i udostępniony na stronie  https://tatamariusz.pl.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     id3v2_priv.wolnelektury.pl?flac_sha1: 8590515082f81407cd3e73e00e26c491f530c023
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   12530kB time=00:06:40.94 bitrate= 256.0kbits/s speed= 773x
# video:0kB audio:12529kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005051%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 01:47:37.818842: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0165s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.00322s.
# Running inference.
# Inference took 317.858s for 400.944s audio file.
# Archive:  ../input/wolne-lektury-audio-zip/antek.zip
#  extracting: boleslaw-prus-antek.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# [mp3 @ 0x55a5a64a3f80] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'boleslaw-prus-antek.mp3':
#   Metadata:
#     title           : Bolesław Prus, Antek
#     artist          : Jan Peszek
#     album           : Wolne Lektury
#     date            : 2009
#     genre           : Speech
#     copyright       : 2009 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/antek/
#     comment         : Audiobook nagrany w ramach projektu Rymy, pętle, rytmy finansowanego przez Akademia Orange.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     encoder         : Lavf52.87.1
#     id3v2_priv.wolnelektury.pl?flac_sha1: 0db66d83e059b292c04c393e9880e4aa213cc989
#     id3v2_priv.wolnelektury.pl?project: Rymy, p\xc4\x99tle, rytmy
#     id3v2_priv.wolnelektury.pl?funded_by: Akademia Orange
#   Duration: 01:02:07.80, start: 0.000000, bitrate: 64 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'boleslaw-prus-antek.wav':
#   Metadata:
#     INAM            : Bolesław Prus, Antek
#     IART            : Jan Peszek
#     IPRD            : Wolne Lektury
#     ICRD            : 2009
#     IGNR            : Speech
#     ICOP            : 2009 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/antek/
#     ICMT            : Audiobook nagrany w ramach projektu Rymy, pętle, rytmy finansowanego przez Akademia Orange.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?funded_by: Akademia Orange
#     id3v2_priv.wolnelektury.pl?flac_sha1: 0db66d83e059b292c04c393e9880e4aa213cc989
#     id3v2_priv.wolnelektury.pl?project: Rymy, p\xc4\x99tle, rytmy
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=  116494kB time=01:02:07.80 bitrate= 256.0kbits/s speed= 740x
# video:0kB audio:116494kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000515%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 01:53:01.639365: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0212s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.0065s.
# Running inference.
# Inference took 6817.068s for 3727.804s audio file.
# Archive:  ../input/wolne-lektury-audio-zip/aptekarzowa.zip
#  extracting: anton-czechow-aptekarzowa.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# [mp3 @ 0x55a0bf195f80] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'anton-czechow-aptekarzowa.mp3':
#   Metadata:
#     title           : Anton Czechow, Aptekarzowa (tłum. A. W.)
#     artist          : Wiktor Korzeniewski
#     album           : Wolne Lektury
#     date            : 2010
#     genre           : Speech
#     copyright       : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/aptekarzowa/
#     comment         : Audiobook nagrany w ramach projektu Słuchamy Polski finansowanego przez Senat RP.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     encoder         : Lavf52.87.1
#     id3v2_priv.wolnelektury.pl?funded_by: Senat RP
#     id3v2_priv.wolnelektury.pl?flac_sha1: b0074a9fab681070577200f61fdcf43d47f011a9
#     id3v2_priv.wolnelektury.pl?project: S\xc5\x82uchamy Polski
#   Duration: 00:13:53.12, start: 0.000000, bitrate: 64 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'anton-czechow-aptekarzowa.wav':
#   Metadata:
#     INAM            : Anton Czechow, Aptekarzowa (tłum. A. W.)
#     IART            : Wiktor Korzeniewski
#     IPRD            : Wolne Lektury
#     ICRD            : 2010
#     IGNR            : Speech
#     ICOP            : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/aptekarzowa/
#     ICMT            : Audiobook nagrany w ramach projektu Słuchamy Polski finansowanego przez Senat RP.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?project: S\xc5\x82uchamy Polski
#     id3v2_priv.wolnelektury.pl?funded_by: Senat RP
#     id3v2_priv.wolnelektury.pl?flac_sha1: b0074a9fab681070577200f61fdcf43d47f011a9
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=   26036kB time=00:13:53.12 bitrate= 256.0kbits/s speed= 751x
# video:0kB audio:26035kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.002393%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 03:46:40.738453: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0182s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.00544s.
# Running inference.
# Inference took 668.193s for 833.123s audio file.
# Archive:  ../input/wolne-lektury-audio-zip/atlas-i-kitaj.zip
#  extracting: ignacy-krasicki-bajki-i-przypowiesci-atlas-i-kitaj.mp3
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Unknown attached picture mimetype: ('image/png', None), skipping.
# [mp3 @ 0x564d6ced9f80] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'ignacy-krasicki-bajki-i-przypowiesci-atlas-i-kitaj.mp3':
#   Metadata:
#     title           : Ignacy Krasicki, Bajki i przypowieści, Atłas i kitaj
#     artist          : Bartosz Mazur
#     album           : Wolne Lektury
#     date            : 2010
#     genre           : Speech
#     copyright       : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/atlas-i-kitaj/
#     comment         : Audiobook nagrany w ramach projektu Remiksujemy bibliotekę.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     encoder         : Lavf52.87.1
#     id3v2_priv.wolnelektury.pl?funded_by:
#     id3v2_priv.wolnelektury.pl?flac_sha1: 4631f80fb9c99fdff7b53212460b4f68c53c8b6f
#     id3v2_priv.wolnelektury.pl?project: Remiksujemy bibliotek\xc4\x99
#   Duration: 00:00:37.38, start: 0.000000, bitrate: 67 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ignacy-krasicki-bajki-i-przypowiesci-atlas-i-kitaj.wav':
#   Metadata:
#     INAM            : Ignacy Krasicki, Bajki i przypowieści, Atłas i kitaj
#     IART            : Bartosz Mazur
#     IPRD            : Wolne Lektury
#     ICRD            : 2010
#     IGNR            : Speech
#     ICOP            : 2010 Fundacja Nowoczesna Polska. Licensed to the public under http://creativecommons.org/licenses/by-sa/3.0/deed.pl verify at http://www.wolnelektury.pl/katalog/lektura/atlas-i-kitaj/
#     ICMT            : Audiobook nagrany w ramach projektu Remiksujemy bibliotekę.
#                     :
#                     : Przekaż 1% podatku na rozwój Wolnych Lektur:
#                     : Fundacja Nowoczesna Polska
#                     : KRS 0000070056
#                     : http://nowoczesnapolska.org.pl/wesprzyj_nas/
#                     :
#     publisher       : Fundacja Nowoczesna Polska
#     performer       : Marcin Cisło
#     album_artist    : Fundacja Nowoczesna Polska
#     ILNG            : pol
#     id3v2_priv.wolnelektury.pl?project: Remiksujemy bibliotek\xc4\x99
#     id3v2_priv.wolnelektury.pl?funded_by:
#     id3v2_priv.wolnelektury.pl?flac_sha1: 4631f80fb9c99fdff7b53212460b4f68c53c8b6f
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.91.100 pcm_s16le
# size=    1169kB time=00:00:37.38 bitrate= 256.1kbits/s speed= 723x
# video:0kB audio:1168kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.052332%
# Loading model from file ../input/polish-deepspeech-models/output_graph_pl.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2021-05-23 03:57:49.398554: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded model in 0.0166s.
# Loading scorer from files ../input/polish-deepspeech-models/kenlm_pl.scorer
# Loaded scorer in 0.00495s.
# Running inference.
# Inference took 25.054s for 37.381s audio file.
