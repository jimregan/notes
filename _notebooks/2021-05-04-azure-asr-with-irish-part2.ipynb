# %% [markdown]
# # "Azure speech recognition for Irish"
# > "Authentication is a bit of a pain; recognition is fantastic, but let down by number inverse normalisation"
#
# - toc: false
# - branch: master
# - comments: true
# - categories: [azure, irish, asr]

# %%
# %%capture
# !pip install azure-cognitiveservices-speech
# !pip install youtube-dl

# %%
# %%capture
# !youtube-dl https://www.youtube.com/watch?v=cfjdfaqWY3Y

# %%
import azure.cognitiveservices.speech as speechsdk

# %% [markdown]
# Use either Key1 or Key2 (on [Azure Portal](https://portal.azure.com/), in "Keys and Endpoints" from the menu on the left hand side of the screen).

# %%
_SUBS=input('put your subscription key here: ')

# %%
_LOC='westeurope'

# %%
speech_config = speechsdk.SpeechConfig(region=_LOC, subscription=_SUBS)

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/6/60/MSF_chapter_3.ogg https://upload.wikimedia.org/wikipedia/commons/e/ee/MSF_chapter_4.ogg https://upload.wikimedia.org/wikipedia/commons/b/b3/MSF_chapter_5.ogg https://upload.wikimedia.org/wikipedia/commons/2/21/MSF_chapter_6.ogg https://upload.wikimedia.org/wikipedia/commons/7/71/MSF_chapter_7.ogg https://upload.wikimedia.org/wikipedia/commons/d/d5/MSF_chapter_8.ogg

# %%
# !ffmpeg -i MSF_chapter_5.ogg -acodec pcm_s16le -ac 1 -ar 16000 MSF_chapter_5.wav

# %%
speech_config.speech_recognition_language = 'ga-IE'
speech_config.request_word_level_timestamps()
speech_config.output_format = speechsdk.OutputFormat(1)
speech_config.endpoint_id=f'https://{_LOC}.api.cognitive.microsoft.com/sts/v1.0/issuetoken'

# %%
# https://github.com/Azure-Samples/cognitive-services-speech-sdk/blob/master/samples/python/console/speech_sample.py
# Copyright (c) Microsoft. All rights reserved.
# Licensed under the MIT license. See LICENSE.md file in the project root for full license information.
import time
import json
def speech_recognize_continuous_from_file(speech_config, filename):
    """performs continuous speech recognition with input from an audio file"""
    speech_config = speech_config
    audio_config = speechsdk.audio.AudioConfig(filename=filename)
    outfilename = filename.replace('.wav', '.json')
    outfile = open(outfilename, 'a')


    speech_recognizer = speechsdk.SpeechRecognizer(speech_config=speech_config, language='ga-IE', audio_config=audio_config)

    done = False

    def stop_cb(evt):
        """callback that signals to stop continuous recognition upon receiving an event `evt`"""
        print('CLOSING on {}'.format(evt))
        nonlocal done
        done = True

    def cancelled(evt):
      result = evt.result
      cancellation_details = result.cancellation_details
      print("Speech Recognition canceled: {}".format(cancellation_details.reason))
      if cancellation_details.reason == speechsdk.CancellationReason.Error:
        print("Error details: {}".format(cancellation_details.error_details))

    def recognised(evt):
      response = json.loads(evt.result.json)
      outfile.write('{}\n'.format(evt.result.json))

    # Connect callbacks to the events fired by the speech recognizer
    speech_recognizer.recognizing.connect(lambda evt: print('RECOGNIZING: {}'.format(evt)))
    speech_recognizer.recognized.connect(recognised)
    speech_recognizer.session_started.connect(lambda evt: print('SESSION STARTED: {}'.format(evt)))
    speech_recognizer.session_stopped.connect(lambda evt: print('SESSION STOPPED {}'.format(evt)))
    speech_recognizer.canceled.connect(cancelled)
    # stop continuous recognition on either session stopped or canceled events
    speech_recognizer.session_stopped.connect(stop_cb)
    speech_recognizer.canceled.connect(stop_cb)

    # Start continuous speech recognition
    speech_recognizer.start_continuous_recognition()
    while not done:
        time.sleep(.5)

    speech_recognizer.stop_continuous_recognition()
    outfile.close()

# %%
for i in "345678":
  speech_recognize_continuous_from_file(speech_config, f'MSF_chapter_{i}.wav')
# Out:
# Streaming output truncated to the last 5000 lines.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=b6cfd91490274f34a4fb0a3db510af66, text="nuair a chonaic 6 cad é an gnó a bhí don", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=5258c6a2374f4e41ab1b2a40483bb573, text="nuair a chonaic 6 cad é an gnó a bhí don cad a bhí", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=fed59bd81f5845f69754ad270098b0fc, text="nuair a chonaic 6 cad é an gnó a bhí don cad a bhí bhí", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=0fb547ef62554b98b119281e383e2e01, text="nuair a chonaic 6 cad é an gnó a bhí don cad a bhí bhí spórt acu", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=9ee94305984f4a31b1830fc6ddcce6be, text="tha", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=0a35e535656d452684561c26ea14a065, text="tháinig an", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=812b60dcc9f841b7bb23adea2aa60de6, text="tháinig an gorta", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=5ccabe021fde4c47ad1ecf0d51a9cee1, text="tháinig an gorta agus", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=203702cdae014699b8742cc578a4669f, text="tháinig an gorta agus b'éigean", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=6546adc4522e4510ae68b300bf3b6165, text="tháinig an gorta agus b'éigean do", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=87e3322314d44df3ba335c564d790cdc, text="tháinig an gorta agus b'éigean do shíle", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=06e80fbdce1d4d0cbc3ffd2710a97c60, text="tháinig an gorta agus b'éigean do shíle agus", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=44bcf339807b428fa66126f9b128d27b, text="tháinig an gorta agus b'éigean do shíle agus dá", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=56d4e848ed1e42008ea9a9c80f3927ba, text="tháinig an gorta agus b'éigean do shíle agus dá hathair", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=4e8efc5d4cc44aac9e111126121d1a59, text="tháinig an gorta agus b'éigean do shíle agus dá hathair is dá", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=d05e37c709264d91b9d44a8549ffa913, text="tháinig an gorta agus b'éigean do shíle agus dá hathair is dá mba", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=51392a51ab8c45eeb84e560433f09e28, text="tháinig an gorta agus b'éigean do shíle agus dá hathair agus dá máthair", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=8d0a19a1187f45a285e26fdec4846fca, text="tháinig an gorta agus b'éigean do shíle agus dá hathair agus dá máthair agus do", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=ef5a711d7bbf4d3d838d93268d1364b2, text="tháinig an gorta agus b'éigean do shíle agus dá hathair agus dá máthair agus do dhiarmuidín", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=362cfa0345364e2496dc97c0f026bf33, text="tháinig an gorta agus b'éigean do shíle agus dá hathair agus dá máthair agus do dhiarmuidín i", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=d62636be3f284b93ac304b032e45f0f6, text="tháinig an gorta agus b'éigean do shíle agus dá hathair agus dá máthair agus do dhiarmuidín imtheacht síos", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=fa213e96b87449a8923100aac4e4c081, text="tháinig an gorta agus b'éigean do shíle agus dá hathair agus dá máthair agus do dhiarmuidín imtheacht síos go moch", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=697899ff8c0a4907a4e9fc784156fcc2, text="tháinig an gorta agus b'éigean do shíle agus dá hathair agus dá máthair agus do dhiarmuidín imtheacht síos do mo chrá", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=ef18b3bfe6824125994db1f5b0b47633, text="tháinig an gorta agus b'éigean do shíle agus dá hathair agus dá máthair agus do dhiarmuidín imtheacht síos go mion dhráma", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=e523856e7ef84756a9b9832f921891b7, text="tháinig an gorta agus b'éigean do shíle agus dá hathair agus dá máthair agus do dhiarmuidín imtheacht síos go moch fhráma", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=cf903bdd90114639b217d1b57f85d006, text="tháinig an gorta agus b'éigean do shíle agus dá hathair agus dá máthair agus do dhiarmuidín imtheacht síos go mion dhráma", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=c6257714e3154e93a15c295888730c20, text="tháinig an gorta agus b'éigean do shíle agus dá hathair agus dá máthair agus do dhiarmuidín imtheacht síos go mion dhráma agus", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=fcc6780df8e64669add1c9349930e87e, text="tháinig an gorta agus b'éigean do shíle agus dá hathair agus dá máthair agus do dhiarmuidín imtheacht síos go mion dhráma agus dul", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=30963be38b9849c9a5183b1abcfdf70a, text="tháinig an gorta agus b'éigean do shíle agus dá hathair agus dá máthair agus do dhiarmuidín imtheacht síos go mion dhráma agus dul isteach", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=c112a1baae71419e9567ea4309ed685f, text="tháinig an gorta agus b'éigean do shíle agus dá hathair agus dá máthair agus do dhiarmuidín imtheacht síos go mion dhráma agus dul isteach i dtigh", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=8daec30d98864e34956d8605a6481d4d, text="tháinig an gorta agus b'éigean do shíle agus dá hathair agus dá máthair agus do dhiarmuidín imtheacht síos go mion dhráma agus dul isteach i dtigh na mba", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=803b57e9af4c430682c1bb31d1c91767, text="tháinig an gorta agus b'éigean do shíle agus dá hathair agus dá máthair agus do dhiarmuidín imtheacht síos go mion dhráma agus dul isteach i dtigh na mbocht", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=c8fdaffc9a6d44f1aeba37e4fe6d9277, text="an", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=c1de33b80049430698ff741f93d6a6b8, text="an tuaiscirt orthu", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=1772c619f59f4d8fb7f60462fa12e26b, text="an tuaiscirt ord", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=897d7a1a3fff4805a32c734ee8234918, text="an tuaiscirt oráiste", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=ca5e771fa406483fb558335bb9cd97e9, text="an tuaiscirt an rud i gceart", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=000e90836860461785d32e6c5bd80a6e, text="an tuaiscirt ord oráisteach ann", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=e55ccf960aac4e71b3866bb7215ba14d, text="an tuaiscirt oráiste i gceann de", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=fff9e937c3f147e2ae7d70110dcc5a92, text="an tuaiscirt oráiste i gceann de scaraigí", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=b9443a67a64d4ec2a3e6919ea510c2e6, text="an tuaiscirt ord oráisteach an nasc againn go", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=2a8d3dc6efbb49b797d10e2905a8b6e5, text="an tuaiscirt oráiste i gceann de scaraigí an dlí lena", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=dcd1af4092f246f5866d6b9b54542fbf, text="an tuaiscirt oráiste i gceann de scaraigí dlí lena chéile", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=b8e8d0dae9c44ed59eaba944f765a0be, text="tá cuid", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=4221d702dea8490e9e0fb451e3fbcee0, text="tá cuid againn", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=b983ef31685a4291853a7676f524e91a, text="chuidigh an", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=c8468b0d3d234f5193322fedd99ac496, text="chuidigh an taithí leis na", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=853b1f94983b4f6a9daa645f1e3d7b6f, text="chuidigh an tathair des na", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=e1512735a67a48378282530b3f7f5eb1, text="chuidigh an taithí leis na cuirí chun", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id=fa0a9473d2f741a08d6a6796a19cf043, text="chuidigh an tathair des na gaeilge an mháthair maith", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=a2608c3e4eca400096948ca387ab593c, result=SpeechRecognitionResult(result_id
reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42, result=SpeechRecognitionResult(result_id=7c367840258c41db8b398a21652ce144, text="bíonn", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42, result=SpeechRecognitionResult(result_id=f7817d3de7274cd0b12db7bfbf1bdd76, text="bíonn sí", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42, result=SpeechRecognitionResult(result_id=a8762729983e4e6594987e07d147f79c, text="bíonn cuí a bheidh sí an", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42, result=SpeechRecognitionResult(result_id=399a5e9a88e044c8b41d927885420fdc, text="bíonn caomhach sí an scéal é", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42, result=SpeechRecognitionResult(result_id=f7e253d7dc154ef8a9d632176c06d4ea, text="bíonn caomhach sí an scéal é go", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42, result=SpeechRecognitionResult(result_id=6287f1bfdbb14019b453c1b4581c3c84, text="bíonn caomhach sí an scéal é gur focal", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42, result=SpeechRecognitionResult(result_id=abdbc0e9477d48b0b9287f12b679469f, text="bíonn caomhach sí an scéal é gur shocraigh", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42, result=SpeechRecognitionResult(result_id=c24c95fa1ab745a1b3cabd23bfbac950, text="bíonn caomhach sí an scéal é gur shocraigh maithe", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42, result=SpeechRecognitionResult(result_id=fbc42bd482c948079634ff2bce11db66, text="bíonn caomhach sí an scéal é gur shocraigh mé ar mo", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42, result=SpeechRecognitionResult(result_id=392991c80da344b5b0ab14e616d4a16f, text="bíonn caomhach sí an scéal é gur shocraigh maithe i meiriceá", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42, result=SpeechRecognitionResult(result_id=3e9b98f4bfe74b2bb7c234333fc7f69d, text="bíonn caomhach sí an scéal é gur shocraigh mé ar maith agat", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42, result=SpeechRecognitionResult(result_id=ccfb45d384ce4c5b826a15a970d0b838, text="bíonn caomhach sí an scéal é gur shocraigh mé ar maith agat ag", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42, result=SpeechRecognitionResult(result_id=e83819c837394547b165bc9a49850a73, text="bíonn caomhach sí an scéal é gur shocraigh maithe mé chugat ag foghlaim na leanaí", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42, result=SpeechRecognitionResult(result_id=404d1034f8b94d958a27f934bc05c53a, text="bíonn caomhach sí an scéal é gur shocraigh maithe mé chugat ag foghlaim na", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42, result=SpeechRecognitionResult(result_id=037d34738196420db1543f03dc591d8b, text="bíonn caomhach sí an scéal é gur shocraigh maithe mé chugat ag foghlaim le leathnú", reason=ResultReason.RecognizingSpeech))
# Speech Recognition canceled: CancellationReason.EndOfStream
# CLOSING on SpeechRecognitionCanceledEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42, result=SpeechRecognitionResult(result_id=6c03fa6d2d8c4732b2db55a398b28c46, text="", reason=ResultReason.Canceled))
# SESSION STOPPED SessionEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42)
# CLOSING on SessionEventArgs(session_id=c2fd30a963cb44c9ad62f942b5501e42)

# %% [markdown]
# Debugging with `curl`

# %%
 # !curl -v -X POST "https://{_LOC}.api.cognitive.microsoft.com/sts/v1.0/issueToken" -H "Ocp-Apim-Subscription-Key: {_SUBS}" -H "Content-type: application/x-www-form-urlencoded" -H "Content-Length: 0"

# %%
_TOK=''

# %%
# !curl -v -X POST "https://{_LOC}.stt.speech.microsoft.com/speech/recognition/interactive/cognitiveservices/v1?language=ga-IE" -H "Authorization: Bearer {_TOK}" -H "Transfer-Encoding: chunked" -H "Content-type: audio/wav; codec=audio/pcm; samplerate=16000" --data-binary @cfjdfaqWY3Y.wav

# %% [markdown]
# Next step, get at the innards (TODO)

# %%
transcript_display_list = []
transcript_ITN_list = []
confidence_list = []
words = []

def parse_azure_result(evt):
  import json
  response = json.loads(evt.result.json)
  transcript_display_list.append(response['DisplayText'])
  confidence_list_temp = [item.get('Confidence') for item in response['NBest']]
  max_confidence_index = confidence_list_temp.index(max(confidence_list_temp))
  confidence_list.append(response['NBest'][max_confidence_index]['Confidence'])
  transcript_ITN_list.append(response['NBest'][max_confidence_index]['ITN'])
  words.extend(response['NBest'][max_confidence_index]['Words'])
  logger.debug(evt)
