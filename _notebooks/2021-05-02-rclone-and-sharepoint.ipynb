# %%
# %%capture
# !curl https://rclone.org/install.sh |bash

# %%
#_URL='https://uniwersytetlodzki-my.sharepoint.com/:f:/g/personal/pelcra_uni_lodz_pl/EtxBCk44jGZIs24XDRds4lgB6VcQvXMjL5MIiTk5RMND_w'
_URL='https://uniwersytetlodzki-my.sharepoint.com/personal/pelcra_uni_lodz_pl/Documents'

# %%
#!rclone config create pelcra webdav webdav-url 'https://uniwersytetlodzki-my.sharepoint.com/personal/pelcra_uni_lodz_pl/Documents'  webdav-vendor other
#!rclone config create pelcra webdav url 'https://uniwersytetlodzki-my.sharepoint.com/personal/pelcra_uni_lodz_pl/Documents/SHARE/CLARIN/SPOKES/PELCRA_EMO'  webdav-vendor other
#!rclone config create pelcra webdav url 'https://uniwersytetlodzki-my.sharepoint.com/personal/pelcra_uni_lodz_pl/Documents'  webdav-vendor other cookie '{_COOKIE}'
#!rclone config create pelcra webdav url 'https://uniwersytetlodzki-my.sharepoint.com/personal/pelcra_uni_lodz_pl/Documents'  webdav-vendor sharepoint setcookie '{_COOKIE}'
# !rclone config create pelcra webdav url 'https://uniwersytetlodzki-my.sharepoint.com/personal/pelcra_uni_lodz_pl/Documents'  webdav-vendor sharepoint
# Out:
# Remote config
# --------------------
# [pelcra]
# type = webdav
# url = https://uniwersytetlodzki-my.sharepoint.com/personal/pelcra_uni_lodz_pl/Documents
# webdav-vendor = sharepoint
# --------------------

# %%
#!rclone --http-headers 'set-cookie:{_COOKIE}' ls --use-cookies -vv 'pelcra:SHARE/CLARIN/SPOKES/PELCRA_EMO' --dump bodies
#!rclone ls --use-cookies -vv 'pelcra:SHARE/CLARIN/SPOKES/PELCRA_EMO' --dump bodies
# !rclone ls --use-cookies -vv 'pelcra:SHARE/CLARIN/SPOKES/PELCRA_EMO' --dump bodies
# Out:
# 2021/05/02 21:39:20 DEBUG : Using config file from "/root/.config/rclone/rclone.conf"
# 2021/05/02 21:39:20 DEBUG : rclone: Version "v1.55.1" starting with parameters ["rclone" "ls" "--use-cookies" "-vv" "pelcra:SHARE/CLARIN/SPOKES/PELCRA_EMO" "--dump" "bodies"]
# 2021/05/02 21:39:20 DEBUG : Creating backend with remote "pelcra:SHARE/CLARIN/SPOKES/PELCRA_EMO"
# 2021/05/02 21:39:20 DEBUG : You have specified to dump information. Please be noted that the Accept-Encoding as shown may not be correct in the request and the response may not show Content-Encoding if the go standard libraries auto gzip encoding was in effect. In this case the body of the request will be gunzipped before showing it.
# 2021/05/02 21:39:20 DEBUG : >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 2021/05/02 21:39:20 DEBUG : HTTP REQUEST (req 0xc00057a300)
# 2021/05/02 21:39:20 DEBUG : PROPFIND /personal/pelcra_uni_lodz_pl/Documents/SHARE/CLARIN/SPOKES/PELCRA_EMO HTTP/1.1
# ...

# %%
# !rclone ls :http: --http-url 'https://uniwersytetlodzki-my.sharepoint.com/:f:/g/personal/pelcra_uni_lodz_pl/EpPehikqGqZJltrAKlVp3k0BOeyzEgBBO_ZwmFC9WaLbWw' --use-cookies -vv
# Out:
# 2021/05/02 21:22:17 DEBUG : Using config file from "/root/.config/rclone/rclone.conf"
# 2021/05/02 21:22:17 DEBUG : rclone: Version "v1.55.1" starting with parameters ["rclone" "ls" ":http:" "--http-url" "https://uniwersytetlodzki-my.sharepoint.com/:f:/g/personal/pelcra_uni_lodz_pl/EpPehikqGqZJltrAKlVp3k0BOeyzEgBBO_ZwmFC9WaLbWw" "--use-cookies" "-vv"]
# 2021/05/02 21:22:17 DEBUG : Creating backend with remote ":http:"
# 2021/05/02 21:22:17 DEBUG : :http: detected overridden config - adding "{R77z6}" suffix to name
# 2021/05/02 21:22:17 DEBUG : fs cache: renaming cache item ":http:" to be canonical ":http{R77z6}:"
# 2021/05/02 21:22:18 ERROR : : error listing: error listing "": failed to readDir: HTTP Error 403: 403 Forbidden
# 2021/05/02 21:22:18 DEBUG : 3 go routines active
# 2021/05/02 21:22:18 Failed to ls with 2 errors: last error was: error listing "": failed to readDir: HTTP Error 403: 403 Forbidden

# %%
# !rclone config dump
# Out:
# {
#     "pelcra": {
#         "type": "webdav",
#         "webdav-url": "https://uniwersytetlodzki-my.sharepoint.com/personal/pelcra_uni_lodz_pl/Documents/",
#         "webdav-vendor": "other"
#     }
# }

# %%
# !curl -i 'https://uniwersytetlodzki-my.sharepoint.com/:f:/g/personal/pelcra_uni_lodz_pl/EpPehikqGqZJltrAKlVp3k0BOeyzEgBBO_ZwmFC9WaLbWw'
# Out:
# HTTP/2 302
# cache-control: private
# content-length: 518
# content-type: text/html; charset=utf-8
# location: https://uniwersytetlodzki-my.sharepoint.com/personal/pelcra_uni_lodz_pl/_layouts/15/onedrive.aspx?id=%2Fpersonal%2Fpelcra%5Funi%5Flodz%5Fpl%2FDocuments%2FSHARE%2FCLARIN%2FSPOKES%2FPELCRA%5FPARL&originalPath=aHR0cHM6Ly91bml3ZXJzeXRldGxvZHpraS1teS5zaGFyZXBvaW50LmNvbS86ZjovZy9wZXJzb25hbC9wZWxjcmFfdW5pX2xvZHpfcGwvRXBQZWhpa3FHcVpKbHRyQUtsVnAzazBCT2V5ekVnQkJPX1p3bUZDOVdhTGJXdz9ydGltZT1waTNzcExBTjJVZw
# p3p: CP="ALL IND DSP COR ADM CONo CUR CUSo IVAo IVDo PSA PSD TAI TELo OUR SAMo CNT COM INT NAV ONL PHY PRE PUR UNI"
# set-cookie: FedAuth=...; path=/; SameSite=None; secure; HttpOnly
# x-sharepointhealthscore: 0
# x-aspnet-version: 4.0.30319
# sprequestguid: 4812c49f-60f4-2000-e142-6c603c2da7c4
# request-id: 4812c49f-60f4-2000-e142-6c603c2da7c4
# ms-cv: n8QSSPRgACDhQmxgPC2nxA.0
# strict-transport-security: max-age=31536000
# x-frame-options: SAMEORIGIN
# ...

# %%
_COOKIE='FedAuth=...; path=/; SameSite=None; secure; HttpOnly'
