# %% [markdown]
# # Leighleat pieces
#
# > "Partial, incomplete"
#
# - hidden: true
# - categories: [leighleat]
# - branch: master
# - badges: true

# %%
MIANTA = {
    "https://www.leighleat.com/pages/548": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > h1",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p:nth-child(2)"
    ],
    "https://www.leighleat.com/pages/549": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > h1",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p:nth-child(1)",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p:nth-child(2)"
    ],
    "https://www.leighleat.com/pages/550": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/551": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/552": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/553": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > h1",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/554": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/555": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/556": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/557": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/558": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/559": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > h1",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/560": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/561": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/562": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/563": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/564": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/565": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > h1",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/566": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/567": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/568": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/569": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/570": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/571": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > h1",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/572": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/573": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > h1",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/574": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/575": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/576": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/577": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/578": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/579": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/580": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p:nth-child(1)",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p:nth-child(2)"
    ],
    "https://www.leighleat.com/pages/581": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/582": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > h1",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/583": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/584": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/585": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-1 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/586": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > h1",
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ],
    "https://www.leighleat.com/pages/587": [
        "#mianta-page > div.container.outer-container > div > div.col-md-7.col-sm-12.align-self-center.order-md-12 > div > div.text > p"
    ]
}

# %% [markdown]
# dron
# url = https://www.leighleat.com/pages/620
# img_selector = #ajax-page-container > div > div:nth-child(2) > img
#
# url = https://www.leighleat.com/pages/621
# img_selector = #ajax-page-container > div > div:nth-child(2) > img
#
# url = https://www.leighleat.com/pages/622
# img_selector = #ajax-page-container > div > div:nth-child(2) > img
#
# url = https://www.leighleat.com/pages/623
# img_selector = #ajax-page-container > div > div:nth-child(2) > img
#
# url = https://www.leighleat.com/pages/624
# img_selector = #ajax-page-container > div > div:nth-child(2) > img
#
# url = https://www.leighleat.com/pages/625
# img_selector = #ajax-page-container > div > div:nth-child(2) > img
#
# url = https://www.leighleat.com/pages/626
# img_selector = #ajax-page-container > div > div:nth-child(2) > img
#
# url = https://www.leighleat.com/pages/628
# img_selector = #ajax-page-container > div > div:nth-child(2) > img
#
# url = https://www.leighleat.com/pages/629
# img_selector = #ajax-page-container > div > div:nth-child(2) > img
#
# url = https://www.leighleat.com/pages/630
# img_selector = #ajax-page-container > div > div:nth-child(2) > img
#
# url = https://www.leighleat.com/pages/631
# img_selector = #ajax-page-container > div > div:nth-child(2) > img

# %%
import json

with open("/content/via_project_16May2025_16h0m (2).json") as inf:
    data = json.load(inf)

# %%
for img in data["_via_img_metadata"]:
    part = data["_via_img_metadata"][img]
    filename = part["filename"].split("/")[-1]
    for region in part["regions"]:
        print(f"{filename},{region['shape_attributes']['x']},{region['shape_attributes']['y']},{region['shape_attributes']['width']},{region['shape_attributes']['height']}")
