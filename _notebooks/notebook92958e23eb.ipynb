# %%
import soundfile as sf
sf.read('/kaggle/input/wav2vec-u-cv-swedish-vads/wav/test/common-voice-swedish-16bit-wav/common_voice_sv-SE_23828220.wav')

# %%
# !cp -r /kaggle/input/wav2vec-u-cv-swedish-vads/wav/ /tmp

# %%
# !find /kaggle/input/wav2vec-u-cv-swedish-vads/ -name 'common_voice_sv-SE_23828220.wav'

# %%
# !conda list | grep cuda

# %%
# !conda install faiss-gpu -c pytorch

# %%
# !ps aux

# %%
exit(1)
