# %% [markdown]
# # "Running wav2vec2 for Polish on Kashubian"
# > "How does it fare with closely related languages? Part 1: Processing"
#
# - toc: false
# - branch: master
# - comments: true
# - categories: [wav2vec2, kashubian]"

# %%
# %%capture
import requests 
from bs4 import BeautifulSoup

# %%
URL='http://www.miesiecznikpomerania.pl/audio'

# %%
req = requests.get(URL)
soup = BeautifulSoup(req.content, 'html.parser')

# %%
contents = list()
for part in soup.find_all('div', class_='sp-accordion-inner'):
  out = {}
  audtag = part.find('audio')
  source = audtag.find('source')
  out['audio'] = 'http://www.miesiecznikpomerania.pl{}'.format(source['src'])
  audtag.decompose()
  out['text'] = part.text.strip()
  contents.append(out)

# %%
for c in contents:
  # !echo {c['audio']} >> input

# %%
# %%capture
# !cat input|sort|uniq > input.sorted
# !wget -i input.sorted

# %%
# !cat input.sorted|grep -v uczba_5_Miedzy_niebem_a_ziemia_-_Najo_uczba|awk '{print "http://web.archive.org/web/" $0}' > input.wayback

# %%
# %%capture
# !wget -i input.wayback

# %%
import json
with open('data.json', 'w') as outfile:
    json.dump(contents, outfile)

# %%
# %%capture
# !for i in *.ogg;do ffmpeg -y -i "$i" -acodec pcm_s16le -ac 1 -ar 16000 "$i.wav";done

# %%
# %%capture
# !pip install librosa webrtcvad

# %%
#collapse-hide
# VAD wrapper is taken from PyTorch Speaker Verification:
# https://github.com/HarryVolek/PyTorch_Speaker_Verification
# Copyright (c) 2019, HarryVolek
# License: BSD-3-Clause
# based on https://github.com/wiseman/py-webrtcvad/blob/master/example.py
# Copyright (c) 2016 John Wiseman
# License: MIT
import collections
import contextlib
import numpy as np
import sys
import librosa
import wave

import webrtcvad

#from hparam import hparam as hp
sr = 16000

def read_wave(path, sr):
    """Reads a .wav file.
    Takes the path, and returns (PCM audio data, sample rate).
    Assumes sample width == 2
    """
    with contextlib.closing(wave.open(path, 'rb')) as wf:
        num_channels = wf.getnchannels()
        assert num_channels == 1
        sample_width = wf.getsampwidth()
        assert sample_width == 2
        sample_rate = wf.getframerate()
        assert sample_rate in (8000, 16000, 32000, 48000)
        pcm_data = wf.readframes(wf.getnframes())
    data, _ = librosa.load(path, sr)
    assert len(data.shape) == 1
    assert sr in (8000, 16000, 32000, 48000)
    return data, pcm_data
    
class Frame(object):
    """Represents a "frame" of audio data."""
    def __init__(self, bytes, timestamp, duration):
        self.bytes = bytes
        self.timestamp = timestamp
        self.duration = duration


def frame_generator(frame_duration_ms, audio, sample_rate):
    """Generates audio frames from PCM audio data.
    Takes the desired frame duration in milliseconds, the PCM data, and
    the sample rate.
    Yields Frames of the requested duration.
    """
    n = int(sample_rate * (frame_duration_ms / 1000.0) * 2)
    offset = 0
    timestamp = 0.0
    duration = (float(n) / sample_rate) / 2.0
    while offset + n < len(audio):
        yield Frame(audio[offset:offset + n], timestamp, duration)
        timestamp += duration
        offset += n


def vad_collector(sample_rate, frame_duration_ms,
                  padding_duration_ms, vad, frames):
    """Filters out non-voiced audio frames.
    Given a webrtcvad.Vad and a source of audio frames, yields only
    the voiced audio.
    Uses a padded, sliding window algorithm over the audio frames.
    When more than 90% of the frames in the window are voiced (as
    reported by the VAD), the collector triggers and begins yielding
    audio frames. Then the collector waits until 90% of the frames in
    the window are unvoiced to detrigger.
    The window is padded at the front and back to provide a small
    amount of silence or the beginnings/endings of speech around the
    voiced frames.
    Arguments:
    sample_rate - The audio sample rate, in Hz.
    frame_duration_ms - The frame duration in milliseconds.
    padding_duration_ms - The amount to pad the window, in milliseconds.
    vad - An instance of webrtcvad.Vad.
    frames - a source of audio frames (sequence or generator).
    Returns: A generator that yields PCM audio data.
    """
    num_padding_frames = int(padding_duration_ms / frame_duration_ms)
    # We use a deque for our sliding window/ring buffer.
    ring_buffer = collections.deque(maxlen=num_padding_frames)
    # We have two states: TRIGGERED and NOTTRIGGERED. We start in the
    # NOTTRIGGERED state.
    triggered = False

    voiced_frames = []
    for frame in frames:
        is_speech = vad.is_speech(frame.bytes, sample_rate)

        if not triggered:
            ring_buffer.append((frame, is_speech))
            num_voiced = len([f for f, speech in ring_buffer if speech])
            # If we're NOTTRIGGERED and more than 90% of the frames in
            # the ring buffer are voiced frames, then enter the
            # TRIGGERED state.
            if num_voiced > 0.9 * ring_buffer.maxlen:
                triggered = True
                start = ring_buffer[0][0].timestamp
                # We want to yield all the audio we see from now until
                # we are NOTTRIGGERED, but we have to start with the
                # audio that's already in the ring buffer.
                for f, s in ring_buffer:
                    voiced_frames.append(f)
                ring_buffer.clear()
        else:
            # We're in the TRIGGERED state, so collect the audio data
            # and add it to the ring buffer.
            voiced_frames.append(frame)
            ring_buffer.append((frame, is_speech))
            num_unvoiced = len([f for f, speech in ring_buffer if not speech])
            # If more than 90% of the frames in the ring buffer are
            # unvoiced, then enter NOTTRIGGERED and yield whatever
            # audio we've collected.
            if num_unvoiced > 0.9 * ring_buffer.maxlen:
                triggered = False
                yield (start, frame.timestamp + frame.duration)
                ring_buffer.clear()
                voiced_frames = []
    # If we have any leftover voiced audio when we run out of input,
    # yield it.
    if voiced_frames:
        yield (start, frame.timestamp + frame.duration)


def VAD_chunk(aggressiveness, path):
    audio, byte_audio = read_wave(path, sr)
    vad = webrtcvad.Vad(int(aggressiveness))
    frames = frame_generator(20, byte_audio, sr)
    frames = list(frames)
    times = vad_collector(sr, 20, 200, vad, frames)
    speech_times = []
    speech_segs = []
    for i, time in enumerate(times):
        start = np.round(time[0],decimals=2)
        end = np.round(time[1],decimals=2)
        j = start
        while j + .4 < end:
            end_j = np.round(j+.4,decimals=2)
            speech_times.append((j, end_j))
            speech_segs.append(audio[int(j*sr):int(end_j*sr)])
            j = end_j
        else:
            speech_times.append((j, end))
            speech_segs.append(audio[int(j*sr):int(end*sr)])
    return speech_times, speech_segs

# %%
#collapse-hide
# Based on code from PyTorch Speaker Verification:
# https://github.com/HarryVolek/PyTorch_Speaker_Verification
# Copyright (c) 2019, HarryVolek
# Additions Copyright (c) 2021, Jim O'Regan
# License: MIT
import numpy as np

# wav2vec2's max duration is 40 seconds, using 39 by default
# to be a little safer
def vad_concat(times, segs, max_duration=39.0):
    """
    Concatenate continuous times and their segments, where the end time
    of a segment is the same as the start time of the next
        Parameters:
            times: list of tuple (start, end)
            segs: list of segments (audio frames)
            max_duration: maximum duration of the resulting concatenated
                segments; the kernel size of wav2vec2 is 40 seconds, so
                the default max_duration is 39, to ensure the resulting
                list of segments will fit
        Returns:
            concat_times: list of tuple (start, end)
            concat_segs: list of segments (audio frames)
    """
    absolute_maximum=40.0
    if max_duration > absolute_maximum:
        raise Exception('`max_duration` {:.2f} larger than kernel size (40 seconds)'.format(max_duration))
    # we take 0.0 to mean "don't concatenate"
    do_concat = (max_duration != 0.0)
    concat_seg = []
    concat_times = []
    seg_concat = segs[0]
    time_concat = times[0]
    for i in range(0, len(times)-1):
        can_concat = (times[i+1][1] - time_concat[0]) < max_duration
        if time_concat[1] == times[i+1][0] and do_concat and can_concat:
            seg_concat = np.concatenate((seg_concat, segs[i+1]))
            time_concat = (time_concat[0], times[i+1][1])
        else:
            concat_seg.append(seg_concat)
            seg_concat = segs[i+1]
            concat_times.append(time_concat)
            time_concat = times[i+1]
    else:
        concat_seg.append(seg_concat)
        concat_times.append(time_concat)
    return concat_times, concat_seg

# %%
def make_dataset(concat_times, concat_segs):
  starts = [s[0] for s in concat_times]
  ends = [s[1] for s in concat_times]
  return {'start': starts,
          'end': ends,
          'speech': concat_segs}

# %%
# %%capture
# !pip install datasets

# %%
from datasets import Dataset

def vad_to_dataset(path, max_duration):
    t,s = VAD_chunk(3, path)
    if max_duration > 0.0:
        ct, cs = vad_concat(t, s, max_duration)
        dset = make_dataset(ct, cs)
    else:
        dset = make_dataset(t, s)
    return Dataset.from_dict(dset)

# %%
# %%capture
# !pip install -q transformers

# %%
# %%capture
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
# load model and tokenizer
processor = Wav2Vec2Processor.from_pretrained("mbien/wav2vec2-large-xlsr-polish")
model = Wav2Vec2ForCTC.from_pretrained("mbien/wav2vec2-large-xlsr-polish")
model.to("cuda")

# %%
def speech_file_to_array_fn(batch):
    import torchaudio
    speech_array, sampling_rate = torchaudio.load(batch["path"])
    batch["speech"] = speech_array[0].numpy()
    batch["sampling_rate"] = sampling_rate
    batch["target_text"] = batch["sentence"]
    return batch
def evaluate(batch):
  import torch
  inputs = processor(batch["speech"], sampling_rate=16_000, return_tensors="pt", padding=True)

  with torch.no_grad():
    logits = model(inputs.input_values.to("cuda"), attention_mask=inputs.attention_mask.to("cuda")).logits

  pred_ids = torch.argmax(logits, dim=-1)
  batch["pred_strings"] = processor.batch_decode(pred_ids)
  return batch

# %%
import json
def process_wave(filename, duration):
    import json
    dataset = vad_to_dataset(filename, duration)
    result = dataset.map(evaluate, batched=True, batch_size=16)
    speechless = result.remove_columns(['speech'])
    d=speechless.to_dict()
    tlog = list()
    for i in range(0, len(d['end']) - 1):
        out = dict()
        out['start'] = d['start'][i]
        out['end'] = d['end'][i]
        out['transcript'] = d['pred_strings'][i]
        tlog.append(out)
    with open('{}.tlog'.format(filename), 'w') as outfile:
        json.dump(tlog, outfile)

# %%
import glob
for f in glob.glob('./*.wav'):
    print(f)
    process_wave(f, 10.0)
# Out:
# ./29. Zadeszno reaktiwacjo.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./13_Jak_przechloscec_letnika.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ./109__Maya_Gielniak_-_Majwka_kl_Tuszkwsczi_Matczi.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./41_Ana_Gleszczesko_-_Zrozmiec_biaka.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ./38.Hinzow_Jurk - Jo_tam_broni_nie_brekuja.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./43.Romk Drzezdzonk - Naju z brifka nowotworowanie.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./20.Tatiana Slowi - Stoleca godo po kaszebsku.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# ./23.Na Marsa.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./117__Stanisw_Janke_-_Wsziwk_wpisny_w_mje_c.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=9.0), HTML(value='')))
# ./45.Hinzow Jurk - Moje wioldze kaszebscze wesele.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./78_Tomk_Fopka_-_Po_dredzi_stronie_komputra.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ./06.Rewolucjo_w_egzaminach.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./08.Odzweskono_Kaszebka.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ./10_Odemkle_Chmurniczi.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./120__Artur_Jablonsczi_-_Neokaszubia_to_je_wicy_jak_ndzeja.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ./106__Tomk_Fopka_-_Godzynczi.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# ./09.Roczezna_w_Fertanim_zoglow.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./11.Grif_dobiwo.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./104__Bozena_Ugowsko_-_Molo_galerio_akwarelkow_o_szczescym.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ./uczba_5_Miedzy_niebem_a_ziemia_-_Najo_uczba.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# ./89_Tomk_Fopka_-_Zeza_zawieszedla.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./99_Romk_Drzezdzonk_-_Jastrowo_kortka_do_brifczi.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ./70_Maya_Gielniak_-_Godka_o_kaszebsczich_kowbojach.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./72_Darek_Majkowski_-_Kto_chce_czyta_po_kaszubsku.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./51_Mateusz_Bullmann_-_Historio_zamklo_w_lesce.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# ./84_Ana_Gleszczinsko_-_Nie-nasz_k-roj.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# ./34_Dariusz_Majkowsczi_-_Co_z_tima_owcama.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ./59_Mateusz_Bullmann_-_Leno_jeden_taczi.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# ./01.chto_rzadzy_doma.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ./85_Ana_Gliszczynska_-_Kuron_w_akcje.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# ./03.nie_dlo_chlopa.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./122__Kazimierz_Ostrowski_-_Jiwr_welownika.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ./42_Rmk_Drzednk_-_Lest_do_Donalda.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ./86_Andrzej_Krauze_Tomosz_Lidzbarsczi_-_100_lat_parafie_-_Borowim_Mlinie.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# ./54_Wielojazekowosc_bokadosco_krojne.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# ./22.Bliza, co mergo muzycznym szeka.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ./65_Lucyna_Kurpiewska_-_Kaszbsczi_krl_miodnosc.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ./83_Kazimierz_Ostrowski_-_W_ceni_smantorzowech_drzew.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./92_Maya_Gielniak_-_Dzemione.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./87_Kadzmierz_Ostrowsczi_-_Rok_pokojnego_slunca.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ./21.Pioter Lessnau, Patrk Mudlaw - Bienvenidos a gniewino.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# ./62_Eugeniusz_Pryczkowski_-_Wjedno_kaszebe.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ./18.Przed pierszim gwizdka.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./79_Dariusz_Majkowski_-_Z_kaszebizna_w_kazdym_dzejanim.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# ./36_Kresztof_Korda_-_Ambasador_Pomorzego.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ./52_Tomk_Fopka_-_Moje_strone.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./125__Dark_Majkwsczi_-_Na_kc_Erop_i_jesz_dali.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ./111__Rmk_Drzdnk_-_Plckwscz_erowelnczi.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ./69_Martina_Zienkiewicz_-_Zrzeszony_z_regiona.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# ./57_Karolena_Serkowsko_-_Reza_po_kaszebska_swiada.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./16.Pelckowscze Eurobulowanie.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ./101_Slowk_Formella_-_Jak_to_biwalo.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ./35_Rmk_Drzednk_-_Wszetkowiedzo_Pelckowa.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./24.Pleckowscze-note.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./49_Hinzow_Jurk_-_Kunc_swiata_z_tima_Majama.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./58_Tatiana_Slowi_-_Akordeonista_z_Suleczyna.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ./44.Ana Gleszczensko - Kask optimistno.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./12.Nie_zabec_mowe_matczi.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# ./93_Jadwiga_Bogdan_-_Diament_z_Gochow.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ./97_Roman_Robaczewsczi_-_Derdowsczi_w_Parizu.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ./55_Poselcowie_z_Litwe_przezeraja_sa_Kaszebom.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# ./88_Romk_Drzezdzonk_-_Choc_roz.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ./47_Romk_Drzezdzonk_-_Roczi_3.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./40_Hinzw_Jurk_-_Noworoczne_postanowienia_zarobiaech.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./91_Zbigniew_Byczkowski_-_Pobloce.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ./115__Rmk_Drzdnk_-_Plckwsk_afera_pdschw.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ./113__Pioter_Lessna_welina_Stefask_-_Cle_msz_bc_realn.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# ./114__Tmk_Fpka_-_Droga.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ./124__Kaszbizna_w_stolc.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./50_Eugeniusz_Preczkowsczi_-_Zece_zawdzacziwol_Kaszebsczi_Krolewi.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./123__Rmk_Drzdnk_-_Szlach_Abecada.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# ./110__Tmk_Fpka_-_Bez_brod_spiwani.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ./112__Czrno-t_Swito_Dzkcznieni.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# ./33.Romk Drzezdzonk - Kunc swiata.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# ./96_Roman_Drzezdzon_-_Wejrowscze_slechanie_Bozego_Slowa.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# ./37.Mateusz_Bullmann - O jednym_niesmiertelniku.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./32.Mateusz Bullmann - Nowi symbol Norde.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./39.Romk_Drzezdzonk - Arbata_po_betowsku.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./75_Pioter_Dzekanowsczi_-_Nazod_do_lasu.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./82_Romk_Drzezdzonk_-_Waspon_na_Pelckowie.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./81_Stanislaw_Janke_-_Stolemrodem_z_Rolbika.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ./56_Mateusz_Bullmann_-_Konia_po_Nordze.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./66_Egeniusz_Prczkwsczi_-_Stegn_smierc_kl_Brazylii.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=9.0), HTML(value='')))
# ./74_Romk_Drzezdzonk_-_Jesenne_godczi_o_pelckowsczi_pismieniznie.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# ./02._jadrowo_elektrownio.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# ./04.Psalme_we_wejrowsczi_kolegiace.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# ./46_Jerzi_Nacel_-_Bozi_Slega_ks_Roszczinialsczi_i_Les_Pustini.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./14_Nie_sygnie_sedzec_doma.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# ./31.Maya Gelniok - Husky na Pomorzim.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ./60_Romk_Drzezdzonk_-_Pelckowsko_malena.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# ./103_Romk_Drzezdzonk_-_Pelckowsko_komka.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ./68_Rmk_Drzdnk_-_W_szkoowi_awie.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./100_Dariusz_Majkowski_-_Nie_leno_dlo_szkolnech.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ./127__Rmk_Drzdnk_-_Plckwsczi_meloman.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ./27.Pelckowsczi skorb.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ./05.Czego_chcele_Mlodokaszebi.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./94_Tomk_Fopka_-_Prawie_prawo.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ./64_Kazimierz_Ostrowski_-_Janio_Chemwsczg.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# ./80_Jerzy_Hoppe_-_Oficer_cz2.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ./105__Jan_Dosz_-_Hokejowi_most_dreszbe.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ./76_Ewelina_Roman_Drzezdzonowie_-_Zamarte.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ./116__Grgr_J__Schramke_-_Wieleklturowi_festiwal.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./25.To sa nie oploco.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./28. Szkolna bec.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# ./108__Pioter_Dzekanowsczi_-_Malown_pwistczi.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# ./98_Tomk_Fopka_-_Z_braku_warkow.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# ./126__Tmk_Fpka_-_Po_czim_pznac_artist.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# ./95_Romk_Drzezdzonk_-_Widzy_mie_sa.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ./90_Daniel_Kalinowski_-_Dramaturgio_Anne_Lajming.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# ./48_Ana_Gleszczinsko_-_Jiwer_z_rena_abo_co_widzy_szkolny_przed_zwonka.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./19.Romk Drzezdzonk - Gdunsczi bowka.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./53_Romk_Drzezdzonk_-_Obzerczi.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ./119__Tmk_Fpka_-_Czed_chop_m_sznp.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# ./77_Szymon_Radzyminski_-_Artysta_sie_bywa.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ./63_Tomk_Fopka_-_Z_Lesniewa_wyszo.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ./118__Tmk_Fpka_-_P_wosk.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# ./121__Rmk_Drzdnk_-_Brifkwi_bsd_Niestateczng_Sdu.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ./102_Karol_Wicher_-_Utworca_wirtualnech_swiatow.ogg.wav
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))

# %%
# !ls *tlog|zip tlogs-csb.zip -@
# Out:
#   adding: 01.chto_rzadzy_doma.ogg.wav.tlog (deflated 66%)
#   adding: 02._jadrowo_elektrownio.ogg.wav.tlog (deflated 66%)
#   adding: 03.nie_dlo_chlopa.ogg.wav.tlog (deflated 62%)
#   adding: 04.Psalme_we_wejrowsczi_kolegiace.ogg.wav.tlog (deflated 56%)
#   adding: 05.Czego_chcele_Mlodokaszebi.ogg.wav.tlog (deflated 63%)
#   adding: 06.Rewolucjo_w_egzaminach.ogg.wav.tlog (deflated 63%)
#   adding: 08.Odzweskono_Kaszebka.ogg.wav.tlog (deflated 65%)
#   adding: 09.Roczezna_w_Fertanim_zoglow.ogg.wav.tlog (deflated 63%)
#   adding: 100_Dariusz_Majkowski_-_Nie_leno_dlo_szkolnech.ogg.wav.tlog (deflated 66%)
#   adding: 101_Slowk_Formella_-_Jak_to_biwalo.ogg.wav.tlog (deflated 66%)
#   adding: 102_Karol_Wicher_-_Utworca_wirtualnech_swiatow.ogg.wav.tlog (deflated 62%)
#   adding: 103_Romk_Drzezdzonk_-_Pelckowsko_komka.ogg.wav.tlog (deflated 66%)
#   adding: 104__Bozena_Ugowsko_-_Molo_galerio_akwarelkow_o_szczescym.ogg.wav.tlog (deflated 65%)
#   adding: 105__Jan_Dosz_-_Hokejowi_most_dreszbe.ogg.wav.tlog (deflated 65%)
#   adding: 106__Tomk_Fopka_-_Godzynczi.ogg.wav.tlog (deflated 67%)
#   adding: 108__Pioter_Dzekanowsczi_-_Malown_pwistczi.ogg.wav.tlog (deflated 65%)
#   adding: 109__Maya_Gielniak_-_Majwka_kl_Tuszkwsczi_Matczi.ogg.wav.tlog (deflated 65%)
#   adding: 10_Odemkle_Chmurniczi.ogg.wav.tlog (deflated 64%)
#   adding: 110__Tmk_Fpka_-_Bez_brod_spiwani.ogg.wav.tlog (deflated 66%)
#   adding: 111__Rmk_Drzdnk_-_Plckwscz_erowelnczi.ogg.wav.tlog (deflated 67%)
#   adding: 112__Czrno-t_Swito_Dzkcznieni.ogg.wav.tlog (deflated 61%)
#   adding: 113__Pioter_Lessna_welina_Stefask_-_Cle_msz_bc_realn.ogg.wav.tlog (deflated 67%)
#   adding: 114__Tmk_Fpka_-_Droga.ogg.wav.tlog (deflated 67%)
#   adding: 115__Rmk_Drzdnk_-_Plckwsk_afera_pdschw.ogg.wav.tlog (deflated 66%)
#   adding: 116__Grgr_J__Schramke_-_Wieleklturowi_festiwal.ogg.wav.tlog (deflated 63%)
#   adding: 117__Stanisw_Janke_-_Wsziwk_wpisny_w_mje_c.ogg.wav.tlog (deflated 65%)
#   adding: 118__Tmk_Fpka_-_P_wosk.ogg.wav.tlog (deflated 67%)
#   adding: 119__Tmk_Fpka_-_Czed_chop_m_sznp.ogg.wav.tlog (deflated 67%)
#   adding: 11.Grif_dobiwo.ogg.wav.tlog (deflated 64%)
#   adding: 120__Artur_Jablonsczi_-_Neokaszubia_to_je_wicy_jak_ndzeja.ogg.wav.tlog (deflated 65%)
#   adding: 121__Rmk_Drzdnk_-_Brifkwi_bsd_Niestateczng_Sdu.ogg.wav.tlog (deflated 68%)
#   adding: 122__Kazimierz_Ostrowski_-_Jiwr_welownika.ogg.wav.tlog (deflated 64%)
#   adding: 123__Rmk_Drzdnk_-_Szlach_Abecada.ogg.wav.tlog (deflated 68%)
#   adding: 124__Kaszbizna_w_stolc.ogg.wav.tlog (deflated 63%)
#   adding: 125__Dark_Majkwsczi_-_Na_kc_Erop_i_jesz_dali.ogg.wav.tlog (deflated 66%)
#   adding: 126__Tmk_Fpka_-_Po_czim_pznac_artist.ogg.wav.tlog (deflated 66%)
#   adding: 127__Rmk_Drzdnk_-_Plckwsczi_meloman.ogg.wav.tlog (deflated 66%)
#   adding: 12.Nie_zabec_mowe_matczi.ogg.wav.tlog (deflated 65%)
#   adding: 13_Jak_przechloscec_letnika.ogg.wav.tlog (deflated 64%)
#   adding: 14_Nie_sygnie_sedzec_doma.ogg.wav.tlog (deflated 66%)
#   adding: 16.Pelckowscze Eurobulowanie.ogg.wav.tlog (deflated 65%)
#   adding: 18.Przed pierszim gwizdka.ogg.wav.tlog (deflated 60%)
#   adding: 19.Romk Drzezdzonk - Gdunsczi bowka.ogg.wav.tlog (deflated 62%)
#   adding: 20.Tatiana Slowi - Stoleca godo po kaszebsku.ogg.wav.tlog (deflated 60%)
#   adding: 21.Pioter Lessnau, Patrk Mudlaw - Bienvenidos a gniewino.ogg.wav.tlog (deflated 63%)
#   adding: 22.Bliza, co mergo muzycznym szeka.ogg.wav.tlog (deflated 63%)
#   adding: 23.Na Marsa.ogg.wav.tlog (deflated 64%)
#   adding: 24.Pleckowscze-note.ogg.wav.tlog (deflated 64%)
#   adding: 25.To sa nie oploco.ogg.wav.tlog (deflated 63%)
#   adding: 27.Pelckowsczi skorb.ogg.wav.tlog (deflated 65%)
#   adding: 28. Szkolna bec.ogg.wav.tlog (deflated 61%)
#   adding: 29. Zadeszno reaktiwacjo.ogg.wav.tlog (deflated 61%)
#   adding: 31.Maya Gelniok - Husky na Pomorzim.ogg.wav.tlog (deflated 63%)
#   adding: 32.Mateusz Bullmann - Nowi symbol Norde.ogg.wav.tlog (deflated 60%)
#   adding: 33.Romk Drzezdzonk - Kunc swiata.ogg.wav.tlog (deflated 63%)
#   adding: 34_Dariusz_Majkowsczi_-_Co_z_tima_owcama.ogg.wav.tlog (deflated 64%)
#   adding: 35_Rmk_Drzednk_-_Wszetkowiedzo_Pelckowa.ogg.wav.tlog (deflated 65%)
#   adding: 36_Kresztof_Korda_-_Ambasador_Pomorzego.ogg.wav.tlog (deflated 64%)
#   adding: 37.Mateusz_Bullmann - O jednym_niesmiertelniku.ogg.wav.tlog (deflated 63%)
#   adding: 38.Hinzow_Jurk - Jo_tam_broni_nie_brekuja.ogg.wav.tlog (deflated 63%)
#   adding: 39.Romk_Drzezdzonk - Arbata_po_betowsku.ogg.wav.tlog (deflated 63%)
#   adding: 40_Hinzw_Jurk_-_Noworoczne_postanowienia_zarobiaech.ogg.wav.tlog (deflated 62%)
#   adding: 41_Ana_Gleszczesko_-_Zrozmiec_biaka.ogg.wav.tlog (deflated 67%)
#   adding: 42_Rmk_Drzednk_-_Lest_do_Donalda.ogg.wav.tlog (deflated 64%)
#   adding: 43.Romk Drzezdzonk - Naju z brifka nowotworowanie.ogg.wav.tlog (deflated 64%)
#   adding: 44.Ana Gleszczensko - Kask optimistno.ogg.wav.tlog (deflated 61%)
#   adding: 45.Hinzow Jurk - Moje wioldze kaszebscze wesele.ogg.wav.tlog (deflated 63%)
#   adding: 46_Jerzi_Nacel_-_Bozi_Slega_ks_Roszczinialsczi_i_Les_Pustini.ogg.wav.tlog (deflated 62%)
#   adding: 47_Romk_Drzezdzonk_-_Roczi_3.ogg.wav.tlog (deflated 62%)
#   adding: 48_Ana_Gleszczinsko_-_Jiwer_z_rena_abo_co_widzy_szkolny_przed_zwonka.ogg.wav.tlog (deflated 62%)
#   adding: 49_Hinzow_Jurk_-_Kunc_swiata_z_tima_Majama.ogg.wav.tlog (deflated 62%)
#   adding: 50_Eugeniusz_Preczkowsczi_-_Zece_zawdzacziwol_Kaszebsczi_Krolewi.ogg.wav.tlog (deflated 63%)
#   adding: 51_Mateusz_Bullmann_-_Historio_zamklo_w_lesce.ogg.wav.tlog (deflated 60%)
#   adding: 52_Tomk_Fopka_-_Moje_strone.ogg.wav.tlog (deflated 63%)
#   adding: 53_Romk_Drzezdzonk_-_Obzerczi.ogg.wav.tlog (deflated 63%)
#   adding: 54_Wielojazekowosc_bokadosco_krojne.ogg.wav.tlog (deflated 58%)
#   adding: 55_Poselcowie_z_Litwe_przezeraja_sa_Kaszebom.ogg.wav.tlog (deflated 57%)
#   adding: 56_Mateusz_Bullmann_-_Konia_po_Nordze.ogg.wav.tlog (deflated 60%)
#   adding: 57_Karolena_Serkowsko_-_Reza_po_kaszebska_swiada.ogg.wav.tlog (deflated 62%)
#   adding: 58_Tatiana_Slowi_-_Akordeonista_z_Suleczyna.ogg.wav.tlog (deflated 63%)
#   adding: 59_Mateusz_Bullmann_-_Leno_jeden_taczi.ogg.wav.tlog (deflated 60%)
#   adding: 60_Romk_Drzezdzonk_-_Pelckowsko_malena.ogg.wav.tlog (deflated 62%)
#   adding: 62_Eugeniusz_Pryczkowski_-_Wjedno_kaszebe.ogg.wav.tlog (deflated 63%)
#   adding: 63_Tomk_Fopka_-_Z_Lesniewa_wyszo.ogg.wav.tlog (deflated 65%)
#   adding: 64_Kazimierz_Ostrowski_-_Janio_Chemwsczg.ogg.wav.tlog (deflated 61%)
#   adding: 65_Lucyna_Kurpiewska_-_Kaszbsczi_krl_miodnosc.ogg.wav.tlog (deflated 65%)
#   adding: 66_Egeniusz_Prczkwsczi_-_Stegn_smierc_kl_Brazylii.ogg.wav.tlog (deflated 66%)
#   adding: 68_Rmk_Drzdnk_-_W_szkoowi_awie.ogg.wav.tlog (deflated 62%)
#   adding: 69_Martina_Zienkiewicz_-_Zrzeszony_z_regiona.ogg.wav.tlog (deflated 60%)
#   adding: 70_Maya_Gielniak_-_Godka_o_kaszebsczich_kowbojach.ogg.wav.tlog (deflated 63%)
#   adding: 72_Darek_Majkowski_-_Kto_chce_czyta_po_kaszubsku.ogg.wav.tlog (deflated 64%)
#   adding: 74_Romk_Drzezdzonk_-_Jesenne_godczi_o_pelckowsczi_pismieniznie.ogg.wav.tlog (deflated 59%)
#   adding: 75_Pioter_Dzekanowsczi_-_Nazod_do_lasu.ogg.wav.tlog (deflated 61%)
#   adding: 76_Ewelina_Roman_Drzezdzonowie_-_Zamarte.ogg.wav.tlog (deflated 64%)
#   adding: 77_Szymon_Radzyminski_-_Artysta_sie_bywa.ogg.wav.tlog (deflated 65%)
#   adding: 78_Tomk_Fopka_-_Po_dredzi_stronie_komputra.ogg.wav.tlog (deflated 65%)
#   adding: 79_Dariusz_Majkowski_-_Z_kaszebizna_w_kazdym_dzejanim.ogg.wav.tlog (deflated 66%)
#   adding: 80_Jerzy_Hoppe_-_Oficer_cz2.ogg.wav.tlog (deflated 66%)
#   adding: 81_Stanislaw_Janke_-_Stolemrodem_z_Rolbika.ogg.wav.tlog (deflated 66%)
#   adding: 82_Romk_Drzezdzonk_-_Waspon_na_Pelckowie.ogg.wav.tlog (deflated 61%)
#   adding: 83_Kazimierz_Ostrowski_-_W_ceni_smantorzowech_drzew.ogg.wav.tlog (deflated 61%)
#   adding: 84_Ana_Gleszczinsko_-_Nie-nasz_k-roj.ogg.wav.tlog (deflated 60%)
#   adding: 85_Ana_Gliszczynska_-_Kuron_w_akcje.ogg.wav.tlog (deflated 65%)
#   adding: 86_Andrzej_Krauze_Tomosz_Lidzbarsczi_-_100_lat_parafie_-_Borowim_Mlinie.ogg.wav.tlog (deflated 67%)
#   adding: 87_Kadzmierz_Ostrowsczi_-_Rok_pokojnego_slunca.ogg.wav.tlog (deflated 64%)
#   adding: 88_Romk_Drzezdzonk_-_Choc_roz.ogg.wav.tlog (deflated 66%)
#   adding: 89_Tomk_Fopka_-_Zeza_zawieszedla.ogg.wav.tlog (deflated 64%)
#   adding: 90_Daniel_Kalinowski_-_Dramaturgio_Anne_Lajming.ogg.wav.tlog (deflated 66%)
#   adding: 91_Zbigniew_Byczkowski_-_Pobloce.ogg.wav.tlog (deflated 66%)
#   adding: 92_Maya_Gielniak_-_Dzemione.ogg.wav.tlog (deflated 65%)
#   adding: 93_Jadwiga_Bogdan_-_Diament_z_Gochow.ogg.wav.tlog (deflated 66%)
#   adding: 94_Tomk_Fopka_-_Prawie_prawo.ogg.wav.tlog (deflated 66%)
#   adding: 95_Romk_Drzezdzonk_-_Widzy_mie_sa.ogg.wav.tlog (deflated 66%)
#   adding: 96_Roman_Drzezdzon_-_Wejrowscze_slechanie_Bozego_Slowa.ogg.wav.tlog (deflated 68%)
#   adding: 97_Roman_Robaczewsczi_-_Derdowsczi_w_Parizu.ogg.wav.tlog (deflated 66%)
#   adding: 98_Tomk_Fopka_-_Z_braku_warkow.ogg.wav.tlog (deflated 66%)
#   adding: 99_Romk_Drzezdzonk_-_Jastrowo_kortka_do_brifczi.ogg.wav.tlog (deflated 66%)
#   adding: uczba_5_Miedzy_niebem_a_ziemia_-_Najo_uczba.ogg.wav.tlog (deflated 67%)
