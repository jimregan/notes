# %% [markdown]
# # Filter Braxen for phone frequencies
#
# > "Local, incomplete"
#
# - branch: master
# - categories: [wip, braxen]
# - hidden: true

# %%
# !cat /tmp/braxen-eng.txt |awk -F'\t' '{print $2}'|tr ' ' '\n'|sort|uniq -c |sort -nr > /tmp/braxen-eng.freq

# %%
# !tail -n 8 /tmp/braxen-eng.freq|awk '{print $2}'|while read i;do echo $i; grep " $i " /tmp/braxen-eng.txt || grep "$i " /tmp/braxen-eng.txt;echo;done
# Out:
# y:
# Byrock	b y: r o k
# Halloween-kostym	h a l oh w i: n k oh s t y: m
# PsycARTICLES	p s y: k a: rt i k ex l s
# Tru64	t r uu: s e k s t i f y: r a
# dyreklinikken	d y: r ex k l i n i k ex n
# rysarserie	r y: s a r s e: r i ex
# rysarseries	r y: s a r s e: r i ex s
#
# x
# 11-year	i l e v ex n j iex rh
# 11-year-old	i l e v ex n j iex rh ou l d
# 24SevenOffice	t w e n t i f o: r0 s e v ex n o f i s
# 27-hour	t w e n t i s e v ex n au ex rh
# 2CARE4	t uw: k eex r0 f o: r0
# 2CUREX	t uw: k j uex rh e k s
# 2ENTERTAIN	t v o: e n t ex r t e j n
# 49erFX	f o: r0 t i n ai n ex rh e f e k s
# 49ers	f o: rh t i n a j n ex rh s
# 4MOTION	f o: r m ou rs ex n
# 4ever	f o: rh e v ex r0
# 4evergreen	f o: rh e v ex r0 g rh i: n
# 7-stars	s e v ex n s t a: r0 s
# 7-up	s ae v ex n a p
# AURIANT	o: rh i ex n t
# Aaron	ae rh ex n
# Aaron's	ae rh ex n s
# Abagail	ae b ex g ei l
# Abagail	ae b ex g e j l
# Abagnale	ae b ex g n e j l
# Abagnales	ae b ex g n e j l s
# Abberley	ae b ex r0 l i
# ...
